# %% [markdown]
# <a href="https://colab.research.google.com/github/babupallam/Msc_AI_Module1_Neural_Systems/blob/main/Supporting%20Research/MCQs/Set_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **MCQ Questions and Answers: Sparse and Partially Connected Neural Networks**
#
# 1. **What is one of the primary advantages of sparse neural networks compared to fully connected networks?**
#    - A) Increased training time
#    - B) Improved generalization capabilities
#    - C) Higher redundancy
#    - D) More complex hardware requirements
#    - **Answer: B) Improved generalization capabilities**【150†source】
#
# 2. **What is meant by a "fully connected neural network" (FCNN)?**
#    - A) A network with no connections between neurons
#    - B) A network where all possible connections between neurons are present
#    - C) A network with random connections
#    - D) A network with connections only between input and output layers
#    - **Answer: B) A network where all possible connections between neurons are present**【151†source】
#
# 3. **Which method is used in non-ontogenic sparse neural networks to achieve reduced connectivity?**
#    - A) Backpropagation
#    - B) Pruning during training
#    - C) Defining the topology before training
#    - D) Genetic programming
#    - **Answer: C) Defining the topology before training**【150†source】
#
# 4. **What type of neural network is often easier to construct than fully connected networks, according to the paper?**
#    - A) Modular neural networks
#    - B) Ontogenic networks
#    - C) Associative memory networks
#    - D) Randomly connected networks
#    - **Answer: A) Modular neural networks**【150†source】
#
# 5. **Which type of partially connected neural networks is inspired by biological systems?**
#    - A) Non-ontogenic networks
#    - B) Application-dependent networks
#    - C) Methods derived from biological neural networks
#    - D) Modular networks
#    - **Answer: C) Methods derived from biological neural networks**【150†source】
#
# 6. **What is a common goal of hybrid methods in sparse neural networks?**
#    - A) To improve recall time
#    - B) To integrate genetic programming and neural networks
#    - C) To remove neurons during training
#    - D) To use only random connections
#    - **Answer: B) To integrate genetic programming and neural networks**【151†source】
#
# 7. **What type of connectivity is used in biologically inspired partially connected neural networks?**
#    - A) Random connectivity
#    - B) Full connectivity
#    - C) Localized sparse connectivity
#    - D) Redundant connectivity
#    - **Answer: C) Localized sparse connectivity**【151†source】
#
# 8. **How are non-ontogenic methods different from ontogenic methods in sparse neural networks?**
#    - A) Ontogenic methods do not modify network topology
#    - B) Non-ontogenic methods modify the network during training
#    - C) Non-ontogenic methods have a static topology throughout learning
#    - D) Ontogenic methods only work with modular networks
#    - **Answer: C) Non-ontogenic methods have a static topology throughout learning**【151†source】
#
# 9. **Which of the following methods is used for hardware implementation of sparse neural networks?**
#    - A) Pruning connections during learning
#    - B) Genetic algorithms
#    - C) Developing partial connectivity strategies
#    - D) Adding more layers to the network
#    - **Answer: C) Developing partial connectivity strategies**【150†source】
#
# 10. **Which statement is true about the topology of modular neural networks?**
#     - A) They are always fully connected between modules
#     - B) They solve problems using one large neural network
#     - C) They divide the problem into smaller sub-problems for individual sub-networks
#     - D) They only use recurrent connections
#     - **Answer: C) They divide the problem into smaller sub-problems for individual sub-networks**【150†source】
#
# 11. **What is a key advantage of partially connected neural networks (PCNNs) over fully connected networks?**
#     - A) Reduced redundancy
#     - B) Increased computational complexity
#     - C) Requires more training time
#     - D) Randomized weight values
#     - **Answer: A) Reduced redundancy**【151†source】
#
# 12. **What type of partially connected neural network is often used in the study of biological synaptic growth?**
#     - A) Random connectivity models
#     - B) Synaptic growth networks
#     - C) Associative memory networks
#     - D) Fully connected models
#     - **Answer: B) Synaptic growth networks**【151†source】
#
# 13. **What is the primary objective of using hybrid methods that combine neural networks and inductive knowledge?**
#     - A) To reduce training data requirements
#     - B) To define both network topology and initial weight values using domain-specific knowledge
#     - C) To create fully connected topologies
#     - D) To randomly connect neurons
#     - **Answer: B) To define both network topology and initial weight values using domain-specific knowledge**【151†source】
#
# 14. **How is the topology of non-ontogenic sparse neural networks defined?**
#     - A) During the learning phase
#     - B) After each training epoch
#     - C) Prior to the learning phase
#     - D) Randomly at each iteration
#     - **Answer: C) Prior to the learning phase**【151†source】
#
# 15. **What are the three classes of partially connected neural network methods discussed in the paper?**
#     - A) Modular, incremental, hybrid
#     - B) Ontogenic, non-ontogenic, hybrid
#     - C) Feedforward, recurrent, convolutional
#     - D) Genetic, symbolic, associative
#     - **Answer: B) Ontogenic, non-ontogenic, hybrid**【151†source】
#
# 16. **Which approach in PCNNs aims to simulate the biological neural network's sparse connectivity?**
#     - A) Full connectivity approach
#     - B) Weight sharing method
#     - C) Random connectivity strategy
#     - D) Genetic programming
#     - **Answer: C) Random connectivity strategy**【151†source】
#
# 17. **What is one potential downside of using genetic algorithms for sparse neural network topology optimization?**
#     - A) Insufficient computational time
#     - B) Requires fully connected topologies
#     - C) Excessive computational time required to find a good topology
#     - D) Limited generalization capability
#     - **Answer: C) Excessive computational time required to find a good topology**【150†source】
#
# 18. **What type of partially connected neural network focuses on optimizing both the topology and the weights?**
#     - A) Ontogenic networks
#     - B) Hybrid methods combining genetic programming
#     - C) Fully connected networks
#     - D) Associative networks
#     - **Answer: B) Hybrid methods combining genetic programming**【150†source】
#
# 19. **Which type of neural network is most commonly used as a basis for modular neural networks?**
#     - A) Recurrent networks
#     - B) Feedforward networks
#     - C) Cellular neural networks
#     - D) Associative memory networks
#     - **Answer: B) Feedforward networks**【151†source】
#
# 20. **How do modular methods benefit hardware implementation of neural networks?**
#     - A) By increasing redundancy
#     - B) By simplifying the connectivity strategy
#     - C) By making them fully connected
#     - D) By removing hidden layers
#     - **Answer: B) By simplifying the connectivity strategy**【150†source**

# %% [markdown]
# 1. **Which classification method of Sparse Neural Networks is defined before the learning phase and remains unchanged?**
#    - A) Ontogenic methods
#    - B) Non-ontogenic methods
#    - C) Hybrid methods
#    - D) Modular methods
#    - **Answer: B) Non-ontogenic methods**【156:1†source】
#
# 2. **What is the main objective of hybrid methods combining neural networks with genetic programming?**
#    - A) To develop randomly connected neural networks
#    - B) To optimize both the network topology and initial weights
#    - C) To reduce the fan-in and fan-out of neurons
#    - D) To create fully connected topologies
#    - **Answer: B) To optimize both the network topology and initial weights**【156:5†source】
#
# 3. **Which type of method divides the learning problem into smaller sub-problems to be handled by individual sub-networks?**
#    - A) Theoretical methods
#    - B) Modular methods
#    - C) Ontogenic methods
#    - D) Random connectivity methods
#    - **Answer: B) Modular methods**【156:11†source】
#
# 4. **What is a key feature of ontogenic methods in neural networks?**
#    - A) They reduce redundancy by deleting connections during training
#    - B) They define the network topology before training
#    - C) They use parallel processing to improve efficiency
#    - D) They require symbolic domain knowledge
#    - **Answer: A) They reduce redundancy by deleting connections during training**【156:11†source】
#
# 5. **What is the main benefit of using non-ontogenic methods in neural networks?**
#    - A) Dynamic modification of topology during training
#    - B) Reduced complexity by using a predefined static topology
#    - C) Increased generalization by adding new neurons dynamically
#    - D) Ability to train recurrent neural networks
#    - **Answer: B) Reduced complexity by using a predefined static topology**【156:1†source】
#
# 6. **How are modular neural networks advantageous for hardware implementation?**
#    - A) They use genetic programming to evolve network topologies
#    - B) They reduce the number of connections, making implementation simpler
#    - C) They ensure that all neurons are fully connected
#    - D) They are optimized only for digital systems
#    - **Answer: B) They reduce the number of connections, making implementation simpler**【156:0†source】
#
# 7. **Which of the following is true about the connectivity of a biologically inspired sparse neural network model?**
#    - A) Fully connected with all neurons
#    - B) Partially connected with localized connections only
#    - C) Completely random without any locality
#    - D) No connections allowed between neurons
#    - **Answer: B) Partially connected with localized connections only**【156:11†source】
#
# 8. **What is the main motivation for restructuring fully connected topologies into partially connected ones for hardware implementation?**
#    - A) To increase the learning rate
#    - B) To reduce degrees of freedom and improve hardware feasibility
#    - C) To achieve a higher number of neurons
#    - D) To ensure that all nodes are interconnected
#    - **Answer: B) To reduce degrees of freedom and improve hardware feasibility**【156:17†source】
#
# 9. **What type of approach aims to design neural networks that are tailored for specific applications by using domain knowledge?**
#    - A) Genetic algorithm-based methods
#    - B) Application-dependent methods
#    - C) Random connectivity methods
#    - D) Fully connected neural network methods
#    - **Answer: B) Application-dependent methods**【156:11†source】
#
# 10. **Which method uses symbolic domain knowledge as rules to create the topology of the neural network?**
#     - A) Hybrid methods
#     - B) Random connectivity methods
#     - C) Ontogenic methods
#     - D) Feedforward methods
#     - **Answer: A) Hybrid methods**【156:11†source】
#
# 11. **Which type of network topology is designed to reduce the number of connections while maintaining or improving performance?**
#     - A) Fully connected neural networks (FCNN)
#     - B) Sparse neural networks (SCNN)
#     - C) Cascade Correlation Networks
#     - D) Associative Memory Networks
#     - **Answer: B) Sparse neural networks (SCNN)**【156:1†source】
#
# 12. **How do modular networks link different sub-networks together?**
#     - A) By using fully connected layers
#     - B) Through a decision layer that selects the output in a winner-take-all fashion
#     - C) By randomizing connections between modules
#     - D) By applying genetic algorithms to optimize weights
#     - **Answer: B) Through a decision layer that selects the output in a winner-take-all fashion**【156:17†source】
#
# 13. **Which neural network implementation is motivated by the limitations of VLSI technology?**
#     - A) Genetic programming-based hybrid networks
#     - B) Non-ontogenic sparse neural networks for hardware implementation
#     - C) Fully connected digital neural networks
#     - D) Modular associative neural networks
#     - **Answer: B) Non-ontogenic sparse neural networks for hardware implementation**【156:17†source】
#
# 14. **What is a limitation of using genetic algorithms for neural network topology optimization?**
#     - A) Increased computational efficiency
#     - B) Requires excessively high computational time
#     - C) Inability to work with feedforward networks
#     - D) Generates fully connected topologies only
#     - **Answer: B) Requires excessively high computational time**【156:17†source】
#
# 15. **Which neural network type is focused on dividing tasks into specialized sub-tasks for parallel resolution?**
#     - A) Fully Connected Neural Networks (FCNN)
#     - B) Modular Neural Networks
#     - C) Hybrid Inductive Networks
#     - D) Recurrent Neural Networks (RNN)
#     - **Answer: B) Modular Neural Networks**【156:17†source】
#
# 16. **Which type of network typically achieves reduced training and recall time by eliminating redundant connections?**
#     - A) Ontogenic Sparse Neural Networks
#     - B) Non-Ontogenic Sparse Neural Networks
#     - C) Modular Fully Connected Networks
#     - D) Genetic Recurrent Networks
#     - **Answer: B) Non-Ontogenic Sparse Neural Networks**【156:1†source】
#
# 17. **What is the role of pruning in ontogenic neural network methods?**
#     - A) Increase the number of connections during learning
#     - B) Optimize the initial topology and weights using genetic algorithms
#     - C) Remove unnecessary connections from an oversized network after training
#     - D) Divide a complex problem into multiple sub-networks
#     - **Answer: C) Remove unnecessary connections from an oversized network after training**【156:13†source】
#
# 18. **In what type of neural network are connections added or removed based on biological growth strategies?**
#     - A) Ontogenic Sparse Neural Networks
#     - B) Non-Ontogenic Networks
#     - C) Biologically Derived Methods
#     - D) Random Connectivity Networks
#     - **Answer: C) Biologically Derived Methods**【156:11†source】
#
# 19. **How does modular network design help address complex tasks?**
#     - A) It uses a random selection of neurons
#     - B) It creates fully connected networks
#     - C) It splits the task into specialized sub-networks that solve sub-problems independently
#     - D) It uses symbolic rules to enhance learning efficiency
#     - **Answer: C) It splits the task into specialized sub-networks that solve sub-problems independently**【156:17†source】
#
# 20. **What is one method used for optimizing the topology of a neural network in GA-based methods?**
#     - A) Marker-based encoding from DNA
#     - B) Random connectivity strategy
#     - C) Layered fully connected approach
#     - D) Random initialization of all weights
#     - **Answer: A) Marker-based encoding from DNA**【156:17†source】

# %% [markdown]
# 141. **What is a significant limitation of ontogenic methods in neural networks?**
#    - A) They require genetic programming
#    - B) Their topology changes during the training process
#    - C) They cannot be used for biological modeling
#    - D) They produce fully connected topologies only
#    - **Answer: B) Their topology changes during the training process**【160:8†source】
#
# 142. **How do biologically derived PCNN models determine their sparse connectivity?**
#    - A) Using domain knowledge
#    - B) Based on statistical measures of biological synaptic growth
#    - C) By applying genetic algorithms
#    - D) By random deletion of connections
#    - **Answer: B) Based on statistical measures of biological synaptic growth**【160:14†source】
#
# 143. **What is the primary goal of non-ontogenic methods in sparse neural networks?**
#    - A) Dynamic modification of topology during training
#    - B) Reducing connectivity to a predefined level before the learning phase
#    - C) Maximizing synaptic growth during training
#    - D) Using convolutional kernels for feature detection
#    - **Answer: B) Reducing connectivity to a predefined level before the learning phase**【160:6†source】
#
# 144. **Which type of partially connected neural network is most useful for VLSI hardware implementation?**
#    - A) Fully connected networks
#    - B) Randomly connected networks
#    - C) Radix-r partially connected neural networks
#    - D) Associative memory networks
#    - **Answer: C) Radix-r partially connected neural networks**【160:0†source】
#
# 145. **What is the effect of hardware limitations on fully connected neural networks (FICNN)?**
#    - A) Increase in training time
#    - B) Requires the use of local rather than global connections
#    - C) Full connectivity becomes difficult to maintain due to physical restrictions
#    - D) Makes backpropagation infeasible
#    - **Answer: C) Full connectivity becomes difficult to maintain due to physical restrictions**【160:0†source】
#
# 146. **What kind of connectivity approach is used by cellular neural networks (CNNs)?**
#    - A) Fully connected across multiple layers
#    - B) Locally connected to neighboring cells within a specified range
#    - C) Connected to random units throughout the entire network
#    - D) Only connected to hidden units
#    - **Answer: B) Locally connected to neighboring cells within a specified range**【160:14†source】
#
# 147. **What was the primary purpose of developing hybrid methods combining neural networks and genetic programming?**
#    - A) To ensure full connectivity at all layers
#    - B) To optimize network topology and initial weight values
#    - C) To speed up the backpropagation algorithm
#    - D) To eliminate bias from input data
#    - **Answer: B) To optimize network topology and initial weight values**【160:19†source】
#
# 148. **Which of the following is a critical factor when optimizing sparse network topologies using genetic algorithms?**
#    - A) The selection of activation functions
#    - B) The initialization of synaptic connections
#    - C) The random mutation rate
#    - D) The marker-based encoding of DNA for structural optimization
#    - **Answer: D) The marker-based encoding of DNA for structural optimization**【160:8†source】
#
# 149. **In a modular neural network, how are sub-networks typically assembled?**
#    - A) In a fully connected manner
#    - B) Using logical operators such as AND and OR
#    - C) By sharing hidden layers across modules
#    - D) By reducing the weights of interconnections
#    - **Answer: B) Using logical operators such as AND and OR**【160:0†source】
#
# 150. **What are the main advantages of modular neural networks in terms of implementation?**
#    - A) Complexity in topology
#    - B) Easier mapping to hierarchical hardware
#    - C) Requires increased number of connections
#    - D) Limits parallel processing
#    - **Answer: B) Easier mapping to hierarchical hardware**【160:0†source】
#
# 151. **Which connectivity strategy is typically used in application-dependent methods for PCNNs?**
#    - A) Random connections
#    - B) Connectivity based on geometric relationships between input patterns
#    - C) Use of convolutional filters
#    - D) Full interlayer connections
#    - **Answer: B) Connectivity based on geometric relationships between input patterns**【160:9†source】
#
# 152. **How is the degree of connectivity optimized in non-ontogenic methods for PCNNs?**
#    - A) By pruning connections during the learning phase
#    - B) By adding neurons incrementally until convergence
#    - C) By setting a predefined connectivity level before training starts
#    - D) By dynamically adjusting weights during training
#    - **Answer: C) By setting a predefined connectivity level before training starts**【160:8†source】
#
# 153. **What is a key advantage of reducing the fan-in and fan-out in neural networks for VLSI hardware?**
#    - A) Improved generalization capabilities
#    - B) Reduced storage requirements
#    - C) Increased hardware complexity
#    - D) Full connectivity within all network modules
#    - **Answer: B) Reduced storage requirements**【160:0†source】
#
# 154. **Which approach is considered more biologically plausible when structuring sparse neural networks?**
#    - A) Fully connected models
#    - B) Methods derived from biological systems with sparse connectivity
#    - C) Networks trained using only gradient descent
#    - D) Fully recurrent networks
#    - **Answer: B) Methods derived from biological systems with sparse connectivity**【160:14†source】
#
# 155. **What is the role of a gating network in a modular neural network?**
#    - A) It performs backpropagation across the entire network
#    - B) It selects which expert network will respond to an input pattern
#    - C) It connects hidden layers to output layers
#    - D) It randomizes weight values across the network
#    - **Answer: B) It selects which expert network will respond to an input pattern**【160:4†source】
#
# 156. **How do hybrid PCNN methods benefit from using inductive knowledge?**
#    - A) They guarantee convergence of backpropagation
#    - B) They help to define network topology using domain-specific rules
#    - C) They randomly delete connections until an optimal level is achieved
#    - D) They always ensure full connectivity
#    - **Answer: B) They help to define network topology using domain-specific rules**【160:19†source】
#
# 157. **Which method helps in reducing the complexity of FICNN when implemented in hardware?**
#    - A) Using genetic programming
#    - B) Applying pruning methods during training
#    - C) Restructuring into partially connected neural networks
#    - D) Converting to convolutional neural networks
#    - **Answer: C) Restructuring into partially connected neural networks**【160:0†source】
#
# 158. **What is a common disadvantage of non-ontogenic sparse neural networks compared to ontogenic ones?**
#    - A) Static topology that does not adapt during learning
#    - B) Requires additional layers for accurate classification
#    - C) Depends entirely on random initialization of weights
#    - D) Reduced applicability in biological modeling
#    - **Answer: A) Static topology that does not adapt during learning**【160:8†source】
#
# 159. **In modular VLSI implementations, how is classification achieved for linearly and non-linearly separable classes?**
#    - A) Through recursive backpropagation
#    - B) By dividing into linearly and non-linearly separable subsets and combining outputs logically
#    - C) By randomly assigning neurons to each subset
#    - D) By using support vector machines as the final layer
#    - **Answer: B) By dividing into linearly and non-linearly separable subsets and combining outputs logically**【160:0†source】
#
# 160. **Which type of neural network structure is commonly used in modular methods to solve distinct sub-tasks?**
#    - A) Convolutional neural networks
#    - B) Associative neural networks
#    - C) Feed-forward neural networks with specialized layers
#    - D) Recurrent neural networks
#    - **Answer: C) Feed-forward neural networks with specialized layers**【160:11†source】

# %% [markdown]
# 141. **What is a significant limitation of ontogenic methods in neural networks?**
#    - A) They require genetic programming
#    - B) Their topology changes during the training process
#    - C) They cannot be used for biological modeling
#    - D) They produce fully connected topologies only
#    - **Answer: B) Their topology changes during the training process**【160:8†source】
#
# 142. **How do biologically derived PCNN models determine their sparse connectivity?**
#    - A) Using domain knowledge
#    - B) Based on statistical measures of biological synaptic growth
#    - C) By applying genetic algorithms
#    - D) By random deletion of connections
#    - **Answer: B) Based on statistical measures of biological synaptic growth**【160:14†source】
#
# 143. **What is the primary goal of non-ontogenic methods in sparse neural networks?**
#    - A) Dynamic modification of topology during training
#    - B) Reducing connectivity to a predefined level before the learning phase
#    - C) Maximizing synaptic growth during training
#    - D) Using convolutional kernels for feature detection
#    - **Answer: B) Reducing connectivity to a predefined level before the learning phase**【160:6†source】
#
# 144. **Which type of partially connected neural network is most useful for VLSI hardware implementation?**
#    - A) Fully connected networks
#    - B) Randomly connected networks
#    - C) Radix-r partially connected neural networks
#    - D) Associative memory networks
#    - **Answer: C) Radix-r partially connected neural networks**【160:0†source】
#
# 145. **What is the effect of hardware limitations on fully connected neural networks (FICNN)?**
#    - A) Increase in training time
#    - B) Requires the use of local rather than global connections
#    - C) Full connectivity becomes difficult to maintain due to physical restrictions
#    - D) Makes backpropagation infeasible
#    - **Answer: C) Full connectivity becomes difficult to maintain due to physical restrictions**【160:0†source】
#
# 146. **What kind of connectivity approach is used by cellular neural networks (CNNs)?**
#    - A) Fully connected across multiple layers
#    - B) Locally connected to neighboring cells within a specified range
#    - C) Connected to random units throughout the entire network
#    - D) Only connected to hidden units
#    - **Answer: B) Locally connected to neighboring cells within a specified range**【160:14†source】
#
# 147. **What was the primary purpose of developing hybrid methods combining neural networks and genetic programming?**
#    - A) To ensure full connectivity at all layers
#    - B) To optimize network topology and initial weight values
#    - C) To speed up the backpropagation algorithm
#    - D) To eliminate bias from input data
#    - **Answer: B) To optimize network topology and initial weight values**【160:19†source】
#
# 148. **Which of the following is a critical factor when optimizing sparse network topologies using genetic algorithms?**
#    - A) The selection of activation functions
#    - B) The initialization of synaptic connections
#    - C) The random mutation rate
#    - D) The marker-based encoding of DNA for structural optimization
#    - **Answer: D) The marker-based encoding of DNA for structural optimization**【160:8†source】
#
# 149. **In a modular neural network, how are sub-networks typically assembled?**
#    - A) In a fully connected manner
#    - B) Using logical operators such as AND and OR
#    - C) By sharing hidden layers across modules
#    - D) By reducing the weights of interconnections
#    - **Answer: B) Using logical operators such as AND and OR**【160:0†source】
#
# 150. **What are the main advantages of modular neural networks in terms of implementation?**
#    - A) Complexity in topology
#    - B) Easier mapping to hierarchical hardware
#    - C) Requires increased number of connections
#    - D) Limits parallel processing
#    - **Answer: B) Easier mapping to hierarchical hardware**【160:0†source】
#
# 151. **Which connectivity strategy is typically used in application-dependent methods for PCNNs?**
#    - A) Random connections
#    - B) Connectivity based on geometric relationships between input patterns
#    - C) Use of convolutional filters
#    - D) Full interlayer connections
#    - **Answer: B) Connectivity based on geometric relationships between input patterns**【160:9†source】
#
# 152. **How is the degree of connectivity optimized in non-ontogenic methods for PCNNs?**
#    - A) By pruning connections during the learning phase
#    - B) By adding neurons incrementally until convergence
#    - C) By setting a predefined connectivity level before training starts
#    - D) By dynamically adjusting weights during training
#    - **Answer: C) By setting a predefined connectivity level before training starts**【160:8†source】
#
# 153. **What is a key advantage of reducing the fan-in and fan-out in neural networks for VLSI hardware?**
#    - A) Improved generalization capabilities
#    - B) Reduced storage requirements
#    - C) Increased hardware complexity
#    - D) Full connectivity within all network modules
#    - **Answer: B) Reduced storage requirements**【160:0†source】
#
# 154. **Which approach is considered more biologically plausible when structuring sparse neural networks?**
#    - A) Fully connected models
#    - B) Methods derived from biological systems with sparse connectivity
#    - C) Networks trained using only gradient descent
#    - D) Fully recurrent networks
#    - **Answer: B) Methods derived from biological systems with sparse connectivity**【160:14†source】
#
# 155. **What is the role of a gating network in a modular neural network?**
#    - A) It performs backpropagation across the entire network
#    - B) It selects which expert network will respond to an input pattern
#    - C) It connects hidden layers to output layers
#    - D) It randomizes weight values across the network
#    - **Answer: B) It selects which expert network will respond to an input pattern**【160:4†source】
#
# 156. **How do hybrid PCNN methods benefit from using inductive knowledge?**
#    - A) They guarantee convergence of backpropagation
#    - B) They help to define network topology using domain-specific rules
#    - C) They randomly delete connections until an optimal level is achieved
#    - D) They always ensure full connectivity
#    - **Answer: B) They help to define network topology using domain-specific rules**【160:19†source】
#
# 157. **Which method helps in reducing the complexity of FICNN when implemented in hardware?**
#    - A) Using genetic programming
#    - B) Applying pruning methods during training
#    - C) Restructuring into partially connected neural networks
#    - D) Converting to convolutional neural networks
#    - **Answer: C) Restructuring into partially connected neural networks**【160:0†source】
#
# 158. **What is a common disadvantage of non-ontogenic sparse neural networks compared to ontogenic ones?**
#    - A) Static topology that does not adapt during learning
#    - B) Requires additional layers for accurate classification
#    - C) Depends entirely on random initialization of weights
#    - D) Reduced applicability in biological modeling
#    - **Answer: A) Static topology that does not adapt during learning**【160:8†source】
#
# 159. **In modular VLSI implementations, how is classification achieved for linearly and non-linearly separable classes?**
#    - A) Through recursive backpropagation
#    - B) By dividing into linearly and non-linearly separable subsets and combining outputs logically
#    - C) By randomly assigning neurons to each subset
#    - D) By using support vector machines as the final layer
#    - **Answer: B) By dividing into linearly and non-linearly separable subsets and combining outputs logically**【160:0†source】
#
# 160. **Which type of neural network structure is commonly used in modular methods to solve distinct sub-tasks?**
#    - A) Convolutional neural networks
#    - B) Associative neural networks
#    - C) Feed-forward neural networks with specialized layers
#    - D) Recurrent neural networks
#    - **Answer: C) Feed-forward neural networks with specialized layers**【160:11†source】
