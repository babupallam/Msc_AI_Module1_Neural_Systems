# %% [markdown]
# <a href="https://colab.research.google.com/github/babupallam/Msc_AI_Module1_Neural_Systems/blob/main/Supporting%20Research/MCQs/Set_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **MCQ Questions and Answers: Linear Separability and Neural Networks**
#
# 1. **What is the Recursive Deterministic Perceptron (RDP) neural network primarily used for?**
#    - A) Solving linearly separable problems only
#    - B) Solving both linearly and non-linearly separable problems
#    - C) Generating random weights for a neural network
#    - D) Enhancing convergence speed for backpropagation
#    - **Answer: B) Solving both linearly and non-linearly separable problems**【177†source】
#
# 2. **What type of problem is "Max-Separability" as mentioned in the papers?**
#    - A) P-type
#    - B) NP-Complete
#    - C) Polynomial-time
#    - D) Heuristic-based
#    - **Answer: B) NP-Complete**【182†source】
#
# 3. **What is a critical feature of the Recursive Deterministic Perceptron (RDP)?**
#    - A) Uses genetic algorithms for optimization
#    - B) Always converges to separate linearly separable and non-linearly separable sets
#    - C) Only works for linearly separable sets
#    - D) Implements reinforcement learning for classification
#    - **Answer: B) Always converges to separate linearly separable and non-linearly separable sets**【179†source】
#
# 4. **Which of the following is an exact method for testing linear separability?**
#    - A) Fisher Linear Discriminant
#    - B) Simplex Algorithm
#    - C) Genetic Algorithms
#    - D) Gradient Descent
#    - **Answer: B) Simplex Algorithm**【179†source】
#
# 5. **What is the primary aim of transforming a non-linearly separable (NLS) classification problem into an LS one using RDP?**
#    - A) Reducing the number of input features
#    - B) Improving the topology size
#    - C) Transforming the problem so that it becomes linearly separable
#    - D) Increasing computational complexity
#    - **Answer: C) Transforming the problem so that it becomes linearly separable**【179†source】
#
# 6. **What does the Convex Hull method determine regarding two classes?**
#    - A) Whether they have overlapping features
#    - B) If they are linearly separable by verifying disjoint convex hulls
#    - C) Their classification complexity
#    - D) The optimal hyperplane for separating them
#    - **Answer: B) If they are linearly separable by verifying disjoint convex hulls**【181†source】
#
# 7. **What type of data does the Recursive Deterministic Perceptron (RDP) deal with to ensure separability?**
#    - A) Continuous data only
#    - B) Both binary and analog data
#    - C) Only binary data
#    - D) Categorical data only
#    - **Answer: B) Both binary and analog data**【182†source】
#
# 8. **Which algorithm is used to convert non-linearly separable data into linearly separable data in the RDP model?**
#    - A) Genetic Programming
#    - B) Class of Linear Separability (CLS)
#    - C) Backpropagation
#    - D) Fisher Linear Discriminant
#    - **Answer: B) Class of Linear Separability (CLS)**【182†source】
#
# 9. **How does the Fisher Linear Discriminant method function for classification?**
#    - A) It finds a nonlinear decision boundary
#    - B) It minimizes the distance between features of different classes
#    - C) It finds a hyperplane that maximizes the separation between projections of two classes
#    - D) It uses random selection to classify points
#    - **Answer: C) It finds a hyperplane that maximizes the separation between projections of two classes**【179†source】
#
# 10. **Which method is considered to converge in an infinite number of steps when testing linear separability?**
#     - A) Perceptron Algorithm
#     - B) Simplex Algorithm
#     - C) Convex Hull Algorithm
#     - D) Anderson’s Method
#     - **Answer: C) Convex Hull Algorithm**【179†source】
#
# 11. **Which method provides a stopping condition to ensure finite convergence when using the Convex Hull algorithm?**
#     - A) Fisher Linear Discriminant
#     - B) Kozinec’s Algorithm
#     - C) Genetic Optimization
#     - D) Simplex Algorithm
#     - **Answer: B) Kozinec’s Algorithm**【179†source】
#
# 12. **What does "affinely independent" mean in the context of points in a set?**
#     - A) All points lie along a straight line
#     - B) No point in the set can be expressed as a linear combination of the others
#     - C) The points overlap perfectly
#     - D) The points form a regular polygon
#     - **Answer: B) No point in the set can be expressed as a linear combination of the others**【181†source】
#
# 13. **What is the aim of the Recursive Deterministic Perceptron’s intermediate neurons?**
#     - A) To compute the mean of inputs
#     - B) To augment the affine dimension of the input space
#     - C) To reduce computational complexity
#     - D) To add noise to the input data
#     - **Answer: B) To augment the affine dimension of the input space**【181†source】
#
# 14. **Which neural network training algorithm guarantees convergence for linearly separable classes?**
#     - A) Backpropagation
#     - B) Cascade Correlation
#     - C) Perceptron Learning Algorithm
#     - D) Fisher Linear Discriminant
#     - **Answer: C) Perceptron Learning Algorithm**【181†source】
#
# 15. **Which of the following is true for non-linearly separable problems when using an RDP network?**
#     - A) The classes will always overlap
#     - B) The RDP transforms the problem into a sequence of linearly separable steps
#     - C) It cannot solve non-linearly separable problems
#     - D) Only binary problems can be solved
#     - **Answer: B) The RDP transforms the problem into a sequence of linearly separable steps**【178†source】
#
# 16. **What is the typical computational complexity of testing linear separability using an exhaustive method?**
#     - A) Linear
#     - B) Polynomial
#     - C) Exponential
#     - D) Logarithmic
#     - **Answer: C) Exponential**【182†source】
#
# 17. **Which concept helps transform non-linearly separable data into linearly separable using additional dimensions?**
#     - A) Nonlinear SVMs
#     - B) Affine Augmentation
#     - C) Gradient Boosting
#     - D) Random Forests
#     - **Answer: B) Affine Augmentation**【182†source】
#
# 18. **In classification problems, what role does the Recursive Deterministic Perceptron (RDP) serve?**
#     - A) It is primarily used for clustering
#     - B) It transforms non-linearly separable problems into linearly separable problems
#     - C) It directly provides an optimal decision boundary
#     - D) It is used to train support vector machines
#     - **Answer: B) It transforms non-linearly separable problems into linearly separable problems**【178†source】
#
# 19. **Which linear separability testing method is characterized by the intersection of convex hulls being empty?**
#     - A) Fisher Linear Discriminant
#     - B) Convex Hull Method
#     - C) Simplex Algorithm
#     - D) Incremental Learning
#     - **Answer: B) Convex Hull Method**【181†source】
#
# 20. **What are the primary components used in RDP to enhance classification capabilities for NLS problems?**
#     - A) Recurrent Layers
#     - B) Intermediate Neurons and Hyperplanes
#     - C) Generative Adversarial Models
#     - D) Cluster Centers
#     - **Answer: B) Intermediate Neurons and Hyperplanes**【182†source】

# %% [markdown]
# 51. **Which method is effective for quantifying the complexity of a classification problem by transforming a non-linearly separable (NLS) problem into linearly separable (LS) steps?**
#    - A) Genetic Programming
#    - B) Recursive Deterministic Perceptron (RDP)
#    - C) Backpropagation Neural Network
#    - D) Simplex Algorithm
#    - **Answer: B) Recursive Deterministic Perceptron (RDP)**【188:1†source】
#
# 52. **What is the purpose of adding intermediate neurons in an RDP network?**
#    - A) To add layers for convolution
#    - B) To augment the affine dimension of the input vector and make classes separable
#    - C) To increase computational complexity
#    - D) To provide non-deterministic results
#    - **Answer: B) To augment the affine dimension of the input vector and make classes separable**【188:0†source】
#
# 53. **Which method provides a way to eliminate variables from a set of linear equations during testing of linear separability?**
#    - A) Simplex Method
#    - B) Fourier–Kuhn Elimination Method
#    - C) Convex Hull Algorithm
#    - D) Backpropagation
#    - **Answer: B) Fourier–Kuhn Elimination Method**【188:15†source】
#
# 54. **What is one of the primary differences between RDP and traditional Perceptron models?**
#    - A) RDP handles non-linearly separable problems by adding intermediate neurons
#    - B) Traditional Perceptron models use multiple hidden layers
#    - C) RDP uses gradient descent for weight adjustment
#    - D) Traditional Perceptron can handle both linear and non-linear problems without changes
#    - **Answer: A) RDP handles non-linearly separable problems by adding intermediate neurons**【188:18†source】
#
# 55. **What is the main goal of the Incremental Learning Method in RDP networks?**
#    - A) Reduce memory complexity
#    - B) Solve classification problems without any convergence guarantee
#    - C) Solve non-linear classification problems with guaranteed convergence
#    - D) Apply reinforcement learning techniques
#    - **Answer: C) Solve non-linear classification problems with guaranteed convergence**【188:16†source】
#
# 56. **Which of the following methods uses acyclic graphs to represent neural networks?**
#    - A) Backpropagation
#    - B) Recursive Deterministic Perceptron
#    - C) Genetic Algorithm
#    - D) Simple Perceptron Learning Algorithm
#    - **Answer: B) Recursive Deterministic Perceptron**【188:5†source】
#
# 57. **What is the computational complexity of the Fourier–Kuhn Elimination method for large classification problems?**
#    - A) Polynomial
#    - B) Linear
#    - C) Exponential
#    - D) Logarithmic
#    - **Answer: C) Exponential**【188:15†source】
#
# 58. **Which neural network model is guaranteed to converge and provides a solution for any two-class classification problem?**
#    - A) Simple Perceptron
#    - B) Recursive Deterministic Perceptron
#    - C) Convolutional Neural Network
#    - D) Kohonen Network
#    - **Answer: B) Recursive Deterministic Perceptron**【188:18†source】
#
# 59. **Which method is used to determine whether two classes are linearly separable based on the intersection of convex hulls?**
#    - A) Fisher Linear Discriminant
#    - B) Convex Hull Method
#    - C) Linear Regression
#    - D) Genetic Optimization
#    - **Answer: B) Convex Hull Method**【188:7†source】
#
# 60. **Which learning method is highlighted as using a finite number of iterations to always transform an NLS problem into an LS one?**
#     - A) Fisher Linear Discriminant
#     - B) Recursive Deterministic Perceptron
#     - C) Backpropagation
#     - D) Support Vector Machines
#     - **Answer: B) Recursive Deterministic Perceptron**【188:0†source】
#
# 61. **What does the "affinely independent" property mean in a set of points in the context of convex hull and classification problems?**
#     - A) All points lie along a straight line
#     - B) No point can be expressed as a linear combination of the others
#     - C) Points are entirely dependent on each other
#     - D) Points form a circular pattern
#     - **Answer: B) No point can be expressed as a linear combination of the others**【188:8†source】
#
# 62. **How does the RDP method ensure that two classes become linearly separable?**
#     - A) By continuously adding new layers
#     - B) By progressively adding outputs from intermediate neurons
#     - C) By using only linear activation functions
#     - D) By backpropagating errors until separation occurs
#     - **Answer: B) By progressively adding outputs from intermediate neurons**【188:18†source】
#
# 63. **What type of problem does the RDP aim to solve by converting it into LS steps?**
#     - A) Non-linear clustering
#     - B) Binary classification only
#     - C) Non-linearly separable problems
#     - D) Genetic optimization issues
#     - **Answer: C) Non-linearly separable problems**【188:1†source】
#
# 64. **In which scenario are intermediate neurons added in the RDP model?**
#     - A) When two classes remain non-linearly separable
#     - B) To increase the number of hidden layers
#     - C) To optimize weight convergence speed
#     - D) To reduce computation by pruning neurons
#     - **Answer: A) When two classes remain non-linearly separable**【188:18†source】
#
# 65. **What kind of neural network model is the Recursive Deterministic Perceptron considered as?**
#     - A) A model that evolves through reinforcement learning
#     - B) A generalized multilayer perceptron that ensures convergence for NLS problems
#     - C) A simple perceptron without learning capability
#     - D) A type of convolutional network designed for image data
#     - **Answer: B) A generalized multilayer perceptron that ensures convergence for NLS problems**【188:18†source】
#
# 66. **Which of the following is used as a measure for the complexity of classification problems, according to the RDP approach?**
#     - A) The number of classes involved
#     - B) The degree of non-separability
#     - C) The sum of squared errors
#     - D) The backpropagation loss value
#     - **Answer: B) The degree of non-separability**【188:4†source】
#
# 67. **What does the "height" of an RDP network represent?**
#     - A) The total number of input features
#     - B) The number of intermediate neurons in the network
#     - C) The depth of hidden layers in a neural network
#     - D) The size of the input dimension
#     - **Answer: B) The number of intermediate neurons in the network**【188:19†source】
#
# 68. **How do linear programming methods like the Simplex Algorithm help test linear separability?**
#     - A) By providing statistical measures of data overlap
#     - B) By solving a set of linear equations to determine if a hyperplane exists
#     - C) By generating new classes for better separation
#     - D) By clustering points into similar groups
#     - **Answer: B) By solving a set of linear equations to determine if a hyperplane exists**【188:15†source】

# %% [markdown]
# 101. **What does the term "affine dimension augmentation" refer to in the RDP method?**
#    - A) Increasing the depth of neural layers
#    - B) Adding components to the input vector from intermediate neurons
#    - C) Removing redundant input features
#    - D) Applying a genetic algorithm for optimization
#    - **Answer: B) Adding components to the input vector from intermediate neurons**【192:0†source】
#
# 102. **What is a distinguishing feature of Batch, Incremental, and Modular methods used in RDP construction?**
#    - A) They rely on backpropagation
#    - B) They all provide identical topologies
#    - C) They offer different levels of complexity and topology structures
#    - D) They require user-provided parameters to converge
#    - **Answer: C) They offer different levels of complexity and topology structures**【192:0†source】
#
# 103. **Which method in RDP construction is known to be NP-complete in complexity?**
#    - A) Incremental method
#    - B) Batch method
#    - C) Modular method
#    - D) Cascade method
#    - **Answer: B) Batch method**【192:0†source】
#
# 104. **What is a significant advantage of the Incremental method for building RDP networks?**
#    - A) Minimal number of intermediate neurons required
#    - B) Polynomial time complexity
#    - C) Ability to reduce hyperplanes dynamically
#    - D) Requires user-defined parameters
#    - **Answer: B) Polynomial time complexity**【192:0†source】
#
# 105. **Which approach is suggested to solve the NP-completeness of the Batch method in RDP construction?**
#    - A) Pre-clustering the datasets and refining using metaheuristics
#    - B) Using fully connected networks
#    - C) Eliminating neurons at random
#    - D) Employing a linear regression model
#    - **Answer: A) Pre-clustering the datasets and refining using metaheuristics**【192:17†source】
#
# 106. **How does the Convex Hull method determine if two classes are linearly separable?**
#    - A) By finding a common hyperplane
#    - B) If the intersection of their convex hulls is empty
#    - C) By comparing Euclidean distances between classes
#    - D) Using backpropagation to find the boundaries
#    - **Answer: B) If the intersection of their convex hulls is empty**【192:15†source】
#
# 107. **What type of problem is the Incremental RDP method well suited for?**
#    - A) Clustering problems
#    - B) Dynamic classification problems
#    - C) Feature extraction
#    - D) Regression analysis
#    - **Answer: B) Dynamic classification problems**【192:17†source】
#
# 108. **Which method for building an RDP network uses the maximum cardinality subset approach?**
#    - A) Incremental method
#    - B) Batch method
#    - C) Fisher method
#    - D) Convex Hull method
#    - **Answer: B) Batch method**【192:17†source】
#
# 109. **Which method can confirm that no separating plane exists if that is the case?**
#    - A) Fourier-Kuhn Elimination
#    - B) Simplex Algorithm
#    - C) Fisher Linear Discriminant
#    - D) Genetic Programming
#    - **Answer: B) Simplex Algorithm**【192:19†source】
#
# 110. **What is the primary function of a single-layer perceptron in the context of RDP networks?**
#    - A) Performing nonlinear regression
#    - B) Augmenting the affine dimension for solving NLS problems
#    - C) Implementing gradient descent learning
#    - D) Pruning unnecessary neurons
#    - **Answer: B) Augmenting the affine dimension for solving NLS problems**【192:0†source】
#
# 111. **Which property is essential for constructing an RDP network to achieve linearly separable classes?**
#    - A) Linear regression
#    - B) Affine independence of input points
#    - C) Random neuron addition
#    - D) Reinforcement learning
#    - **Answer: B) Affine independence of input points**【192:9†source】
#
# 112. **Which problem-solving approach is generally more suitable for static classification problems?**
#    - A) Batch method
#    - B) Incremental method
#    - C) Modular method
#    - D) Fisher Linear Discriminant
#    - **Answer: A) Batch method**【192:17†source】
#
# 113. **What technique does the Incremental RDP method use to add new intermediate neurons?**
#    - A) Adds neurons every fixed time step
#    - B) Adds a new intermediate neuron whenever a point is not classified correctly
#    - C) Uses genetic programming for neuron addition
#    - D) Adds multiple neurons simultaneously for efficiency
#    - **Answer: B) Adds a new intermediate neuron whenever a point is not classified correctly**【192:17†source】
#
# 114. **Which of the following is true about the complexity of the Batch RDP method?**
#    - A) It provides polynomial complexity results
#    - B) It is generally applicable only for clustering problems
#    - C) It is NP-complete due to its strategy for maximum cardinality subsets
#    - D) It relies heavily on user intervention
#    - **Answer: C) It is NP-complete due to its strategy for maximum cardinality subsets**【192:17†source】
#
# 115. **Which of the following can be used to simplify the problem of building an RDP with the Batch method?**
#    - A) Using a linear transformation
#    - B) Pre-clustering the data and using metaheuristics
#    - C) Randomly removing features
#    - D) Adding hidden layers
#    - **Answer: B) Pre-clustering the data and using metaheuristics**【192:17†source】
#
# 116. **What is the final output of an Incremental RDP method based on?**
#    - A) Random initialization
#    - B) A fixed set of rules
#    - C) The number of intermediate neurons added to achieve separability
#    - D) The maximum depth of the network
#    - **Answer: C) The number of intermediate neurons added to achieve separability**【192:17†source】
#
# 117. **Which complexity is achieved by the Modular RDP construction method?**
#    - A) Logarithmic
#    - B) Polynomial
#    - C) Exponential
#    - D) Constant
#    - **Answer: B) Polynomial**【192:17†source】
#
# 118. **What characterizes the stopping condition in the Incremental method of RDP?**
#    - A) When maximum cardinality is achieved
#    - B) When all points are linearly separated
#    - C) After a fixed number of iterations
#    - D) Upon achieving minimal loss value
#    - **Answer: B) When all points are linearly separated**【192:0†source】
#
# 119. **What is the primary goal of modular RDP networks?**
#    - A) To increase redundancy
#    - B) To simplify the classification problem into smaller, more manageable subproblems
#    - C) To achieve non-linear mapping of features
#    - D) To improve clustering performance
#    - **Answer: B) To simplify the classification problem into smaller, more manageable subproblems**【192:17†source】
#
# 120. **Which of the following methods is used to characterize the set of hyperplanes separating two classes in linear separability?**
#    - A) Linear Regression
#    - B) Class of Linear Separability Method
#    - C) Random Forests
#    - D) Logistic Regression
#    - **Answer: B) Class of Linear Separability Method**【192:15†source】
