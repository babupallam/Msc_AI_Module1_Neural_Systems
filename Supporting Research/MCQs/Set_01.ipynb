# %% [markdown]
# <a href="https://colab.research.google.com/github/babupallam/Msc_AI_Module1_Neural_Systems/blob/main/Supporting%20Research/MCQs/Set_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Lecture 01: Introduction
#
# 1. **What is intelligence composed of?**
#    - A) Ability to reason
#    - B) Acquire and apply knowledge
#    - C) Manipulate and communicate ideas
#    - D) All of the above
#    - **Answer: D) All of the above**
#
# 2. **Which of the following is NOT part of Marvin Minsky's definition of AI?**
#    - A) Making machines think like humans
#    - B) Making machines do things requiring intelligence
#    - C) Performing complex calculations
#    - D) Making machines mimic human behavior
#    - **Answer: C) Performing complex calculations**
#
# 3. **What does the "Age of Automation" refer to?**
#    - A) The First Industrial Revolution
#    - B) The Second Industrial Revolution
#    - C) The Information Age
#    - D) The Knowledge Revolution
#    - **Answer: A) The First Industrial Revolution**
#
# 4. **Which era focused on extending man's mental capabilities?**
#    - A) First Industrial Revolution
#    - B) Information and Knowledge Revolution
#    - C) Second Industrial Revolution
#    - D) Age of Reason
#    - **Answer: C) Second Industrial Revolution**
#
# 5. **Who proposed the "Turing Test"?**
#    - A) Alan Turing
#    - B) Marvin Minsky
#    - C) John McCarthy
#    - D) Herbert Simon
#    - **Answer: A) Alan Turing**
#
# 6. **What is the main idea behind the "Turing Test"?**
#    - A) To check a machine's ability to perform calculations
#    - B) To test a machine's ability to mimic human responses
#    - C) To measure the speed of a machine
#    - D) To determine the cost of building a machine
#    - **Answer: B) To test a machine's ability to mimic human responses**
#
# 7. **What does the phrase "walks like a duck, quacks like a duck" represent in AI?**
#    - A) The Turing Test
#    - B) Behaviorist's view on intelligent machines
#    - C) Strong AI
#    - D) Weak AI
#    - **Answer: B) Behaviorist's view on intelligent machines**
#
# 8. **Which of the following statements describes "Strong AI"?**
#    - A) Computers cannot think but can simulate thinking
#    - B) Computers have genuine intelligence
#    - C) Machines can help humans solve problems
#    - D) AI is limited to performing calculations
#    - **Answer: B) Computers have genuine intelligence**
#
# 9. **"Weak AI" is defined as?**
#    - A) AI that simulates mental activity without actually having a mind
#    - B) AI that is less powerful
#    - C) AI that does not have any intelligence
#    - D) AI that can only reason deductively
#    - **Answer: A) AI that simulates mental activity without actually having a mind**
#
# 10. **Which of the following is an AI milestone from the 1950s?**
#     - A) Chess playing programs
#     - B) Internet development
#     - C) Introduction of LISP
#     - D) Both A and C
#     - **Answer: D) Both A and C**
#
# 11. **Who is considered one of the founders of AI?**
#     - A) Alan Turing
#     - B) John McCarthy
#     - C) Marvin Minsky
#     - D) All of the above
#     - **Answer: D) All of the above**
#
# 12. **What was the focus of AI research in the 1950s and 1960s?**
#     - A) Cybernetics
#     - B) Chess playing and theorem proving
#     - C) Networking
#     - D) Deep Learning
#     - **Answer: B) Chess playing and theorem proving**
#
# 13. **Which conference marked the official beginning of AI?**
#     - A) Dartmouth Summer Workshop
#     - B) Stanford AI Conference
#     - C) MIT Robotics Symposium
#     - D) New York Tech Conference
#     - **Answer: A) Dartmouth Summer Workshop**
#
# 14. **What caused the "AI Winter"?**
#     - A) A lack of interest in AI research
#     - B) Excessive optimism followed by failures to achieve expected results
#     - C) Lack of funding for AI projects
#     - D) All of the above
#     - **Answer: D) All of the above**
#
# 15. **Which is an example of an AI system?**
#     - A) Chess-playing program
#     - B) Game Playing
#     - C) Speech Recognition
#     - D) All of the above
#     - **Answer: D) All of the above**
#
# 16. **What is "Machine Translation"?**
#     - A) Translating one machine into another
#     - B) The process of converting one language into another using computers
#     - C) Programming AI in different languages
#     - D) None of the above
#     - **Answer: B) The process of converting one language into another using computers**
#
# 17. **Which concept is associated with the Behaviorist's view on AI?**
#     - A) Observing external behavior as a sign of intelligence
#     - B) Building machines with internal consciousness
#     - C) Mimicking animal instincts
#     - D) Creating symbolic representations
#     - **Answer: A) Observing external behavior as a sign of intelligence**
#
# 18. **Alan Turing’s paper “Computing Machinery and Intelligence” was published in which year?**
#     - A) 1950
#     - B) 1943
#     - C) 1960
#     - D) 1973
#     - **Answer: A) 1950**
#
# 19. **In the Turing Test, what must a judge determine?**
#     - A) Which machine is faster
#     - B) Whether they are interacting with a human or an AI
#     - C) The type of language the computer uses
#     - D) The physical capabilities of the computer
#     - **Answer: B) Whether they are interacting with a human or an AI**
#
# 20. **Which AI field is focused on making machines work smarter?**
#     - A) Robotics
#     - B) Knowledge Technology
#     - C) Mechanical Engineering
#     - D) Computer Graphics
#     - **Answer: B) Knowledge Technology**
#
# 21. **Who defined AI as “the science of making machines do things that would require intelligence if done by humans”?**
#     - A) Alan Turing
#     - B) Marvin Minsky
#     - C) E. Feigenbaum
#     - D) John McCarthy
#     - **Answer: B) Marvin Minsky**
#
# 22. **What is the main goal of Reinforcement Learning?**
#     - A) Supervise learning
#     - B) Classify data
#     - C) Maximize the expected value of a criterion function
#     - D) Train only using labeled data
#     - **Answer: C) Maximize the expected value of a criterion function**
#
# 23. **What is an example of a reactive agent in AI?**
#     - A) Robot vacuum cleaner
#     - B) A chess-playing AI
#     - C) A smartphone assistant
#     - D) A self-driving car
#     - **Answer: A) Robot vacuum cleaner**
#
# 24. **What is the role of sensors in an agent?**
#     - A) Process data
#     - B) Perceive the environment
#     - C) Act in the environment
#     - D) Store information
#     - **Answer: B) Perceive the environment**
#
# 25. **Which of these agents uses effectors?**
#     - A) Human
#     - B) Robot
#     - C) Both A and B
#     - D) None of the above
#     - **Answer: C) Both A and B**
#
# 26. **Which approach to AI is based on mimicking biological systems?**
#     - A) Symbolist Approach
#     - B) Connectionist Approach
#     - C) Logicist Approach
#     - D) Rationalist Approach
#     - **Answer: B) Connectionist Approach**
#
# 27. **What is the outcome of applying the Turing Test to an AI system?**
#     - A) The machine passes the test if the judge is fooled
#     - B) The machine is rejected if it cannot do arithmetic
#     - C) The machine's speed is measured
#     - D) The machine's power consumption is compared
#     - **Answer: A) The machine passes the test if the judge is fooled**
#
# 28. **Which form of learning is used when an AI system is given input-output pairs to learn from?**
#     - A) Unsupervised Learning
#     - B) Reinforcement Learning
#     - C) Supervised Learning
#     - D) Genetic Algorithm
#     - **Answer: C) Supervised Learning**
#
# 29. **Which of the following uses unsupervised learning?**
#     - A) Clustering
#     - B) Classification
#     - C) Backpropagation
#     - D) Regression
#     - **Answer: A) Clustering**
#
# 30. **Which method does AI use to solve problems through trial and error?**
#     - A) Supervised Learning
#     - B) Unsupervised Learning
#     - C) Reinforcement Learning
#     - D) Symbolic Logic
#     - **Answer: C) Reinforcement Learning**

# %% [markdown]
# 31. **Which of the following is NOT an AI application discussed in the lecture?**
#     - A) Game playing
#     - B) Image Processing
#     - C) Machine Translation
#     - D) Voice Recognition
#     - **Answer: B) Image Processing**
#
# 32. **What is the main concept of a "Knowledge Revolution"?**
#     - A) Working harder
#     - B) Working smarter by building intelligence into systems
#     - C) Replacing humans with machines
#     - D) Creating only hardware solutions
#     - **Answer: B) Working smarter by building intelligence into systems**
#
# 33. **What is the difference between Strong AI and Weak AI?**
#     - A) Strong AI performs only basic tasks, Weak AI is more advanced
#     - B) Strong AI has genuine intelligence, Weak AI simulates intelligence
#     - C) Weak AI can operate autonomously, Strong AI needs supervision
#     - D) Strong AI is a concept, Weak AI is implemented
#     - **Answer: B) Strong AI has genuine intelligence, Weak AI simulates intelligence**
#
# 34. **Which early AI approach focused on formal grammar and language?**
#     - A) Connectionism
#     - B) Cybernetics
#     - C) Symbolism
#     - D) Genetic Algorithms
#     - **Answer: C) Symbolism**
#
# 35. **Who developed the chess-playing program that was an early success in AI?**
#     - A) Alan Turing
#     - B) John McCarthy
#     - C) Claude Shannon
#     - D) Herbert Simon
#     - **Answer: C) Claude Shannon**
#
# 36. **Which of these was an important AI milestone in the 1950s?**
#     - A) Introduction of RNNs
#     - B) Chess-playing programs and machine translation
#     - C) Discovery of deep learning
#     - D) Development of CNNs
#     - **Answer: B) Chess-playing programs and machine translation**
#
# 37. **The Turing Test involves interaction via what medium?**
#     - A) Speech
#     - B) Video
#     - C) Written text
#     - D) Physical action
#     - **Answer: C) Written text**
#
# 38. **Which AI subfield deals with creating systems that have human-like reasoning capability?**
#     - A) Expert Systems
#     - B) Knowledge Engineering
#     - C) Neural Networks
#     - D) Machine Translation
#     - **Answer: A) Expert Systems**
#
# 39. **Which of these is an important contributor to the field of AI history?**
#     - A) John von Neumann
#     - B) Marvin Minsky
#     - C) Ada Lovelace
#     - D) Charles Babbage
#     - **Answer: B) Marvin Minsky**
#
# 40. **Which AI method is described as "learning from trial and error"?**
#     - A) Supervised Learning
#     - B) Reinforcement Learning
#     - C) Unsupervised Learning
#     - D) Classification
#     - **Answer: B) Reinforcement Learning**
#
# 41. **Which AI milestone involved the development of LISP?**
#     - A) 1950s
#     - B) 1960s
#     - C) 1970s
#     - D) 1980s
#     - **Answer: A) 1950s**
#
# 42. **Which system demonstrates the use of reinforcement learning?**
#     - A) Google Translate
#     - B) TD-Gammon for backgammon
#     - C) Neural Style Transfer
#     - D) Grammar Checker
#     - **Answer: B) TD-Gammon for backgammon**
#
# 43. **Which term refers to machines that can extend human physical capabilities?**
#     - A) Automation
#     - B) Knowledge Systems
#     - C) Intelligent Systems
#     - D) Expert Systems
#     - **Answer: A) Automation**
#
# 44. **The Information Revolution extends which aspect of humans?**
#     - A) Emotional capabilities
#     - B) Physical capabilities
#     - C) Mental capabilities
#     - D) Artistic skills
#     - **Answer: C) Mental capabilities**
#
# 45. **The term "AI Winter" refers to which period?**
#     - A) A period of rapid growth in AI
#     - B) A decline in AI funding and research
#     - C) The introduction of the internet
#     - D) The emergence of neural networks
#     - **Answer: B) A decline in AI funding and research**
#
# 46. **Which is a key benefit of "Weak AI"?**
#     - A) Machines have their own consciousness
#     - B) AI systems can teach us about human minds
#     - C) AI programs can create other AI systems
#     - D) Weak AI is superior to Strong AI
#     - **Answer: B) AI systems can teach us about human minds**
#
# 47. **What was a significant limitation of early chess-playing AI programs?**
#     - A) Limited processing power
#     - B) High cost of hardware
#     - C) Poor understanding of chess rules
#     - D) Inability to play with human experts
#     - **Answer: A) Limited processing power**
#
# 48. **What is the main purpose of the Turing Test in AI?**
#     - A) To determine if a machine can think
#     - B) To measure a machine's speed
#     - C) To calculate energy consumption
#     - D) To identify physical characteristics of robots
#     - **Answer: A) To determine if a machine can think**
#
# 49. **What does the behaviorist's view state about intelligent machines?**
#     - A) Intelligence can only be proven if observed
#     - B) Machines need to be self-aware
#     - C) Intelligence is based on calculations
#     - D) Intelligence cannot be simulated
#     - **Answer: A) Intelligence can only be proven if observed**
#
# 50. **What concept does the Turing Test explore in AI?**
#     - A) Physical abilities
#     - B) Computational speed
#     - C) Ability to mimic human-like conversation
#     - D) Ability to store data
#     - **Answer: C) Ability to mimic human-like conversation**
#
# 51. **Which of the following was a philosophical question addressed in AI?**
#     - A) Can computers learn on their own?
#     - B) How do machines multiply numbers?
#     - C) How much power does AI consume?
#     - D) Can a machine replace all human jobs?
#     - **Answer: A) Can computers learn on their own?**
#
# 52. **What is the key difference between supervised and unsupervised learning?**
#     - A) Supervised uses labeled data, unsupervised does not
#     - B) Unsupervised is slower
#     - C) Supervised does not need training data
#     - D) Unsupervised requires user intervention
#     - **Answer: A) Supervised uses labeled data, unsupervised does not**
#
# 53. **What was Alan Turing's famous contribution to AI?**
#     - A) Development of the first computer
#     - B) Creating the Turing Test
#     - C) Designing neural networks
#     - D) Establishing the internet
#     - **Answer: B) Creating the Turing Test**
#
# 54. **Which of the following is a typical domain of AI?**
#     - A) Game playing
#     - B) Business analytics
#     - C) Natural language processing
#     - D) All of the above
#     - **Answer: D) All of the above**
#
# 55. **Which learning approach does NOT use labeled data?**
#     - A) Supervised Learning
#     - B) Unsupervised Learning
#     - C) Reinforcement Learning
#     - D) None of the above
#     - **Answer: B) Unsupervised Learning**
#
# 56. **The "duck test" is often used to justify which view of AI?**
#     - A) Strong AI
#     - B) Behaviorist's view
#     - C) Symbolist approach
#     - D) Genetic Algorithms
#     - **Answer: B) Behaviorist's view**
#
# 57. **Which AI approach primarily focuses on creating models to make machines think?**
#     - A) Connectionist
#     - B) Symbolic
#     - C) Mechanical
#     - D) Cybernetics
#     - **Answer: B) Symbolic**
#
# 58. **Which AI programming language was developed in the 1950s and became popular in AI research?**
#     - A) Python
#     - B) LISP
#     - C) Java
#     - D) C++
#     - **Answer: B) LISP**
#
# 59. **What is the purpose of intelligent agents in AI?**
#     - A) To perceive and act in an environment
#     - B) To communicate with other agents
#     - C) To reduce power consumption
#     - D) To enhance the user interface
#     - **Answer: A) To perceive and act in an environment**
#
# 60. **Who was an important figure in popularizing the "knowledge technology" in AI?**
#     - A) Alan Turing
#     - B) Marvin Minsky
#     - C) John McCarthy
#     - D) E. Feigenbaum
#     - **Answer: D) E. Feigenbaum**

# %% [markdown]
# 61. **Which AI system can help predict human-like behavior to enhance quality of life?**
#     - A) Neural Networks
#     - B) Genetic Algorithms
#     - C) Expert Systems
#     - D) Behaviorist Model
#     - **Answer: C) Expert Systems**
#
# 62. **What was Alan Turing’s motivation behind the Turing Test?**
#     - A) To prove that computers could replace humans
#     - B) To assess if machines could exhibit intelligent behavior equivalent to humans
#     - C) To design new hardware
#     - D) To predict the future of computers
#     - **Answer: B) To assess if machines could exhibit intelligent behavior equivalent to humans**
#
# 63. **Which AI branch is focused on mimicking human senses like vision and speech?**
#     - A) Neural Networks
#     - B) Sensory Processing
#     - C) Intelligent Sensing
#     - D) Knowledge Representation
#     - **Answer: B) Sensory Processing**
#
# 64. **The term “knowledge technology” is related to which of the following?**
#     - A) Extending physical capabilities
#     - B) Automating repetitive tasks
#     - C) Enhancing cognitive capabilities
#     - D) Designing hardware systems
#     - **Answer: C) Enhancing cognitive capabilities**
#
# 65. **In the Turing Test, which form of communication is used between the human judge and the test subject?**
#     - A) Audio
#     - B) Video
#     - C) Written Text
#     - D) Gestures
#     - **Answer: C) Written Text**
#
# 66. **What was the main contribution of Marvin Minsky in AI?**
#     - A) Creating LISP
#     - B) Developing a comprehensive definition of AI
#     - C) Establishing symbolic AI methods
#     - D) Designing the internet
#     - **Answer: B) Developing a comprehensive definition of AI**
#
# 67. **What is the primary goal of AI as defined by E. Feigenbaum?**
#     - A) To create physical robots
#     - B) To design intelligent computer systems
#     - C) To develop virtual reality
#     - D) To replace all human jobs
#     - **Answer: B) To design intelligent computer systems**
#
# 68. **What is the most important component in the definition of AI according to the Japan-Singapore AI Centre?**
#     - A) Mimicking human appearance
#     - B) Improving business competitiveness
#     - C) Reducing physical labor
#     - D) Enhancing artistic skills
#     - **Answer: B) Improving business competitiveness**
#
# 69. **Which of the following is NOT considered a traditional AI system?**
#     - A) Game Playing
#     - B) Resource Scheduling
#     - C) DNA Replication
#     - D) Machine Translation
#     - **Answer: C) DNA Replication**
#
# 70. **What AI capability was exhibited by chess-playing programs in the 1950s?**
#     - A) Mimicking human conversations
#     - B) Problem-solving using reasoning
#     - C) Conducting internet searches
#     - D) Image recognition
#     - **Answer: B) Problem-solving using reasoning**
#
# 71. **What was the original purpose of AI research during the 1950s and 60s?**
#     - A) Replace humans with computers
#     - B) Improve industrial productivity
#     - C) Build systems that exhibit human-like intelligence
#     - D) Perform basic arithmetic calculations
#     - **Answer: C) Build systems that exhibit human-like intelligence**
#
# 72. **The development of which language helped in establishing AI programming in the 1950s?**
#     - A) Python
#     - B) LISP
#     - C) Java
#     - D) C#
#     - **Answer: B) LISP**
#
# 73. **The Dartmouth Conference in 1956 marked what significant milestone?**
#     - A) The end of the AI Winter
#     - B) The official beginning of AI research
#     - C) The introduction of neural networks
#     - D) The invention of the Turing Test
#     - **Answer: B) The official beginning of AI research**
#
# 74. **What caused early AI research to experience significant setbacks?**
#     - A) Lack of data
#     - B) Unrealistic expectations and lack of progress
#     - C) High cost of computer hardware
#     - D) Lack of government support
#     - **Answer: B) Unrealistic expectations and lack of progress**
#
# 75. **Which of the following AI systems is aimed at co-operation and coordination in a noisy environment?**
#     - A) Robocup
#     - B) Expert Systems
#     - C) Machine Translation
#     - D) Neural Networks
#     - **Answer: A) Robocup**
#
# 76. **The “duck test” analogy in AI suggests:**
#     - A) Physical appearance is important for AI
#     - B) AI systems must be evaluated based on their behavior
#     - C) AI systems should not be self-learning
#     - D) Computers must be treated as animals
#     - **Answer: B) AI systems must be evaluated based on their behavior**
#
# 77. **Who proposed that if a machine behaves “as if it was intelligent,” then it is intelligent?**
#     - A) Alan Turing
#     - B) John Searle
#     - C) Marvin Minsky
#     - D) Claude Shannon
#     - **Answer: A) Alan Turing**
#
# 78. **What was the significance of the AI Winter?**
#     - A) Expansion of AI research
#     - B) Decline in funding and research interest
#     - C) Introduction of new AI technologies
#     - D) Increased commercial investment
#     - **Answer: B) Decline in funding and research interest**
#
# 79. **Which of the following is an example of using AI to “extend man’s mental capabilities”?**
#     - A) Developing mechanical arms
#     - B) Creating a speech recognition system
#     - C) Building industrial robots
#     - D) Installing solar panels
#     - **Answer: B) Creating a speech recognition system**
#
# 80. **Who defined AI as the science of making machines that perform tasks requiring human intelligence?**
#     - A) Marvin Minsky
#     - B) Alan Turing
#     - C) John McCarthy
#     - D) Claude Shannon
#     - **Answer: A) Marvin Minsky**
#
# 81. **Which of these AI concepts relates to ethical considerations and philosophical aspects of intelligence?**
#     - A) The Turing Test
#     - B) Convolutional Networks
#     - C) Logical Systems
#     - D) Deep Learning
#     - **Answer: A) The Turing Test**
#
# 82. **In which decade was the “AI Winter” observed?**
#     - A) 1940s
#     - B) 1950s
#     - C) 1970s - 1980s
#     - D) 2000s
#     - **Answer: C) 1970s - 1980s**
#
# 83. **AI systems in the medical field often fall under which category?**
#     - A) Expert Systems
#     - B) Robotics
#     - C) Game Playing
#     - D) Image Compression
#     - **Answer: A) Expert Systems**
#
# 84. **Which of the following is an example of a machine using AI for resource scheduling?**
#     - A) Chess-playing computer
#     - B) Elevator scheduling system
#     - C) Computer vision system
#     - D) Chatbot system
#     - **Answer: B) Elevator scheduling system**
#
# 85. **The concept that AI can “extend and multiply man’s physical capabilities” refers to:**
#     - A) The Age of Automation
#     - B) Knowledge Revolution
#     - C) Information Age
#     - D) Machine Learning
#     - **Answer: A) The Age of Automation**
#
# 86. **What was a primary reason for the decline in AI research during the AI Winter?**
#     - A) Lack of interest from the general public
#     - B) Poor performance and unmet expectations
#     - C) Newer technologies replacing AI
#     - D) High cost of computation
#     - **Answer: B) Poor performance and unmet expectations**
#
# 87. **Which of the following AI systems was used for diagnosis and advisory purposes?**
#     - A) Neural Networks
#     - B) Expert Systems
#     - C) Genetic Algorithms
#     - D) Robocup
#     - **Answer: B) Expert Systems**
#
# 88. **In the Turing Test, what role does the judge play?**
#     - A) To decide if the subject is human or machine
#     - B) To train the AI system
#     - C) To supervise the AI’s learning process
#     - D) To rate the performance of the computer
#     - **Answer: A) To decide if the subject is human or machine**
#
# 89. **Which of these methods is used to validate if an AI system is intelligent?**
#     - A) Deep Learning Training
#     - B) Backpropagation
#     - C) Turing Test
#     - D) Reinforcement Learning
#     - **Answer: C) Turing Test**
#
# 90. **What type of learning does an elevator scheduling system use?**
#     - A) Supervised Learning
#     - B) Reinforcement Learning
#     - C) Unsupervised Learning
#     - D) Genetic Algorithm
#     - **Answer: B) Reinforcement Learning**

# %% [markdown]
# 91. **Which of the following is considered an intelligent behavior in AI?**
#     - A) Solving puzzles
#     - B) Storing data
#     - C) Printing documents
#     - D) Scanning text
#     - **Answer: A) Solving puzzles**
#
# 92. **Which type of AI agent would primarily be concerned with decision making under uncertainty?**
#     - A) Reactive Agent
#     - B) Utility-based Agent
#     - C) Goal-based Agent
#     - D) Symbolic Agent
#     - **Answer: B) Utility-based Agent**
#
# 93. **Which learning approach allows AI systems to learn from unstructured data?**
#     - A) Supervised Learning
#     - B) Reinforcement Learning
#     - C) Unsupervised Learning
#     - D) Batch Learning
#     - **Answer: C) Unsupervised Learning**
#
# 94. **What does the Turing Test aim to assess in a machine?**
#     - A) Memory capacity
#     - B) Computational power
#     - C) Ability to exhibit human-like intelligence
#     - D) Ability to do calculations quickly
#     - **Answer: C) Ability to exhibit human-like intelligence**
#
# 95. **Which philosopher’s contributions are fundamental to the field of AI?**
#     - A) Immanuel Kant
#     - B) Bertrand Russell
#     - C) Alan Turing
#     - D) All of the above
#     - **Answer: D) All of the above**
#
# 96. **Which of these is NOT a category of intelligent agent used in AI?**
#     - A) Reactive Agent
#     - B) Reflexive Agent
#     - C) Goal-based Agent
#     - D) Learning Agent
#     - **Answer: B) Reflexive Agent**
#
# 97. **What do AI expert systems use to simulate the decision-making ability of a human expert?**
#     - A) Neural Networks
#     - B) Rule-based knowledge
#     - C) Genetic Algorithms
#     - D) Deep Learning
#     - **Answer: B) Rule-based knowledge**
#
# 98. **Which of the following is used to improve AI system performance over time?**
#     - A) Data Storage
#     - B) Learning Algorithms
#     - C) Printing Algorithms
#     - D) Compilation
#     - **Answer: B) Learning Algorithms**
#
# 99. **Which AI approach allows systems to acquire and apply knowledge through interaction?**
#     - A) Supervised Learning
#     - B) Reinforcement Learning
#     - C) Symbolic Reasoning
#     - D) Genetic Algorithms
#     - **Answer: B) Reinforcement Learning**
#
# 100. **What is the key difference between a strong AI and a weak AI?**
#     - A) Weak AI is a concept, while strong AI is a practical approach
#     - B) Strong AI is intended to be truly intelligent like a human, while weak AI is not
#     - C) Strong AI is for robots, and weak AI is for software
#     - D) There is no difference
#     - **Answer: B) Strong AI is intended to be truly intelligent like a human, while weak AI is not**

# %% [markdown]
# ### **Lecture 2: Introduction to Neural Networks**
#
# 1. **What is the main inspiration behind Artificial Neural Networks (ANNs)?**
#    - A) Biological neurons in the human brain
#    - B) Quantum computing
#    - C) Traditional machine algorithms
#    - D) Cloud computing
#    - **Answer: A) Biological neurons in the human brain**
#
# 2. **What are ANNs composed of?**
#    - A) Logical circuits
#    - B) Interconnected processing elements (nodes)
#    - C) Integrated circuits
#    - D) Central processing units
#    - **Answer: B) Interconnected processing elements (nodes)**
#
# 3. **Which of the following is a key component of a neural network?**
#    - A) Nodes and connections
#    - B) Transistors
#    - C) Microprocessors
#    - D) Resistive circuits
#    - **Answer: A) Nodes and connections**
#
# 4. **How does a biological neuron transmit information?**
#    - A) Through electronic signals
#    - B) Through electrochemical signals
#    - C) Through infrared signals
#    - D) Through digital signals
#    - **Answer: B) Through electrochemical signals**
#
# 5. **Which term refers to the connection strength between nodes in a neural network?**
#    - A) Weight
#    - B) Bias
#    - C) Threshold
#    - D) Activation
#    - **Answer: A) Weight**
#
# 6. **Which learning technique involves labeled data for training an ANN?**
#    - A) Unsupervised Learning
#    - B) Supervised Learning
#    - C) Reinforcement Learning
#    - D) Genetic Algorithm
#    - **Answer: B) Supervised Learning**
#
# 7. **What is the main goal of unsupervised learning in ANNs?**
#    - A) Predict future data
#    - B) Identify patterns without labels
#    - C) Classify input into predetermined classes
#    - D) Minimize errors using labeled data
#    - **Answer: B) Identify patterns without labels**
#
# 8. **Which learning rule is considered the basis for most ANN algorithms?**
#    - A) Hebbian Learning
#    - B) Gradient Descent
#    - C) Reinforcement Learning
#    - D) Genetic Algorithm
#    - **Answer: A) Hebbian Learning**
#
# 9. **Which of the following is true about human brains compared to ANNs?**
#    - A) Brains have more neurons than ANNs
#    - B) ANNs can reason better than the human brain
#    - C) ANNs are capable of creativity
#    - D) ANNs are slower in arithmetic operations than human brains
#    - **Answer: A) Brains have more neurons than ANNs**
#
# 10. **What is the primary type of learning rule in ANNs used for adjusting weights?**
#     - A) Error backpropagation
#     - B) Evolutionary Learning
#     - C) Symbolic Learning
#     - D) None of the above
#     - **Answer: A) Error backpropagation**
#
# 11. **The process of learning in ANNs is often described as:**
#     - A) Replacing the original model
#     - B) Adjusting the weights
#     - C) Improving computation speed
#     - D) Creating new nodes
#     - **Answer: B) Adjusting the weights**
#
# 12. **Which of the following is a key advantage of ANNs?**
#     - A) Can handle noisy and incomplete data
#     - B) Requires a lot of manual input
#     - C) Can only solve linear problems
#     - D) Requires no training
#     - **Answer: A) Can handle noisy and incomplete data**
#
# 13. **Which is an important aspect of ANNs that differentiates them from traditional algorithms?**
#     - A) Static connections
#     - B) Dynamic state responses to inputs
#     - C) Strict hierarchical layers
#     - D) Lack of learning capabilities
#     - **Answer: B) Dynamic state responses to inputs**
#
# 14. **The historical development of ANNs dates back to:**
#     - A) Early 20th century
#     - B) 19th century
#     - C) The year 2000
#     - D) The 21st century
#     - **Answer: A) Early 20th century**
#
# 15. **Who first demonstrated that calculations could be performed using a network of artificial binary neurons?**
#     - A) John McCarthy
#     - B) McCulloch and Pitts
#     - C) Marvin Minsky
#     - D) Alan Turing
#     - **Answer: B) McCulloch and Pitts**
#
# 16. **What concept did the Hebb learning rule introduce to ANNs?**
#     - A) Recurrent Networks
#     - B) Learning through synaptic strength changes
#     - C) Genetic Algorithms
#     - D) Symbolic Reasoning
#     - **Answer: B) Learning through synaptic strength changes**
#
# 17. **Which of the following was a significant drawback of early Perceptron models?**
#     - A) Inability to solve non-linearly separable problems
#     - B) Difficulty in linear separability
#     - C) Lack of hardware support
#     - D) Poor power consumption
#     - **Answer: A) Inability to solve non-linearly separable problems**
#
# 18. **The introduction of hidden layers in neural networks was key to solving what kind of problems?**
#     - A) Linearly separable problems
#     - B) Non-linearly separable problems
#     - C) Arithmetic problems
#     - D) Sorting problems
#     - **Answer: B) Non-linearly separable problems**
#
# 19. **Which type of neural network is known for having multiple layers, including hidden layers?**
#     - A) Perceptron
#     - B) Multilayer Perceptron (MLP)
#     - C) Kohonen Map
#     - D) Radial Basis Function Network
#     - **Answer: B) Multilayer Perceptron (MLP)**
#
# 20. **Which type of data is NOT well-suited for traditional algorithmic approaches but can be solved using ANNs?**
#     - A) Linear data
#     - B) Noisy data
#     - C) Regular time series data
#     - D) Sorted data
#     - **Answer: B) Noisy data**
#
# 21. **Which of the following statements is true for artificial neurons?**
#     - A) Artificial neurons use synaptic connections
#     - B) Artificial neurons are modeled using mathematical functions
#     - C) Artificial neurons have dendrites
#     - D) Artificial neurons produce chemical signals
#     - **Answer: B) Artificial neurons are modeled using mathematical functions**
#
# 22. **Which of the following represents a set of interconnected processing units in an ANN?**
#     - A) Perceptron
#     - B) Cluster
#     - C) Network topology
#     - D) Synaptic mesh
#     - **Answer: C) Network topology**
#
# 23. **What happens if the summed input to an artificial neuron exceeds the threshold?**
#     - A) The neuron does nothing
#     - B) The neuron sends a signal
#     - C) The weights are reset
#     - D) The network stops training
#     - **Answer: B) The neuron sends a signal**
#
# 24. **What is the purpose of weights in an artificial neural network?**
#     - A) To activate nodes
#     - B) To store data
#     - C) To determine the strength of connections between nodes
#     - D) To measure the size of a network
#     - **Answer: C) To determine the strength of connections between nodes**
#
# 25. **The backpropagation learning rule primarily helps to:**
#     - A) Increase training time
#     - B) Adjust weights to minimize error
#     - C) Determine the number of nodes
#     - D) Set initial weights
#     - **Answer: B) Adjust weights to minimize error**
#
# 26. **Which term is used for the function that determines the output of an artificial neuron?**
#     - A) Activation function
#     - B) Summation function
#     - C) Loss function
#     - D) Backpropagation function
#     - **Answer: A) Activation function**
#
# 27. **Which component of a neural network is responsible for learning from experience?**
#     - A) Input layer
#     - B) Hidden layer
#     - C) Output layer
#     - D) Weights
#     - **Answer: D) Weights**
#
# 28. **Which ANN model was specifically developed to address the limitations of Perceptron?**
#     - A) Radial Basis Function Network
#     - B) Backpropagation Neural Network (BPNN)
#     - C) Kohonen Network
#     - D) Convolutional Neural Network
#     - **Answer: B) Backpropagation Neural Network (BPNN)**
#
# 29. **Which type of data can be best classified using Perceptron Networks?**
#     - A) Non-linear data
#     - B) Noisy data
#     - C) Linear separable data
#     - D) Symbolic data
#     - **Answer: C) Linear separable data**
#
# 30. **The early Perceptron model was primarily criticized because it could only solve:**
#     - A) Non-linearly separable problems
#     - B) Linear separable problems
#     - C) Arithmetic problems
#     - D) Algebraic problems
#     - **Answer: B) Linear separable problems**

# %% [markdown]
# 31. **What is the main limitation of Perceptron networks when applied to complex problems?**
#    - A) High power consumption
#    - B) Inability to solve non-linearly separable problems
#    - C) Requirement of labeled data
#    - D) High computational complexity
#    - **Answer: B) Inability to solve non-linearly separable problems**
#
# 32. **Who developed the backpropagation algorithm that helped in the evolution of ANNs?**
#    - A) Marvin Minsky
#    - B) Rumelhart and McClelland
#    - C) Alan Turing
#    - D) Claude Shannon
#    - **Answer: B) Rumelhart and McClelland**
#
# 33. **Which layer in a neural network is used to learn complex features in the data?**
#    - A) Input layer
#    - B) Hidden layer
#    - C) Output layer
#    - D) Bias layer
#    - **Answer: B) Hidden layer**
#
# 34. **What are the types of activation functions used in ANNs?**
#    - A) Linear and nonlinear functions
#    - B) Arithmetic and geometric functions
#    - C) Logical and physical functions
#    - D) Temporal and sequential functions
#    - **Answer: A) Linear and nonlinear functions**
#
# 35. **What is the purpose of using a sigmoid activation function in ANNs?**
#    - A) To perform subtraction
#    - B) To compress output values between 0 and 1
#    - C) To increase training speed
#    - D) To solve arithmetic problems
#    - **Answer: B) To compress output values between 0 and 1**
#
# 36. **Which type of neural network was introduced to deal with non-linearly separable problems?**
#    - A) Single-layer Perceptron
#    - B) Multilayer Perceptron (MLP)
#    - C) Kohonen Network
#    - D) Radial Basis Function Network
#    - **Answer: B) Multilayer Perceptron (MLP)**
#
# 37. **Which of the following is NOT an example of an application of ANNs?**
#    - A) Classification of handwritten digits
#    - B) Stock price prediction
#    - C) Sorting numbers in ascending order
#    - D) Speech recognition
#    - **Answer: C) Sorting numbers in ascending order**
#
# 38. **How are ANN nodes typically connected?**
#    - A) Serially
#    - B) In parallel
#    - C) Using weighted links
#    - D) Randomly
#    - **Answer: C) Using weighted links**
#
# 39. **Which of the following is a major strength of ANNs?**
#    - A) Ability to learn from experience
#    - B) Ability to replicate human speech
#    - C) High speed computation of matrix operations
#    - D) Low energy consumption
#    - **Answer: A) Ability to learn from experience**
#
# 40. **In ANNs, what is meant by “training”?**
#    - A) Learning from input data by adjusting weights
#    - B) Developing a new algorithm
#    - C) Setting up hardware configurations
#    - D) Developing a new neuron structure
#    - **Answer: A) Learning from input data by adjusting weights**
#
# 41. **Which method is used to evaluate the error in backpropagation learning?**
#    - A) Mean Squared Error (MSE)
#    - B) Geometric Mean
#    - C) Harmonic Mean
#    - D) Logical Comparison
#    - **Answer: A) Mean Squared Error (MSE)**
#
# 42. **Which component in an ANN processes information by changing its state in response to inputs?**
#    - A) Synapse
#    - B) Activation function
#    - C) Neuron
#    - D) Output function
#    - **Answer: C) Neuron**
#
# 43. **Which network topology has only one hidden layer?**
#    - A) Single-layer Perceptron
#    - B) Multilayer Perceptron (MLP)
#    - C) Convolutional Neural Network
#    - D) Radial Basis Function Network
#    - **Answer: B) Multilayer Perceptron (MLP)**
#
# 44. **What happens if the weights in an ANN are initialized improperly?**
#    - A) Faster learning
#    - B) Decreased training time
#    - C) Slow or incomplete convergence
#    - D) Network will skip hidden layers
#    - **Answer: C) Slow or incomplete convergence**
#
# 45. **What is the main goal of error backpropagation in ANNs?**
#    - A) Increase error
#    - B) Propagate error to the output layer
#    - C) Adjust weights to minimize the total error
#    - D) Forward propagate data faster
#    - **Answer: C) Adjust weights to minimize the total error**
#
# 46. **What is the purpose of using a threshold in a neural network?**
#    - A) To prevent overfitting
#    - B) To limit the number of connections
#    - C) To determine whether the neuron fires or not
#    - D) To reduce training time
#    - **Answer: C) To determine whether the neuron fires or not**
#
# 47. **Which of the following best describes a linear activation function?**
#    - A) It returns only values of 0 or 1
#    - B) It is a constant function
#    - C) The output is directly proportional to the input
#    - D) It adds random values to input
#    - **Answer: C) The output is directly proportional to the input**
#
# 48. **How are multilayer neural networks different from single-layer networks?**
#    - A) They are simpler in terms of calculations
#    - B) They have multiple hidden layers that allow them to learn complex patterns
#    - C) They cannot be used for classification problems
#    - D) They have only input and output layers
#    - **Answer: B) They have multiple hidden layers that allow them to learn complex patterns**
#
# 49. **Which of the following statements is true for multilayer feedforward neural networks?**
#    - A) They only have a single layer of weights
#    - B) Information flows in a single direction, from input to output
#    - C) They have connections looping back from output to input
#    - D) They always use a linear activation function
#    - **Answer: B) Information flows in a single direction, from input to output**
#
# 50. **What is an advantage of multilayer neural networks compared to a single-layer Perceptron?**
#    - A) Can solve non-linear problems
#    - B) Higher processing power requirement
#    - C) Requires less training data
#    - D) They are less expensive to implement
#    - **Answer: A) Can solve non-linear problems**
#
# 51. **Which of the following methods can be used to initialize weights in ANNs?**
#    - A) Random initialization
#    - B) Setting all weights to zero
#    - C) Fixed initial values
#    - D) Incremental initialization
#    - **Answer: A) Random initialization**
#
# 52. **Which function allows neurons to determine whether to "activate" or not?**
#    - A) Activation function
#    - B) Loss function
#    - C) Propagation function
#    - D) Cost function
#    - **Answer: A) Activation function**
#
# 53. **What is the output of an artificial neuron if the activation function is a step function and the input is greater than the threshold?**
#    - A) 0
#    - B) 1
#    - C) -1
#    - D) Infinity
#    - **Answer: B) 1**
#
# 54. **Which neural network model is used for classifying linearly separable data?**
#    - A) Perceptron
#    - B) Multilayer Perceptron
#    - C) Kohonen Network
#    - D) Recurrent Neural Network
#    - **Answer: A) Perceptron**
#
# 55. **What is the output of a neuron when the sigmoid activation function is used and the input is zero?**
#    - A) 0
#    - B) 0.5
#    - C) 1
#    - D) -1
#    - **Answer: B) 0.5**
#
# 56. **What does a hidden layer in a neural network represent?**
#    - A) Data preprocessing layer
#    - B) Feature extraction
#    - C) Output determination
#    - D) Direct data input layer
#    - **Answer: B) Feature extraction**
#
# 57. **Which method is used to update weights during backpropagation?**
#    - A) Learning rate gradient
#    - B) Stochastic gradient descent
#    - C) Data compression
#    - D) Linear regression
#    - **Answer: B) Stochastic gradient descent**
#
# 58. **What happens to the output of a ReLU activation function if the input is negative?**
#    - A) It outputs 0
#    - B) It outputs a positive value
#    - C) It doubles the input value
#    - D) It outputs a constant value
#    - **Answer: A) It outputs 0**
#
# 59. **Which of these learning techniques involves learning from rewards and penalties?**
#    - A) Reinforcement Learning
#    - B) Supervised Learning
#    - C) Unsupervised Learning
#    - D) Gradient Descent
#    - **Answer: A) Reinforcement Learning**
#
# 60. **What type of problem can be solved by the introduction of non-linear activation functions in ANNs?**
#    - A) Only linearly separable problems
#    - B) Both linear and non-linear separable problems
#    - C) Problems involving sorting of numbers
#    - D) Only multiplication-based problems
#    - **Answer: B) Both linear and non-linear separable problems**

# %% [markdown]
# 61. **What type of output values are typically produced by a sigmoid activation function?**
#    - A) Integer values
#    - B) Binary values (0 or 1)
#    - C) Values between 0 and 1
#    - D) Negative values only
#    - **Answer: C) Values between 0 and 1**
#
# 62. **What is the main reason for using activation functions in artificial neurons?**
#    - A) To connect different layers
#    - B) To add linearity
#    - C) To introduce non-linearity into the model
#    - D) To reduce the number of weights
#    - **Answer: C) To introduce non-linearity into the model**
#
# 63. **Which of the following describes a "feedforward neural network"?**
#    - A) Data moves forward through multiple layers
#    - B) Data flows in cycles
#    - C) Information is propagated backward
#    - D) Nodes share feedback across the entire network
#    - **Answer: A) Data moves forward through multiple layers**
#
# 64. **What is the primary role of the input layer in an ANN?**
#    - A) Process data
#    - B) Provide raw input data to the network
#    - C) Perform computations
#    - D) Store the final result
#    - **Answer: B) Provide raw input data to the network**
#
# 65. **Which neural network element is adjusted to minimize the overall network error during training?**
#    - A) Activation function
#    - B) Weights
#    - C) Biases
#    - D) Inputs
#    - **Answer: B) Weights**
#
# 66. **Which of the following activation functions is considered non-linear?**
#    - A) Identity function
#    - B) Sigmoid
#    - C) Linear function
#    - D) Threshold function
#    - **Answer: B) Sigmoid**
#
# 67. **What property of neural networks makes them suitable for handling noisy data?**
#    - A) Interconnected nature of neurons
#    - B) Use of linear activation functions
#    - C) Ability to reason logically
#    - D) Large number of weights
#    - **Answer: A) Interconnected nature of neurons**
#
# 68. **Which ANN learning type does NOT require labeled data?**
#    - A) Supervised learning
#    - B) Reinforcement learning
#    - C) Unsupervised learning
#    - D) All learning types require labels
#    - **Answer: C) Unsupervised learning**
#
# 69. **What does the “bias” term in neural networks do?**
#    - A) Reduces the weights
#    - B) Increases the computational complexity
#    - C) Shifts the activation function to fit better
#    - D) Stores error values
#    - **Answer: C) Shifts the activation function to fit better**
#
# 70. **Which term is used to describe the output value of a neuron?**
#    - A) Weight value
#    - B) Activation value
#    - C) Bias value
#    - D) Node index
#    - **Answer: B) Activation value**
#
# 71. **Which of these algorithms helps minimize a neural network's error?**
#    - A) Backpropagation
#    - B) Random Forest
#    - C) Decision Tree
#    - D) K-means Clustering
#    - **Answer: A) Backpropagation**
#
# 72. **Which function is often used to calculate error in a neural network?**
#    - A) Loss function
#    - B) Activation function
#    - C) Transformation function
#    - D) Evaluation function
#    - **Answer: A) Loss function**
#
# 73. **The process of reducing the impact of extreme weight updates in a neural network is called:**
#    - A) Clipping
#    - B) Regularization
#    - C) Weight scaling
#    - D) Pruning
#    - **Answer: B) Regularization**
#
# 74. **Which of the following is a primary drawback of sigmoid activation functions?**
#    - A) Produces only binary output
#    - B) Leads to vanishing gradient problem
#    - C) Slows down computation speed
#    - D) Always produces negative values
#    - **Answer: B) Leads to vanishing gradient problem**
#
# 75. **What is the output of a ReLU activation function for any positive input value?**
#    - A) 0
#    - B) Input value itself
#    - C) -1
#    - D) A random value between 0 and 1
#    - **Answer: B) Input value itself**
#
# 76. **What type of problem cannot be solved by a single-layer Perceptron?**
#    - A) Linearly separable problems
#    - B) Non-linearly separable problems
#    - C) Classification problems
#    - D) Logical AND problem
#    - **Answer: B) Non-linearly separable problems**
#
# 77. **Which activation function provides output values between -1 and 1?**
#    - A) Sigmoid
#    - B) Tanh
#    - C) ReLU
#    - D) Step function
#    - **Answer: B) Tanh**
#
# 78. **Which of the following refers to the training process where weights are updated after every sample?**
#    - A) Batch training
#    - B) Incremental training (online)
#    - C) Epoch-based training
#    - D) Step-by-step training
#    - **Answer: B) Incremental training (online)**
#
# 79. **What issue does introducing multiple hidden layers solve in ANNs?**
#    - A) Data storage
#    - B) Overfitting problem
#    - C) Learning complex non-linear relationships
#    - D) Reducing computation time
#    - **Answer: C) Learning complex non-linear relationships**
#
# 80. **What is the role of a "learning rate" in training a neural network?**
#    - A) To determine the number of hidden layers
#    - B) To decide the input value range
#    - C) To control the step size during weight updates
#    - D) To calculate the final output
#    - **Answer: C) To control the step size during weight updates**
#
# 81. **Which of the following is a disadvantage of using a high learning rate?**
#    - A) Increased convergence speed
#    - B) Weights oscillate and may never converge
#    - C) Model trains faster
#    - D) Model fits perfectly to the training data
#    - **Answer: B) Weights oscillate and may never converge**
#
# 82. **Which of the following describes gradient descent in ANNs?**
#    - A) Iterative optimization method for minimizing the error
#    - B) Algorithm used for generating random weights
#    - C) Method to initialize biases
#    - D) Procedure to normalize input data
#    - **Answer: A) Iterative optimization method for minimizing the error**
#
# 83. **What is meant by "local minima" in neural networks?**
#    - A) A point where error is maximum
#    - B) A point where error is lower than all nearby points but not necessarily the lowest overall
#    - C) The point of starting error
#    - D) The lowest possible value of error
#    - **Answer: B) A point where error is lower than all nearby points but not necessarily the lowest overall**
#
# 84. **Which function helps prevent neurons from becoming inactive due to zero gradients during training?**
#    - A) Sigmoid
#    - B) ReLU
#    - C) Step function
#    - D) Logarithmic function
#    - **Answer: B) ReLU**
#
# 85. **In which situation would backpropagation NOT work well?**
#    - A) When the network is shallow
#    - B) When there is no activation function
#    - C) When using high-dimensional data
#    - D) When training with small learning rates
#    - **Answer: B) When there is no activation function**
#
# 86. **Which of the following methods adjusts network weights to reduce prediction error?**
#    - A) Activation function adjustment
#    - B) Gradient descent
#    - C) Learning rate calculation
#    - D) Network topology design
#    - **Answer: B) Gradient descent**
#
# 87. **What happens if the learning rate is too low during training?**
#    - A) Model may never converge
#    - B) Model converges too fast
#    - C) Model cannot learn complex patterns
#    - D) Model trains with excessive noise
#    - **Answer: A) Model may never converge**
#
# 88. **What type of activation function is often used in the output layer for binary classification tasks?**
#    - A) Tanh
#    - B) ReLU
#    - C) Sigmoid
#    - D) Identity function
#    - **Answer: C) Sigmoid**
#
# 89. **Which of the following is true for feedforward neural networks?**
#    - A) They include feedback connections
#    - B) Data flows in one direction only
#    - C) They have only two layers
#    - D) They require convolution operations
#    - **Answer: B) Data flows in one direction only**
#
# 90. **What does an "epoch" represent in ANN training?**
#    - A) The number of nodes in the network
#    - B) A complete pass through the entire training dataset
#    - C) A single input value
#    - D) The number of hidden layers
#    - **Answer: B) A complete pass through the entire training dataset**
#
# 91. **Which activation function is often used to normalize output in between -1 and 1?**
#    - A) Tanh
#    - B) Step
#    - C) Softmax
#    - D) ReLU
#    - **Answer: A) Tanh**
#
# 92. **Which method helps avoid overfitting in neural networks?**
#    - A) Increasing learning rate
#    - B) Adding more layers
#    - C) Regularization techniques
#    - D) Decreasing the number of neurons
#    - **Answer: C) Regularization techniques**
#
# 93. **What is the key concept behind supervised learning?**
#    - A) Predicting data without labels
#    - B) Learning from labeled input-output pairs
#    - C) Using reinforcement to learn
#    - D) Using random sampling for training
#    - **Answer: B) Learning from labeled input-output pairs**
#
# 94. **Which ANN application is commonly used for recognizing handwritten digits?**
#    - A) Handwriting Analysis System
#    - B) Optical Character Recognition (OCR)
#    - C) Voice Command Recognition
#    - D) Sentiment Analysis
#    - **Answer: B) Optical Character Recognition (OCR)**
#
# 95. **Which of the following describes dropout in ANN?**
#    - A) Adding random values to weights
#    - B) Ignoring random neurons during training to prevent overfitting
#    - C) Removing layers from the network
#    - D) Initializing weights with zero
#    - **Answer: B) Ignoring random neurons during training to prevent overfitting**
#
# 96. **Which term refers to the iterative nature of weight updating during ANN training?**
#    - A) Feedback
#    - B) Epoch
#    - C) Stochastic process
#    - D) Backpropagation loop
#    - **Answer: D) Backpropagation loop**
#
# 97. **What kind of problem can be easily solved using a Radial Basis Function Network?**
#    - A) Linearly separable problems
#    - B) Time-series prediction
#    - C) Data clustering problems
#    - D) Reinforcement learning
#    - **Answer: C) Data clustering problems**
#
# 98. **Which of the following is crucial for neural network convergence?**
#    - A) Random weight initialization
#    - B) Selection of activation function
#    - C) Learning rate
#    - D) All of the above
#    - **Answer: D) All of the above**
#
# 99. **Which feature of ANNs is inspired by human neurons?**
#    - A) Feedback mechanism
#    - B) Activation function
#    - C) Use of layers
#    - D) Batch processing
#    - **Answer: B) Activation function**
#
# 100. **What is the primary role of weights in a neural network?**
#     - A) To store outputs
#     - B) To regulate the strength of input signals
#     - C) To decide the network topology
#     - D) To set the learning rate
#     - **Answer: B) To regulate the strength of input signals**

# %% [markdown]
# ### **Lecture 3: Recursive Deterministic Perceptron (RDP)**
#
# 1. **What does RDP stand for in the context of neural networks?**
#    - A) Recursive Deterministic Perceptron
#    - B) Recurrent Dynamic Processing
#    - C) Random Deep Propagation
#    - D) Recursive Data Processing
#    - **Answer: A) Recursive Deterministic Perceptron**
#
# 2. **What type of problem can RDP solve that traditional Perceptrons cannot?**
#    - A) Arithmetic operations
#    - B) Non-linearly separable problems
#    - C) Simple regression problems
#    - D) Classification of linear data
#    - **Answer: B) Non-linearly separable problems**
#
# 3. **Which method does RDP use for building the neural network?**
#    - A) Recursive algorithm
#    - B) Backpropagation
#    - C) Genetic algorithms
#    - D) Stochastic optimization
#    - **Answer: A) Recursive algorithm**
#
# 4. **In RDP, what is the primary focus during network construction?**
#    - A) Building a large network
#    - B) Optimizing weights randomly
#    - C) Iteratively finding the required architecture
#    - D) Reducing computational complexity
#    - **Answer: C) Iteratively finding the required architecture**
#
# 5. **What is the difference between RDP and traditional Perceptrons?**
#    - A) RDP is only used for clustering
#    - B) RDP iteratively grows the network to solve non-linear problems
#    - C) RDP is linear while Perceptrons are non-linear
#    - D) There is no difference
#    - **Answer: B) RDP iteratively grows the network to solve non-linear problems**
#
# 6. **What kind of datasets can RDP effectively work on?**
#    - A) Linearly separable datasets only
#    - B) Non-linearly separable datasets
#    - C) Sorted datasets only
#    - D) Clustering-based datasets only
#    - **Answer: B) Non-linearly separable datasets**
#
# 7. **Which of the following is an important feature of the Recursive Deterministic Perceptron?**
#    - A) Random initialization of weights
#    - B) Growing neural network based on requirements
#    - C) Reducing the number of neurons
#    - D) Static architecture
#    - **Answer: B) Growing neural network based on requirements**
#
# 8. **How does RDP differ from other neural networks like MLP?**
#    - A) It uses convolutional layers
#    - B) It grows its structure dynamically
#    - C) It only has an input and output layer
#    - D) It is not trainable
#    - **Answer: B) It grows its structure dynamically**
#
# 9. **What is the main challenge with traditional Perceptrons that RDP attempts to overcome?**
#    - A) Inability to process large datasets
#    - B) Inability to solve the XOR problem
#    - C) High computational cost
#    - D) Long training times
#    - **Answer: B) Inability to solve the XOR problem**
#
# 10. **Which of the following methods can be used to determine linear separability in RDP?**
#     - A) Gradient descent
#     - B) Convex Hull technique
#     - C) Genetic algorithms
#     - D) Simulated annealing
#     - **Answer: B) Convex Hull technique**
#
# 11. **What is the main goal of the Convex Hull method used in RDP?**
#     - A) To separate linearly separable classes
#     - B) To compute activation functions
#     - C) To calculate the total weight
#     - D) To train hidden layers
#     - **Answer: A) To separate linearly separable classes**
#
# 12. **How does RDP decide whether more neurons are required?**
#     - A) Based on a fixed number of iterations
#     - B) By evaluating the classification performance
#     - C) By randomly selecting additional neurons
#     - D) By measuring computational time
#     - **Answer: B) By evaluating the classification performance**
#
# 13. **Which of the following is an example of a non-linearly separable dataset that RDP can handle?**
#     - A) AND logic gate dataset
#     - B) XOR logic gate dataset
#     - C) OR logic gate dataset
#     - D) Simple arithmetic dataset
#     - **Answer: B) XOR logic gate dataset**
#
# 14. **In which phase of the RDP does the network grow?**
#     - A) Initialization phase
#     - B) Training phase
#     - C) Recursive phase
#     - D) Output phase
#     - **Answer: C) Recursive phase**
#
# 15. **What is the advantage of growing the neural network in RDP dynamically?**
#     - A) Reduces computation time
#     - B) Optimizes the network for the specific problem
#     - C) Randomizes weight initialization
#     - D) Always results in better accuracy
#     - **Answer: B) Optimizes the network for the specific problem**
#
# 16. **How does the "batch method" apply in RDP development?**
#     - A) Adds neurons one at a time
#     - B) Adds a group of neurons at once to speed up convergence
#     - C) Uses reinforcement learning
#     - D) Eliminates hidden layers
#     - **Answer: B) Adds a group of neurons at once to speed up convergence**
#
# 17. **What is the “incremental method” in RDP used for?**
#     - A) Growing the network gradually with one neuron at a time
#     - B) Removing hidden layers
#     - C) Classifying linearly separable data
#     - D) Calculating training error
#     - **Answer: A) Growing the network gradually with one neuron at a time**
#
# 18. **The "modular method" in RDP is focused on:**
#     - A) Breaking the problem into smaller, manageable sub-problems
#     - B) Increasing the number of connections
#     - C) Weight initialization
#     - D) Calculating convergence time
#     - **Answer: A) Breaking the problem into smaller, manageable sub-problems**
#
# 19. **Which is a primary advantage of RDP compared to standard neural networks?**
#     - A) Fixed structure that requires no adjustments
#     - B) Ability to change its structure based on problem complexity
#     - C) Fast training speed with large networks
#     - D) No need for training data
#     - **Answer: B) Ability to change its structure based on problem complexity**
#
# 20. **What is the role of Convex Hulls in testing for linear separability in RDP?**
#     - A) Defining boundaries that separate classes
#     - B) Calculating weights
#     - C) Determining neuron activation functions
#     - D) Updating weights
#     - **Answer: A) Defining boundaries that separate classes**
#
# 21. **What is the output of the XOR example in RDP for input (1, 0)?**
#     - A) 0
#     - B) 1
#     - C) -1
#     - D) Undefined
#     - **Answer: B) 1**
#
# 22. **How is the error corrected in RDP during training?**
#     - A) Using backpropagation
#     - B) By adjusting weights recursively
#     - C) By adding new layers randomly
#     - D) By decreasing learning rate
#     - **Answer: B) By adjusting weights recursively**
#
# 23. **What type of topology does RDP start with?**
#     - A) Fully connected
#     - B) Modular topology
#     - C) Small topology which grows if needed
#     - D) Randomly generated topology
#     - **Answer: C) Small topology which grows if needed**
#
# 24. **Which method helps RDP networks converge faster?**
#     - A) Batch Method
#     - B) Incremental Method
#     - C) Modular Method
#     - D) Heuristic Search
#     - **Answer: A) Batch Method**
#
# 25. **Which problem type is RDP well-suited to solve?**
#     - A) Unsupervised clustering
#     - B) Non-linearly separable problems
#     - C) Sorting numbers
#     - D) Finding shortest paths
#     - **Answer: B) Non-linearly separable problems**
#
# 26. **What type of approach does RDP use to modify its structure?**
#     - A) Hybrid learning
#     - B) Evolutionary approach
#     - C) Recursive and deterministic approach
#     - D) Heuristic approach
#     - **Answer: C) Recursive and deterministic approach**
#
# 27. **Which of the following statements describes the Convex Hull technique used in RDP?**
#     - A) It identifies whether classes are linearly separable
#     - B) It determines the correct activation function
#     - C) It initializes the weight values
#     - D) It reduces network redundancy
#     - **Answer: A) It identifies whether classes are linearly separable**
#
# 28. **Which of the following features can improve RDP network performance?**
#     - A) Random neuron addition
#     - B) Convex Hull-based heuristics for separability testing
#     - C) Decreasing the learning rate gradually
#     - D) Fixed weight initialization
#     - **Answer: B) Convex Hull-based heuristics for separability testing**
#
# 29. **What does the modular method achieve in RDP neural networks?**
#     - A) Makes the network smaller
#     - B) Simplifies complex problems by breaking them down
#     - C) Reduces training data requirements
#     - D) Improves computational efficiency by using only linear models
#     - **Answer: B) Simplifies complex problems by breaking them down**
#
# 30. **What is a key characteristic of a fully connected RDP?**
#     - A) Every neuron is connected to every other neuron
#     - B) All neurons are connected in a sequential order
#     - C) Only hidden layers are interconnected
#     - D) The network has no hidden layers
#     - **Answer: A) Every neuron is connected to every other neuron**

# %% [markdown]
# 31. **Which phase is crucial in RDP to determine if more neurons are needed?**
#    - A) Initialization
#    - B) Recursive Phase
#    - C) Validation Phase
#    - D) Testing Phase
#    - **Answer: B) Recursive Phase**
#
# 32. **How is the output generated in RDP for a given input?**
#    - A) Using a single feedforward pass
#    - B) Through multiple recursive computations
#    - C) Using backpropagation
#    - D) Using random weight adjustments
#    - **Answer: B) Through multiple recursive computations**
#
# 33. **Which approach is used by RDP to classify non-linearly separable data?**
#    - A) Heuristic Search
#    - B) Recursive addition of new neurons
#    - C) Single-layer computation
#    - D) Gradient descent only
#    - **Answer: B) Recursive addition of new neurons**
#
# 34. **Which is an important aspect of the modular method in RDP?**
#    - A) Recursively adding layers
#    - B) Dividing complex problems into smaller, independent units
#    - C) Increasing the learning rate
#    - D) Eliminating bias terms
#    - **Answer: B) Dividing complex problems into smaller, independent units**
#
# 35. **What is the benefit of using the batch method in RDP development?**
#    - A) Faster training and convergence
#    - B) More complexity in network structure
#    - C) Reduced accuracy
#    - D) Decreasing computation power requirements
#    - **Answer: A) Faster training and convergence**
#
# 36. **Which type of learning is primarily employed by RDP?**
#    - A) Supervised Learning
#    - B) Reinforcement Learning
#    - C) Unsupervised Learning
#    - D) Semi-supervised Learning
#    - **Answer: A) Supervised Learning**
#
# 37. **What determines when an RDP stops adding neurons?**
#    - A) When the learning rate drops below a threshold
#    - B) When a satisfactory classification accuracy is reached
#    - C) When a fixed number of neurons is added
#    - D) When the recursive phase completes a set number of iterations
#    - **Answer: B) When a satisfactory classification accuracy is reached**
#
# 38. **In the context of RDP, what is the primary purpose of the Convex Hull?**
#    - A) To visualize the structure of a neural network
#    - B) To verify if classes can be separated linearly
#    - C) To initialize bias values
#    - D) To determine the learning rate
#    - **Answer: B) To verify if classes can be separated linearly**
#
# 39. **What is the key goal of using RDP instead of other neural networks like MLP?**
#    - A) Solve linear problems faster
#    - B) Dynamically adjust network complexity based on the problem's nature
#    - C) Use fewer neurons
#    - D) Provide deterministic outputs
#    - **Answer: B) Dynamically adjust network complexity based on the problem's nature**
#
# 40. **Which type of learning approach is used in Recursive Deterministic Perceptron?**
#    - A) Instance-based learning
#    - B) Recursive and heuristic learning
#    - C) Static and fixed learning
#    - D) Evolutionary learning
#    - **Answer: B) Recursive and heuristic learning**
#
# 41. **Which of the following approaches does NOT apply to RDP?**
#    - A) Batch Method
#    - B) Incremental Method
#    - C) Random Weight Generation
#    - D) Modular Method
#    - **Answer: C) Random Weight Generation**
#
# 42. **What type of algorithm is RDP considered?**
#    - A) Probabilistic and non-deterministic
#    - B) Recursive and deterministic
#    - C) Evolutionary
#    - D) Genetic
#    - **Answer: B) Recursive and deterministic**
#
# 43. **Which issue is directly addressed by using modular methods in RDP?**
#    - A) Overfitting
#    - B) High computational complexity
#    - C) Non-linearly separable problems
#    - D) Redundancy in connections
#    - **Answer: C) Non-linearly separable problems**
#
# 44. **How is the XOR problem solved using RDP?**
#    - A) Using a single layer
#    - B) By adding more neurons until separability is achieved
#    - C) By using random forest models
#    - D) By decreasing the learning rate
#    - **Answer: B) By adding more neurons until separability is achieved**
#
# 45. **Which feature allows RDP to modify its structure during learning?**
#    - A) Deterministic weights
#    - B) Recursive growth of neurons
#    - C) Convolution layers
#    - D) Fixed architecture
#    - **Answer: B) Recursive growth of neurons**
#
# 46. **Which technique is used in RDP to handle inseparable data classes?**
#    - A) Convex Hulls
#    - B) PCA
#    - C) Normalization
#    - D) Dropout
#    - **Answer: A) Convex Hulls**
#
# 47. **How does RDP ensure efficient usage of neurons?**
#    - A) By initializing all neurons at once
#    - B) By adding neurons recursively as needed
#    - C) By using genetic algorithms
#    - D) By training all neurons simultaneously
#    - **Answer: B) By adding neurons recursively as needed**
#
# 48. **Which of the following methods are used for evaluating network performance in RDP?**
#    - A) Regression analysis
#    - B) Validation error
#    - C) Convex Hull separability test
#    - D) Data normalization
#    - **Answer: C) Convex Hull separability test**
#
# 49. **What is a primary benefit of using RDP's deterministic nature?**
#    - A) Ensures randomness in weight initialization
#    - B) Provides consistent results every time
#    - C) Reduces the need for training data
#    - D) Removes the need for validation
#    - **Answer: B) Provides consistent results every time**
#
# 50. **In the context of neural networks, what does "growing the network" imply?**
#    - A) Increasing the number of layers
#    - B) Adding new neurons based on classification results
#    - C) Decreasing the size of hidden layers
#    - D) Initializing new weights
#    - **Answer: B) Adding new neurons based on classification results**
#
# 51. **Why is the modular approach important in RDP?**
#    - A) It improves computation speed
#    - B) It enables solving complex problems by breaking them into simpler modules
#    - C) It reduces the number of iterations
#    - D) It eliminates redundant data
#    - **Answer: B) It enables solving complex problems by breaking them into simpler modules**
#
# 52. **Which of these is an advantage of RDP over traditional Perceptrons?**
#    - A) Fixed number of neurons
#    - B) Random growth of hidden layers
#    - C) Dynamic addition of neurons for non-linear problems
#    - D) Reduced convergence time
#    - **Answer: C) Dynamic addition of neurons for non-linear problems**
#
# 53. **What is an important benefit of recursively adding neurons in RDP?**
#    - A) Improved accuracy for non-linearly separable problems
#    - B) Reduces memory usage
#    - C) Faster processing speed
#    - D) Increases convergence speed for linear data
#    - **Answer: A) Improved accuracy for non-linearly separable problems**
#
# 54. **Which of the following describes the incremental method in RDP?**
#    - A) Adding a single neuron at each step
#    - B) Adding layers in bulk
#    - C) Reducing weights recursively
#    - D) Calculating error in each epoch
#    - **Answer: A) Adding a single neuron at each step**
#
# 55. **In which situation would the batch method be most useful in RDP?**
#    - A) When dealing with a large number of samples
#    - B) When working with linear problems
#    - C) When trying to add neurons one at a time
#    - D) When the training set is very small
#    - **Answer: A) When dealing with a large number of samples**
#
# 56. **The primary focus of RDP is:**
#    - A) Classifying inseparable data using recursive growth
#    - B) Training with a fixed topology
#    - C) Eliminating weights
#    - D) Data normalization
#    - **Answer: A) Classifying inseparable data using recursive growth**
#
# 57. **Which aspect of RDP allows it to adapt to different problem complexities?**
#    - A) Its fixed architecture
#    - B) Its ability to grow recursively
#    - C) Its use of stochastic gradient descent
#    - D) Its use of backpropagation
#    - **Answer: B) Its ability to grow recursively**
#
# 58. **What happens if RDP determines that linear separability is not possible with its current structure?**
#    - A) It stops training
#    - B) It adds more neurons to improve performance
#    - C) It reduces the learning rate
#    - D) It removes redundant neurons
#    - **Answer: B) It adds more neurons to improve performance**
#
# 59. **What does "recursive growth" imply in the context of RDP?**
#    - A) Sequential addition of neurons as needed
#    - B) Removal of neurons one by one
#    - C) Growing only the hidden layers
#    - D) Random neuron addition
#    - **Answer: A) Sequential addition of neurons as needed**
#
# 60. **What is a key use of Convex Hulls in the RDP method?**
#    - A) Determine whether a problem is linearly separable
#    - B) Normalize the input data
#    - C) Train the network faster
#    - D) Reduce bias
#    - **Answer: A) Determine whether a problem is linearly separable**

# %% [markdown]
# 61. **What does the recursive nature of RDP help in achieving during training?**
#    - A) Random structure creation
#    - B) Targeted network growth until optimal performance is reached
#    - C) Fixed structure to minimize training cost
#    - D) Shorter training duration irrespective of complexity
#    - **Answer: B) Targeted network growth until optimal performance is reached**
#
# 62. **What role does the "validation set" play in RDP?**
#    - A) Initializes the weights
#    - B) Tests whether the network requires additional neurons
#    - C) Determines if a batch method should be applied
#    - D) Optimizes the network using genetic algorithms
#    - **Answer: B) Tests whether the network requires additional neurons**
#
# 63. **Which of these statements is true regarding the modular approach in RDP?**
#    - A) It adds random layers in the network
#    - B) It splits the problem into independent sub-problems for better processing
#    - C) It does not require testing or validation
#    - D) It avoids backpropagation altogether
#    - **Answer: B) It splits the problem into independent sub-problems for better processing**
#
# 64. **How does RDP respond when a classification task becomes challenging with existing neurons?**
#    - A) Adds more neurons
#    - B) Reduces the number of hidden layers
#    - C) Adjusts learning rate only
#    - D) Stops learning immediately
#    - **Answer: A) Adds more neurons**
#
# 65. **What is the advantage of adding neurons recursively instead of having a fixed architecture in RDP?**
#    - A) Reduced memory usage
#    - B) Dynamically adjusting network complexity for better performance
#    - C) Higher training costs
#    - D) Ensures all problems are linearly solved
#    - **Answer: B) Dynamically adjusting network complexity for better performance**
#
# 66. **Which of the following can help prevent overfitting in RDP networks?**
#    - A) Using a large number of neurons initially
#    - B) Adding neurons only when necessary
#    - C) Reducing the training data size
#    - D) Increasing the learning rate
#    - **Answer: B) Adding neurons only when necessary**
#
# 67. **Which feature is unique to RDP compared to standard multilayer neural networks?**
#    - A) Fixed weight structure
#    - B) Recursive topology growth
#    - C) Deterministic convergence
#    - D) Use of dropout layers
#    - **Answer: B) Recursive topology growth**
#
# 68. **Which of these is a drawback of using a fixed number of neurons in neural networks?**
#    - A) Higher convergence rates
#    - B) Inability to adapt to complex non-linear relationships
#    - C) Optimized performance for all cases
#    - D) Easy interpretability
#    - **Answer: B) Inability to adapt to complex non-linear relationships**
#
# 69. **How does RDP handle non-linear boundaries in complex classification problems?**
#    - A) By recursively growing the network
#    - B) By removing hidden layers
#    - C) By setting a lower learning rate
#    - D) By using only the input layer
#    - **Answer: A) By recursively growing the network**
#
# 70. **Which approach ensures that RDP does not grow excessively large without reason?**
#    - A) Modular approach
#    - B) Validation set evaluation
#    - C) Batch processing
#    - D) Learning rate reduction
#    - **Answer: B) Validation set evaluation**
#
# 71. **What type of network does RDP start with?**
#    - A) A fully connected network with multiple hidden layers
#    - B) A simple network with minimal neurons
#    - C) A pre-trained deep neural network
#    - D) A fully modular network with added redundancy
#    - **Answer: B) A simple network with minimal neurons**
#
# 72. **In RDP, what action is taken if the current network configuration is unable to classify correctly?**
#    - A) Learning rate is reduced
#    - B) New neurons are added until correct classification is achieved
#    - C) Network is discarded
#    - D) Weights are randomly changed
#    - **Answer: B) New neurons are added until correct classification is achieved**
#
# 73. **What is the advantage of the deterministic aspect of RDP?**
#    - A) Random learning and generalization
#    - B) Consistency in results irrespective of input order
#    - C) Requires more computation than non-deterministic methods
#    - D) More prone to overfitting
#    - **Answer: B) Consistency in results irrespective of input order**
#
# 74. **What kind of problems does the modular method help solve more efficiently in RDP?**
#    - A) Problems with a linear nature
#    - B) Complex non-linear problems by breaking them into simpler sub-problems
#    - C) Small classification problems
#    - D) Problems involving fewer data samples
#    - **Answer: B) Complex non-linear problems by breaking them into simpler sub-problems**
#
# 75. **What kind of connectivity is possible in a fully connected RDP network?**
#    - A) Each neuron connects only to the output
#    - B) Each neuron connects to every neuron in the following layer
#    - C) Each neuron connects only to neighboring neurons
#    - D) Each neuron connects to every other neuron in the network
#    - **Answer: B) Each neuron connects to every neuron in the following layer**
#
# 76. **Why is recursive growth important in RDP for dealing with the XOR problem?**
#    - A) The XOR problem requires multiple neurons to separate non-linearly separable classes
#    - B) The XOR problem is easy to solve with a single neuron
#    - C) The XOR problem can be solved only using convolutional networks
#    - D) Recursive growth reduces training time for the XOR problem
#    - **Answer: A) The XOR problem requires multiple neurons to separate non-linearly separable classes**
#
# 77. **What is the impact of convex hulls in the classification process of RDP?**
#    - A) They are used to reduce data dimensionality
#    - B) They determine linear separability of data classes
#    - C) They help in initializing random weights
#    - D) They are only used in the output layer
#    - **Answer: B) They determine linear separability of data classes**
#
# 78. **Which problem would an RDP model be suitable for?**
#    - A) Sorting numbers
#    - B) Classifying handwritten digits (non-linear problem)
#    - C) Basic arithmetic operations
#    - D) Random number generation
#    - **Answer: B) Classifying handwritten digits (non-linear problem)**
#
# 79. **Which of these methods allows RDP to effectively handle non-linearly separable data?**
#    - A) Use of only one layer
#    - B) Recursive addition of neurons until the problem becomes separable
#    - C) Decreasing the input size
#    - D) Fixed weight initialization
#    - **Answer: B) Recursive addition of neurons until the problem becomes separable**
#
# 80. **How does the batch method speed up the training process in RDP?**
#    - A) It removes neurons from the network
#    - B) It adds multiple neurons at once
#    - C) It increases the learning rate
#    - D) It reduces the input data set size
#    - **Answer: B) It adds multiple neurons at once**
#
# 81. **Which of the following does the RDP's modular method focus on?**
#    - A) Classifying only linearly separable problems
#    - B) Solving complex problems by dividing them into modules
#    - C) Removing hidden layers
#    - D) Using fixed activation functions
#    - **Answer: B) Solving complex problems by dividing them into modules**
#
# 82. **Which statement best describes the purpose of recursive addition of neurons in RDP?**
#    - A) Decrease network complexity
#    - B) Improve accuracy for non-linear problems
#    - C) Train the network using only one epoch
#    - D) Avoid using activation functions
#    - **Answer: B) Improve accuracy for non-linear problems**
#
# 83. **Which aspect of RDP ensures that the model isn't overly complex?**
#    - A) Using a low learning rate
#    - B) Validation to determine necessity for additional neurons
#    - C) Always adding multiple neurons in every iteration
#    - D) Using fewer data points during training
#    - **Answer: B) Validation to determine necessity for additional neurons**
#
# 84. **What does the recursive deterministic growth in RDP enable in terms of network architecture?**
#    - A) It creates identical neuron connections for all problems
#    - B) It customizes the network architecture for different types of problems
#    - C) It removes all hidden layers
#    - D) It focuses only on random weight generation
#    - **Answer: B) It customizes the network architecture for different types of problems**
#
# 85. **Which type of activation function is commonly used in RDP to introduce non-linearity?**
#    - A) Linear
#    - B) Step function
#    - C) Sigmoid
#    - D) Identity function
#    - **Answer: C) Sigmoid**
#
# 86. **What is the primary difference between traditional Perceptrons and RDP?**
#    - A) RDP uses recurrent connections
#    - B) RDP can add neurons recursively to improve problem solving
#    - C) RDP only solves linearly separable problems
#    - D) Traditional Perceptrons are modular
#    - **Answer: B) RDP can add neurons recursively to improve problem solving**
#
# 87. **In which scenarios would using RDP be advantageous?**
#    - A) When working on a simple linear regression problem
#    - B) When handling complex classification problems that require network adaptation
#    - C) When working with fixed input-output relationships
#    - D) When no training data is available
#    - **Answer: B) When handling complex classification problems that require network adaptation**
#
# 88. **How does the incremental method contribute to RDP training?**
#    - A) It randomly changes the activation function
#    - B) It adds neurons gradually, one at a time, to optimize the network
#    - C) It reduces the number of input features
#    - D) It stops training early
#    - **Answer: B) It adds neurons gradually, one at a time, to optimize the network**
#
# 89. **Which of the following is a benefit of recursive addition of neurons in RDP?**
#    - A) Reduced network complexity for simple problems
#    - B) Enhanced ability to handle non-linear problems
#    - C) Randomization of weight initialization
#    - D) Use of only one layer for all types of data
#    - **Answer: B) Enhanced ability to handle non-linear problems**
#
# 90. **What is the goal of the Convex Hull technique in the RDP approach?**
#    - A) Identify optimal neuron weights
#    - B) Test linear separability of data classes
#    - C) Reduce error in weights
#    - D) Perform feature extraction
#    - **Answer: B) Test linear separability of data classes**
#
# 91. **Which part of the RDP architecture changes based on the problem complexity?**
#    - A) Input layer only
#    - B) Number of hidden layers and neurons
#    - C) Output layer
#    - D) Type of activation function
#    - **Answer: B) Number of hidden layers and neurons**
#
# 92. **Which aspect makes RDP suitable for real-world non-linear problems?**
#    - A) Use of linear activation functions
#    - B) Recursive growth of the network to suit problem complexity
#    - C) Randomized topology
#    - D) Static weight structure
#    - **Answer: B) Recursive growth of the network to suit problem complexity**
#
# 93. **What does the modular approach enable in RDP?**
#    - A) Random initialization of neurons
#    - B) Solving the problem by dividing it into manageable sub-problems
#    - C) Increasing the size of the dataset
#    - D) Eliminating the validation phase
#    - **Answer: B) Solving the problem by dividing it into manageable sub-problems**
#
# 94. **Which term is associated with adjusting the network during the training process in RDP?**
#    - A) Modular method
#    - B) Batch training
#    - C) Recursive neuron addition
#    - D) Random initialization
#    - **Answer: C) Recursive neuron addition**
#
# 95. **How does the deterministic nature of RDP influence training outcomes?**
#    - A) It makes the training outcomes random
#    - B) It ensures the same outcome for similar problems
#    - C) It guarantees overfitting
#    - D) It changes the activation function in every iteration
#    - **Answer: B) It ensures the same outcome for similar problems**
#
# 96. **Which problem-solving capability does RDP provide that is not found in traditional Perceptrons?**
#    - A) Ability to perform simple classification
#    - B) Ability to solve non-linearly separable problems by adding neurons as needed
#    - C) Ability to compute arithmetic operations faster
#    - D) Use of fixed learning rates for all problems
#    - **Answer: B) Ability to solve non-linearly separable problems by adding neurons as needed**
#
# 97. **What characteristic allows RDP to stop adding neurons when required?**
#    - A) Backpropagation error becomes too high
#    - B) Network achieves desired accuracy on validation data
#    - C) All neurons are initialized
#    - D) Random number of neurons added
#    - **Answer: B) Network achieves desired accuracy on validation data**
#
# 98. **What role does the Convex Hull play in the training process of RDP?**
#    - A) Identifies whether classes are linearly separable
#    - B) Changes learning rate automatically
#    - C) Initializes all neurons
#    - D) Adds randomness to network weights
#    - **Answer: A) Identifies whether classes are linearly separable**
#
# 99. **Which of the following is crucial to ensure RDP doesn’t overgrow unnecessarily?**
#    - A) Validation-based control of network growth
#    - B) Adding multiple neurons regardless of complexity
#    - C) Using fixed bias terms
#    - D) Using stochastic methods
#    - **Answer: A) Validation-based control of network growth**
#
# 100. **What makes the Recursive Deterministic Perceptron a flexible solution for classification tasks?**
#     - A) It grows dynamically based on the complexity of the problem
#     - B) It does not require training data
#     - C) It uses a fixed number of neurons
#     - D) It only handles linearly separable problems
#     - **Answer: A) It grows dynamically based on the complexity of the problem**

# %% [markdown]
# 1. **What does MLP stand for in the context of neural networks?**
#    - A) Multilayer Perceptron
#    - B) Modular Layer Processing
#    - C) Multiple Loop Processing
#    - D) Machine Learning Perceptron
#    - **Answer: A) Multilayer Perceptron**
#
# 2. **What is the primary benefit of using hidden layers in an MLP?**
#    - A) Reduced training time
#    - B) Ability to solve non-linear problems
#    - C) Simplify the network
#    - D) Lower memory usage
#    - **Answer: B) Ability to solve non-linear problems**
#
# 3. **What type of activation function is commonly used in hidden layers of MLP?**
#    - A) Linear function
#    - B) Sigmoid function
#    - C) Step function
#    - D) Identity function
#    - **Answer: B) Sigmoid function**
#
# 4. **Which of the following is true about a feedforward neural network?**
#    - A) Connections are made backward
#    - B) Information flows in only one direction, from input to output
#    - C) It has cycles within its architecture
#    - D) It uses feedback from the output to adjust weights in real-time
#    - **Answer: B) Information flows in only one direction, from input to output**
#
# 5. **How does an MLP solve the XOR problem?**
#    - A) By using a single layer with multiple nodes
#    - B) By using one hidden layer to learn non-linearly separable patterns
#    - C) By removing hidden layers
#    - D) By randomly adjusting weights
#    - **Answer: B) By using one hidden layer to learn non-linearly separable patterns**
#
# 6. **Which method is used to update the weights in MLP during training?**
#    - A) Backpropagation
#    - B) Linear regression
#    - C) Convex Hull optimization
#    - D) Clustering
#    - **Answer: A) Backpropagation**
#
# 7. **What is the role of an activation function in MLP?**
#    - A) To multiply weights
#    - B) To introduce non-linearity to the network
#    - C) To normalize the input values
#    - D) To initialize weights
#    - **Answer: B) To introduce non-linearity to the network**
#
# 8. **Which of the following activation functions is non-linear?**
#    - A) Identity function
#    - B) Step function
#    - C) Sigmoid function
#    - D) Linear function
#    - **Answer: C) Sigmoid function**
#
# 9. **What is the primary function of the hidden layer in an MLP?**
#    - A) Provide input to the network
#    - B) Extract features and introduce complexity to the model
#    - C) Control the output layer
#    - D) Reduce the dimensionality of data
#    - **Answer: B) Extract features and introduce complexity to the model**
#
# 10. **How does information flow in a feedforward network?**
#     - A) Cyclically through all layers
#     - B) In a loop between hidden and output layers
#     - C) In a unidirectional flow from input to output
#     - D) Through recurrent connections
#     - **Answer: C) In a unidirectional flow from input to output**
#
# 11. **Which of the following is the main advantage of using MLP compared to single-layer Perceptrons?**
#     - A) Faster processing
#     - B) Capability to solve non-linear problems
#     - C) Requires less data
#     - D) Lower memory requirement
#     - **Answer: B) Capability to solve non-linear problems**
#
# 12. **What type of problem can be effectively solved by using an MLP network?**
#     - A) Linearly separable problems
#     - B) Non-linearly separable problems
#     - C) Data compression problems
#     - D) Arithmetic problems
#     - **Answer: B) Non-linearly separable problems**
#
# 13. **Which algorithm is commonly used for training MLP networks?**
#     - A) Genetic algorithms
#     - B) Backpropagation
#     - C) k-Nearest Neighbors
#     - D) Support Vector Machine
#     - **Answer: B) Backpropagation**
#
# 14. **What is the typical flow of data in a feedforward neural network?**
#     - A) Output to input
#     - B) Random order
#     - C) Input to output without loops
#     - D) Input, hidden, and then cyclic to output
#     - **Answer: C) Input to output without loops**
#
# 15. **Which learning method does an MLP use?**
#     - A) Supervised learning
#     - B) Unsupervised learning
#     - C) Reinforcement learning
#     - D) Evolutionary learning
#     - **Answer: A) Supervised learning**
#
# 16. **How does backpropagation work in an MLP?**
#     - A) By changing the structure of the network
#     - B) By adjusting weights based on the error gradient
#     - C) By adding more layers
#     - D) By randomizing the outputs
#     - **Answer: B) By adjusting weights based on the error gradient**
#
# 17. **Which type of activation function is typically used in the output layer for binary classification?**
#     - A) ReLU
#     - B) Sigmoid
#     - C) Tanh
#     - D) Step function
#     - **Answer: B) Sigmoid**
#
# 18. **Which of the following is a key feature of MLP architecture?**
#     - A) Hidden layers are not required
#     - B) Contains multiple hidden layers to capture complex patterns
#     - C) Contains only one layer for activation
#     - D) Always uses a linear activation function
#     - **Answer: B) Contains multiple hidden layers to capture complex patterns**
#
# 19. **What is the key difference between a Perceptron and a Multilayer Perceptron?**
#     - A) Perceptron uses multiple layers while MLP uses one
#     - B) MLP can solve non-linear problems by introducing hidden layers
#     - C) Perceptron can handle non-linear data
#     - D) MLP does not require an activation function
#     - **Answer: B) MLP can solve non-linear problems by introducing hidden layers**
#
# 20. **Which method helps MLP minimize the overall network error?**
#     - A) Forward propagation
#     - B) Backpropagation
#     - C) Gradient ascent
#     - D) Genetic optimization
#     - **Answer: B) Backpropagation**
#
# 21. **What is the main purpose of using the hidden layer in an MLP?**
#     - A) To increase computation speed
#     - B) To introduce non-linear combinations of inputs
#     - C) To reduce the number of nodes in the input layer
#     - D) To output classification results
#     - **Answer: B) To introduce non-linear combinations of inputs**
#
# 22. **What happens if no activation function is used in an MLP?**
#     - A) The network will become non-linear
#     - B) The network will function as a linear regression model
#     - C) The training time will be reduced
#     - D) The network will overfit the data
#     - **Answer: B) The network will function as a linear regression model**
#
# 23. **Which activation function helps deal with vanishing gradient problems better than sigmoid?**
#     - A) Step function
#     - B) Tanh
#     - C) ReLU
#     - D) Identity function
#     - **Answer: C) ReLU**
#
# 24. **Which activation function is used in hidden layers to ensure that the model can learn non-linear representations?**
#     - A) Linear
#     - B) ReLU
#     - C) Constant
#     - D) None
#     - **Answer: B) ReLU**
#
# 25. **Which statement is true about the gradient descent method used in MLP?**
#     - A) It maximizes error
#     - B) It minimizes the error by adjusting weights
#     - C) It randomly selects weights
#     - D) It has no effect on weights
#     - **Answer: B) It minimizes the error by adjusting weights**
#
# 26. **What is the purpose of using bias in MLP neurons?**
#     - A) To initialize weights
#     - B) To allow more flexible movement of the activation function
#     - C) To deactivate certain neurons
#     - D) To increase training speed
#     - **Answer: B) To allow more flexible movement of the activation function**
#
# 27. **Which algorithm is primarily used in MLP for learning from labeled data?**
#     - A) Backpropagation
#     - B) PCA
#     - C) k-Means Clustering
#     - D) Genetic Algorithm
#     - **Answer: A) Backpropagation**
#
# 28. **How does the backpropagation algorithm in MLP find the best weights?**
#     - A) By using random initialization
#     - B) By propagating errors back from the output layer to the input layer
#     - C) By removing all the hidden layers
#     - D) By optimizing the bias terms
#     - **Answer: B) By propagating errors back from the output layer to the input layer**
#
# 29. **What is the result of using multiple hidden layers in an MLP?**
#     - A) Higher computation cost and improved learning of complex features
#     - B) Faster training
#     - C) Higher possibility of underfitting
#     - D) Decreased network accuracy
#     - **Answer: A) Higher computation cost and improved learning of complex features**
#
# 30. **Which function is used to reduce the error in MLP training?**
#     - A) Cost function
#     - B) Gradient descent optimization
#     - C) Heuristic evaluation
#     - D) Constant output function
#     - **Answer: B) Gradient descent optimization**

# %% [markdown]
# 31. **What is the main advantage of using the ReLU activation function over the sigmoid function in MLPs?**
#    - A) It outputs negative values
#    - B) It reduces computation cost and mitigates the vanishing gradient problem
#    - C) It works only for binary classifications
#    - D) It is not differentiable
#    - **Answer: B) It reduces computation cost and mitigates the vanishing gradient problem**
#
# 32. **Which of the following components is found in every neuron in an MLP?**
#    - A) Activation function, bias, and weights
#    - B) Only weights
#    - C) Only activation functions
#    - D) Only biases
#    - **Answer: A) Activation function, bias, and weights**
#
# 33. **What kind of error does backpropagation aim to minimize in MLP?**
#    - A) Mean Squared Error (MSE)
#    - B) Absolute Error
#    - C) Random Error
#    - D) Overfitting Error
#    - **Answer: A) Mean Squared Error (MSE)**
#
# 34. **Which of the following is true regarding the number of layers in MLP?**
#    - A) MLP has at least one input layer, one hidden layer, and one output layer
#    - B) MLP does not require hidden layers
#    - C) MLP has only one layer
#    - D) MLP requires only an output layer
#    - **Answer: A) MLP has at least one input layer, one hidden layer, and one output layer**
#
# 35. **What is the major problem when training MLP with sigmoid activation functions?**
#    - A) Exploding gradient problem
#    - B) Vanishing gradient problem
#    - C) Non-linearity
#    - D) High computational requirements
#    - **Answer: B) Vanishing gradient problem**
#
# 36. **In which type of learning environment does MLP work best?**
#    - A) Supervised learning with labeled datasets
#    - B) Unsupervised learning without any labels
#    - C) Reinforcement learning using rewards and penalties
#    - D) Generative learning with synthetic data
#    - **Answer: A) Supervised learning with labeled datasets**
#
# 37. **Which function helps MLPs approximate complex decision boundaries?**
#    - A) Activation function
#    - B) Cost function
#    - C) Threshold function
#    - D) Bias function
#    - **Answer: A) Activation function**
#
# 38. **What is the typical structure of a Multilayer Feedforward Neural Network?**
#    - A) Input, output layers only
#    - B) Input, hidden, and output layers
#    - C) Recurrent connections between neurons
#    - D) Cyclic flow between layers
#    - **Answer: B) Input, hidden, and output layers**
#
# 39. **Which of these is used to ensure that an MLP can learn non-linear relationships between features?**
#    - A) Multiple hidden layers and non-linear activation functions
#    - B) Linear activation functions only
#    - C) Reducing the learning rate
#    - D) Using no hidden layers
#    - **Answer: A) Multiple hidden layers and non-linear activation functions**
#
# 40. **Which activation function is known to introduce non-linearity in MLP and prevent the network from simply acting as a linear model?**
#    - A) ReLU
#    - B) Linear
#    - C) Step function
#    - D) Identity function
#    - **Answer: A) ReLU**
#
# 41. **Why is ReLU a popular activation function in MLP hidden layers?**
#    - A) It helps in non-linear transformations and avoids the vanishing gradient problem
#    - B) It is linear and has no gradient
#    - C) It is suitable for regression tasks only
#    - D) It outputs values between -1 and 1
#    - **Answer: A) It helps in non-linear transformations and avoids the vanishing gradient problem**
#
# 42. **What is the main role of the bias term in a neural network?**
#    - A) Reduces the learning rate
#    - B) Increases the complexity of computations
#    - C) Helps in shifting the activation function
#    - D) Always outputs zero
#    - **Answer: C) Helps in shifting the activation function**
#
# 43. **Which of the following features is unique to MLP compared to traditional linear regression models?**
#    - A) Use of weights
#    - B) Inclusion of non-linear activation functions and hidden layers
#    - C) Prediction of continuous values
#    - D) Using linear equations only
#    - **Answer: B) Inclusion of non-linear activation functions and hidden layers**
#
# 44. **How does backpropagation calculate the adjustment required for each weight?**
#    - A) By randomly selecting a value
#    - B) By propagating the output error backward and updating based on the gradient of each weight
#    - C) By forward passing through the network
#    - D) By removing neurons that contribute less
#    - **Answer: B) By propagating the output error backward and updating based on the gradient of each weight**
#
# 45. **What does "feedforward" imply in the context of MLP?**
#    - A) Output values are fed back to the hidden layer
#    - B) Data flows from input to output without any cycles or loops
#    - C) Training data is fed back into the network
#    - D) Data flows randomly between layers
#    - **Answer: B) Data flows from input to output without any cycles or loops**
#
# 46. **Which of the following activation functions can help reduce the vanishing gradient problem?**
#    - A) Sigmoid
#    - B) Tanh
#    - C) ReLU
#    - D) Identity function
#    - **Answer: C) ReLU**
#
# 47. **What does the backpropagation algorithm help to adjust in MLP training?**
#    - A) The number of neurons
#    - B) Weights and biases
#    - C) The size of the dataset
#    - D) The learning rate
#    - **Answer: B) Weights and biases**
#
# 48. **What happens if the learning rate is too high during MLP training?**
#    - A) The model will converge too quickly
#    - B) The weights may oscillate and fail to converge
#    - C) The model will overfit the training data
#    - D) The training time will be reduced
#    - **Answer: B) The weights may oscillate and fail to converge**
#
# 49. **Which learning rule is primarily used in MLP for adjusting weights during training?**
#    - A) Hebbian learning
#    - B) Gradient descent
#    - C) Clustering
#    - D) Genetic algorithm
#    - **Answer: B) Gradient descent**
#
# 50. **Which of the following prevents neurons in MLP from being "stuck" or inactive during training?**
#    - A) Dropout
#    - B) Random initialization of weights
#    - C) Use of ReLU activation function
#    - D) Decreasing learning rate
#    - **Answer: C) Use of ReLU activation function**
#
# 51. **Which of the following techniques can help improve generalization in an MLP model?**
#    - A) Adding more hidden layers
#    - B) Using dropout to randomly ignore neurons during training
#    - C) Increasing learning rate
#    - D) Removing activation functions
#    - **Answer: B) Using dropout to randomly ignore neurons during training**
#
# 52. **Which component of the MLP is responsible for transforming the input data?**
#    - A) Input layer
#    - B) Hidden layer
#    - C) Output layer
#    - D) Bias nodes
#    - **Answer: B) Hidden layer**
#
# 53. **What kind of activation function is used in the output layer for multi-class classification problems in MLP?**
#    - A) Sigmoid
#    - B) ReLU
#    - C) Softmax
#    - D) Identity function
#    - **Answer: C) Softmax**
#
# 54. **How does adding more neurons in the hidden layers of MLP affect the model?**
#    - A) It decreases accuracy
#    - B) It allows the model to learn more complex features
#    - C) It reduces computation speed
#    - D) It simplifies the model
#    - **Answer: B) It allows the model to learn more complex features**
#
# 55. **Which of the following is a primary reason for using multiple hidden layers in MLP?**
#    - A) To approximate highly complex functions
#    - B) To decrease training time
#    - C) To minimize memory usage
#    - D) To prevent non-linearity
#    - **Answer: A) To approximate highly complex functions**
#
# 56. **How does the bias term help in neural network training?**
#    - A) It helps neurons activate even when inputs are zero
#    - B) It prevents gradient descent
#    - C) It removes non-linearity
#    - D) It always outputs one
#    - **Answer: A) It helps neurons activate even when inputs are zero**
#
# 57. **What happens during the forward pass of an MLP?**
#    - A) The input is propagated through the network to calculate the output
#    - B) The weights are adjusted
#    - C) The gradient is propagated
#    - D) The activation function is replaced
#    - **Answer: A) The input is propagated through the network to calculate the output**
#
# 58. **What can be done to handle overfitting in an MLP network?**
#    - A) Increase learning rate
#    - B) Use regularization techniques like dropout
#    - C) Remove hidden layers
#    - D) Train longer
#    - **Answer: B) Use regularization techniques like dropout**
#
# 59. **What is the goal of the backpropagation process in an MLP?**
#    - A) Minimize the network's overall error by updating weights
#    - B) Increase the number of neurons in the output layer
#    - C) Initialize all bias terms
#    - D) Perform forward propagation
#    - **Answer: A) Minimize the network's overall error by updating weights**
#
# 60. **Which type of problem is MLP unable to solve effectively without a non-linear activation function?**
#    - A) Linear regression
#    - B) Non-linearly separable problems
#    - C) Arithmetic operations
#    - D) Linear classification
#    - **Answer: B) Non-linearly separable problems**

# %% [markdown]
# 61. **What is the main disadvantage of using the sigmoid activation function in MLP?**
#    - A) It is not differentiable
#    - B) It suffers from the vanishing gradient problem
#    - C) It cannot be used in classification problems
#    - D) It always outputs negative values
#    - **Answer: B) It suffers from the vanishing gradient problem**
#
# 62. **Which of the following activation functions produces an output between -1 and 1?**
#    - A) Sigmoid
#    - B) Tanh
#    - C) ReLU
#    - D) Softmax
#    - **Answer: B) Tanh**
#
# 63. **What kind of loss function is used for a regression problem in MLP?**
#    - A) Cross-Entropy Loss
#    - B) Hinge Loss
#    - C) Mean Squared Error (MSE)
#    - D) Log Loss
#    - **Answer: C) Mean Squared Error (MSE)**
#
# 64. **What is the main purpose of the cost function in MLP training?**
#    - A) Measure the accuracy of the network
#    - B) Calculate the difference between the actual and predicted values
#    - C) Adjust the learning rate
#    - D) Randomly initialize weights
#    - **Answer: B) Calculate the difference between the actual and predicted values**
#
# 65. **Which type of activation function is used in the output layer of an MLP to handle multiclass classification tasks?**
#    - A) ReLU
#    - B) Sigmoid
#    - C) Tanh
#    - D) Softmax
#    - **Answer: D) Softmax**
#
# 66. **How does increasing the number of hidden layers affect the MLP model?**
#    - A) It makes the model more interpretable
#    - B) It allows the model to learn more complex functions
#    - C) It always reduces overfitting
#    - D) It decreases the time required to train the model
#    - **Answer: B) It allows the model to learn more complex functions**
#
# 67. **What is the main challenge of using too many hidden layers in an MLP?**
#    - A) Underfitting the training data
#    - B) Overfitting the training data and increasing computational complexity
#    - C) Decreasing the accuracy of the model
#    - D) Making the network linear
#    - **Answer: B) Overfitting the training data and increasing computational complexity**
#
# 68. **Which type of optimization algorithm is primarily used to minimize the error in MLP?**
#    - A) Gradient Descent
#    - B) Genetic Algorithm
#    - C) Particle Swarm Optimization
#    - D) Principal Component Analysis
#    - **Answer: A) Gradient Descent**
#
# 69. **Which activation function in MLP produces an output of exactly 0 for any negative input?**
#    - A) Sigmoid
#    - B) ReLU
#    - C) Tanh
#    - D) Softmax
#    - **Answer: B) ReLU**
#
# 70. **What does dropout do during MLP training?**
#    - A) Drops the learning rate
#    - B) Randomly ignores neurons to prevent overfitting
#    - C) Removes unnecessary layers
#    - D) Increases the activation of neurons
#    - **Answer: B) Randomly ignores neurons to prevent overfitting**
#
# 71. **Which type of problem can MLP effectively solve that a simple perceptron cannot?**
#    - A) XOR classification
#    - B) Linearly separable problems
#    - C) Simple regression problems
#    - D) Logical AND problems
#    - **Answer: A) XOR classification**
#
# 72. **What is the purpose of the learning rate in the gradient descent algorithm for MLP?**
#    - A) It controls the speed of weight updates
#    - B) It determines the network's complexity
#    - C) It controls the output of the activation function
#    - D) It is used to initialize the weights
#    - **Answer: A) It controls the speed of weight updates**
#
# 73. **Which of the following can cause overfitting in MLP networks?**
#    - A) Using a very high learning rate
#    - B) Using too many neurons or layers relative to the size of the training data
#    - C) Using dropout during training
#    - D) Increasing the batch size
#    - **Answer: B) Using too many neurons or layers relative to the size of the training data**
#
# 74. **How is a large learning rate likely to affect the training of an MLP?**
#    - A) Faster convergence with higher accuracy
#    - B) The weights may oscillate and fail to converge
#    - C) Slow training with minimal weight updates
#    - D) Always leads to better generalization
#    - **Answer: B) The weights may oscillate and fail to converge**
#
# 75. **What is the effect of adding multiple hidden layers in an MLP network?**
#    - A) Reduces computation cost
#    - B) Increases the network's ability to learn deep representations
#    - C) Reduces overfitting
#    - D) Leads to always linear classification
#    - **Answer: B) Increases the network's ability to learn deep representations**
#
# 76. **Which term describes the error that occurs when the MLP model fits the training data too well, capturing noise?**
#    - A) Underfitting
#    - B) Overfitting
#    - C) Generalization Error
#    - D) Training Error
#    - **Answer: B) Overfitting**
#
# 77. **Which of the following techniques is commonly used to prevent overfitting in MLP?**
#    - A) Increasing the number of neurons
#    - B) Regularization methods like L2 and dropout
#    - C) Using linear activation functions
#    - D) Reducing the learning rate
#    - **Answer: B) Regularization methods like L2 and dropout**
#
# 78. **What does the term "epoch" mean in the context of training an MLP?**
#    - A) A single pass through the entire training dataset
#    - B) The number of neurons in each layer
#    - C) The time taken to train the network
#    - D) The number of hidden layers in the network
#    - **Answer: A) A single pass through the entire training dataset**
#
# 79. **What is the advantage of using a non-linear activation function in MLPs?**
#    - A) It makes the model interpretable
#    - B) It allows the network to learn complex, non-linear relationships
#    - C) It reduces computational complexity
#    - D) It makes the network linear
#    - **Answer: B) It allows the network to learn complex, non-linear relationships**
#
# 80. **How does using batch normalization help in training MLPs?**
#    - A) It increases the learning rate
#    - B) It standardizes the inputs to each layer, improving training speed and stability
#    - C) It removes the need for activation functions
#    - D) It decreases the size of the dataset
#    - **Answer: B) It standardizes the inputs to each layer, improving training speed and stability**
#
# 81. **Which metric is typically used to evaluate the performance of MLP in classification tasks?**
#    - A) Mean Absolute Error
#    - B) Accuracy
#    - C) Loss function only
#    - D) Root Mean Squared Error
#    - **Answer: B) Accuracy**
#
# 82. **How can underfitting be avoided when training an MLP model?**
#    - A) Increasing the number of neurons or hidden layers
#    - B) Reducing the size of the training dataset
#    - C) Using a very high learning rate
#    - D) Using linear activation functions only
#    - **Answer: A) Increasing the number of neurons or hidden layers**
#
# 83. **Which of the following can be done to improve the generalization of an MLP model?**
#    - A) Increase the learning rate
#    - B) Use cross-validation to tune hyperparameters
#    - C) Add as many hidden layers as possible
#    - D) Train only with small datasets
#    - **Answer: B) Use cross-validation to tune hyperparameters**
#
# 84. **Which term refers to the situation where a model performs well on training data but poorly on unseen test data?**
#    - A) Overfitting
#    - B) Underfitting
#    - C) Gradient explosion
#    - D) Epoch skipping
#    - **Answer: A) Overfitting**
#
# 85. **What does backpropagation calculate to help MLP models learn effectively?**
#    - A) Weight initialization
#    - B) Gradient of the loss function with respect to each weight
#    - C) Activation functions
#    - D) Input values
#    - **Answer: B) Gradient of the loss function with respect to each weight**
#
# 86. **How can the problem of vanishing gradients in MLPs be mitigated?**
#    - A) Using a linear activation function
#    - B) Using activation functions like ReLU instead of sigmoid
#    - C) Increasing the number of hidden layers
#    - D) Reducing the batch size
#    - **Answer: B) Using activation functions like ReLU instead of sigmoid**
#
# 87. **Why might we prefer a lower learning rate during MLP training?**
#    - A) To prevent overfitting
#    - B) To avoid skipping the optimal solution due to large weight updates
#    - C) To make training faster
#    - D) To ignore some neurons
#    - **Answer: B) To avoid skipping the optimal solution due to large weight updates**
#
# 88. **What is the role of the Softmax function in MLP classification?**
#    - A) To reduce training time
#    - B) To convert output scores into probabilities for each class
#    - C) To eliminate neurons during training
#    - D) To increase the input size
#    - **Answer: B) To convert output scores into probabilities for each class**
#
# 89. **What is a potential disadvantage of using ReLU as an activation function?**
#    - A) It is computationally intensive
#    - B) It cannot handle negative input values and may cause some neurons to die
#    - C) It always outputs a value of 1
#    - D) It is not differentiable
#    - **Answer: B) It cannot handle negative input values and may cause some neurons to die**
#
# 90. **Which term describes training a neural network on the same data until it achieves zero training error?**
#    - A) Underfitting
#    - B) Perfect fitting
#    - C) Overfitting
#    - D) Gradient clipping
#    - **Answer: C) Overfitting**
#
# 91. **What is the purpose of using gradient clipping in MLP?**
#    - A) To increase the learning rate
#    - B) To prevent the gradients from growing too large during training
#    - C) To eliminate neurons with lower values
#    - D) To reduce the number of epochs required
#    - **Answer: B) To prevent the gradients from growing too large during training**
#
# 92. **What is the effect of using an extremely small learning rate in MLP training?**
#    - A) Faster convergence
#    - B) Longer training time and possible difficulty converging
#    - C) Increase in accuracy
#    - D) Decreased computational requirements
#    - **Answer: B) Longer training time and possible difficulty converging**
#
# 93. **Which of these is used to reduce computational redundancy in large MLP models?**
#    - A) Batch normalization
#    - B) Increasing hidden layers
#    - C) Increasing learning rate
#    - D) Using identity activation functions
#    - **Answer: A) Batch normalization**
#
# 94. **Which of the following is an example of an adaptive learning rate optimizer used in MLP training?**
#    - A) SGD (Stochastic Gradient Descent)
#    - B) Adam
#    - C) PCA (Principal Component Analysis)
#    - D) ReLU
#    - **Answer: B) Adam**
#
# 95. **What is the primary purpose of the cross-entropy loss function in classification tasks?**
#    - A) To measure the distance between output values
#    - B) To calculate probabilities
#    - C) To minimize the difference between predicted and actual class labels
#    - D) To normalize the input data
#    - **Answer: C) To minimize the difference between predicted and actual class labels**
#
# 96. **How can adding dropout layers to an MLP improve the model?**
#    - A) By increasing the number of neurons
#    - B) By reducing overfitting through neuron randomization
#    - C) By speeding up training
#    - D) By ensuring all neurons are always active
#    - **Answer: B) By reducing overfitting through neuron randomization**
#
# 97. **Which optimizer is most commonly used to speed up convergence during MLP training?**
#    - A) Stochastic Gradient Descent (SGD)
#    - B) Genetic Algorithm
#    - C) Adam
#    - D) Convex Optimization
#    - **Answer: C) Adam**
#
# 98. **How can we measure how well an MLP model is performing during training?**
#    - A) By checking the model's training error and validation error
#    - B) By examining the weights directly
#    - C) By changing the activation function randomly
#    - D) By modifying the input features
#    - **Answer: A) By checking the model's training error and validation error**
#
# 99. **Which of the following helps prevent dead neurons in an MLP?**
#    - A) Using a linear activation function
#    - B) Using the ReLU activation function carefully
#    - C) Increasing the number of epochs
#    - D) Increasing the learning rate to maximum
#    - **Answer: B) Using the ReLU activation function carefully**
#
# 100. **Why is L2 regularization used in MLP training?**
#     - A) To increase the complexity of the model
#     - B) To add more hidden layers
#     - C) To penalize large weights and help prevent overfitting
#     - D) To reduce the number of inputs
#     - **Answer: C) To penalize large weights and help prevent overfitting**

# %% [markdown]
# ### **Lecture 5: Backpropagation and Optimization in Neural Networks**
#
# 1. **What is backpropagation primarily used for in neural networks?**
#    - A) Forward propagation of input data
#    - B) Calculating the error and updating the weights
#    - C) Randomly initializing weights
#    - D) Determining the number of hidden layers
#    - **Answer: B) Calculating the error and updating the weights**
#
# 2. **Which function is used to calculate the error between predicted and actual values in backpropagation?**
#    - A) Activation function
#    - B) Cost function
#    - C) Gradient function
#    - D) Weight function
#    - **Answer: B) Cost function**
#
# 3. **What is the first step in the backpropagation process?**
#    - A) Random weight initialization
#    - B) Forward pass to calculate the output
#    - C) Updating weights
#    - D) Calculating the gradient
#    - **Answer: B) Forward pass to calculate the output**
#
# 4. **Which of the following methods is used to adjust weights in backpropagation?**
#    - A) Gradient descent
#    - B) Principal Component Analysis
#    - C) Genetic Algorithm
#    - D) K-Means Clustering
#    - **Answer: A) Gradient descent**
#
# 5. **Which term refers to calculating the derivative of the loss function with respect to each weight during backpropagation?**
#    - A) Gradient computation
#    - B) Regularization
#    - C) Weight pruning
#    - D) Cross-validation
#    - **Answer: A) Gradient computation**
#
# 6. **Which part of the neural network does backpropagation focus on?**
#    - A) Output layer only
#    - B) All layers except the input layer
#    - C) Input layer only
#    - D) Hidden layers only
#    - **Answer: B) All layers except the input layer**
#
# 7. **What is the purpose of using an activation function in backpropagation?**
#    - A) To perform linear transformation
#    - B) To introduce non-linearity and calculate the gradient during backpropagation
#    - C) To adjust the learning rate
#    - D) To initialize weights
#    - **Answer: B) To introduce non-linearity and calculate the gradient during backpropagation**
#
# 8. **Which term is used for the direction in which weights are updated during backpropagation?**
#    - A) Forward direction
#    - B) Negative gradient direction
#    - C) Random direction
#    - D) Activation direction
#    - **Answer: B) Negative gradient direction**
#
# 9. **What role does the learning rate play in backpropagation?**
#    - A) Decides the number of hidden layers
#    - B) Controls the step size for weight updates
#    - C) Determines the number of neurons
#    - D) Initializes the weights
#    - **Answer: B) Controls the step size for weight updates**
#
# 10. **What happens if the learning rate is too high during backpropagation?**
#     - A) Model converges quickly with high accuracy
#     - B) Weights may oscillate and fail to converge
#     - C) Training becomes very slow
#     - D) Model will underfit the data
#     - **Answer: B) Weights may oscillate and fail to converge**
#
# 11. **Which of the following is true about a small learning rate in backpropagation?**
#     - A) The model may converge quickly
#     - B) Training time may be longer but the model can converge more reliably
#     - C) Weights will oscillate
#     - D) The model cannot overfit the data
#     - **Answer: B) Training time may be longer but the model can converge more reliably**
#
# 12. **What is the gradient in backpropagation used for?**
#     - A) To compute the forward pass
#     - B) To determine the direction and amount of weight updates
#     - C) To initialize biases
#     - D) To determine the size of the dataset
#     - **Answer: B) To determine the direction and amount of weight updates**
#
# 13. **What does the term "local minima" refer to in the context of backpropagation?**
#     - A) The point of lowest error globally
#     - B) A point where error is minimized locally but not necessarily globally
#     - C) A point of maximum error
#     - D) Random initialization point
#     - **Answer: B) A point where error is minimized locally but not necessarily globally**
#
# 14. **Which optimizer is often used as an alternative to gradient descent for faster convergence in backpropagation?**
#     - A) Stochastic Gradient Descent (SGD)
#     - B) Adam Optimizer
#     - C) Linear Regression
#     - D) K-Means Clustering
#     - **Answer: B) Adam Optimizer**
#
# 15. **How does batch gradient descent differ from stochastic gradient descent in backpropagation?**
#     - A) Batch gradient descent updates weights using a small sample of data
#     - B) Stochastic gradient descent updates weights after every individual sample
#     - C) Batch gradient descent has a lower learning rate
#     - D) Stochastic gradient descent always results in faster convergence
#     - **Answer: B) Stochastic gradient descent updates weights after every individual sample**
#
# 16. **Which function is used to measure the error during backpropagation in a classification problem?**
#     - A) Cross-entropy loss
#     - B) Mean Squared Error (MSE)
#     - C) L1 Regularization
#     - D) Softmax function
#     - **Answer: A) Cross-entropy loss**
#
# 17. **Why is the chain rule important in backpropagation?**
#     - A) It initializes all the weights
#     - B) It allows the computation of gradients for weight updates by linking partial derivatives through each layer
#     - C) It determines the learning rate
#     - D) It computes activation functions
#     - **Answer: B) It allows the computation of gradients for weight updates by linking partial derivatives through each layer**
#
# 18. **What is the main purpose of regularization in backpropagation?**
#     - A) To speed up convergence
#     - B) To prevent overfitting by adding a penalty term to the loss
#     - C) To increase the number of hidden layers
#     - D) To reduce the training dataset size
#     - **Answer: B) To prevent overfitting by adding a penalty term to the loss**
#
# 19. **Which technique can help in escaping local minima during backpropagation?**
#     - A) Momentum
#     - B) Decreasing the learning rate to zero
#     - C) Using linear activation functions only
#     - D) Reducing the dataset size
#     - **Answer: A) Momentum**
#
# 20. **What effect does momentum have on gradient descent during backpropagation?**
#     - A) Slows down convergence
#     - B) Increases training time
#     - C) Helps to maintain the direction of previous updates, thus speeding up convergence
#     - D) Eliminates weight updates
#     - **Answer: C) Helps to maintain the direction of previous updates, thus speeding up convergence**
#
# 21. **Which activation function can cause the vanishing gradient problem in backpropagation?**
#     - A) ReLU
#     - B) Sigmoid
#     - C) Linear
#     - D) Softmax
#     - **Answer: B) Sigmoid**
#
# 22. **What does the term "vanishing gradient problem" mean in the context of backpropagation?**
#     - A) Gradients become too large during weight updates
#     - B) Gradients become too small, preventing effective weight updates
#     - C) Weights remain constant during training
#     - D) The output remains constant
#     - **Answer: B) Gradients become too small, preventing effective weight updates**
#
# 23. **Which of these optimizers adapts the learning rate for each parameter to speed up convergence?**
#     - A) SGD
#     - B) Adam
#     - C) Mini-batch Gradient Descent
#     - D) Convex Optimization
#     - **Answer: B) Adam**
#
# 24. **Which technique can prevent the exploding gradient problem in backpropagation?**
#     - A) Increasing the number of neurons
#     - B) Using gradient clipping
#     - C) Increasing the learning rate
#     - D) Removing activation functions
#     - **Answer: B) Using gradient clipping**
#
# 25. **What is the role of weight initialization in backpropagation?**
#     - A) To assign the final values of weights
#     - B) To start with reasonable initial weights to ensure good convergence
#     - C) To reduce the number of iterations
#     - D) To eliminate neurons that do not contribute
#     - **Answer: B) To start with reasonable initial weights to ensure good convergence**
#
# 26. **Which term describes a training process where the entire dataset is used to calculate the gradient before updating weights?**
#     - A) Stochastic Gradient Descent
#     - B) Batch Gradient Descent
#     - C) Mini-batch Gradient Descent
#     - D) Random Sampling
#     - **Answer: B) Batch Gradient Descent**
#
# 27. **Which of these can speed up convergence by adding a fraction of the previous update to the current weight update in backpropagation?**
#     - A) L2 Regularization
#     - B) Dropout
#     - C) Momentum
#     - D) Learning Rate Decay
#     - **Answer: C) Momentum**
#
# 28. **What is the purpose of using mini-batch gradient descent in backpropagation?**
#     - A) To avoid updating weights
#     - B) To find the exact gradient of the cost function
#     - C) To balance between the computational efficiency of batch gradient descent and the randomness of SGD
#     - D) To use the entire dataset in every iteration
#     - **Answer: C) To balance between the computational efficiency of batch gradient descent and the randomness of SGD**
#
# 29. **What is "learning rate decay" in backpropagation?**
#     - A) Increasing the learning rate at each step
#     - B) Decreasing the learning rate gradually to ensure convergence
#     - C) Randomly changing the learning rate
#     - D) Setting the learning rate to a fixed value
#     - **Answer: B) Decreasing the learning rate gradually to ensure convergence**
#
# 30. **How does adaptive gradient (AdaGrad) differ from basic gradient descent?**
#     - A) It keeps a constant learning rate
#     - B) It adapts the learning rate for each parameter based on previous updates
#     - C) It updates weights only for a subset of neurons
#     - D) It works only for binary classification problems
#     - **Answer: B) It adapts the learning rate for each parameter based on previous updates**

# %% [markdown]
# 31. **Which of the following is a major problem with using the sigmoid activation function in backpropagation?**
#    - A) High computational cost
#    - B) Leads to the vanishing gradient problem, especially in deep networks
#    - C) Not differentiable
#    - D) Produces only negative output
#    - **Answer: B) Leads to the vanishing gradient problem, especially in deep networks**
#
# 32. **How does ReLU help alleviate the vanishing gradient problem during backpropagation?**
#    - A) ReLU outputs are always negative
#    - B) ReLU outputs are constant
#    - C) ReLU allows gradients to pass through when inputs are positive, maintaining effective weight updates
#    - D) ReLU only works for shallow networks
#    - **Answer: C) ReLU allows gradients to pass through when inputs are positive, maintaining effective weight updates**
#
# 33. **Which of the following describes the process of backpropagation?**
#    - A) Forward propagating input data to get an output
#    - B) Calculating the loss and propagating it back to update the weights
#    - C) Randomly adjusting the weights
#    - D) Initializing the weights
#    - **Answer: B) Calculating the loss and propagating it back to update the weights**
#
# 34. **What role does the chain rule play in backpropagation?**
#    - A) It allows us to compute the partial derivatives needed to update the weights
#    - B) It initializes weights
#    - C) It computes forward propagation
#    - D) It increases the number of neurons
#    - **Answer: A) It allows us to compute the partial derivatives needed to update the weights**
#
# 35. **What is the main advantage of using mini-batch gradient descent?**
#    - A) Reduces computation time and helps in faster convergence compared to full-batch gradient descent
#    - B) Always provides the exact gradients
#    - C) Only works with small datasets
#    - D) No randomness in updating weights
#    - **Answer: A) Reduces computation time and helps in faster convergence compared to full-batch gradient descent**
#
# 36. **Which optimization algorithm adjusts the learning rate for each parameter based on the average of recent gradients?**
#    - A) Adam
#    - B) SGD
#    - C) AdaGrad
#    - D) ReLU
#    - **Answer: C) AdaGrad**
#
# 37. **What is the key difference between Adam and SGD in backpropagation?**
#    - A) Adam keeps a constant learning rate
#    - B) Adam adapts the learning rate individually for each parameter, while SGD keeps a fixed rate
#    - C) SGD uses adaptive rates while Adam does not
#    - D) SGD always converges faster
#    - **Answer: B) Adam adapts the learning rate individually for each parameter, while SGD keeps a fixed rate**
#
# 38. **What is the purpose of using weight initialization techniques like Xavier initialization in backpropagation?**
#    - A) To prevent weights from being zero
#    - B) To improve convergence by starting with reasonable initial values
#    - C) To increase the network's complexity
#    - D) To make the gradients constant
#    - **Answer: B) To improve convergence by starting with reasonable initial values**
#
# 39. **Which of the following optimization techniques combines both momentum and adaptive learning rate for faster convergence?**
#    - A) SGD with momentum
#    - B) Adam
#    - C) RMSprop
#    - D) Dropout
#    - **Answer: B) Adam**
#
# 40. **Why does using momentum in backpropagation help improve training?**
#    - A) It stops training early
#    - B) It adds a fraction of the previous weight change to the current update, reducing oscillation
#    - C) It increases the learning rate
#    - D) It decreases the number of neurons
#    - **Answer: B) It adds a fraction of the previous weight change to the current update, reducing oscillation**
#
# 41. **What happens if the learning rate is too small during backpropagation?**
#    - A) Training becomes very slow and might get stuck in a local minimum
#    - B) The model converges very quickly
#    - C) Weights oscillate between positive and negative values
#    - D) Model overfits immediately
#    - **Answer: A) Training becomes very slow and might get stuck in a local minimum**
#
# 42. **Which of these can help prevent overfitting during the training of a neural network?**
#    - A) Using dropout layers
#    - B) Increasing the number of epochs
#    - C) Removing neurons randomly
#    - D) Using linear activation functions
#    - **Answer: A) Using dropout layers**
#
# 43. **What is the primary purpose of L2 regularization in backpropagation?**
#    - A) Increase the number of hidden layers
#    - B) Add a penalty term to the loss to prevent large weight values
#    - C) Reduce training time
#    - D) Reduce the batch size
#    - **Answer: B) Add a penalty term to the loss to prevent large weight values**
#
# 44. **Which of the following describes gradient clipping?**
#    - A) Decreasing the number of hidden layers
#    - B) Limiting the value of gradients to prevent them from growing too large
#    - C) Adding additional neurons to the hidden layer
#    - D) Removing weights from the model
#    - **Answer: B) Limiting the value of gradients to prevent them from growing too large**
#
# 45. **How does the Adam optimizer adapt during training?**
#    - A) It keeps a constant learning rate
#    - B) It uses past gradients to adapt the learning rate for each parameter individually
#    - C) It removes neurons during training
#    - D) It eliminates backpropagation
#    - **Answer: B) It uses past gradients to adapt the learning rate for each parameter individually**
#
# 46. **What happens during the backpropagation process when an extremely high learning rate is used?**
#    - A) The model converges quickly and accurately
#    - B) The weights may oscillate, leading to a failure to converge
#    - C) The training error decreases continuously
#    - D) The model always overfits
#    - **Answer: B) The weights may oscillate, leading to a failure to converge**
#
# 47. **Which of these is a common issue encountered in deep networks during backpropagation?**
#    - A) Vanishing gradient problem
#    - B) Overcoming non-linear problems
#    - C) High activation function values
#    - D) Constant weights
#    - **Answer: A) Vanishing gradient problem**
#
# 48. **What is the effect of adding a momentum term to stochastic gradient descent (SGD)?**
#    - A) It increases training speed by adding the influence of previous weight updates
#    - B) It eliminates the learning rate
#    - C) It increases the likelihood of being stuck in local minima
#    - D) It decreases the complexity of the model
#    - **Answer: A) It increases training speed by adding the influence of previous weight updates**
#
# 49. **Which of the following describes the role of weight initialization techniques in deep learning?**
#    - A) They provide random weights to initialize the neurons
#    - B) They initialize weights to suitable values that prevent gradients from vanishing or exploding
#    - C) They reduce the training dataset size
#    - D) They remove overfitting from the model
#    - **Answer: B) They initialize weights to suitable values that prevent gradients from vanishing or exploding**
#
# 50. **Which activation function can prevent dead neurons and improve backpropagation in deep networks?**
#    - A) Sigmoid
#    - B) Tanh
#    - C) ReLU
#    - D) Step function
#    - **Answer: C) ReLU**
#
# 51. **What is a common effect of using the Tanh activation function in neural networks compared to Sigmoid?**
#    - A) Larger gradients leading to better weight updates
#    - B) Always outputs zero
#    - C) Produces only positive outputs
#    - D) Decreases the number of layers
#    - **Answer: A) Larger gradients leading to better weight updates**
#
# 52. **What does the term "exploding gradient" refer to during backpropagation?**
#    - A) Gradients becoming extremely large, leading to unstable updates
#    - B) Gradients disappearing completely
#    - C) Constant weights with no updates
#    - D) Gradients decreasing to zero
#    - **Answer: A) Gradients becoming extremely large, leading to unstable updates**
#
# 53. **Which optimizer combines the benefits of RMSprop and Momentum?**
#    - A) SGD
#    - B) Adam
#    - C) AdaGrad
#    - D) AdaDelta
#    - **Answer: B) Adam**
#
# 54. **What is the purpose of using RMSprop in neural network training?**
#    - A) To eliminate weight updates
#    - B) To use an adaptive learning rate for each parameter, ensuring faster convergence
#    - C) To increase the complexity of the network
#    - D) To remove neurons during training
#    - **Answer: B) To use an adaptive learning rate for each parameter, ensuring faster convergence**
#
# 55. **Which of the following is an advantage of using the Adam optimizer?**
#    - A) Constant learning rate
#    - B) Fast convergence by combining momentum and adaptive learning rate
#    - C) Requires less data
#    - D) Works only for binary classification problems
#    - **Answer: B) Fast convergence by combining momentum and adaptive learning rate**
#
# 56. **What is the effect of using learning rate decay during backpropagation?**
#    - A) It allows faster convergence in early stages while ensuring stable convergence later
#    - B) It eliminates the need for regularization
#    - C) It increases the value of gradients
#    - D) It keeps the learning rate constant
#    - **Answer: A) It allows faster convergence in early stages while ensuring stable convergence later**
#
# 57. **What is a disadvantage of using a fixed learning rate during backpropagation?**
#    - A) Requires fewer epochs
#    - B) May result in a suboptimal solution if the learning rate is not well-tuned
#    - C) Always leads to overfitting
#    - D) Eliminates the vanishing gradient problem
#    - **Answer: B) May result in a
#
#  suboptimal solution if the learning rate is not well-tuned**
#
# 58. **What is the primary reason for using dropout in neural networks?**
#    - A) Increase training time
#    - B) Reduce overfitting by ignoring random subsets of neurons during training
#    - C) Decrease the learning rate
#    - D) Increase the number of neurons in hidden layers
#    - **Answer: B) Reduce overfitting by ignoring random subsets of neurons during training**
#
# 59. **Which term describes the method of using a small subset of data to update the weights during backpropagation?**
#    - A) Mini-batch gradient descent
#    - B) Full-batch gradient descent
#    - C) Random descent
#    - D) Gradient clipping
#    - **Answer: A) Mini-batch gradient descent**
#
# 60. **How does adaptive gradient methods like AdaGrad affect the learning rate during training?**
#    - A) Increases the learning rate over time
#    - B) Keeps the learning rate constant
#    - C) Decreases the learning rate for parameters with larger updates
#    - D) Eliminates weight updates
#    - **Answer: C) Decreases the learning rate for parameters with larger updates**

# %% [markdown]
# 61. **What is the primary objective of gradient descent in backpropagation?**
#    - A) Minimize the error by updating weights in the direction of negative gradient
#    - B) Maximize the error rate
#    - C) Adjust the activation function
#    - D) Initialize weights randomly
#    - **Answer: A) Minimize the error by updating weights in the direction of negative gradient**
#
# 62. **Which of the following problems can be effectively addressed using gradient clipping?**
#    - A) Overfitting the training data
#    - B) Exploding gradients during backpropagation
#    - C) Vanishing gradients
#    - D) Increasing computational complexity
#    - **Answer: B) Exploding gradients during backpropagation**
#
# 63. **Which of these optimizers helps reduce the influence of steep, noisy gradients?**
#    - A) RMSprop
#    - B) SGD
#    - C) Random optimizer
#    - D) AdaGrad
#    - **Answer: A) RMSprop**
#
# 64. **What is the key reason for using momentum in optimization?**
#    - A) Avoid weight updates
#    - B) Smooth the direction of weight updates, making convergence faster
#    - C) Randomly select weights
#    - D) Reduce the number of epochs required
#    - **Answer: B) Smooth the direction of weight updates, making convergence faster**
#
# 65. **Which of the following activation functions can alleviate both the vanishing gradient and dead neuron problems?**
#    - A) ReLU
#    - B) Leaky ReLU
#    - C) Sigmoid
#    - D) Step function
#    - **Answer: B) Leaky ReLU**
#
# 66. **How does the Adam optimizer achieve fast convergence compared to traditional SGD?**
#    - A) By keeping a fixed learning rate
#    - B) By using adaptive learning rates and momentum for each parameter
#    - C) By ignoring gradients
#    - D) By updating weights only once
#    - **Answer: B) By using adaptive learning rates and momentum for each parameter**
#
# 67. **Which type of learning rate is more likely to skip over the optimal solution in backpropagation?**
#    - A) Small learning rate
#    - B) Adaptive learning rate
#    - C) Extremely large learning rate
#    - D) Decreasing learning rate
#    - **Answer: C) Extremely large learning rate**
#
# 68. **What is the key benefit of using mini-batch gradient descent over full-batch gradient descent?**
#    - A) Always increases accuracy
#    - B) More computationally efficient and converges faster by balancing computational cost and randomness
#    - C) Reduces memory usage only
#    - D) Provides the exact solution to the cost function
#    - **Answer: B) More computationally efficient and converges faster by balancing computational cost and randomness**
#
# 69. **Which of the following is a common problem when using the sigmoid activation function in deep networks?**
#    - A) Gradients become very small, making learning difficult
#    - B) Gradients grow exponentially
#    - C) No effect on gradients
#    - D) It works well for deep networks
#    - **Answer: A) Gradients become very small, making learning difficult**
#
# 70. **How can L2 regularization be used to improve backpropagation?**
#    - A) By penalizing large weights, reducing model complexity and overfitting
#    - B) By increasing the number of neurons
#    - C) By reducing training time
#    - D) By eliminating hidden layers
#    - **Answer: A) By penalizing large weights, reducing model complexity and overfitting**
#
# 71. **What is the difference between L1 and L2 regularization in backpropagation?**
#    - A) L1 penalizes weight magnitude, while L2 penalizes the sum of the weights
#    - B) L1 penalizes based on the absolute value of weights, while L2 penalizes based on squared weight values
#    - C) L1 increases the weight values
#    - D) L2 reduces the size of the dataset
#    - **Answer: B) L1 penalizes based on the absolute value of weights, while L2 penalizes based on squared weight values**
#
# 72. **Which optimizer would you choose if you want to prevent oscillations during training and ensure faster convergence?**
#    - A) SGD without momentum
#    - B) SGD with momentum
#    - C) Full-batch gradient descent
#    - D) ReLU optimizer
#    - **Answer: B) SGD with momentum**
#
# 73. **Which of the following can help prevent dead neurons during the training of a neural network?**
#    - A) Using ReLU carefully or switching to Leaky ReLU
#    - B) Reducing the learning rate
#    - C) Using more hidden layers
#    - D) Using L1 regularization only
#    - **Answer: A) Using ReLU carefully or switching to Leaky ReLU**
#
# 74. **What is the role of the learning rate schedule in backpropagation?**
#    - A) To increase the size of the dataset
#    - B) To vary the learning rate over time, ensuring faster learning at the beginning and stable convergence later
#    - C) To keep the learning rate constant
#    - D) To prevent vanishing gradients
#    - **Answer: B) To vary the learning rate over time, ensuring faster learning at the beginning and stable convergence later**
#
# 75. **Which of the following statements describes AdaGrad's behavior during training?**
#    - A) Keeps the learning rate constant
#    - B) Adapts learning rates for each parameter by accumulating the squared gradients
#    - C) Does not work for sparse data
#    - D) Eliminates the need for backpropagation
#    - **Answer: B) Adapts learning rates for each parameter by accumulating the squared gradients**
#
# 76. **Which problem arises when weights in a neural network are initialized to zero?**
#    - A) Slow convergence
#    - B) All neurons in each layer learn the same features
#    - C) The learning rate is increased
#    - D) It eliminates gradients
#    - **Answer: B) All neurons in each layer learn the same features**
#
# 77. **Which optimization technique uses both exponentially decaying average of past gradients and gradient squares for better convergence?**
#    - A) SGD
#    - B) Adam
#    - C) Gradient clipping
#    - D) Batch Normalization
#    - **Answer: B) Adam**
#
# 78. **How does batch normalization improve neural network training?**
#    - A) By removing overfitting completely
#    - B) By normalizing the input of each layer to improve stability and speed of convergence
#    - C) By initializing all weights to zero
#    - D) By reducing the number of hidden layers
#    - **Answer: B) By normalizing the input of each layer to improve stability and speed of convergence**
#
# 79. **Which of these describes the "bias correction" term used in the Adam optimizer?**
#    - A) To remove neurons
#    - B) To initialize weights to a high value
#    - C) To adjust the estimates of the mean and variance during early iterations
#    - D) To reduce computation time
#    - **Answer: C) To adjust the estimates of the mean and variance during early iterations**
#
# 80. **Why is weight decay often used in conjunction with backpropagation?**
#    - A) To speed up convergence
#    - B) To prevent overfitting by applying a regularization term to the weights
#    - C) To increase model complexity
#    - D) To add more hidden layers
#    - **Answer: B) To prevent overfitting by applying a regularization term to the weights**
#
# 81. **Which gradient descent variant is used when weight updates are performed after every single training example?**
#    - A) Full-batch gradient descent
#    - B) Mini-batch gradient descent
#    - C) Stochastic Gradient Descent (SGD)
#    - D) Conjugate Gradient Descent
#    - **Answer: C) Stochastic Gradient Descent (SGD)**
#
# 82. **Which of the following can happen if the learning rate decay is set too aggressively?**
#    - A) The learning rate stays constant
#    - B) The model may converge too slowly or get stuck in a local minimum
#    - C) The model always converges faster
#    - D) Gradients vanish completely
#    - **Answer: B) The model may converge too slowly or get stuck in a local minimum**
#
# 83. **Which of the following is an advantage of using ReLU as the activation function during backpropagation?**
#    - A) It avoids the vanishing gradient problem
#    - B) It keeps weights constant
#    - C) It always produces negative outputs
#    - D) It increases overfitting
#    - **Answer: A) It avoids the vanishing gradient problem**
#
# 84. **What is the main purpose of using the Softmax function in backpropagation?**
#    - A) Normalize the outputs into probability values between 0 and 1
#    - B) Remove neurons that contribute less
#    - C) Increase the learning rate
#    - D) Reduce the output to a single value
#    - **Answer: A) Normalize the outputs into probability values between 0 and 1**
#
# 85. **How does learning rate scheduling improve model performance during backpropagation?**
#    - A) Keeps learning rate constant
#    - B) Adjusts learning rate over time, allowing faster learning initially and stability later on
#    - C) Removes the need for training data
#    - D) Eliminates the need for hidden layers
#    - **Answer: B) Adjusts learning rate over time, allowing faster learning initially and stability later on**
#
# 86. **Which of the following helps to mitigate the exploding gradient problem in backpropagation?**
#    - A) L1 regularization
#    - B) Gradient clipping
#    - C) Dropout
#    - D) Adding hidden layers
#    - **Answer: B) Gradient clipping**
#
# 87. **What does "weight decay" refer to in optimization?**
#    - A) A regularization technique that reduces the value of weights to prevent overfitting
#    - B) A method to increase learning rate
#    - C) The removal of hidden layers
#    - D) Eliminating biases during training
#    - **Answer: A) A regularization technique that reduces the value of weights to prevent overfitting**
#
# 88. **Which type of optimizer would you use for faster convergence in deep neural networks?**
#    - A) SGD without momentum
#    - B) Adam
#    - C) Conjugate Gradient
#    - D) Simulated Annealing
#    - **Answer: B) Adam**
#
# 89. **How can batch normalization help in mitigating the vanishing gradient problem?**
#    - A) By initializing weights to zero
#    - B) By normalizing the inputs to each layer, leading to better gradients
#    - C) By removing hidden layers
#    - D) By decreasing the learning rate
#    - **Answer: B) By normalizing the inputs to each layer, leading to better gradients**
#
# 90. **Which approach is used to improve the stability and speed of backpropagation in Recurrent Neural Networks (RNNs)?**
#    - A) Gradient Clipping
#    - B) Removing biases
#    - C) Increasing the number of epochs
#    - D) Decreasing learning rate to zero
#    - **Answer: A) Gradient Clipping**
#
# 91. **What is a benefit of using the Leaky ReLU activation
#
#  function instead of ReLU?**
#    - A) Always keeps the output positive
#    - B) Prevents neurons from dying by allowing a small, non-zero gradient for negative inputs
#    - C) Reduces training time
#    - D) Works only for shallow networks
#    - **Answer: B) Prevents neurons from dying by allowing a small, non-zero gradient for negative inputs**
#
# 92. **What does the term "momentum" refer to in gradient-based optimization?**
#    - A) Adding randomness to the learning rate
#    - B) Accumulating a fraction of the previous weight update to smooth the current gradient
#    - C) Eliminating the need for biases
#    - D) Decreasing the learning rate to zero
#    - **Answer: B) Accumulating a fraction of the previous weight update to smooth the current gradient**
#
# 93. **Which regularization technique can be used to prevent neural networks from relying too heavily on individual neurons?**
#    - A) Dropout
#    - B) Gradient Clipping
#    - C) Full-batch Gradient Descent
#    - D) Increasing learning rate
#    - **Answer: A) Dropout**
#
# 94. **Which of these optimization algorithms uses momentum and adaptive learning rates for each parameter?**
#    - A) AdaGrad
#    - B) Adam
#    - C) RMSprop
#    - D) Gradient Boosting
#    - **Answer: B) Adam**
#
# 95. **What does an extremely low learning rate result in during training?**
#    - A) Faster convergence
#    - B) Slow training and difficulty in reaching the optimal solution
#    - C) Eliminates hidden layers
#    - D) Ensures overfitting
#    - **Answer: B) Slow training and difficulty in reaching the optimal solution**
#
# 96. **What does the term "bias" mean in the context of backpropagation?**
#    - A) A term added to the activation to allow flexibility in movement
#    - B) A method to reduce the number of neurons
#    - C) A way to increase the learning rate
#    - D) A parameter that keeps the weights constant
#    - **Answer: A) A term added to the activation to allow flexibility in movement**
#
# 97. **Which of these is used to convert a multi-class output to probability values during backpropagation?**
#    - A) Softmax function
#    - B) ReLU activation
#    - C) Linear transformation
#    - D) Identity function
#    - **Answer: A) Softmax function**
#
# 98. **How does the RMSprop optimizer handle different learning rates?**
#    - A) Keeps the learning rate constant
#    - B) Adapts learning rates by dividing the gradient by an exponentially decaying average of past squared gradients
#    - C) Ignores previous gradients
#    - D) Keeps weights constant
#    - **Answer: B) Adapts learning rates by dividing the gradient by an exponentially decaying average of past squared gradients**
#
# 99. **What is the primary advantage of using learning rate decay?**
#    - A) Keeps the learning rate constant
#    - B) Increases the learning rate over time
#    - C) Ensures stable convergence by gradually decreasing the learning rate as training progresses
#    - D) Eliminates biases
#    - **Answer: C) Ensures stable convergence by gradually decreasing the learning rate as training progresses**
#
# 100. **What is the benefit of using Xavier (Glorot) initialization in backpropagation?**
#     - A) Prevents the vanishing and exploding gradient problems by ensuring variance is maintained across layers
#     - B) Eliminates biases
#     - C) Ensures all weights are zero
#     - D) Reduces training data size
#     - **Answer: A) Prevents the vanishing and exploding gradient problems by ensuring variance is maintained across layers**

# %% [markdown]
# ### **Lecture 6: Applications of Artificial Neural Networks**
#
# 1. **Which of the following is a common application of artificial neural networks (ANNs)?**
#    - A) Image recognition
#    - B) Sorting numbers
#    - C) File compression
#    - D) Simple addition
#    - **Answer: A) Image recognition**
#
# 2. **How are ANNs used in natural language processing (NLP)?**
#    - A) For identifying the shortest path
#    - B) For translating between languages automatically
#    - C) For reducing computation time
#    - D) For manual speech labeling
#    - **Answer: B) For translating between languages automatically**
#
# 3. **Which of the following is a use case of neural networks in healthcare?**
#    - A) Diagnosing diseases based on image data
#    - B) Managing patient records
#    - C) Creating medical supply chains
#    - D) Transcribing doctor's notes manually
#    - **Answer: A) Diagnosing diseases based on image data**
#
# 4. **What kind of neural network is commonly used for image recognition tasks?**
#    - A) Convolutional Neural Network (CNN)
#    - B) Recurrent Neural Network (RNN)
#    - C) Multi-Layer Perceptron (MLP)
#    - D) Single-Layer Perceptron
#    - **Answer: A) Convolutional Neural Network (CNN)**
#
# 5. **Which application uses Recurrent Neural Networks (RNNs) extensively?**
#    - A) Image classification
#    - B) Speech recognition and language modeling
#    - C) Numerical sorting
#    - D) Calculating mathematical equations
#    - **Answer: B) Speech recognition and language modeling**
#
# 6. **In which field are ANNs used for customer segmentation?**
#    - A) Retail and e-commerce
#    - B) Healthcare
#    - C) Manufacturing
#    - D) Civil engineering
#    - **Answer: A) Retail and e-commerce**
#
# 7. **How are neural networks used in financial forecasting?**
#    - A) Predicting weather patterns
#    - B) Predicting stock market trends and risk assessment
#    - C) Finding the shortest route between two points
#    - D) Creating financial reports
#    - **Answer: B) Predicting stock market trends and risk assessment**
#
# 8. **Which type of neural network is often used in self-driving cars?**
#    - A) CNN for recognizing road signs and pedestrians
#    - B) RNN for recognizing pedestrian movements
#    - C) MLP for mapping simple routes
#    - D) Radial Basis Function Network
#    - **Answer: A) CNN for recognizing road signs and pedestrians**
#
# 9. **What role do neural networks play in fraud detection?**
#    - A) They help process transactions faster
#    - B) They analyze patterns to detect anomalies in financial data
#    - C) They reduce the number of required transaction records
#    - D) They physically block fraudulent transactions
#    - **Answer: B) They analyze patterns to detect anomalies in financial data**
#
# 10. **Which of the following neural network architectures is used in language translation applications like Google Translate?**
#     - A) Recurrent Neural Networks (RNN)
#     - B) Convolutional Neural Networks (CNN)
#     - C) Radial Basis Networks
#     - D) Hopfield Network
#     - **Answer: A) Recurrent Neural Networks (RNN)**
#
# 11. **Which type of ANN is used to generate text, such as chatbots and virtual assistants?**
#     - A) Recurrent Neural Networks (RNN)
#     - B) Convolutional Neural Networks (CNN)
#     - C) Hopfield Networks
#     - D) Boltzmann Machines
#     - **Answer: A) Recurrent Neural Networks (RNN)**
#
# 12. **In which domain are ANNs commonly used for image segmentation?**
#     - A) Healthcare for identifying cancerous regions
#     - B) Retail for managing products
#     - C) Finance for detecting fraud
#     - D) Logistics for packaging
#     - **Answer: A) Healthcare for identifying cancerous regions**
#
# 13. **Which application of ANNs is related to object recognition in images?**
#     - A) Predicting weather
#     - B) Detecting faces in photos
#     - C) Sorting customer reviews
#     - D) Reducing supply chain costs
#     - **Answer: B) Detecting faces in photos**
#
# 14. **How are ANNs used in autonomous vehicles?**
#     - A) They help identify road signs and pedestrians
#     - B) They perform simple addition and subtraction
#     - C) They convert speech to text
#     - D) They power the vehicle's engine
#     - **Answer: A) They help identify road signs and pedestrians**
#
# 15. **Which type of neural network is suitable for time-series prediction, such as weather forecasting?**
#     - A) Recurrent Neural Networks (RNN)
#     - B) Convolutional Neural Networks (CNN)
#     - C) Single-Layer Perceptron
#     - D) Radial Basis Function Network
#     - **Answer: A) Recurrent Neural Networks (RNN)**
#
# 16. **What type of ANN is used in Generative Adversarial Networks (GANs) for generating new data?**
#     - A) Convolutional Neural Networks (CNN)
#     - B) Generator and discriminator networks
#     - C) Radial Basis Function Networks
#     - D) Hopfield Networks
#     - **Answer: B) Generator and discriminator networks**
#
# 17. **Which neural network application helps in identifying specific breeds of dogs in images?**
#     - A) Convolutional Neural Networks (CNN)
#     - B) RNN
#     - C) MLP
#     - D) Hopfield Networks
#     - **Answer: A) Convolutional Neural Networks (CNN)**
#
# 18. **How are ANNs applied in the field of energy?**
#     - A) Predicting power consumption patterns
#     - B) Sorting electricity bills
#     - C) Printing energy reports
#     - D) Manually analyzing energy use
#     - **Answer: A) Predicting power consumption patterns**
#
# 19. **Which of the following neural network models is best suited for speech recognition tasks?**
#     - A) Recurrent Neural Networks (RNN)
#     - B) Radial Basis Function Networks
#     - C) Hopfield Networks
#     - D) Convolutional Neural Networks (CNN)
#     - **Answer: A) Recurrent Neural Networks (RNN)**
#
# 20. **In the context of neural networks, how is sentiment analysis performed?**
#     - A) Using CNN to identify object outlines
#     - B) Using RNN to understand sequences of text and classify sentiments
#     - C) Using MLP for calculating averages
#     - D) Using feedforward networks for predicting numbers
#     - **Answer: B) Using RNN to understand sequences of text and classify sentiments**
#
# 21. **How can ANNs be used in recommendation systems like Netflix or Amazon?**
#     - A) By predicting user preferences based on past interactions
#     - B) By displaying random advertisements
#     - C) By identifying content manually
#     - D) By sorting the content alphabetically
#     - **Answer: A) By predicting user preferences based on past interactions**
#
# 22. **Which neural network application is used to predict customer churn in a subscription-based service?**
#     - A) Classification with an MLP
#     - B) Segmentation with CNN
#     - C) Reinforcement learning
#     - D) Regression with RNN
#     - **Answer: A) Classification with an MLP**
#
# 23. **How are ANNs used in gaming?**
#     - A) To calculate game points
#     - B) To create intelligent characters that adapt based on the player's actions
#     - C) To produce high-quality graphics
#     - D) To load game content faster
#     - **Answer: B) To create intelligent characters that adapt based on the player's actions**
#
# 24. **Which type of ANN is often used in medical imaging for cancer detection?**
#     - A) Convolutional Neural Networks (CNN)
#     - B) Recurrent Neural Networks (RNN)
#     - C) Multi-Layer Perceptron (MLP)
#     - D) Hopfield Network
#     - **Answer: A) Convolutional Neural Networks (CNN)**
#
# 25. **Which application of ANNs helps in analyzing satellite imagery for agriculture?**
#     - A) Identifying crop health using image classification with CNN
#     - B) Forecasting stock prices
#     - C) Monitoring energy consumption
#     - D) Translating spoken languages
#     - **Answer: A) Identifying crop health using image classification with CNN**
#
# 26. **What role do ANNs play in real estate price prediction?**
#     - A) They calculate averages manually
#     - B) They predict property prices based on features like location, size, and amenities
#     - C) They identify buyers and sellers
#     - D) They create advertisements
#     - **Answer: B) They predict property prices based on features like location, size, and amenities**
#
# 27. **Which of the following is an example of using ANNs in transportation?**
#     - A) Optimizing vehicle routes for efficient delivery
#     - B) Creating traffic signals
#     - C) Manual car driving
#     - D) Printing traffic reports
#     - **Answer: A) Optimizing vehicle routes for efficient delivery**
#
# 28. **How do ANNs contribute to spam detection in emails?**
#     - A) They classify incoming emails as spam or not spam based on content patterns
#     - B) They delete all incoming emails
#     - C) They encrypt email content
#     - D) They sort emails alphabetically
#     - **Answer: A) They classify incoming emails as spam or not spam based on content patterns**
#
# 29. **Which neural network architecture is best for translating a video’s spoken content into text?**
#     - A) Recurrent Neural Networks (RNN)
#     - B) Convolutional Neural Networks (CNN)
#     - C) Hopfield Networks
#     - D) Radial Basis Function Networks
#     - **Answer: A) Recurrent Neural Networks (RNN)**
#
# 30. **How do ANNs assist in handwriting recognition tasks?**
#     - A) Using CNN to identify handwritten characters and classify them correctly
#     - B) By clustering data points
#     - C) By manually identifying strokes
#     - D) By creating random labels
#     - **Answer: A) Using CNN to identify handwritten characters and classify them correctly**

# %% [markdown]
# 31. **Which type of neural network is frequently used in the field of anomaly detection, such as in cybersecurity?**
#    - A) Autoencoder Networks
#    - B) Radial Basis Networks
#    - C) Convolutional Neural Networks (CNN)
#    - D) Single-Layer Perceptron
#    - **Answer: A) Autoencoder Networks**
#
# 32. **How do ANNs contribute to retail inventory management?**
#    - A) They predict customer footfall
#    - B) They forecast demand to optimize stock levels
#    - C) They calculate discounts on products
#    - D) They manually organize products on shelves
#    - **Answer: B) They forecast demand to optimize stock levels**
#
# 33. **What is an example of using ANNs for optical character recognition (OCR)?**
#    - A) Identifying objects in an image
#    - B) Extracting text from a scanned document
#    - C) Predicting financial trends
#    - D) Analyzing market competition
#    - **Answer: B) Extracting text from a scanned document**
#
# 34. **How are ANNs used in the domain of customer service?**
#    - A) To manually connect customers with agents
#    - B) To power chatbots that assist customers by understanding their queries and providing responses
#    - C) To send automatic reminders for payments
#    - D) To manually store call logs
#    - **Answer: B) To power chatbots that assist customers by understanding their queries and providing responses**
#
# 35. **Which neural network architecture is typically used for generating new images, such as for artistic content?**
#    - A) Generative Adversarial Networks (GANs)
#    - B) Radial Basis Function Networks
#    - C) Multi-Layer Perceptron (MLP)
#    - D) Hopfield Networks
#    - **Answer: A) Generative Adversarial Networks (GANs)**
#
# 36. **What kind of data is used by ANNs in weather prediction applications?**
#    - A) Historical weather data like temperature, pressure, and humidity
#    - B) Customer reviews
#    - C) Financial records
#    - D) Handwritten text
#    - **Answer: A) Historical weather data like temperature, pressure, and humidity**
#
# 37. **Which neural network model is used in Google’s voice search feature for understanding and processing spoken language?**
#    - A) Recurrent Neural Networks (RNN)
#    - B) Convolutional Neural Networks (CNN)
#    - C) Radial Basis Function Network
#    - D) Feedforward Networks
#    - **Answer: A) Recurrent Neural Networks (RNN)**
#
# 38. **Which application uses ANNs for detecting and classifying road conditions?**
#    - A) Autonomous vehicle systems
#    - B) Financial analytics
#    - C) Customer segmentation
#    - D) Stock market prediction
#    - **Answer: A) Autonomous vehicle systems**
#
# 39. **Which application of ANNs is used to forecast electricity consumption?**
#    - A) Time series forecasting using RNNs
#    - B) Image segmentation using CNNs
#    - C) Text generation using GANs
#    - D) Dimensionality reduction using PCA
#    - **Answer: A) Time series forecasting using RNNs**
#
# 40. **How are ANNs used in drug discovery?**
#    - A) Predicting potential drug compounds through complex data analysis
#    - B) Calculating manufacturing costs
#    - C) Sorting drugs based on type
#    - D) Printing prescription information
#    - **Answer: A) Predicting potential drug compounds through complex data analysis**
#
# 41. **Which of the following applications uses neural networks for automatic number plate recognition (ANPR)?**
#    - A) Convolutional Neural Networks (CNN) for character recognition
#    - B) RNN for sequence prediction
#    - C) Hopfield Network for optimization
#    - D) Radial Basis Function Network for clustering
#    - **Answer: A) Convolutional Neural Networks (CNN) for character recognition**
#
# 42. **What role do ANNs play in agriculture through precision farming?**
#    - A) Forecasting optimal irrigation schedules using data analysis
#    - B) Manually planting seeds
#    - C) Printing soil health reports
#    - D) Monitoring energy consumption in farming equipment
#    - **Answer: A) Forecasting optimal irrigation schedules using data analysis**
#
# 43. **How are ANNs used in traffic management systems?**
#    - A) By analyzing real-time traffic data to predict and reduce congestion
#    - B) By monitoring pedestrian crossings manually
#    - C) By optimizing manufacturing processes
#    - D) By sorting cars based on speed
#    - **Answer: A) By analyzing real-time traffic data to predict and reduce congestion**
#
# 44. **Which of the following is an example of using ANNs in personalized marketing?**
#    - A) Recommending products based on a user’s previous purchases
#    - B) Sorting customer emails
#    - C) Manually calculating product discounts
#    - D) Randomly showing product ads
#    - **Answer: A) Recommending products based on a user’s previous purchases**
#
# 45. **What kind of ANN is typically used to improve facial recognition in security systems?**
#    - A) Convolutional Neural Networks (CNN)
#    - B) Radial Basis Networks
#    - C) Hopfield Networks
#    - D) Recurrent Neural Networks (RNN)
#    - **Answer: A) Convolutional Neural Networks (CNN)**
#
# 46. **How are neural networks applied in the automotive industry for predictive maintenance?**
#    - A) Predicting potential machine failures before they occur
#    - B) Sorting spare parts manually
#    - C) Calculating fuel efficiency
#    - D) Creating advertisements for vehicles
#    - **Answer: A) Predicting potential machine failures before they occur**
#
# 47. **Which type of neural network architecture is well-suited for detecting tumors in medical images?**
#    - A) Convolutional Neural Networks (CNN)
#    - B) Recurrent Neural Networks (RNN)
#    - C) Hopfield Networks
#    - D) Multi-Layer Perceptron (MLP)
#    - **Answer: A) Convolutional Neural Networks (CNN)**
#
# 48. **How do ANNs help in natural disaster prediction?**
#    - A) By analyzing time-series data to predict earthquakes and hurricanes
#    - B) By predicting weather patterns only
#    - C) By manually assessing satellite images
#    - D) By monitoring energy consumption
#    - **Answer: A) By analyzing time-series data to predict earthquakes and hurricanes**
#
# 49. **What is an application of ANNs in human resources?**
#    - A) Screening resumes automatically based on predefined criteria
#    - B) Printing salary slips
#    - C) Arranging interview schedules manually
#    - D) Assigning office equipment
#    - **Answer: A) Screening resumes automatically based on predefined criteria**
#
# 50. **Which neural network architecture is frequently used in creating smart home assistants like Alexa or Google Assistant?**
#    - A) Recurrent Neural Networks (RNN)
#    - B) Hopfield Networks
#    - C) Radial Basis Networks
#    - D) Generative Adversarial Networks (GANs)
#    - **Answer: A) Recurrent Neural Networks (RNN)**
#
# 51. **Which ANN model is used to generate realistic-looking fake images, such as for face aging apps?**
#    - A) Generative Adversarial Networks (GANs)
#    - B) Recurrent Neural Networks (RNN)
#    - C) Hopfield Networks
#    - D) Radial Basis Networks
#    - **Answer: A) Generative Adversarial Networks (GANs)**
#
# 52. **How are ANNs applied in handwriting analysis for forensics?**
#    - A) To detect the author of handwritten content using pattern recognition
#    - B) To manually sort handwriting samples
#    - C) To encrypt forensic reports
#    - D) To classify document types
#    - **Answer: A) To detect the author of handwritten content using pattern recognition**
#
# 53. **What role do ANNs play in e-commerce price optimization?**
#    - A) They manually calculate prices
#    - B) They recommend optimal pricing strategies by analyzing consumer behavior and competition
#    - C) They randomly select prices
#    - D) They reduce product features
#    - **Answer: B) They recommend optimal pricing strategies by analyzing consumer behavior and competition**
#
# 54. **Which neural network architecture is used to identify musical genres based on audio features?**
#    - A) Convolutional Neural Networks (CNN)
#    - B) Multi-Layer Perceptron (MLP)
#    - C) Recurrent Neural Networks (RNN)
#    - D) Hopfield Networks
#    - **Answer: A) Convolutional Neural Networks (CNN)**
#
# 55. **How can ANNs contribute to diagnosing neurological disorders?**
#    - A) By analyzing EEG signals using pattern detection algorithms
#    - B) By randomly assigning a disorder
#    - C) By encrypting medical records
#    - D) By diagnosing without any data
#    - **Answer: A) By analyzing EEG signals using pattern detection algorithms**
#
# 56. **Which of the following is an example of using ANNs in social media analytics?**
#    - A) Sentiment analysis of user comments
#    - B) Sending friend requests
#    - C) Encrypting user posts
#    - D) Printing user activity reports
#    - **Answer: A) Sentiment analysis of user comments**
#
# 57. **Which ANN-based model is used to predict upcoming words in a text, such as in predictive keyboards?**
#    - A) Recurrent Neural Networks (RNN)
#    - B) Hopfield Networks
#    - C) Multi-Layer Perceptron (MLP)
#    - D) Radial Basis Networks
#    - **Answer: A) Recurrent Neural Networks (RNN)**
#
# 58. **How are ANNs used to create deepfake videos?**
#    - A) Using GANs to generate manipulated videos that appear real
#    - B) Using RNNs to predict sequences
#    - C) Using MLP to classify video frames
#    - D) Using Hopfield Networks for clustering
#    - **Answer: A) Using GANs to generate manipulated videos that appear real**
#
# 59. **What kind of ANN is used to generate recommendations for online shopping websites?**
#    - A) Collaborative filtering models with MLPs
#    - B) Generative Adversarial Networks (GANs)
#    - C) Hopfield Networks
#    - D) Single-layer Perceptrons
#    - **Answer: A) Collaborative filtering models with MLPs**
#
# 60. **Which neural network architecture can be used to automatically summarize large text documents?**
#    - A) Recurrent Neural Networks (RNN) or Transformers
#    - B) Convolutional Neural Networks (CNN)
#    - C) Hopfield Networks
#    - D) Radial Basis Function Networks
#    - **Answer: A) Recurrent Neural Networks (RNN) or Transformers**

# %% [markdown]
# 61. **Which type of ANN can be used for style transfer in images, such as transferring the style of a famous painting to a photo?**
#    - A) Convolutional Neural Networks (CNN)
#    - B) Recurrent Neural Networks (RNN)
#    - C) Multi-Layer Perceptron (MLP)
#    - D) Hopfield Networks
#    - **Answer: A) Convolutional Neural Networks (CNN)**
#
# 62. **How do ANNs contribute to financial fraud detection in the banking industry?**
#    - A) By recognizing unusual patterns or transactions that differ significantly from the normal behavior
#    - B) By monitoring customer service interactions
#    - C) By manually checking all transactions
#    - D) By creating random alerts
#    - **Answer: A) By recognizing unusual patterns or transactions that differ significantly from the normal behavior**
#
# 63. **What role do ANNs play in generating personalized content recommendations on streaming platforms?**
#    - A) Analyzing viewing history and predicting user preferences
#    - B) Displaying random videos
#    - C) Organizing content alphabetically
#    - D) Manually selecting content for users
#    - **Answer: A) Analyzing viewing history and predicting user preferences**
#
# 64. **Which of the following applications of ANNs helps convert spoken words to text?**
#    - A) Speech-to-text using Recurrent Neural Networks (RNN)
#    - B) Text classification using CNN
#    - C) Image segmentation using GANs
#    - D) Object detection using MLP
#    - **Answer: A) Speech-to-text using Recurrent Neural Networks (RNN)**
#
# 65. **How are ANNs used to identify emotions in spoken language?**
#    - A) By analyzing audio features and patterns using RNNs
#    - B) By calculating word frequency
#    - C) By sorting audio files alphabetically
#    - D) By converting text into emojis
#    - **Answer: A) By analyzing audio features and patterns using RNNs**
#
# 66. **Which of the following ANN applications helps in predicting traffic flow in urban areas?**
#    - A) Time series forecasting using RNNs
#    - B) Image classification using CNN
#    - C) Generative modeling using GANs
#    - D) Random forest classification
#    - **Answer: A) Time series forecasting using RNNs**
#
# 67. **Which neural network is commonly used to detect credit card fraud based on user behavior analysis?**
#    - A) Recurrent Neural Networks (RNN)
#    - B) Convolutional Neural Networks (CNN)
#    - C) Hopfield Networks
#    - D) Autoencoders
#    - **Answer: D) Autoencoders**
#
# 68. **How do ANNs assist in customer feedback analysis?**
#    - A) Using sentiment analysis to determine whether feedback is positive, negative, or neutral
#    - B) By sorting feedback randomly
#    - C) By encrypting user feedback
#    - D) By manually evaluating the content
#    - **Answer: A) Using sentiment analysis to determine whether feedback is positive, negative, or neutral**
#
# 69. **What is the purpose of using neural networks for automated image captioning?**
#    - A) To generate descriptive captions for images by analyzing their contents
#    - B) To encrypt the images
#    - C) To classify images as spam
#    - D) To remove images with lower resolution
#    - **Answer: A) To generate descriptive captions for images by analyzing their contents**
#
# 70. **Which ANN model is commonly used in robotics for path planning?**
#    - A) Reinforcement Learning models
#    - B) Convolutional Neural Networks (CNN)
#    - C) Hopfield Networks
#    - D) Radial Basis Function Networks
#    - **Answer: A) Reinforcement Learning models**
#
# 71. **How are neural networks used in spam filtering?**
#    - A) To classify emails based on word patterns and block unwanted emails
#    - B) To encrypt email data
#    - C) To sort emails by sender
#    - D) To delete all emails
#    - **Answer: A) To classify emails based on word patterns and block unwanted emails**
#
# 72. **How do neural networks contribute to targeted advertising?**
#    - A) By analyzing user behavior and displaying relevant ads to specific users
#    - B) By displaying random advertisements
#    - C) By manually categorizing users
#    - D) By printing advertisements for newspapers
#    - **Answer: A) By analyzing user behavior and displaying relevant ads to specific users**
#
# 73. **Which of the following is an example of using neural networks in game development?**
#    - A) AI-driven non-player characters (NPCs) that adapt to player behavior
#    - B) Manual level design
#    - C) Printing game manuals
#    - D) Manually moving player avatars
#    - **Answer: A) AI-driven non-player characters (NPCs) that adapt to player behavior**
#
# 74. **How are ANNs used in fingerprint recognition?**
#    - A) Convolutional Neural Networks (CNN) are used to classify fingerprint patterns
#    - B) By sorting fingerprints manually
#    - C) By printing fingerprints on paper
#    - D) By encrypting fingerprint data
#    - **Answer: A) Convolutional Neural Networks (CNN) are used to classify fingerprint patterns**
#
# 75. **What type of ANN is often used for predicting stock market trends?**
#    - A) Recurrent Neural Networks (RNN)
#    - B) Convolutional Neural Networks (CNN)
#    - C) Radial Basis Function Networks
#    - D) Hopfield Networks
#    - **Answer: A) Recurrent Neural Networks (RNN)**
#
# 76. **How are ANNs utilized in real-time language translation applications?**
#    - A) RNNs and Transformers are used for translating spoken language between different languages
#    - B) By manually translating each sentence
#    - C) By sorting words alphabetically
#    - D) By creating random sentences
#    - **Answer: A) RNNs and Transformers are used for translating spoken language between different languages**
#
# 77. **Which ANN architecture is used for generating artistic content, such as digital paintings or music?**
#    - A) Generative Adversarial Networks (GANs)
#    - B) Recurrent Neural Networks (RNN)
#    - C) Multi-Layer Perceptron (MLP)
#    - D) Hopfield Networks
#    - **Answer: A) Generative Adversarial Networks (GANs)**
#
# 78. **How are ANNs applied in predictive text entry, such as smartphone keyboards?**
#    - A) By predicting the next word using Recurrent Neural Networks (RNN)
#    - B) By sorting letters alphabetically
#    - C) By removing unnecessary words
#    - D) By encrypting user input
#    - **Answer: A) By predicting the next word using Recurrent Neural Networks (RNN)**
#
# 79. **Which type of neural network is often used for clustering customers based on purchasing behavior?**
#    - A) Self-Organizing Maps (SOM)
#    - B) Recurrent Neural Networks (RNN)
#    - C) Multi-Layer Perceptron (MLP)
#    - D) Hopfield Networks
#    - **Answer: A) Self-Organizing Maps (SOM)**
#
# 80. **How do ANNs contribute to improving the quality of photographs and videos?**
#    - A) By using Super-Resolution techniques with Convolutional Neural Networks (CNN)
#    - B) By encrypting image data
#    - C) By removing all details from images
#    - D) By reducing the resolution of images
#    - **Answer: A) By using Super-Resolution techniques with Convolutional Neural Networks (CNN)**
#
# 81. **Which neural network is used to detect fraudulent activities in insurance claims?**
#    - A) Autoencoders
#    - B) Convolutional Neural Networks (CNN)
#    - C) Recurrent Neural Networks (RNN)
#    - D) Hopfield Networks
#    - **Answer: A) Autoencoders**
#
# 82. **How do ANNs assist in generating realistic human speech for voice assistants?**
#    - A) By using Text-to-Speech (TTS) models, often based on RNNs and Transformers
#    - B) By manually recording human voices
#    - C) By converting audio files to text
#    - D) By deleting audio files
#    - **Answer: A) By using Text-to-Speech (TTS) models, often based on RNNs and Transformers**
#
# 83. **Which neural network is used to segment and identify regions of interest in medical imaging?**
#    - A) Convolutional Neural Networks (CNN)
#    - B) Radial Basis Function Networks
#    - C) Multi-Layer Perceptron (MLP)
#    - D) Hopfield Networks
#    - **Answer: A) Convolutional Neural Networks (CNN)**
#
# 84. **How do neural networks help in movie scene classification?**
#    - A) By using CNN to classify different scenes based on visual features
#    - B) By manually tagging each scene
#    - C) By sorting movie titles
#    - D) By creating random labels for scenes
#    - **Answer: A) By using CNN to classify different scenes based on visual features**
#
# 85. **Which ANN architecture can be used to create automated trading systems for stock markets?**
#    - A) Recurrent Neural Networks (RNN)
#    - B) Generative Adversarial Networks (GANs)
#    - C) Radial Basis Function Networks
#    - D) Self-Organizing Maps (SOM)
#    - **Answer: A) Recurrent Neural Networks (RNN)**
#
# 86. **How are ANNs used in controlling drones autonomously?**
#    - A) By using Reinforcement Learning to navigate and adapt to the environment
#    - B) By controlling the drone manually
#    - C) By encrypting the flight path
#    - D) By reducing the number of sensors on the drone
#    - **Answer: A) By using Reinforcement Learning to navigate and adapt to the environment**
#
# 87. **What type of ANN is suitable for processing video streams in surveillance systems?**
#    - A) Convolutional Neural Networks (CNN)
#    - B) Recurrent Neural Networks (RNN)
#    - C) Hopfield Networks
#    - D) Self-Organizing Maps (SOM)
#    - **Answer: A) Convolutional Neural Networks (CNN)**
#
# 88. **How do ANNs help in autonomous underwater vehicle (AUV) navigation?**
#    - A) Using Reinforcement Learning to navigate underwater while avoiding obstacles
#    - B) Manually steering the vehicle
#    - C) By encrypting water data
#    - D) By reducing underwater speed
#    - **Answer: A) Using Reinforcement Learning to navigate underwater while avoiding obstacles**
#
# 89. **Which ANN model is often used to classify customer reviews as positive, negative, or neutral?**
#    - A) Recurrent Neural Networks (RNN)
#    - B) Convolutional Neural Networks (CNN)
#    - C) Radial Basis Function Networks
#    - D) Hopfield Networks
#    - **Answer: A) Recurrent Neural Networks (RNN)**
#
# 90. **Which neural network architecture is used for handwriting generation, mimicking a particular person’s style?**
#    - A) Recurrent Neural Networks (RNN)
#    - B) Convolutional Neural Networks (CNN)
#    - C) Hopfield Networks
#    - D) Radial Basis Function Networks
#    - **Answer: A) Recurrent Neural Networks (RNN)**
#
# 91. **How do ANNs contribute to DNA sequence analysis?**
#    - A) By classifying DNA sequences using RNNs
#    - B) By manually categorizing DNA strands
#    - C) By sorting genetic data alphabetically
#    - D) By converting DNA to random sequences
#    - **Answer: A) By classifying DNA sequences using RNNs**
#
# 92. **Which type of neural network is used for face recognition to unlock mobile devices?**
#    - A) Convolutional Neural Networks (CNN)
#    - B) Radial Basis Function Networks
#    - C) Multi-Layer Perceptron (MLP)
#    - D) Hopfield Networks
#    - **Answer: A) Convolutional Neural Networks (CNN)**
#
# 93. **Which of the following is a use of ANNs in renewable energy management?**
#    - A) Predicting solar power generation based on weather forecasts
#    - B) Manually operating solar panels
#    - C) Printing energy reports
#    - D) Encrypting power consumption data
#    - **Answer: A) Predicting solar power generation based on weather forecasts**
#
# 94. **How do ANNs assist in defect detection in manufacturing?**
#    - A) By identifying product defects using image analysis with CNN
#    - B) By manually inspecting each product
#    - C) By encrypting defect information
#    - D) By sorting products by name
#    - **Answer: A) By identifying product defects using image analysis with CNN**
#
# 95. **Which neural network can be used to convert a series of images into a cohesive video?**
#    - A) Recurrent Neural Networks (RNN)
#    - B) Convolutional Neural Networks (CNN)
#    - C) Multi-Layer Perceptron (MLP)
#    - D) Radial Basis Function Networks
#    - **Answer: A) Recurrent Neural Networks (RNN)**
#
# 96. **How do neural networks help with protein structure prediction?**
#    - A) Using deep learning models to predict the 3D structure of proteins
#    - B) By manually folding proteins
#    - C) By printing protein sequences
#    - D) By sorting proteins by size
#    - **Answer: A) Using deep learning models to predict the 3D structure of proteins**
#
# 97. **Which type of ANN is used to analyze time-series data, such as predicting future sales?**
#    - A) Recurrent Neural Networks (RNN)
#    - B) Convolutional Neural Networks (CNN)
#    - C) Multi-Layer Perceptron (MLP)
#    - D) Hopfield Networks
#    - **Answer: A) Recurrent Neural Networks (RNN)**
#
# 98. **Which neural network is typically used to classify satellite images for urban planning?**
#    - A) Convolutional Neural Networks (CNN)
#    - B) Radial Basis Function Networks
#    - C) Recurrent Neural Networks (RNN)
#    - D) Hopfield Networks
#    - **Answer: A) Convolutional Neural Networks (CNN)**
#
# 99. **How do ANNs contribute to creating personalized news feeds?**
#    - A) By recommending articles based on user reading behavior and preferences
#    - B) By encrypting news data
#    - C) By sorting articles by title
#    - D) By randomly selecting articles
#    - **Answer: A) By recommending articles based on user reading behavior and preferences**
#
# 100. **What is an example of using ANNs in predictive maintenance for industrial machinery?**
#     - A) Forecasting equipment failures based on sensor data using time-series analysis
#     - B) Manually operating machines
#     - C) Sorting machinery by size
#     - D) Encrypting machine data
#     - **Answer: A) Forecasting equipment failures based on sensor data using time-series analysis**

# %% [markdown]
# ### **Lecture 7: Backpropagation in Neural Networks (Advanced Concepts)**
#
# 1. **What is the main goal of backpropagation in neural networks?**
#    - A) To minimize the loss by adjusting weights using gradient descent
#    - B) To initialize weights randomly
#    - C) To forward propagate inputs
#    - D) To remove bias nodes
#    - **Answer: A) To minimize the loss by adjusting weights using gradient descent**
#
# 2. **Which type of gradient descent updates weights after calculating the gradient using the entire training dataset?**
#    - A) Batch Gradient Descent
#    - B) Stochastic Gradient Descent
#    - C) Mini-Batch Gradient Descent
#    - D) Convex Gradient Descent
#    - **Answer: A) Batch Gradient Descent**
#
# 3. **Which method is used to compute the gradients in backpropagation?**
#    - A) Chain Rule
#    - B) Pythagoras Theorem
#    - C) Convex Optimization
#    - D) Decision Trees
#    - **Answer: A) Chain Rule**
#
# 4. **What does "local minima" mean in backpropagation?**
#    - A) A point where the loss function value is lower compared to nearby points, but not necessarily the global lowest
#    - B) The point of highest error
#    - C) A point where the weights remain constant
#    - D) A point where the network reaches zero error
#    - **Answer: A) A point where the loss function value is lower compared to nearby points, but not necessarily the global lowest**
#
# 5. **Which of the following is a common problem associated with backpropagation in deep networks?**
#    - A) Vanishing Gradient
#    - B) Exploding Gradient
#    - C) Both A and B
#    - D) No issues are present
#    - **Answer: C) Both A and B**
#
# 6. **How can the vanishing gradient problem affect neural network training?**
#    - A) It makes the weights constant
#    - B) It causes the gradients to become too small, leading to slow learning in deeper layers
#    - C) It results in larger gradients and faster learning
#    - D) It causes the neurons to die
#    - **Answer: B) It causes the gradients to become too small, leading to slow learning in deeper layers**
#
# 7. **Which activation function helps mitigate the vanishing gradient problem by maintaining non-zero gradients?**
#    - A) ReLU
#    - B) Sigmoid
#    - C) Tanh
#    - D) Softmax
#    - **Answer: A) ReLU**
#
# 8. **Which optimizer includes a term that helps accelerate the gradient vectors in the correct direction, thus improving convergence?**
#    - A) SGD with Momentum
#    - B) Adam
#    - C) AdaGrad
#    - D) ReLU
#    - **Answer: A) SGD with Momentum**
#
# 9. **How does the learning rate affect backpropagation?**
#    - A) It determines the speed at which weights are updated during gradient descent
#    - B) It reduces the number of neurons
#    - C) It initializes the weights to zero
#    - D) It makes the network deeper
#    - **Answer: A) It determines the speed at which weights are updated during gradient descent**
#
# 10. **Which of the following describes exploding gradients?**
#     - A) Gradients become too large, leading to instability during training
#     - B) Gradients become too small and almost vanish
#     - C) Weights remain constant
#     - D) Learning rate decreases
#     - **Answer: A) Gradients become too large, leading to instability during training**
#
# 11. **Which technique can be used to prevent exploding gradients during backpropagation?**
#     - A) Gradient Clipping
#     - B) Weight Decay
#     - C) Learning Rate Scheduling
#     - D) Adding hidden layers
#     - **Answer: A) Gradient Clipping**
#
# 12. **How can the vanishing gradient problem be mitigated in deep networks?**
#     - A) By using ReLU or Leaky ReLU activation functions
#     - B) By removing hidden layers
#     - C) By increasing the learning rate
#     - D) By reducing the number of neurons
#     - **Answer: A) By using ReLU or Leaky ReLU activation functions**
#
# 13. **Which initialization method is useful for preventing the vanishing gradient problem?**
#     - A) Xavier Initialization
#     - B) Zeros Initialization
#     - C) Random Initialization
#     - D) Identity Initialization
#     - **Answer: A) Xavier Initialization**
#
# 14. **What is the primary reason for using dropout in backpropagation?**
#     - A) To prevent overfitting by randomly ignoring certain neurons during training
#     - B) To reduce the learning rate
#     - C) To initialize weights to zero
#     - D) To remove bias nodes
#     - **Answer: A) To prevent overfitting by randomly ignoring certain neurons during training**
#
# 15. **What does the term "momentum" mean in the context of backpropagation?**
#     - A) Adding a fraction of the previous weight update to the current update to smooth out the gradient descent path
#     - B) Increasing the learning rate
#     - C) Reducing the learning rate to zero
#     - D) Removing neurons
#     - **Answer: A) Adding a fraction of the previous weight update to the current update to smooth out the gradient descent path**
#
# 16. **How does the Adam optimizer improve backpropagation?**
#     - A) By combining momentum with adaptive learning rates for each parameter
#     - B) By keeping a fixed learning rate
#     - C) By randomly updating weights
#     - D) By eliminating the need for regularization
#     - **Answer: A) By combining momentum with adaptive learning rates for each parameter**
#
# 17. **Which type of regularization is often used in backpropagation to penalize large weights?**
#     - A) L2 Regularization
#     - B) L1 Regularization
#     - C) Batch Normalization
#     - D) Weight Decay
#     - **Answer: A) L2 Regularization**
#
# 18. **How does L1 regularization affect backpropagation?**
#     - A) It forces some weights to become zero, creating sparsity
#     - B) It reduces the number of layers
#     - C) It eliminates biases
#     - D) It increases the learning rate
#     - **Answer: A) It forces some weights to become zero, creating sparsity**
#
# 19. **Which activation function is more likely to suffer from dead neurons during training?**
#     - A) ReLU
#     - B) Tanh
#     - C) Sigmoid
#     - D) Softmax
#     - **Answer: A) ReLU**
#
# 20. **How does weight decay affect backpropagation?**
#     - A) It adds a regularization term to reduce overfitting by penalizing large weights
#     - B) It increases the number of epochs
#     - C) It decreases the number of hidden layers
#     - D) It adds momentum
#     - **Answer: A) It adds a regularization term to reduce overfitting by penalizing large weights**
#
# 21. **What is the difference between L2 regularization and weight decay?**
#     - A) Weight decay is a specific implementation of L2 regularization
#     - B) L2 regularization is used to eliminate biases, while weight decay affects gradients
#     - C) L2 regularization increases the learning rate, weight decay reduces it
#     - D) There is no difference
#     - **Answer: A) Weight decay is a specific implementation of L2 regularization**
#
# 22. **Which technique can be used to improve convergence speed in backpropagation for deep networks?**
#     - A) Batch Normalization
#     - B) Removing biases
#     - C) Adding noise to inputs
#     - D) Decreasing the learning rate
#     - **Answer: A) Batch Normalization**
#
# 23. **How does batch normalization affect backpropagation?**
#     - A) It normalizes the inputs of each layer, which can improve the stability and speed of training
#     - B) It increases the number of layers
#     - C) It adds regularization
#     - D) It increases gradients to infinity
#     - **Answer: A) It normalizes the inputs of each layer, which can improve the stability and speed of training**
#
# 24. **Which optimizer is most suitable for sparse data with large gradients?**
#     - A) AdaGrad
#     - B) SGD
#     - C) Adam
#     - D) RMSprop
#     - **Answer: A) AdaGrad**
#
# 25. **What is the main disadvantage of using a very high learning rate in backpropagation?**
#     - A) The model may not converge, and the loss function may oscillate
#     - B) It speeds up convergence
#     - C) It ensures optimal training
#     - D) It reduces overfitting
#     - **Answer: A) The model may not converge, and the loss function may oscillate**
#
# 26. **Which optimizer uses both an adaptive learning rate and momentum?**
#     - A) Adam
#     - B) SGD
#     - C) AdaGrad
#     - D) RMSprop
#     - **Answer: A) Adam**
#
# 27. **Which term describes a training algorithm that calculates gradients based on a small random subset of the training dataset?**
#     - A) Mini-Batch Gradient Descent
#     - B) Batch Gradient Descent
#     - C) Stochastic Gradient Descent (SGD)
#     - D) Deterministic Gradient Descent
#     - **Answer: C) Stochastic Gradient Descent (SGD)**
#
# 28. **How can the exploding gradient problem be addressed during the training of RNNs?**
#     - A) Using gradient clipping to limit the maximum value of gradients
#     - B) By reducing the learning rate to zero
#     - C) By using sigmoid activation functions
#     - D) By increasing the number of hidden layers
#     - **Answer: A) Using gradient clipping to limit the maximum value of gradients**
#
# 29. **How does Leaky ReLU help prevent the problem of dead neurons?**
#     - A) By allowing a small, non-zero gradient for negative inputs
#     - B) By making the learning rate zero
#     - C) By normalizing inputs
#     - D) By removing biases
#     - **Answer: A) By allowing a small, non-zero gradient for negative inputs**
#
# 30. **What is the purpose of using an exponentially decaying learning rate?**
#     - A) To decrease the learning rate over time, ensuring more stable convergence as training progresses
#     - B) To make the learning rate zero
#     - C) To increase the gradient value
#     - D) To remove neurons that are not required
#     - **Answer: A) To decrease the learning rate over time, ensuring more stable convergence as training progresses**

# %% [markdown]
# 31. **What is the main role of the cost function during backpropagation?**
#    - A) To measure how well the model’s predictions match the actual outputs
#    - B) To initialize the weights randomly
#    - C) To reduce the number of neurons
#    - D) To increase the number of hidden layers
#    - **Answer: A) To measure how well the model’s predictions match the actual outputs**
#
# 32. **Which of these optimizers uses an exponentially weighted average of past gradients to adjust the learning rate?**
#    - A) RMSprop
#    - B) AdaGrad
#    - C) SGD
#    - D) Batch Gradient Descent
#    - **Answer: A) RMSprop**
#
# 33. **What is the effect of using momentum during backpropagation?**
#    - A) It helps smooth the trajectory of the weights by accumulating a portion of previous gradients
#    - B) It increases the size of the training set
#    - C) It initializes weights to zero
#    - D) It adds noise to the dataset
#    - **Answer: A) It helps smooth the trajectory of the weights by accumulating a portion of previous gradients**
#
# 34. **Which of the following describes how adaptive optimizers like Adam work?**
#    - A) They adapt learning rates individually for each parameter during training
#    - B) They keep the learning rate constant
#    - C) They remove the gradient computation step
#    - D) They add random noise to weights
#    - **Answer: A) They adapt learning rates individually for each parameter during training**
#
# 35. **What is the purpose of weight initialization in a neural network?**
#    - A) To prevent the vanishing and exploding gradient problems and facilitate good convergence
#    - B) To reduce training data size
#    - C) To add biases
#    - D) To increase learning rate
#    - **Answer: A) To prevent the vanishing and exploding gradient problems and facilitate good convergence**
#
# 36. **How does learning rate scheduling benefit backpropagation?**
#    - A) It adjusts the learning rate during training, helping achieve better convergence
#    - B) It removes neurons that are not required
#    - C) It keeps the learning rate constant
#    - D) It reduces overfitting
#    - **Answer: A) It adjusts the learning rate during training, helping achieve better convergence**
#
# 37. **What is the function of the bias term in neural networks during backpropagation?**
#    - A) It helps neurons activate even when the weighted input sum is zero
#    - B) It makes gradients vanish
#    - C) It reduces the number of layers
#    - D) It removes activation functions
#    - **Answer: A) It helps neurons activate even when the weighted input sum is zero**
#
# 38. **Which optimizer is more suited to handle sparse gradients and adapt learning rates effectively?**
#    - A) Adam
#    - B) SGD
#    - C) RMSprop
#    - D) Batch Gradient Descent
#    - **Answer: A) Adam**
#
# 39. **What is a key advantage of using the Adam optimizer in neural network training?**
#    - A) It combines both momentum and adaptive learning rates for each parameter
#    - B) It keeps the learning rate constant
#    - C) It only works with shallow networks
#    - D) It eliminates biases
#    - **Answer: A) It combines both momentum and adaptive learning rates for each parameter**
#
# 40. **Which activation function has a range between -1 and 1, and is less likely to saturate than the sigmoid?**
#    - A) Tanh
#    - B) ReLU
#    - C) Leaky ReLU
#    - D) Softmax
#    - **Answer: A) Tanh**
#
# 41. **What is gradient clipping, and why is it used?**
#    - A) Limiting the maximum value of gradients to prevent them from growing too large, hence improving training stability
#    - B) Reducing the learning rate to zero
#    - C) Increasing the number of epochs
#    - D) Adding noise to the dataset
#    - **Answer: A) Limiting the maximum value of gradients to prevent them from growing too large, hence improving training stability**
#
# 42. **How does the Xavier initialization method benefit deep networks?**
#    - A) It ensures that the variance of the outputs is roughly the same across layers, reducing the likelihood of vanishing or exploding gradients
#    - B) It initializes weights to zero
#    - C) It adds biases to inputs
#    - D) It always increases the number of neurons
#    - **Answer: A) It ensures that the variance of the outputs is roughly the same across layers, reducing the likelihood of vanishing or exploding gradients**
#
# 43. **Which learning rate adjustment strategy is used to ensure the network can learn quickly initially but settle more accurately later?**
#    - A) Learning Rate Decay
#    - B) Gradient Clipping
#    - C) Constant Learning Rate
#    - D) Momentum Increase
#    - **Answer: A) Learning Rate Decay**
#
# 44. **How can batch normalization be beneficial during backpropagation?**
#    - A) It standardizes inputs to each layer, improving training speed and reducing internal covariate shift
#    - B) It increases the learning rate
#    - C) It reduces the number of layers
#    - D) It removes the need for gradient computation
#    - **Answer: A) It standardizes inputs to each layer, improving training speed and reducing internal covariate shift**
#
# 45. **What effect does the vanishing gradient problem have on deep neural networks?**
#    - A) It slows down learning in the earlier layers because gradients approach zero
#    - B) It makes all gradients explode
#    - C) It increases the accuracy of the network
#    - D) It reduces the depth of the network
#    - **Answer: A) It slows down learning in the earlier layers because gradients approach zero**
#
# 46. **Which type of initialization is particularly effective for ReLU activation functions?**
#    - A) He Initialization
#    - B) Xavier Initialization
#    - C) Zeros Initialization
#    - D) Identity Initialization
#    - **Answer: A) He Initialization**
#
# 47. **Which optimization method uses moving averages of past squared gradients to scale the learning rate for each parameter?**
#    - A) RMSprop
#    - B) SGD
#    - C) AdaGrad
#    - D) Adam
#    - **Answer: A) RMSprop**
#
# 48. **How does dropout help in training a neural network?**
#    - A) By randomly ignoring some neurons during training to reduce overfitting
#    - B) By increasing the number of layers
#    - C) By reducing training time directly
#    - D) By eliminating biases
#    - **Answer: A) By randomly ignoring some neurons during training to reduce overfitting**
#
# 49. **Which of the following describes how gradient descent updates weights during backpropagation?**
#    - A) Weights are updated in the opposite direction of the gradient of the loss function
#    - B) Weights are updated randomly
#    - C) Weights are kept constant
#    - D) Weights are multiplied by the loss function
#    - **Answer: A) Weights are updated in the opposite direction of the gradient of the loss function**
#
# 50. **Which method allows for training stability by keeping layer outputs within a stable range during backpropagation?**
#    - A) Batch Normalization
#    - B) Dropout
#    - C) Weight Clipping
#    - D) Bias Removal
#    - **Answer: A) Batch Normalization**
#
# 51. **What can happen if the learning rate is set too small during backpropagation?**
#    - A) Training becomes very slow, potentially never reaching convergence
#    - B) Training becomes faster
#    - C) Gradients explode
#    - D) Weights are eliminated
#    - **Answer: A) Training becomes very slow, potentially never reaching convergence**
#
# 52. **How does the use of ReLU activation contribute to training efficiency?**
#    - A) It introduces sparsity by allowing only positive values to pass through, helping reduce computational load
#    - B) It keeps outputs constant
#    - C) It makes weights vanish
#    - D) It initializes neurons randomly
#    - **Answer: A) It introduces sparsity by allowing only positive values to pass through, helping reduce computational load**
#
# 53. **Which optimizer can combine momentum with adaptive learning rates for efficient weight updates?**
#    - A) Adam
#    - B) SGD
#    - C) Batch Gradient Descent
#    - D) AdaGrad
#    - **Answer: A) Adam**
#
# 54. **Why is it important to have an appropriate weight initialization scheme in a deep network?**
#    - A) To help the model converge faster and reduce the likelihood of vanishing or exploding gradients
#    - B) To reduce the number of epochs
#    - C) To keep all weights constant
#    - D) To add noise to training data
#    - **Answer: A) To help the model converge faster and reduce the likelihood of vanishing or exploding gradients**
#
# 55. **Which term describes the strategy of modifying the learning rate as training progresses to prevent overshooting the optimal solution?**
#    - A) Learning Rate Scheduling
#    - B) Gradient Boosting
#    - C) Bias Increment
#    - D) Momentum Increase
#    - **Answer: A) Learning Rate Scheduling**
#
# 56. **How can L2 regularization benefit neural network training?**
#    - A) It adds a penalty to large weights, helping to reduce overfitting and maintain generalization
#    - B) It increases the learning rate
#    - C) It makes the weights constant
#    - D) It eliminates the bias term
#    - **Answer: A) It adds a penalty to large weights, helping to reduce overfitting and maintain generalization**
#
# 57. **Which of these activation functions is most susceptible to the vanishing gradient problem?**
#    - A) Sigmoid
#    - B) ReLU
#    - C) Leaky ReLU
#    - D) Softmax
#    - **Answer: A) Sigmoid**
#
# 58. **What happens during the backward pass of backpropagation?**
#    - A) The loss is propagated backward through the network to compute the gradient of the loss function with respect to each weight
#    - B) Inputs are initialized randomly
#    - C) Neurons are activated
#    - D) The network is expanded by adding layers
#    - **Answer: A) The loss is propagated backward through the network to compute the gradient of the loss function with respect to each weight**
#
# 59. **How does the He initialization differ from Xavier initialization?**
#    - A) He initialization is specifically designed for ReLU, using a larger variance than Xavier initialization to accommodate positive-only activations
#    - B) He initialization makes all weights zero
#    - C) Xavier initialization does not work for deep networks
#    - D) He initialization removes biases
#    - **Answer: A) He initialization is specifically designed for ReLU, using a larger variance than Xavier initialization to accommodate positive-only activations**
#
# 60. **What does the term "gradient descent" mean in the context of backpropagation?**
#    - A) A method to find the minimum of the loss function by iteratively adjusting the weights in the direction opposite to the gradient
#    - B) A process of initializing all neurons to zero
#    - C) A method of increasing the loss function
#    - D) A method to randomly select training examples
#    - **Answer: A) A method to find the minimum of the loss function by iteratively adjusting the weights in the direction opposite to the gradient**

# %% [markdown]
# 61. **Which optimization technique is suitable for reducing computation time in large datasets by updating weights for small subsets of data?**
#    - A) Mini-Batch Gradient Descent
#    - B) Full-Batch Gradient Descent
#    - C) Deterministic Gradient Descent
#    - D) Momentum Gradient Descent
#    - **Answer: A) Mini-Batch Gradient Descent**
#
# 62. **How does adding dropout affect the training of a neural network during backpropagation?**
#    - A) It randomly ignores a subset of neurons during training to prevent overfitting
#    - B) It increases the learning rate
#    - C) It ensures all neurons are always activated
#    - D) It eliminates the need for biases
#    - **Answer: A) It randomly ignores a subset of neurons during training to prevent overfitting**
#
# 63. **Which of the following describes the impact of learning rate on the convergence of backpropagation?**
#    - A) A high learning rate may lead to overshooting and prevent convergence
#    - B) A low learning rate always guarantees faster convergence
#    - C) A learning rate only impacts input neurons
#    - D) Learning rate has no effect on the convergence
#    - **Answer: A) A high learning rate may lead to overshooting and prevent convergence**
#
# 64. **What is the primary advantage of using adaptive learning rate optimizers like AdaGrad?**
#    - A) They adjust learning rates based on the frequency of updates to each parameter
#    - B) They keep learning rates constant
#    - C) They increase the number of hidden layers
#    - D) They eliminate the need for biases
#    - **Answer: A) They adjust learning rates based on the frequency of updates to each parameter**
#
# 65. **Which of the following is a common method for mitigating the vanishing gradient problem?**
#    - A) Using ReLU or Leaky ReLU activation functions
#    - B) Increasing the number of hidden layers
#    - C) Reducing the number of output neurons
#    - D) Eliminating biases
#    - **Answer: A) Using ReLU or Leaky ReLU activation functions**
#
# 66. **What role does the chain rule play in backpropagation?**
#    - A) It is used to compute the gradient of the loss function with respect to each weight by linking the derivatives through the layers
#    - B) It reduces the learning rate
#    - C) It increases the number of neurons
#    - D) It eliminates the need for bias terms
#    - **Answer: A) It is used to compute the gradient of the loss function with respect to each weight by linking the derivatives through the layers**
#
# 67. **Which optimizer is typically preferred for training very deep networks due to its robustness in handling sparse data and faster convergence?**
#    - A) Adam
#    - B) SGD
#    - C) AdaGrad
#    - D) Batch Gradient Descent
#    - **Answer: A) Adam**
#
# 68. **What is an effective solution for handling the problem of exploding gradients in Recurrent Neural Networks (RNNs)?**
#    - A) Gradient Clipping
#    - B) Decreasing learning rate to zero
#    - C) Using a sigmoid activation function
#    - D) Increasing the number of hidden layers
#    - **Answer: A) Gradient Clipping**
#
# 69. **Which type of activation function is prone to the problem of neurons "dying," leading them to produce zero outputs consistently?**
#    - A) ReLU
#    - B) Tanh
#    - C) Sigmoid
#    - D) Softmax
#    - **Answer: A) ReLU**
#
# 70. **What is the purpose of using He initialization in ReLU networks?**
#    - A) To maintain the variance of the activations across layers by using an appropriate scaling factor
#    - B) To initialize weights to zero
#    - C) To make all neurons equal
#    - D) To increase the learning rate
#    - **Answer: A) To maintain the variance of the activations across layers by using an appropriate scaling factor**
#
# 71. **Which type of gradient descent uses the entire dataset to compute the gradient, providing a more stable convergence but longer computation time?**
#    - A) Batch Gradient Descent
#    - B) Stochastic Gradient Descent
#    - C) Mini-Batch Gradient Descent
#    - D) Random Gradient Descent
#    - **Answer: A) Batch Gradient Descent**
#
# 72. **What is a common effect of the exploding gradient problem on the weights during backpropagation?**
#    - A) Weights grow excessively large, leading to numerical instability
#    - B) Weights become zero
#    - C) Weights remain constant
#    - D) Weights decrease to very small values
#    - **Answer: A) Weights grow excessively large, leading to numerical instability**
#
# 73. **How does dropout help improve the generalization capability of neural networks?**
#    - A) By reducing the co-adaptation of neurons by randomly dropping some during training
#    - B) By increasing the training set size
#    - C) By removing all biases
#    - D) By adding noise to gradients
#    - **Answer: A) By reducing the co-adaptation of neurons by randomly dropping some during training**
#
# 74. **Which of the following learning rate schedules gradually decreases the learning rate based on a predefined function of time?**
#    - A) Exponential Decay
#    - B) Momentum Adjustment
#    - C) Constant Learning Rate
#    - D) He Initialization
#    - **Answer: A) Exponential Decay**
#
# 75. **What is the primary goal of using L2 regularization in backpropagation?**
#    - A) To add a penalty for larger weights, preventing overfitting
#    - B) To initialize weights to high values
#    - C) To increase the number of layers
#    - D) To make the network linear
#    - **Answer: A) To add a penalty for larger weights, preventing overfitting**
#
# 76. **Which activation function helps mitigate the problem of vanishing gradients while keeping neurons active for negative inputs?**
#    - A) Leaky ReLU
#    - B) Sigmoid
#    - C) Tanh
#    - D) Softmax
#    - **Answer: A) Leaky ReLU**
#
# 77. **Which of the following describes the key challenge that the vanishing gradient problem presents in backpropagation for deep networks?**
#    - A) Gradients become extremely small, preventing the weights from being updated effectively
#    - B) Gradients become extremely large, leading to instability
#    - C) The number of layers decreases
#    - D) The network becomes completely linear
#    - **Answer: A) Gradients become extremely small, preventing the weights from being updated effectively**
#
# 78. **What effect does batch normalization have during training?**
#    - A) It standardizes the inputs of each layer, which can help accelerate training and improve stability
#    - B) It removes biases
#    - C) It adds new neurons to each layer
#    - D) It decreases the batch size
#    - **Answer: A) It standardizes the inputs of each layer, which can help accelerate training and improve stability**
#
# 79. **How does increasing the number of hidden layers in a neural network generally affect backpropagation?**
#    - A) It increases the likelihood of the vanishing or exploding gradient problem
#    - B) It makes the learning rate constant
#    - C) It eliminates biases
#    - D) It ensures that all neurons activate equally
#    - **Answer: A) It increases the likelihood of the vanishing or exploding gradient problem**
#
# 80. **Which method in backpropagation involves normalizing the input of each layer to improve training speed?**
#    - A) Batch Normalization
#    - B) Gradient Clipping
#    - C) Weight Decay
#    - D) Zero Initialization
#    - **Answer: A) Batch Normalization**
#
# 81. **How does momentum enhance the training of neural networks in backpropagation?**
#    - A) By adding a fraction of the previous update to the current update, smoothing the optimization path
#    - B) By initializing weights to zero
#    - C) By decreasing the learning rate
#    - D) By eliminating biases
#    - **Answer: A) By adding a fraction of the previous update to the current update, smoothing the optimization path**
#
# 82. **Which optimizer is an extension of SGD that includes both momentum and adaptive learning rates for each parameter?**
#    - A) Adam
#    - B) Batch Gradient Descent
#    - C) AdaGrad
#    - D) Mini-Batch Gradient Descent
#    - **Answer: A) Adam**
#
# 83. **What does the term "overfitting" mean in the context of neural network training?**
#    - A) The model performs extremely well on training data but poorly on new, unseen data
#    - B) The model converges quickly
#    - C) The network has too few hidden layers
#    - D) The network cannot learn at all
#    - **Answer: A) The model performs extremely well on training data but poorly on new, unseen data**
#
# 84. **Which technique can help reduce overfitting in a neural network?**
#    - A) Dropout
#    - B) Increasing the learning rate
#    - C) Removing biases
#    - D) Reducing the batch size
#    - **Answer: A) Dropout**
#
# 85. **What is the effect of using a too-small learning rate during backpropagation?**
#    - A) Training becomes very slow, and the model may get stuck in a local minimum
#    - B) The model converges faster
#    - C) Gradients explode
#    - D) Neurons deactivate
#    - **Answer: A) Training becomes very slow, and the model may get stuck in a local minimum**
#
# 86. **Which initialization method is designed to work well with ReLU activation by scaling variance based on the number of input nodes?**
#    - A) He Initialization
#    - B) Xavier Initialization
#    - C) Random Initialization
#    - D) Identity Initialization
#    - **Answer: A) He Initialization**
#
# 87. **What is the primary benefit of using mini-batch gradient descent instead of full-batch gradient descent?**
#    - A) Faster convergence and a balance between computational efficiency and model accuracy
#    - B) It always converges to the global minimum
#    - C) It reduces training set size
#    - D) It keeps learning rates constant
#    - **Answer: A) Faster convergence and a balance between computational efficiency and model accuracy**
#
# 88. **How can gradient clipping prevent numerical instability during the training of deep networks?**
#    - A) By limiting the size of the gradients, preventing them from growing too large
#    - B) By reducing the learning rate to zero
#    - C) By removing biases
#    - D) By reducing the number of hidden layers
#    - **Answer: A) By limiting the size of the gradients, preventing them from growing too large**
#
# 89. **Which activation function can lead to dead neurons, especially if the learning rate is too high?**
#    - A) ReLU
#    - B) Tanh
#    - C) Sigmoid
#    - D) Softmax
#    - **Answer: A) ReLU**
#
# 90. **What is the purpose of using an exponentially decaying learning rate during training?**
#    - A) To decrease the learning rate over time, which helps stabilize convergence
#    - B) To increase the number of neurons
#    - C) To eliminate hidden layers
#    - D) To add noise to inputs
#    - **Answer: A) To decrease the learning rate over time, which helps stabilize convergence**
#
# 91. **Which regularization technique involves adding a term to the loss function that penalizes the sum of the absolute values of weights?**
#    - A) L1 Regularization
#    - B) L2 Regularization
#    - C) Weight Clipping
#    - D) Bias Decay
#    - **Answer: A) L1 Regularization**
#
# 92. **How does adaptive gradient (AdaGrad) improve the backpropagation process?**
#    - A) By adjusting the learning rate for each parameter based on past gradient magnitudes
#    - B) By eliminating biases
#    - C) By reducing the number of hidden layers
#    - D) By initializing all weights to zero
#    - **Answer: A) By adjusting the learning rate for each parameter based on past gradient magnitudes**
#
# 93. **How does the ReLU activation function help in mitigating the vanishing gradient problem?**
#    - A) By allowing gradients to pass through for positive inputs without significant decay
#    - B) By normalizing inputs
#    - C) By reducing the learning rate
#    - D) By increasing the number of layers
#    - **Answer: A) By allowing gradients to pass through for positive inputs without significant decay**
#
# 94. **Which optimizer is known for being computationally efficient and well-suited for large datasets?**
#    - A) SGD with Mini-Batches
#    - B) Batch Gradient Descent
#    - C) He Initialization Optimizer
#    - D) Radial Basis Optimizer
#    - **Answer: A) SGD with Mini-Batches**
#
# 95. **How does the Adam optimizer achieve efficient weight updates?**
#    - A) By combining both momentum and an adaptive learning rate for each parameter
#    - B) By keeping a fixed learning rate
#    - C) By eliminating biases
#    - D) By adding random noise to gradients
#    - **Answer: A) By combining both momentum and an adaptive learning rate for each parameter**
#
# 96. **What role does the "bias correction" term play in the Adam optimizer?**
#    - A) It adjusts the mean and variance estimates during the early stages of training
#    - B) It initializes weights
#    - C) It reduces the number of layers
#    - D) It removes biases
#    - **Answer: A) It adjusts the mean and variance estimates during the early stages of training**
#
# 97. **What is a disadvantage of using a large batch size in gradient descent?**
#    - A) It may lead to poor generalization because it smooths the gradient too much
#    - B) It always leads to faster convergence
#    - C) It eliminates all biases
#    - D) It keeps gradients constant
#    - **Answer: A) It may lead to poor generalization because it smooths the gradient too much**
#
# 98. **What is a key advantage of using learning rate decay during training?**
#    - A) It helps the model converge more stably by reducing the learning rate over time
#    - B) It reduces training data size
#    - C) It eliminates weights
#    - D) It always increases accuracy
#    - **Answer: A) It helps the model converge more stably by
#
#  reducing the learning rate over time**
#
# 99. **Which of these is a common practice to ensure stable training in deep neural networks?**
#    - A) Batch Normalization
#    - B) Removing hidden layers
#    - C) Adding biases to all neurons
#    - D) Reducing the training dataset
#    - **Answer: A) Batch Normalization**
#
# 100. **What is the purpose of regularizing the weights of a neural network?**
#     - A) To prevent overfitting and improve the generalization ability of the model
#     - B) To reduce the training dataset size
#     - C) To increase learning rate exponentially
#     - D) To eliminate biases
#     - **Answer: A) To prevent overfitting and improve the generalization ability of the model**

# %% [markdown]
# ### **Lecture 8: Optimization Techniques in Neural Networks**
#
# 1. **What is the primary objective of optimization in neural networks?**
#    - A) Minimize the loss function by adjusting the model parameters
#    - B) Maximize the number of neurons
#    - C) Increase the number of layers
#    - D) Randomize weights
#    - **Answer: A) Minimize the loss function by adjusting the model parameters**
#
# 2. **Which optimizer is often considered as a baseline for comparing other optimizers?**
#    - A) Stochastic Gradient Descent (SGD)
#    - B) Adam
#    - C) RMSprop
#    - D) AdaGrad
#    - **Answer: A) Stochastic Gradient Descent (SGD)**
#
# 3. **Which optimization technique uses an exponentially weighted average of past gradients to adjust the learning rate for each parameter?**
#    - A) RMSprop
#    - B) SGD
#    - C) Adam
#    - D) Adadelta
#    - **Answer: A) RMSprop**
#
# 4. **What is the main difference between SGD and Batch Gradient Descent?**
#    - A) SGD updates weights after every sample, while Batch Gradient Descent updates after processing the entire dataset
#    - B) SGD has a constant learning rate, while Batch Gradient Descent changes it
#    - C) SGD uses biases, while Batch Gradient Descent does not
#    - D) SGD always leads to slower convergence
#    - **Answer: A) SGD updates weights after every sample, while Batch Gradient Descent updates after processing the entire dataset**
#
# 5. **Which optimizer adapts learning rates for each parameter, making it suitable for sparse datasets?**
#    - A) AdaGrad
#    - B) SGD
#    - C) Batch Gradient Descent
#    - D) Leaky ReLU
#    - **Answer: A) AdaGrad**
#
# 6. **What is the main advantage of using momentum with SGD?**
#    - A) It helps accelerate the gradient vectors in the correct direction, improving convergence
#    - B) It decreases the number of layers
#    - C) It removes biases
#    - D) It reduces the training data size
#    - **Answer: A) It helps accelerate the gradient vectors in the correct direction, improving convergence**
#
# 7. **Which optimizer is well-suited for handling the vanishing gradient problem?**
#    - A) Adam
#    - B) Batch Gradient Descent
#    - C) Adadelta
#    - D) SGD without momentum
#    - **Answer: A) Adam**
#
# 8. **Which of the following describes how the Adam optimizer works?**
#    - A) It combines momentum and adaptive learning rates for each parameter
#    - B) It keeps the learning rate constant
#    - C) It eliminates biases from the network
#    - D) It only works with a single layer
#    - **Answer: A) It combines momentum and adaptive learning rates for each parameter**
#
# 9. **What role does the learning rate play in optimization?**
#    - A) It controls the step size for updating weights during training
#    - B) It decreases the number of neurons
#    - C) It increases the size of the input layer
#    - D) It makes the model deeper
#    - **Answer: A) It controls the step size for updating weights during training**
#
# 10. **Which optimization algorithm includes momentum to accelerate convergence?**
#     - A) SGD with Momentum
#     - B) RMSprop
#     - C) AdaGrad
#     - D) Batch Gradient Descent
#     - **Answer: A) SGD with Momentum**
#
# 11. **How does the AdaGrad optimizer adjust the learning rate for each parameter?**
#     - A) It accumulates the squared gradients of each parameter and divides the learning rate by this sum
#     - B) It keeps a fixed learning rate for all parameters
#     - C) It removes biases
#     - D) It increases the learning rate exponentially
#     - **Answer: A) It accumulates the squared gradients of each parameter and divides the learning rate by this sum**
#
# 12. **What is the primary purpose of using RMSprop in optimization?**
#     - A) To adjust learning rates based on an exponentially weighted average of past squared gradients
#     - B) To increase the number of hidden layers
#     - C) To remove biases
#     - D) To add noise to the inputs
#     - **Answer: A) To adjust learning rates based on an exponentially weighted average of past squared gradients**
#
# 13. **Which optimizer combines the benefits of RMSprop and momentum?**
#     - A) Adam
#     - B) SGD
#     - C) AdaGrad
#     - D) Batch Gradient Descent
#     - **Answer: A) Adam**
#
# 14. **What is the effect of using an excessively large learning rate during optimization?**
#     - A) It may cause weights to oscillate and prevent convergence
#     - B) It ensures faster convergence
#     - C) It reduces the number of epochs required
#     - D) It eliminates biases
#     - **Answer: A) It may cause weights to oscillate and prevent convergence**
#
# 15. **What is the purpose of using a learning rate schedule during training?**
#     - A) To reduce the learning rate over time to ensure stable convergence
#     - B) To increase the number of neurons in hidden layers
#     - C) To initialize all weights to zero
#     - D) To eliminate the need for bias terms
#     - **Answer: A) To reduce the learning rate over time to ensure stable convergence**
#
# 16. **Which of the following optimizers is suitable for large-scale data and deep networks?**
#     - A) Adam
#     - B) SGD without momentum
#     - C) Batch Gradient Descent
#     - D) Leaky ReLU
#     - **Answer: A) Adam**
#
# 17. **What is a major limitation of the AdaGrad optimizer?**
#     - A) The learning rate keeps decreasing, which may lead to convergence issues for long training sessions
#     - B) It requires a very large batch size
#     - C) It cannot be used with deep networks
#     - D) It increases overfitting
#     - **Answer: A) The learning rate keeps decreasing, which may lead to convergence issues for long training sessions**
#
# 18. **Which optimization technique maintains separate learning rates for each parameter, adapting them individually based on past gradients?**
#     - A) Adam
#     - B) Batch Gradient Descent
#     - C) SGD without Momentum
#     - D) Random Optimization
#     - **Answer: A) Adam**
#
# 19. **How does weight decay contribute to optimizing neural networks?**
#     - A) By adding a penalty term to the loss function, it discourages large weight values, reducing overfitting
#     - B) By increasing the learning rate
#     - C) By keeping all weights constant
#     - D) By adding noise to the inputs
#     - **Answer: A) By adding a penalty term to the loss function, it discourages large weight values, reducing overfitting**
#
# 20. **Which optimizer would you choose if you want the network to converge faster with less oscillation in the weight updates?**
#     - A) SGD with Momentum
#     - B) Batch Gradient Descent
#     - C) SGD without Momentum
#     - D) Random Gradient Descent
#     - **Answer: A) SGD with Momentum**
#
# 21. **What is the advantage of using learning rate decay during the optimization process?**
#     - A) It helps to stabilize training by reducing the learning rate as training progresses
#     - B) It eliminates biases
#     - C) It increases training dataset size
#     - D) It removes hidden layers
#     - **Answer: A) It helps to stabilize training by reducing the learning rate as training progresses**
#
# 22. **Which optimizer is generally preferred when dealing with deep networks and complex data sets?**
#     - A) Adam
#     - B) AdaGrad
#     - C) SGD without Momentum
#     - D) Batch Gradient Descent
#     - **Answer: A) Adam**
#
# 23. **How does the momentum term in SGD help accelerate convergence?**
#     - A) By accumulating a fraction of the previous weight update and adding it to the current update
#     - B) By keeping the weights constant
#     - C) By removing biases from the network
#     - D) By increasing the learning rate exponentially
#     - **Answer: A) By accumulating a fraction of the previous weight update and adding it to the current update**
#
# 24. **Which learning rate schedule decreases the learning rate by multiplying it with a factor after a certain number of epochs?**
#     - A) Step Decay
#     - B) Constant Learning Rate
#     - C) Exponential Decay
#     - D) Adaptive Decay
#     - **Answer: A) Step Decay**
#
# 25. **How does RMSprop help in controlling the oscillation of weight updates during training?**
#     - A) By adjusting the learning rate based on the average of past squared gradients
#     - B) By keeping the learning rate constant
#     - C) By increasing the weight updates
#     - D) By removing biases
#     - **Answer: A) By adjusting the learning rate based on the average of past squared gradients**
#
# 26. **Which technique can be used to avoid exploding gradients during training?**
#     - A) Gradient Clipping
#     - B) Removing biases
#     - C) Increasing learning rate exponentially
#     - D) Reducing batch size to zero
#     - **Answer: A) Gradient Clipping**
#
# 27. **Which of the following best describes the Adam optimizer?**
#     - A) It uses adaptive learning rates for each parameter and incorporates momentum
#     - B) It has a constant learning rate
#     - C) It only works with small datasets
#     - D) It removes the bias term
#     - **Answer: A) It uses adaptive learning rates for each parameter and incorporates momentum**
#
# 28. **What is a major advantage of using mini-batch gradient descent compared to batch gradient descent?**
#     - A) Faster convergence with a balance between computational efficiency and gradient accuracy
#     - B) Guaranteed convergence to the global minimum
#     - C) It always reduces training time
#     - D) It requires a fixed learning rate
#     - **Answer: A) Faster convergence with a balance between computational efficiency and gradient accuracy**
#
# 29. **Which optimizer uses adaptive learning rates that are based on past gradient updates, making it effective for sparse datasets?**
#     - A) AdaGrad
#     - B) SGD without Momentum
#     - C) Batch Gradient Descent
#     - D) Convex Optimization
#     - **Answer: A) AdaGrad**
#
# 30. **Which of these optimization techniques can help prevent the vanishing gradient problem?**
#     - A) RMSprop or Adam Optimizers
#     - B) Full-Batch Gradient Descent
#     - C) Learning Rate Decay
#     - D) Removing hidden layers
#     - **Answer: A) RMSprop or Adam Optimizers**

# %% [markdown]
# 31. **What is the purpose of gradient clipping during training?**
#    - A) To prevent the gradients from growing too large, ensuring stable training
#    - B) To increase the learning rate for faster convergence
#    - C) To reduce the number of epochs
#    - D) To eliminate hidden layers
#    - **Answer: A) To prevent the gradients from growing too large, ensuring stable training**
#
# 32. **Which technique can be used to speed up convergence during optimization by scaling the inputs?**
#    - A) Batch Normalization
#    - B) Gradient Clipping
#    - C) Learning Rate Decay
#    - D) Dropout
#    - **Answer: A) Batch Normalization**
#
# 33. **Which optimizer adjusts the learning rate for each parameter independently by considering the past gradient history?**
#    - A) AdaGrad
#    - B) SGD
#    - C) Momentum
#    - D) Batch Gradient Descent
#    - **Answer: A) AdaGrad**
#
# 34. **Which optimization method is most suitable for online learning where data arrives in a stream?**
#    - A) Stochastic Gradient Descent (SGD)
#    - B) Batch Gradient Descent
#    - C) Mini-Batch Gradient Descent
#    - D) Adam
#    - **Answer: A) Stochastic Gradient Descent (SGD)**
#
# 35. **Which optimizer uses a momentum term that accumulates past gradients to smooth out the update direction?**
#    - A) SGD with Momentum
#    - B) Adam
#    - C) AdaGrad
#    - D) Batch Gradient Descent
#    - **Answer: A) SGD with Momentum**
#
# 36. **What is the key feature of the Adam optimizer that makes it suitable for many deep learning applications?**
#    - A) It combines momentum and adaptive learning rates for each parameter
#    - B) It uses a fixed learning rate
#    - C) It eliminates biases
#    - D) It is designed specifically for shallow networks
#    - **Answer: A) It combines momentum and adaptive learning rates for each parameter**
#
# 37. **How does the learning rate decay improve training stability?**
#    - A) By reducing the learning rate over time, it helps the model settle in a minimum without overshooting
#    - B) By increasing the learning rate periodically
#    - C) By removing neurons that are not needed
#    - D) By adding biases to all neurons
#    - **Answer: A) By reducing the learning rate over time, it helps the model settle in a minimum without overshooting**
#
# 38. **Which optimizer is typically preferred for training very deep networks due to its robustness in handling both vanishing and exploding gradients?**
#    - A) Adam
#    - B) SGD without Momentum
#    - C) Batch Gradient Descent
#    - D) AdaGrad
#    - **Answer: A) Adam**
#
# 39. **Which type of gradient descent updates the weights after calculating the gradient based on a small batch of the dataset?**
#    - A) Mini-Batch Gradient Descent
#    - B) Stochastic Gradient Descent
#    - C) Batch Gradient Descent
#    - D) Full-Batch Gradient Descent
#    - **Answer: A) Mini-Batch Gradient Descent**
#
# 40. **Which optimization technique is designed to adjust the learning rate automatically for each parameter and is suitable for non-stationary objectives?**
#    - A) RMSprop
#    - B) Batch Gradient Descent
#    - C) Constant Learning Rate
#    - D) He Initialization
#    - **Answer: A) RMSprop**
#
# 41. **How does the Adadelta optimizer differ from AdaGrad?**
#    - A) It improves upon AdaGrad by preventing the learning rate from decaying to zero over time
#    - B) It keeps a fixed learning rate
#    - C) It eliminates biases
#    - D) It is used for linear networks only
#    - **Answer: A) It improves upon AdaGrad by preventing the learning rate from decaying to zero over time**
#
# 42. **Which of the following best describes "gradient explosion"?**
#    - A) Gradients grow excessively during backpropagation, leading to numerical instability
#    - B) Gradients vanish to zero
#    - C) Gradients stay constant
#    - D) Gradients always become negative
#    - **Answer: A) Gradients grow excessively during backpropagation, leading to numerical instability**
#
# 43. **How does RMSprop control the learning rate during training?**
#    - A) It divides the gradient by a moving average of the magnitudes of recent gradients
#    - B) It keeps a fixed learning rate
#    - C) It increases the learning rate after each epoch
#    - D) It removes the biases
#    - **Answer: A) It divides the gradient by a moving average of the magnitudes of recent gradients**
#
# 44. **Which learning rate schedule reduces the learning rate exponentially over time?**
#    - A) Exponential Decay
#    - B) Step Decay
#    - C) Constant Learning Rate
#    - D) Adaptive Decay
#    - **Answer: A) Exponential Decay**
#
# 45. **What is the benefit of using gradient clipping in deep networks?**
#    - A) To prevent the gradients from becoming too large and causing instability
#    - B) To eliminate biases
#    - C) To increase the batch size
#    - D) To reduce the training set size
#    - **Answer: A) To prevent the gradients from becoming too large and causing instability**
#
# 46. **Which of the following optimization techniques is most likely to handle sparse gradients well?**
#    - A) Adam
#    - B) SGD
#    - C) Batch Gradient Descent
#    - D) Mini-Batch Gradient Descent
#    - **Answer: A) Adam**
#
# 47. **What is the role of weight decay in optimization?**
#    - A) It helps prevent overfitting by adding a penalty for large weight values
#    - B) It increases the number of neurons
#    - C) It removes biases
#    - D) It decreases the learning rate
#    - **Answer: A) It helps prevent overfitting by adding a penalty for large weight values**
#
# 48. **How does the momentum term help in SGD optimization?**
#    - A) It accumulates a fraction of past gradients to smooth the update direction
#    - B) It decreases the learning rate exponentially
#    - C) It removes the activation function
#    - D) It always adds a bias term
#    - **Answer: A) It accumulates a fraction of past gradients to smooth the update direction**
#
# 49. **What is the main disadvantage of using a very small learning rate in optimization?**
#    - A) Training takes too long and might never reach an optimal solution
#    - B) Training converges too fast
#    - C) Gradients explode
#    - D) The model overfits immediately
#    - **Answer: A) Training takes too long and might never reach an optimal solution**
#
# 50. **Which optimizer is best suited for problems where the gradient can be very noisy?**
#    - A) Adam
#    - B) Batch Gradient Descent
#    - C) SGD without Momentum
#    - D) AdaGrad
#    - **Answer: A) Adam**
#
# 51. **How can a high learning rate affect optimization?**
#    - A) It can cause the model to overshoot the minimum and fail to converge
#    - B) It speeds up convergence consistently
#    - C) It eliminates biases
#    - D) It makes the model learn fewer features
#    - **Answer: A) It can cause the model to overshoot the minimum and fail to converge**
#
# 52. **Which technique is commonly used to reduce the risk of overfitting during training?**
#    - A) Dropout
#    - B) Increase the learning rate exponentially
#    - C) Remove biases
#    - D) Keep weights constant
#    - **Answer: A) Dropout**
#
# 53. **Which of the following is a key feature of the AdaGrad optimizer?**
#    - A) It adjusts the learning rate for each parameter based on the sum of past gradients
#    - B) It uses a fixed learning rate
#    - C) It eliminates biases
#    - D) It is suitable only for linear regression
#    - **Answer: A) It adjusts the learning rate for each parameter based on the sum of past gradients**
#
# 54. **Which optimizer would be preferred if we need an adaptive learning rate that decreases during training?**
#    - A) RMSprop
#    - B) SGD with Momentum
#    - C) Batch Gradient Descent
#    - D) Random Descent
#    - **Answer: A) RMSprop**
#
# 55. **What is the impact of using mini-batch gradient descent?**
#    - A) It provides a balance between noisy updates and computational efficiency
#    - B) It always converges to the global minimum
#    - C) It eliminates biases
#    - D) It increases the number of neurons
#    - **Answer: A) It provides a balance between noisy updates and computational efficiency**
#
# 56. **Which type of learning rate decay multiplies the learning rate by a constant factor at fixed intervals?**
#    - A) Step Decay
#    - B) Adaptive Decay
#    - C) Exponential Decay
#    - D) Constant Rate
#    - **Answer: A) Step Decay**
#
# 57. **What is a common technique to prevent the vanishing gradient problem in deep networks?**
#    - A) Use activation functions like ReLU or Leaky ReLU
#    - B) Use a very high learning rate
#    - C) Eliminate biases
#    - D) Increase the training dataset
#    - **Answer: A) Use activation functions like ReLU or Leaky ReLU**
#
# 58. **Which optimizer makes use of momentum and adaptive learning rates to stabilize updates during training?**
#    - A) Adam
#    - B) SGD without Momentum
#    - C) Batch Gradient Descent
#    - D) AdaGrad
#    - **Answer: A) Adam**
#
# 59. **How does weight decay help improve generalization during training?**
#    - A) It penalizes large weights, which reduces the model's complexity and helps prevent overfitting
#    - B) It eliminates hidden layers
#    - C) It reduces the batch size
#    - D) It keeps the weights constant
#    - **Answer: A) It penalizes large weights, which reduces the model's complexity and helps prevent overfitting**
#
# 60. **Which optimizer is known for using two separate moving averages, one for the gradient and one for the squared gradient?**
#    - A) Adam
#    - B) SGD with Momentum
#    - C) RMSprop
#    - D) AdaGrad
#    - **Answer: A) Adam**

# %% [markdown]
# 61. **Which learning rate schedule involves gradually decreasing the learning rate by a fixed percentage each epoch?**
#    - A) Exponential Decay
#    - B) Constant Learning Rate
#    - C) Step Decay
#    - D) Random Decay
#    - **Answer: A) Exponential Decay**
#
# 62. **Which type of optimizer is best suited for dealing with sparse datasets and adaptive learning rates?**
#    - A) AdaGrad
#    - B) SGD without Momentum
#    - C) Batch Gradient Descent
#    - D) Linear Optimizer
#    - **Answer: A) AdaGrad**
#
# 63. **Which of the following is a benefit of using gradient clipping during training?**
#    - A) It prevents gradients from growing excessively large, maintaining numerical stability
#    - B) It removes the bias from the network
#    - C) It keeps weights constant
#    - D) It increases the learning rate exponentially
#    - **Answer: A) It prevents gradients from growing excessively large, maintaining numerical stability**
#
# 64. **How does weight decay contribute to optimization in neural networks?**
#    - A) It adds a regularization term to discourage large weights and helps to prevent overfitting
#    - B) It reduces the number of neurons
#    - C) It keeps gradients constant
#    - D) It removes hidden layers
#    - **Answer: A) It adds a regularization term to discourage large weights and helps to prevent overfitting**
#
# 65. **Which of the following describes the role of momentum in an optimization algorithm?**
#    - A) It smoothens the update trajectory by accumulating a portion of past gradients
#    - B) It decreases the learning rate exponentially
#    - C) It eliminates the use of biases
#    - D) It increases the batch size
#    - **Answer: A) It smoothens the update trajectory by accumulating a portion of past gradients**
#
# 66. **What effect does the vanishing gradient problem have during backpropagation?**
#    - A) It prevents the gradients from effectively updating the weights in earlier layers
#    - B) It makes gradients grow excessively large
#    - C) It increases the batch size
#    - D) It ensures weights are always positive
#    - **Answer: A) It prevents the gradients from effectively updating the weights in earlier layers**
#
# 67. **Which optimizer uses an adaptive learning rate and considers the squared gradient to update each parameter individually?**
#    - A) RMSprop
#    - B) SGD without Momentum
#    - C) Batch Gradient Descent
#    - D) He Initialization
#    - **Answer: A) RMSprop**
#
# 68. **What is the main advantage of using mini-batch gradient descent?**
#    - A) It balances noisy gradient updates and computation efficiency, improving convergence
#    - B) It always guarantees convergence to the global minimum
#    - C) It keeps learning rates constant
#    - D) It eliminates biases
#    - **Answer: A) It balances noisy gradient updates and computation efficiency, improving convergence**
#
# 69. **What is the role of bias correction in the Adam optimizer?**
#    - A) To correct the biased estimates of the gradient and squared gradient during early training
#    - B) To eliminate all biases in the network
#    - C) To keep learning rates constant
#    - D) To add noise to inputs
#    - **Answer: A) To correct the biased estimates of the gradient and squared gradient during early training**
#
# 70. **Which type of gradient descent is more computationally efficient, especially with large datasets?**
#    - A) Mini-Batch Gradient Descent
#    - B) Batch Gradient Descent
#    - C) Full-Batch Gradient Descent
#    - D) Deterministic Gradient Descent
#    - **Answer: A) Mini-Batch Gradient Descent**
#
# 71. **How does the step decay learning rate schedule work?**
#    - A) The learning rate is decreased by a fixed amount after every few epochs
#    - B) The learning rate increases after every epoch
#    - C) The learning rate is constant throughout training
#    - D) The learning rate randomly changes
#    - **Answer: A) The learning rate is decreased by a fixed amount after every few epochs**
#
# 72. **Which optimizer is most effective when the dataset is very noisy and the gradient directions fluctuate significantly?**
#    - A) Adam
#    - B) SGD without Momentum
#    - C) Batch Gradient Descent
#    - D) Adadelta
#    - **Answer: A) Adam**
#
# 73. **What is the benefit of using learning rate decay in optimization?**
#    - A) It ensures stable convergence by reducing the learning rate gradually
#    - B) It keeps the learning rate constant
#    - C) It reduces the number of neurons
#    - D) It eliminates biases
#    - **Answer: A) It ensures stable convergence by reducing the learning rate gradually**
#
# 74. **Which of the following helps to mitigate the problem of exploding gradients?**
#    - A) Gradient Clipping
#    - B) Increasing learning rate exponentially
#    - C) Removing all biases
#    - D) Keeping weights constant
#    - **Answer: A) Gradient Clipping**
#
# 75. **Which optimizer can help prevent poor updates in the case of sparse data by using adaptive learning rates for each parameter?**
#    - A) AdaGrad
#    - B) SGD with Momentum
#    - C) Batch Gradient Descent
#    - D) He Initialization
#    - **Answer: A) AdaGrad**
#
# 76. **What is the role of batch normalization in deep networks?**
#    - A) To normalize inputs to each layer, improving stability and training speed
#    - B) To eliminate biases
#    - C) To decrease the number of layers
#    - D) To remove gradient descent
#    - **Answer: A) To normalize inputs to each layer, improving stability and training speed**
#
# 77. **Which type of optimizer is best suited for training deep networks with significant internal covariate shift?**
#    - A) Adam with Batch Normalization
#    - B) Batch Gradient Descent
#    - C) SGD without Momentum
#    - D) Adadelta
#    - **Answer: A) Adam with Batch Normalization**
#
# 78. **How does the momentum term in optimization affect convergence?**
#    - A) It accelerates convergence by smoothing the gradient descent path
#    - B) It makes gradients vanish
#    - C) It increases the number of neurons
#    - D) It adds noise to the input layer
#    - **Answer: A) It accelerates convergence by smoothing the gradient descent path**
#
# 79. **What is a key benefit of using the RMSprop optimizer?**
#    - A) It helps keep the learning rate controlled based on a moving average of recent squared gradients
#    - B) It eliminates biases
#    - C) It uses a fixed learning rate
#    - D) It reduces the batch size
#    - **Answer: A) It helps keep the learning rate controlled based on a moving average of recent squared gradients**
#
# 80. **Which learning rate scheduling strategy ensures that the learning rate decreases as the model starts converging?**
#    - A) Learning Rate Decay
#    - B) Constant Rate
#    - C) Increasing Learning Rate
#    - D) Bias Reduction
#    - **Answer: A) Learning Rate Decay**
#
# 81. **Which of the following is an advantage of using the Adam optimizer?**
#    - A) It combines adaptive learning rates with momentum, making it effective for non-stationary objectives
#    - B) It keeps weights constant
#    - C) It always uses a fixed learning rate
#    - D) It removes biases from the network
#    - **Answer: A) It combines adaptive learning rates with momentum, making it effective for non-stationary objectives**
#
# 82. **How does gradient clipping affect the optimization process in neural networks?**
#    - A) It prevents gradients from growing too large and causing training instability
#    - B) It reduces the number of epochs required
#    - C) It eliminates the need for learning rate scheduling
#    - D) It keeps the weight values constant
#    - **Answer: A) It prevents gradients from growing too large and causing training instability**
#
# 83. **What is the effect of using a small learning rate in optimization?**
#    - A) It can lead to very slow convergence, and the model may get stuck in a suboptimal solution
#    - B) It always accelerates convergence
#    - C) It makes gradients explode
#    - D) It adds biases to each neuron
#    - **Answer: A) It can lead to very slow convergence, and the model may get stuck in a suboptimal solution**
#
# 84. **Which optimization algorithm uses the average of past squared gradients to control the learning rate for each parameter?**
#    - A) RMSprop
#    - B) Batch Gradient Descent
#    - C) AdaGrad
#    - D) SGD with Momentum
#    - **Answer: A) RMSprop**
#
# 85. **What is the purpose of using dropout in training deep neural networks?**
#    - A) To reduce overfitting by randomly ignoring certain neurons during training
#    - B) To increase the number of hidden layers
#    - C) To eliminate biases
#    - D) To reduce the learning rate
#    - **Answer: A) To reduce overfitting by randomly ignoring certain neurons during training**
#
# 86. **Which optimizer adapts the learning rate for each parameter by combining the benefits of AdaGrad and RMSprop?**
#    - A) Adam
#    - B) SGD without Momentum
#    - C) Batch Gradient Descent
#    - D) Adadelta
#    - **Answer: A) Adam**
#
# 87. **How does the He initialization benefit optimization with ReLU activation functions?**
#    - A) By scaling the variance appropriately, it helps keep the activation values in a healthy range, preventing vanishing or exploding gradients
#    - B) By removing biases
#    - C) By reducing the learning rate exponentially
#    - D) By making all weights constant
#    - **Answer: A) By scaling the variance appropriately, it helps keep the activation values in a healthy range, preventing vanishing or exploding gradients**
#
# 88. **What is the effect of using batch normalization in optimization?**
#    - A) It normalizes layer inputs, which improves training speed and stability
#    - B) It decreases the learning rate
#    - C) It adds noise to gradients
#    - D) It keeps weights constant
#    - **Answer: A) It normalizes layer inputs, which improves training speed and stability**
#
# 89. **Which learning rate schedule divides the learning rate by a certain factor at fixed intervals during training?**
#    - A) Step Decay
#    - B) Adaptive Decay
#    - C) Exponential Decay
#    - D) Linear Rate Schedule
#    - **Answer: A) Step Decay**
#
# 90. **Which technique is useful for handling vanishing gradients in deep networks?**
#    - A) Using ReLU activation functions
#    - B) Removing biases
#    - C) Using sigmoid activation for all layers
#    - D) Increasing the batch size
#    - **Answer: A) Using ReLU activation functions**
#
# 91. **Which optimization technique adapts learning rates for each parameter and is especially effective for complex models and deep learning?**
#    - A) Adam
#    - B) Batch Gradient Descent
#    - C) SGD with Constant Learning Rate
#    - D) Adadelta
#    - **Answer: A) Adam**
#
# 92. **Which optimizer helps avoid large oscillations by controlling the learning rate with a moving average of squared gradients?**
#    - A) RMSprop
#    - B) AdaGrad
#    - C) Batch Gradient Descent
#    - D) SGD with Momentum
#    - **Answer: A) RMSprop**
#
# 93. **How does using momentum help improve the effectiveness of SGD?**
#    - A) By accumulating a fraction of previous gradients, it helps to maintain a consistent direction during training
#    - B) By reducing the learning rate
#    - C) By adding random noise
#    - D) By making weights constant
#    - **Answer: A) By accumulating a fraction of previous gradients, it helps to maintain a consistent direction during training**
#
# 94. **Which learning rate decay method exponentially reduces the learning rate as training progresses?**
#    - A) Exponential Decay
#    - B) Step Decay
#    - C) Constant Rate
#    - D) Random Decay
#    - **Answer: A) Exponential Decay**
#
# 95. **What is a key disadvantage of using a very high learning rate in optimization?**
#    - A) The model may oscillate around the optimal solution and fail to converge
#    - B) It speeds up convergence
#    - C) It eliminates hidden layers
#    - D) It always reduces overfitting
#    - **Answer: A) The model may oscillate around the optimal solution and fail to converge**
#
# 96. **How does
#
#  weight decay prevent overfitting in neural networks?**
#    - A) By adding a penalty to large weights, which encourages simpler models with smaller weights
#    - B) By increasing learning rate
#    - C) By adding biases
#    - D) By making weights constant
#    - **Answer: A) By adding a penalty to large weights, which encourages simpler models with smaller weights**
#
# 97. **Which optimizer combines adaptive learning rates with momentum to achieve fast convergence?**
#    - A) Adam
#    - B) SGD without Momentum
#    - C) Batch Gradient Descent
#    - D) RMSprop
#    - **Answer: A) Adam**
#
# 98. **What role does dropout play in preventing overfitting in deep neural networks?**
#    - A) It randomly drops neurons during training to reduce co-adaptation
#    - B) It keeps all neurons active
#    - C) It removes biases
#    - D) It increases the learning rate
#    - **Answer: A) It randomly drops neurons during training to reduce co-adaptation**
#
# 99. **Which technique is commonly used to normalize the output of each layer in a neural network to improve training?**
#    - A) Batch Normalization
#    - B) Gradient Clipping
#    - C) Dropout
#    - D) He Initialization
#    - **Answer: A) Batch Normalization**
#
# 100. **What is the primary goal of using optimization techniques in neural networks?**
#     - A) To minimize the loss function by adjusting model parameters efficiently
#     - B) To increase the number of layers
#     - C) To remove biases
#     - D) To increase learning rate indefinitely
#     - **Answer: A) To minimize the loss function by adjusting model parameters efficiently**

# %% [markdown]
# ### **Lecture 9: Regularization Techniques in Neural Networks**
#
# 1. **What is the main purpose of regularization in neural networks?**
#    - A) To prevent overfitting by adding constraints or penalties to the model
#    - B) To increase the number of neurons
#    - C) To maximize training accuracy
#    - D) To reduce the computational cost
#    - **Answer: A) To prevent overfitting by adding constraints or penalties to the model**
#
# 2. **Which of the following is a common regularization technique in neural networks?**
#    - A) Dropout
#    - B) Increasing the learning rate
#    - C) Removing biases
#    - D) Adding more hidden layers
#    - **Answer: A) Dropout**
#
# 3. **What does L1 regularization do in a neural network?**
#    - A) It adds a penalty to the absolute value of weights, encouraging sparsity
#    - B) It increases the learning rate
#    - C) It eliminates neurons
#    - D) It reduces batch size
#    - **Answer: A) It adds a penalty to the absolute value of weights, encouraging sparsity**
#
# 4. **Which type of regularization technique helps encourage a sparse network by forcing some weights to become zero?**
#    - A) L1 Regularization
#    - B) L2 Regularization
#    - C) Dropout
#    - D) Batch Normalization
#    - **Answer: A) L1 Regularization**
#
# 5. **How does L2 regularization affect the model's weights?**
#    - A) It adds a penalty proportional to the square of the weight values, discouraging large weights
#    - B) It eliminates all biases
#    - C) It removes hidden layers
#    - D) It increases learning rate
#    - **Answer: A) It adds a penalty proportional to the square of the weight values, discouraging large weights**
#
# 6. **Which of these techniques is used to randomly ignore some neurons during training to prevent overfitting?**
#    - A) Dropout
#    - B) Weight Clipping
#    - C) Momentum
#    - D) Weight Decay
#    - **Answer: A) Dropout**
#
# 7. **What is the primary benefit of L2 regularization?**
#    - A) It helps prevent overfitting by penalizing large weight values
#    - B) It increases the learning rate
#    - C) It eliminates biases
#    - D) It adds more neurons
#    - **Answer: A) It helps prevent overfitting by penalizing large weight values**
#
# 8. **How does dropout work during training?**
#    - A) It randomly deactivates a subset of neurons during each forward pass
#    - B) It keeps all neurons active
#    - C) It increases the batch size
#    - D) It reduces the learning rate
#    - **Answer: A) It randomly deactivates a subset of neurons during each forward pass**
#
# 9. **Which regularization technique is suitable for encouraging sparsity in a neural network?**
#    - A) L1 Regularization
#    - B) Batch Normalization
#    - C) Dropout
#    - D) Weight Decay
#    - **Answer: A) L1 Regularization**
#
# 10. **How does weight decay relate to L2 regularization?**
#     - A) Weight decay is another name for L2 regularization, adding a penalty based on the magnitude of weights
#     - B) Weight decay increases the batch size
#     - C) Weight decay eliminates hidden layers
#     - D) Weight decay decreases learning rate
#     - **Answer: A) Weight decay is another name for L2 regularization, adding a penalty based on the magnitude of weights**
#
# 11. **What is the effect of using dropout during neural network training?**
#     - A) It reduces the likelihood of overfitting by preventing neurons from relying too much on each other
#     - B) It eliminates biases
#     - C) It increases the batch size
#     - D) It reduces the number of layers
#     - **Answer: A) It reduces the likelihood of overfitting by preventing neurons from relying too much on each other**
#
# 12. **Which regularization technique helps stabilize training by adding random noise to the network?**
#     - A) Dropout
#     - B) Weight Decay
#     - C) L1 Regularization
#     - D) Increasing learning rate
#     - **Answer: A) Dropout**
#
# 13. **What is the difference between L1 and L2 regularization?**
#     - A) L1 adds a penalty based on the absolute value of weights, while L2 adds a penalty based on the squared values
#     - B) L1 increases the batch size, while L2 decreases it
#     - C) L1 is used to add more neurons, while L2 removes neurons
#     - D) L1 and L2 regularizations are identical
#     - **Answer: A) L1 adds a penalty based on the absolute value of weights, while L2 adds a penalty based on the squared values**
#
# 14. **Which regularization technique reduces the complexity of a model by forcing some weights to become zero?**
#     - A) L1 Regularization
#     - B) L2 Regularization
#     - C) Batch Normalization
#     - D) Momentum
#     - **Answer: A) L1 Regularization**
#
# 15. **How does L2 regularization affect the loss function of a neural network?**
#     - A) It adds a penalty term proportional to the sum of squared weight values
#     - B) It increases the learning rate
#     - C) It decreases the loss directly
#     - D) It eliminates biases
#     - **Answer: A) It adds a penalty term proportional to the sum of squared weight values**
#
# 16. **What is a key advantage of using dropout as a regularization technique?**
#     - A) It prevents overfitting by making the network less sensitive to specific neuron activations
#     - B) It increases the batch size
#     - C) It eliminates biases
#     - D) It ensures weights stay constant
#     - **Answer: A) It prevents overfitting by making the network less sensitive to specific neuron activations**
#
# 17. **Which regularization method is effective for improving the generalization capability of a model by averaging multiple sub-models during training?**
#     - A) Dropout
#     - B) L1 Regularization
#     - C) Gradient Clipping
#     - D) He Initialization
#     - **Answer: A) Dropout**
#
# 18. **Which technique adds a regularization term to the loss function to penalize large weight values?**
#     - A) L2 Regularization
#     - B) Batch Normalization
#     - C) Dropout
#     - D) Gradient Clipping
#     - **Answer: A) L2 Regularization**
#
# 19. **What happens to the weights of a neural network when using L1 regularization?**
#     - A) Some weights become exactly zero, resulting in a sparse model
#     - B) All weights increase
#     - C) Weights stay constant
#     - D) The learning rate decreases
#     - **Answer: A) Some weights become exactly zero, resulting in a sparse model**
#
# 20. **How does adding dropout during training affect the number of active neurons in a layer?**
#     - A) It reduces the number of active neurons by randomly deactivating some of them
#     - B) It increases the number of active neurons
#     - C) It keeps all neurons active
#     - D) It doubles the active neurons
#     - **Answer: A) It reduces the number of active neurons by randomly deactivating some of them**
#
# 21. **Which regularization method aims to reduce overfitting by forcing the weights to be small?**
#     - A) L2 Regularization
#     - B) Momentum
#     - C) Increasing the learning rate
#     - D) Batch Normalization
#     - **Answer: A) L2 Regularization**
#
# 22. **How does L1 regularization contribute to feature selection in a neural network?**
#     - A) By setting some weights to zero, it effectively selects the most important features
#     - B) By increasing the number of features
#     - C) By adding random noise to features
#     - D) By reducing the number of hidden layers
#     - **Answer: A) By setting some weights to zero, it effectively selects the most important features**
#
# 23. **Which regularization method would you use if you want to penalize large weight values but do not want to enforce sparsity?**
#     - A) L2 Regularization
#     - B) L1 Regularization
#     - C) Dropout
#     - D) Batch Normalization
#     - **Answer: A) L2 Regularization**
#
# 24. **Which of these techniques is typically not considered a regularization method?**
#     - A) Gradient Clipping
#     - B) L2 Regularization
#     - C) Dropout
#     - D) L1 Regularization
#     - **Answer: A) Gradient Clipping**
#
# 25. **How does using dropout during inference (testing) differ from using it during training?**
#     - A) During inference, dropout is turned off, and all neurons are used
#     - B) During inference, more neurons are dropped
#     - C) During inference, only biases are removed
#     - D) During inference, dropout is increased
#     - **Answer: A) During inference, dropout is turned off, and all neurons are used**
#
# 26. **What is the effect of weight decay on the learning process in a neural network?**
#     - A) It reduces the magnitude of weights over time, helping to prevent overfitting
#     - B) It increases the learning rate
#     - C) It keeps biases constant
#     - D) It eliminates hidden layers
#     - **Answer: A) It reduces the magnitude of weights over time, helping to prevent overfitting**
#
# 27. **Which of the following is a key difference between L1 and L2 regularization in terms of their effects on weights?**
#     - A) L1 can lead to sparse weights by making some exactly zero, while L2 discourages large weights but keeps them non-zero
#     - B) L1 always increases weights, while L2 reduces them
#     - C) L1 is not suitable for neural networks, while L2 is
#     - D) L1 and L2 have the same effect on weights
#     - **Answer: A) L1 can lead to sparse weights by making some exactly zero, while L2 discourages large weights but keeps them non-zero**
#
# 28. **How does adding dropout help in reducing the risk of overfitting in a neural network?**
#     - A) By making the network less dependent on individual neurons by randomly dropping them during training
#     - B) By increasing the learning rate
#     - C) By eliminating biases
#     - D) By adding more layers
#     - **Answer: A) By making the network less dependent on individual neurons by
#
#  randomly dropping them during training**
#
# 29. **What is the primary reason for using regularization techniques in neural networks?**
#     - A) To improve the generalization ability of the model by preventing overfitting
#     - B) To make the model more complex
#     - C) To reduce computational cost
#     - D) To increase the number of training samples
#     - **Answer: A) To improve the generalization ability of the model by preventing overfitting**
#
# 30. **How does L2 regularization affect the loss function in a neural network?**
#     - A) It adds a penalty term that is proportional to the sum of the squared values of the weights
#     - B) It eliminates the use of biases
#     - C) It increases the learning rate over time
#     - D) It reduces the number of epochs
#     - **Answer: A) It adds a penalty term that is proportional to the sum of the squared values of the weights**

# %% [markdown]
# 31. **Which of these regularization techniques penalizes the magnitude of the weights in a neural network?**
#    - A) L2 Regularization
#    - B) Batch Normalization
#    - C) Gradient Clipping
#    - D) Increasing the learning rate
#    - **Answer: A) L2 Regularization**
#
# 32. **How does dropout encourage more robust features in a neural network?**
#    - A) By forcing neurons to learn independently by randomly dropping some during training
#    - B) By adding noise to each layer
#    - C) By reducing the learning rate to zero
#    - D) By increasing the number of hidden layers
#    - **Answer: A) By forcing neurons to learn independently by randomly dropping some during training**
#
# 33. **Which regularization technique is often used to penalize large weight values to reduce model complexity?**
#    - A) Weight Decay (L2 Regularization)
#    - B) Dropout
#    - C) Batch Normalization
#    - D) He Initialization
#    - **Answer: A) Weight Decay (L2 Regularization)**
#
# 34. **What is the result of using L1 regularization on the loss function of a neural network?**
#    - A) A penalty proportional to the sum of the absolute values of the weights is added to the loss function
#    - B) The number of neurons is increased
#    - C) All weights are normalized
#    - D) The learning rate is made constant
#    - **Answer: A) A penalty proportional to the sum of the absolute values of the weights is added to the loss function**
#
# 35. **How does L2 regularization prevent overfitting?**
#    - A) By adding a penalty to larger weight values, it reduces the likelihood that the model will become overly complex
#    - B) By increasing the number of epochs
#    - C) By adding new layers to the model
#    - D) By removing the activation function
#    - **Answer: A) By adding a penalty to larger weight values, it reduces the likelihood that the model will become overly complex**
#
# 36. **Which of the following regularization techniques is most likely to encourage sparsity in the weights of a model?**
#    - A) L1 Regularization
#    - B) Dropout
#    - C) Batch Normalization
#    - D) Momentum
#    - **Answer: A) L1 Regularization**
#
# 37. **What happens to neurons during training when dropout is applied?**
#    - A) Neurons are randomly ignored during each forward pass, which forces the network to be more redundant
#    - B) Neurons are eliminated permanently
#    - C) Neurons are made constant
#    - D) Neurons are doubled
#    - **Answer: A) Neurons are randomly ignored during each forward pass, which forces the network to be more redundant**
#
# 38. **How does weight decay differ from dropout?**
#    - A) Weight decay penalizes large weights by adding a regularization term, while dropout randomly ignores neurons during training
#    - B) Weight decay increases the learning rate, while dropout decreases it
#    - C) Weight decay adds biases, while dropout removes them
#    - D) Weight decay eliminates hidden layers
#    - **Answer: A) Weight decay penalizes large weights by adding a regularization term, while dropout randomly ignores neurons during training**
#
# 39. **Which type of regularization works by modifying the network during training and averaging across multiple different models?**
#    - A) Dropout
#    - B) L1 Regularization
#    - C) Gradient Boosting
#    - D) Learning Rate Decay
#    - **Answer: A) Dropout**
#
# 40. **How is the loss function modified when applying L1 regularization?**
#    - A) A penalty proportional to the sum of absolute weight values is added to the original loss
#    - B) The learning rate is increased over time
#    - C) Biases are eliminated
#    - D) Hidden layers are removed
#    - **Answer: A) A penalty proportional to the sum of absolute weight values is added to the original loss**
#
# 41. **What effect does L2 regularization have on weight updates during training?**
#    - A) It encourages the weights to be smaller by adding a penalty for large weights
#    - B) It eliminates all biases
#    - C) It reduces the number of neurons
#    - D) It increases learning rate
#    - **Answer: A) It encourages the weights to be smaller by adding a penalty for large weights**
#
# 42. **What is a key advantage of using L1 regularization for feature selection?**
#    - A) It forces some weights to be exactly zero, effectively reducing the number of features
#    - B) It increases the number of features
#    - C) It keeps all features constant
#    - D) It always reduces the number of epochs
#    - **Answer: A) It forces some weights to be exactly zero, effectively reducing the number of features**
#
# 43. **Which regularization technique reduces overfitting by keeping neurons independent during training?**
#    - A) Dropout
#    - B) L2 Regularization
#    - C) Momentum
#    - D) Learning Rate Scheduling
#    - **Answer: A) Dropout**
#
# 44. **How does L2 regularization differ from L1 regularization in terms of penalizing weights?**
#    - A) L2 penalizes the square of the weights, whereas L1 penalizes the absolute values of the weights
#    - B) L2 and L1 penalize weights in the same way
#    - C) L2 eliminates all weights, while L1 keeps them constant
#    - D) L2 reduces the learning rate, while L1 increases it
#    - **Answer: A) L2 penalizes the square of the weights, whereas L1 penalizes the absolute values of the weights**
#
# 45. **What is the primary benefit of using dropout as a regularization technique?**
#    - A) It prevents the network from relying too heavily on particular neurons by randomly dropping them during training
#    - B) It increases the number of hidden layers
#    - C) It reduces the learning rate over time
#    - D) It removes all biases
#    - **Answer: A) It prevents the network from relying too heavily on particular neurons by randomly dropping them during training**
#
# 46. **Which regularization technique helps to make the weight distribution more uniform, avoiding very large values?**
#    - A) L2 Regularization
#    - B) L1 Regularization
#    - C) Dropout
#    - D) Gradient Clipping
#    - **Answer: A) L2 Regularization**
#
# 47. **How does using L1 regularization affect the model's weight values?**
#    - A) It forces some weights to become zero, creating sparsity
#    - B) It increases all weights equally
#    - C) It reduces the batch size
#    - D) It eliminates hidden neurons
#    - **Answer: A) It forces some weights to become zero, creating sparsity**
#
# 48. **What is the primary difference between L2 regularization and weight decay?**
#    - A) There is no primary difference; weight decay is often considered an implementation of L2 regularization
#    - B) L2 is for convolutional networks, while weight decay is for recurrent networks
#    - C) Weight decay only increases weights, while L2 reduces them
#    - D) Weight decay only applies to biases
#    - **Answer: A) There is no primary difference; weight decay is often considered an implementation of L2 regularization**
#
# 49. **How does dropout affect the forward pass during training?**
#    - A) It randomly sets the output of some neurons to zero
#    - B) It doubles the weights of each neuron
#    - C) It removes all biases
#    - D) It decreases the batch size
#    - **Answer: A) It randomly sets the output of some neurons to zero**
#
# 50. **How is dropout typically applied during inference?**
#    - A) Dropout is turned off during inference, and all neurons are used
#    - B) More neurons are dropped during inference
#    - C) Dropout is increased during inference
#    - D) Only biases are used during inference
#    - **Answer: A) Dropout is turned off during inference, and all neurons are used**
#
# 51. **Which of the following is a major benefit of L2 regularization over L1 regularization?**
#    - A) L2 regularization prevents very large weights without forcing them to be zero, preserving more features
#    - B) L2 regularization increases weights
#    - C) L2 reduces the learning rate more effectively
#    - D) L2 removes biases
#    - **Answer: A) L2 regularization prevents very large weights without forcing them to be zero, preserving more features**
#
# 52. **Which regularization technique aims to reduce model complexity by penalizing the magnitude of the weights?**
#    - A) L2 Regularization
#    - B) Batch Normalization
#    - C) Gradient Boosting
#    - D) Dropout
#    - **Answer: A) L2 Regularization**
#
# 53. **Which type of regularization technique is effective in reducing the dependency on particular neurons by making the network redundant?**
#    - A) Dropout
#    - B) L1 Regularization
#    - C) Batch Normalization
#    - D) Weight Decay
#    - **Answer: A) Dropout**
#
# 54. **How does L1 regularization help in feature selection during training?**
#    - A) It forces less important features to have a weight of zero
#    - B) It increases the number of features
#    - C) It doubles the weight of each feature
#    - D) It adds random noise to features
#    - **Answer: A) It forces less important features to have a weight of zero**
#
# 55. **Which of the following regularization methods applies a penalty term that is proportional to the magnitude of the weight vector?**
#    - A) L1 Regularization
#    - B) L2 Regularization
#    - C) Dropout
#    - D) Momentum
#    - **Answer: A) L1 Regularization**
#
# 56. **Which regularization technique penalizes the squared magnitude of weights to prevent overfitting?**
#    - A) L2 Regularization
#    - B) L1 Regularization
#    - C) Dropout
#    - D) Batch Normalization
#    - **Answer: A) L2 Regularization**
#
# 57. **How does dropout help to prevent overfitting in neural networks?**
#    - A) By randomly dropping neurons during training, it prevents the network from becoming overly reliant on specific neurons
#    - B) By adding more neurons to the network
#    - C) By keeping all neurons active throughout training
#    - D) By reducing the batch size
#    - **Answer: A) By randomly dropping neurons during training, it prevents the network from becoming overly reliant on specific neurons**
#
# 58. **Which regularization technique ensures that neurons are not co-adapting too much during training?**
#    - A) Dropout
#    - B) L2 Regularization
#    - C) He Initialization
#    - D) Batch Normalization
#    - **Answer: A) Dropout**
#
# 59. **What is the effect of using L2 regularization in neural network training?**
#    - A) It discourages large weights by adding a penalty proportional to their squared magnitude
#    - B) It doubles the number of neurons
#    - C) It eliminates biases
#    - D) It reduces the learning rate exponentially
#    - **Answer: A) It discourages large weights by adding a penalty proportional to their squared magnitude**
#
# 60. **Which technique helps to prevent overfitting by ignoring neurons randomly during training?**
#    - A) Dropout
#    - B) Gradient Clipping
#    - C) L1 Regularization
#    - D) Momentum
#    - **Answer: A) Dropout**

# %% [markdown]
# 61. **How does weight decay contribute to regularization in a neural network?**
#    - A) By adding a penalty to the weight values, discouraging large weights and preventing overfitting
#    - B) By increasing the number of neurons
#    - C) By eliminating biases
#    - D) By increasing learning rate exponentially
#    - **Answer: A) By adding a penalty to the weight values, discouraging large weights and preventing overfitting**
#
# 62. **What is the main effect of using dropout during training?**
#    - A) It makes neurons less reliant on others by randomly deactivating them, reducing overfitting
#    - B) It increases the number of neurons
#    - C) It keeps all neurons active
#    - D) It makes the network deeper
#    - **Answer: A) It makes neurons less reliant on others by randomly deactivating them, reducing overfitting**
#
# 63. **Which of these regularization techniques helps to create a sparse model by setting some of the weights to zero?**
#    - A) L1 Regularization
#    - B) L2 Regularization
#    - C) Dropout
#    - D) Batch Normalization
#    - **Answer: A) L1 Regularization**
#
# 64. **What is the purpose of using L2 regularization in a neural network?**
#    - A) To penalize large weight values by adding a squared weight term to the cost function
#    - B) To remove all biases from the network
#    - C) To increase the learning rate exponentially
#    - D) To make weights constant
#    - **Answer: A) To penalize large weight values by adding a squared weight term to the cost function**
#
# 65. **Which type of regularization encourages the network to use fewer features by forcing some weights to be zero?**
#    - A) L1 Regularization
#    - B) L2 Regularization
#    - C) Dropout
#    - D) Momentum
#    - **Answer: A) L1 Regularization**
#
# 66. **How does using dropout during training help to prevent overfitting?**
#    - A) It randomly drops units (neurons), preventing the model from relying too heavily on any one of them
#    - B) It doubles the number of units in the network
#    - C) It reduces the learning rate
#    - D) It removes biases
#    - **Answer: A) It randomly drops units (neurons), preventing the model from relying too heavily on any one of them**
#
# 67. **Which regularization technique adds a penalty to the cost function based on the L2 norm of the weights?**
#    - A) L2 Regularization
#    - B) Dropout
#    - C) Batch Normalization
#    - D) Learning Rate Decay
#    - **Answer: A) L2 Regularization**
#
# 68. **Which regularization method forces some of the weights to become exactly zero?**
#    - A) L1 Regularization
#    - B) L2 Regularization
#    - C) Dropout
#    - D) Weight Decay
#    - **Answer: A) L1 Regularization**
#
# 69. **How does L2 regularization modify the optimization objective in neural networks?**
#    - A) By adding a term to the cost function proportional to the square of the weight values
#    - B) By eliminating hidden layers
#    - C) By decreasing the batch size
#    - D) By reducing learning rate
#    - **Answer: A) By adding a term to the cost function proportional to the square of the weight values**
#
# 70. **What is the primary purpose of using dropout during training in neural networks?**
#    - A) To reduce overfitting by randomly dropping out units
#    - B) To increase the number of epochs
#    - C) To eliminate biases
#    - D) To reduce the learning rate exponentially
#    - **Answer: A) To reduce overfitting by randomly dropping out units**
#
# 71. **Which regularization technique is used to enforce sparsity in the model by encouraging weights to be zero?**
#    - A) L1 Regularization
#    - B) L2 Regularization
#    - C) Dropout
#    - D) Batch Normalization
#    - **Answer: A) L1 Regularization**
#
# 72. **How does using dropout help in improving model robustness?**
#    - A) By forcing the model to learn to work with different subsets of neurons
#    - B) By removing biases
#    - C) By reducing the batch size
#    - D) By increasing the learning rate
#    - **Answer: A) By forcing the model to learn to work with different subsets of neurons**
#
# 73. **Which of the following is most likely to reduce the dependency of a model on a specific group of neurons during training?**
#    - A) Dropout
#    - B) Batch Normalization
#    - C) L2 Regularization
#    - D) Learning Rate Decay
#    - **Answer: A) Dropout**
#
# 74. **What effect does L1 regularization have on weights during training?**
#    - A) It encourages weights to be sparse by making some of them zero
#    - B) It makes weights larger
#    - C) It eliminates hidden layers
#    - D) It increases learning rate
#    - **Answer: A) It encourages weights to be sparse by making some of them zero**
#
# 75. **How does L2 regularization prevent the weights from becoming too large?**
#    - A) By adding a penalty term that grows quadratically with the weight value
#    - B) By reducing the number of neurons
#    - C) By adding biases
#    - D) By eliminating hidden layers
#    - **Answer: A) By adding a penalty term that grows quadratically with the weight value**
#
# 76. **Which regularization technique can help improve generalization by preventing the network from relying on specific neurons during training?**
#    - A) Dropout
#    - B) L2 Regularization
#    - C) Weight Clipping
#    - D) Gradient Boosting
#    - **Answer: A) Dropout**
#
# 77. **What is the primary effect of adding weight decay during training?**
#    - A) It adds a penalty proportional to the sum of squared weights to the loss function, preventing weights from becoming too large
#    - B) It keeps weights constant
#    - C) It increases the learning rate
#    - D) It eliminates biases
#    - **Answer: A) It adds a penalty proportional to the sum of squared weights to the loss function, preventing weights from becoming too large**
#
# 78. **Which regularization method encourages the network to learn using only a subset of features by forcing some weights to zero?**
#    - A) L1 Regularization
#    - B) L2 Regularization
#    - C) Batch Normalization
#    - D) Dropout
#    - **Answer: A) L1 Regularization**
#
# 79. **How does dropout regularization improve the ability of the model to generalize?**
#    - A) By preventing over-reliance on particular neurons, making the network more redundant
#    - B) By reducing the number of neurons
#    - C) By eliminating biases
#    - D) By making the learning rate constant
#    - **Answer: A) By preventing over-reliance on particular neurons, making the network more redundant**
#
# 80. **Which of these is a key advantage of using L2 regularization over L1 regularization?**
#    - A) It prevents very large weights while still keeping them non-zero, thereby preserving feature contributions
#    - B) It eliminates all weights
#    - C) It increases the number of hidden layers
#    - D) It always increases biases
#    - **Answer: A) It prevents very large weights while still keeping them non-zero, thereby preserving feature contributions**
#
# 81. **Which regularization method involves adding a penalty proportional to the absolute value of weights to the cost function?**
#    - A) L1 Regularization
#    - B) L2 Regularization
#    - C) Dropout
#    - D) Momentum
#    - **Answer: A) L1 Regularization**
#
# 82. **What is the main benefit of applying L2 regularization to a neural network model?**
#    - A) It discourages large weight values, thus preventing the model from becoming overly complex
#    - B) It eliminates biases
#    - C) It reduces the batch size
#    - D) It makes the learning rate constant
#    - **Answer: A) It discourages large weight values, thus preventing the model from becoming overly complex**
#
# 83. **How does dropout affect the activation of neurons during training?**
#    - A) It randomly deactivates some neurons, ensuring that the network doesn't rely too heavily on any single one
#    - B) It keeps all neurons activated
#    - C) It increases the batch size
#    - D) It removes biases
#    - **Answer: A) It randomly deactivates some neurons, ensuring that the network doesn't rely too heavily on any single one**
#
# 84. **Which of the following describes how L1 regularization can help with feature selection?**
#    - A) By forcing some weights to be zero, reducing the impact of irrelevant features
#    - B) By making weights larger
#    - C) By adding noise to features
#    - D) By increasing the number of neurons
#    - **Answer: A) By forcing some weights to be zero, reducing the impact of irrelevant features**
#
# 85. **What is the primary effect of using dropout on the performance of a neural network during training?**
#    - A) It reduces the likelihood of overfitting by randomly ignoring certain neurons
#    - B) It keeps all neurons active
#    - C) It reduces the number of epochs required
#    - D) It doubles the weights
#    - **Answer: A) It reduces the likelihood of overfitting by randomly ignoring certain neurons**
#
# 86. **Which regularization technique penalizes the sum of the squares of the weights?**
#    - A) L2 Regularization
#    - B) L1 Regularization
#    - C) Dropout
#    - D) Batch Normalization
#    - **Answer: A) L2 Regularization**
#
# 87. **What happens to neurons during inference when using dropout?**
#    - A) Dropout is turned off, and all neurons are used
#    - B) More neurons are dropped during inference
#    - C) Dropout is increased during inference
#    - D) Only biases are eliminated
#    - **Answer: A) Dropout is turned off, and all neurons are used**
#
# 88. **Which regularization method is best for ensuring sparsity in the network?**
#    - A) L1 Regularization
#    - B) L2 Regularization
#    - C) Dropout
#    - D) Batch Normalization
#    - **Answer: A) L1 Regularization**
#
# 89. **How does using L2 regularization influence the weight values?**
#    - A) It adds a penalty to large weights, preventing them from growing excessively
#    - B) It keeps weights constant
#    - C) It doubles the weight value
#    - D) It eliminates biases
#    - **Answer: A) It adds a penalty to large weights, preventing them from growing excessively**
#
# 90. **Which of the following is a key benefit of using L1 regularization in training neural networks?**
#    - A) It encourages sparsity in weights, helping to select the most important features
#    - B) It increases weights
#    - C) It keeps the learning rate constant
#    - D) It reduces training data
#    - **Answer: A) It encourages sparsity in weights, helping to select the most important features**
#
# 91. **Which regularization technique is primarily used to reduce model complexity by penalizing the squared magnitude of weights?**
#    - A) L2 Regularization
#    - B) Dropout
#    - C) Batch Normalization
#    - D) Momentum
#    - **Answer: A) L2 Regularization**
#
# 92. **Which regularization technique forces some weights to become zero, effectively reducing the number of features?**
#    - A) L1 Regularization
#    - B) L2 Regularization
#    - C) Dropout
#    - D) Learning Rate Decay
#    - **Answer: A) L1 Regularization**
#
# 93. **How does dropout help during training to prevent the network from becoming too specialized?**
#    - A) By randomly dropping neurons, preventing any one neuron from becoming too crucial to the network's
#
#  performance
#    - B) By reducing the number of neurons
#    - C) By eliminating the bias term
#    - D) By reducing the learning rate
#    - **Answer: A) By randomly dropping neurons, preventing any one neuron from becoming too crucial to the network's performance**
#
# 94. **Which type of regularization works by adding noise to the model by dropping neurons during training?**
#    - A) Dropout
#    - B) L2 Regularization
#    - C) Weight Clipping
#    - D) Batch Normalization
#    - **Answer: A) Dropout**
#
# 95. **Which regularization technique is useful for reducing the number of features by driving some weights to zero?**
#    - A) L1 Regularization
#    - B) L2 Regularization
#    - C) Dropout
#    - D) Batch Normalization
#    - **Answer: A) L1 Regularization**
#
# 96. **How does weight decay (L2 regularization) help during training?**
#    - A) By penalizing large weights, thus preventing overfitting
#    - B) By increasing learning rate
#    - C) By keeping the bias constant
#    - D) By adding noise to weights
#    - **Answer: A) By penalizing large weights, thus preventing overfitting**
#
# 97. **Which regularization technique helps to make the network more robust by preventing co-adaptation of neurons?**
#    - A) Dropout
#    - B) Batch Normalization
#    - C) L2 Regularization
#    - D) Gradient Clipping
#    - **Answer: A) Dropout**
#
# 98. **Which method should be used to ensure that a model's weights do not grow excessively large during training?**
#    - A) L2 Regularization
#    - B) Dropout
#    - C) L1 Regularization
#    - D) He Initialization
#    - **Answer: A) L2 Regularization**
#
# 99. **What is the key advantage of using dropout during training?**
#    - A) It prevents neurons from becoming overly dependent on other neurons, enhancing generalization
#    - B) It eliminates biases
#    - C) It increases the learning rate
#    - D) It doubles the number of neurons
#    - **Answer: A) It prevents neurons from becoming overly dependent on other neurons, enhancing generalization**
#
# 100. **Which regularization technique penalizes the absolute value of the weight values, helping to create a sparse model?**
#     - A) L1 Regularization
#     - B) L2 Regularization
#     - C) Dropout
#     - D) Batch Normalization
#     - **Answer: A) L1 Regularization**

# %% [markdown]
# ### **Lecture 10: Activation Functions and Their Applications in Neural Networks**
#
# 1. **What is the purpose of activation functions in neural networks?**
#    - A) To introduce non-linearity, enabling the network to learn complex relationships
#    - B) To initialize weights
#    - C) To increase the number of layers
#    - D) To remove biases
#    - **Answer: A) To introduce non-linearity, enabling the network to learn complex relationships**
#
# 2. **Which activation function has an output range between 0 and 1?**
#    - A) Sigmoid
#    - B) ReLU
#    - C) Tanh
#    - D) Softmax
#    - **Answer: A) Sigmoid**
#
# 3. **Which MATLAB command can be used to create a plot of the ReLU activation function?**
#    - A) `plot(x, max(0, x))`
#    - B) `log(x)`
#    - C) `exp(x)`
#    - D) `cos(x)`
#    - **Answer: A) `plot(x, max(0, x))`**
#
# 4. **What is a disadvantage of using the Sigmoid activation function in deep networks?**
#    - A) Vanishing gradient problem
#    - B) Exploding gradient problem
#    - C) Computational inefficiency
#    - D) Does not normalize input
#    - **Answer: A) Vanishing gradient problem**
#
# 5. **Which activation function can output negative values, with a range between -1 and 1?**
#    - A) Tanh
#    - B) ReLU
#    - C) Sigmoid
#    - D) Softplus
#    - **Answer: A) Tanh**
#
# 6. **Which MATLAB function would be suitable for plotting the Tanh activation function over a range of values?**
#    - A) `tanh(x)`
#    - B) `log(x)`
#    - C) `sqrt(x)`
#    - D) `cosh(x)`
#    - **Answer: A) `tanh(x)`**
#
# 7. **Which activation function is most likely to suffer from the “dead neuron” problem?**
#    - A) ReLU
#    - B) Tanh
#    - C) Sigmoid
#    - D) Leaky ReLU
#    - **Answer: A) ReLU**
#
# 8. **Which of these activation functions allows a small negative gradient to flow, helping to avoid the dead neuron problem?**
#    - A) Leaky ReLU
#    - B) Sigmoid
#    - C) Tanh
#    - D) ReLU
#    - **Answer: A) Leaky ReLU**
#
# 9. **How can you implement a ReLU activation function in MATLAB code for a matrix input X?**
#    - A) `max(0, X)`
#    - B) `min(0, X)`
#    - C) `exp(X)`
#    - D) `X.^2`
#    - **Answer: A) `max(0, X)`**
#
# 10. **Which activation function is used for classification tasks involving multiple classes?**
#     - A) Softmax
#     - B) ReLU
#     - C) Sigmoid
#     - D) Linear
#     - **Answer: A) Softmax**
#
# 11. **Which of the following MATLAB commands would you use to apply the sigmoid activation function to a matrix X?**
#     - A) `1 ./ (1 + exp(-X))`
#     - B) `log(X)`
#     - C) `cos(X)`
#     - D) `exp(X)`
#     - **Answer: A) `1 ./ (1 + exp(-X))`
#
# 12. **What is the key advantage of using ReLU activation in neural networks?**
#     - A) It helps mitigate the vanishing gradient problem by allowing gradients to flow more easily for positive inputs
#     - B) It restricts output values between 0 and 1
#     - C) It has lower computational cost compared to others
#     - D) It always outputs negative values
#     - **Answer: A) It helps mitigate the vanishing gradient problem by allowing gradients to flow more easily for positive inputs**
#
# 13. **What type of activation function is most suitable for output layers dealing with regression problems?**
#     - A) Linear
#     - B) ReLU
#     - C) Tanh
#     - D) Sigmoid
#     - **Answer: A) Linear**
#
# 14. **Which activation function can output probabilities for each class in a multi-class classification problem?**
#     - A) Softmax
#     - B) ReLU
#     - C) Tanh
#     - D) Leaky ReLU
#     - **Answer: A) Softmax**
#
# 15. **How does the Leaky ReLU activation function address the problem of dead neurons?**
#     - A) By allowing a small, non-zero gradient for negative inputs
#     - B) By always outputting zero for negative inputs
#     - C) By normalizing output values between -1 and 1
#     - D) By using an exponential transformation
#     - **Answer: A) By allowing a small, non-zero gradient for negative inputs**
#
# 16. **What is the mathematical formula for the sigmoid activation function?**
#     - A) \( f(x) = \frac{1}{1 + e^{-x}} \)
#     - B) \( f(x) = \max(0, x) \)
#     - C) \( f(x) = x^2 \)
#     - D) \( f(x) = \tan(x) \)
#     - **Answer: A) \( f(x) = \frac{1}{1 + e^{-x}} \)**
#
# 17. **Which activation function has an output range from 0 to infinity?**
#     - A) Softplus
#     - B) ReLU
#     - C) Tanh
#     - D) Sigmoid
#     - **Answer: A) Softplus**
#
# 18. **Which MATLAB command would you use to create a plot of the sigmoid function for values ranging from -10 to 10?**
#     - A) `fplot(@(x) 1./(1+exp(-x)), [-10, 10])`
#     - B) `log(x)`
#     - C) `sqrt(x)`
#     - D) `tan(x)`
#     - **Answer: A) `fplot(@(x) 1./(1+exp(-x)), [-10, 10])`**
#
# 19. **Which activation function is generally preferred for output layers in binary classification tasks?**
#     - A) Sigmoid
#     - B) Softmax
#     - C) ReLU
#     - D) Tanh
#     - **Answer: A) Sigmoid**
#
# 20. **What is a common disadvantage of using ReLU in deep networks?**
#     - A) Dead neurons, where neurons can get stuck and stop learning
#     - B) Vanishing gradient problem
#     - C) Exploding gradient problem
#     - D) High computational complexity
#     - **Answer: A) Dead neurons, where neurons can get stuck and stop learning**
#
# 21. **What is the output range of the tanh activation function?**
#     - A) -1 to 1
#     - B) 0 to 1
#     - C) -2 to 2
#     - D) -∞ to ∞
#     - **Answer: A) -1 to 1**
#
# 22. **In MATLAB, which command would you use to calculate the Softmax of a vector X?**
#     - A) `exp(X) ./ sum(exp(X))`
#     - B) `log(X)`
#     - C) `sin(X)`
#     - D) `cosh(X)`
#     - **Answer: A) `exp(X) ./ sum(exp(X))`
#
# 23. **What type of non-linearity does the sigmoid activation function introduce?**
#     - A) Logistic non-linearity
#     - B) Exponential non-linearity
#     - C) Linear non-linearity
#     - D) Quadratic non-linearity
#     - **Answer: A) Logistic non-linearity**
#
# 24. **Which activation function has a gradient equal to 1 for positive values of the input?**
#     - A) ReLU
#     - B) Sigmoid
#     - C) Tanh
#     - D) Softplus
#     - **Answer: A) ReLU**
#
# 25. **Which activation function is typically used for gating mechanisms in recurrent neural networks (RNNs)?**
#     - A) Sigmoid
#     - B) Tanh
#     - C) Softmax
#     - D) ReLU
#     - **Answer: A) Sigmoid**
#
# 26. **Which of these functions can be used to visualize different activation functions in MATLAB?**
#     - A) `fplot`
#     - B) `bar`
#     - C) `scatter`
#     - D) `histogram`
#     - **Answer: A) `fplot`**
#
# 27. **Which activation function is known for producing smoother transitions and is often used to mitigate vanishing gradients in deep networks?**
#     - A) Tanh
#     - B) ReLU
#     - C) Softmax
#     - D) Leaky ReLU
#     - **Answer: A) Tanh**
#
# 28. **What is a potential downside of using the sigmoid activation function for deep networks?**
#     - A) The gradients tend to vanish as the input values increase or decrease significantly
#     - B) It outputs negative values
#     - C) It is computationally expensive
#     - D) It only works for linear models
#     - **Answer: A) The gradients tend to vanish as the input values increase or decrease significantly**
#
# 29. **How can the ReLU activation function be implemented in MATLAB using a custom function?**
#     - A) Define a function as `relu = @(x) max(0, x);`
#     - B) `relu = @(x) min(0, x);`
#     - C) `relu = @(x) tan(x);`
#     - D) `relu = @(x) cos(x);`
#     - **Answer: A) Define a function as `relu = @(x) max(0, x);`**
#
# 30. **Which activation function helps mitigate the problem of negative outputs by allowing a small slope for negative inputs?**
#     - A) Leaky ReLU
#     - B) Softmax
#     - C) Sigmoid
#     - D) Tanh
#     - **Answer: A) Leaky ReLU**

# %% [markdown]
# 31. **Which activation function is defined as \( f(x) = \max(0, x) \)?**
#    - A) ReLU
#    - B) Tanh
#    - C) Sigmoid
#    - D) Softmax
#    - **Answer: A) ReLU**
#
# 32. **What is the primary benefit of using Tanh over Sigmoid as an activation function?**
#    - A) It centers the data at zero, making learning easier
#    - B) It has faster computation
#    - C) It outputs values only between 0 and 1
#    - D) It has no vanishing gradient problem
#    - **Answer: A) It centers the data at zero, making learning easier**
#
# 33. **Which MATLAB command can you use to visualize the tanh function for an input range of -5 to 5?**
#    - A) `fplot(@tanh, [-5, 5])`
#    - B) `plot(log(x))`
#    - C) `plot(cos(x))`
#    - D) `bar(x)`
#    - **Answer: A) `fplot(@tanh, [-5, 5])`**
#
# 34. **How does the softmax activation function help in multi-class classification tasks?**
#    - A) It converts the outputs into probabilities that sum up to 1
#    - B) It makes outputs between -1 and 1
#    - C) It centers the data
#    - D) It increases the learning rate
#    - **Answer: A) It converts the outputs into probabilities that sum up to 1**
#
# 35. **Which activation function is likely to be used in the output layer of a neural network designed for multi-class classification?**
#    - A) Softmax
#    - B) ReLU
#    - C) Sigmoid
#    - D) Tanh
#    - **Answer: A) Softmax**
#
# 36. **Which activation function ensures that output values are positive for positive inputs and exactly zero for negative inputs?**
#    - A) ReLU
#    - B) Tanh
#    - C) Sigmoid
#    - D) Softmax
#    - **Answer: A) ReLU**
#
# 37. **Which activation function has a slope that is adjustable for negative inputs, helping to avoid the dead neuron problem?**
#    - A) Parametric ReLU (PReLU)
#    - B) Sigmoid
#    - C) ReLU
#    - D) Softmax
#    - **Answer: A) Parametric ReLU (PReLU)**
#
# 38. **What is a major downside of using Tanh in very deep networks?**
#    - A) The gradients can vanish for inputs that are extremely positive or negative
#    - B) The output is always non-negative
#    - C) It increases computational cost significantly
#    - D) It only works for binary classification
#    - **Answer: A) The gradients can vanish for inputs that are extremely positive or negative**
#
# 39. **Which MATLAB function is used to apply the Leaky ReLU activation for a vector X with a small slope factor of 0.01?**
#    - A) `max(0.01 * X, X)`
#    - B) `min(0.01 * X, X)`
#    - C) `exp(X)`
#    - D) `tanh(X)`
#    - **Answer: A) `max(0.01 * X, X)`**
#
# 40. **How is Softmax different from Sigmoid when used in the output layer of a neural network?**
#    - A) Softmax normalizes output across multiple classes, while Sigmoid is used for binary outcomes
#    - B) Softmax outputs between -1 and 1, whereas Sigmoid outputs between 0 and 1
#    - C) Softmax is only used for regression
#    - D) Sigmoid sums up outputs to 1, while Softmax does not
#    - **Answer: A) Softmax normalizes output across multiple classes, while Sigmoid is used for binary outcomes**
#
# 41. **Which of the following is an advantage of using the ReLU activation function?**
#    - A) It helps mitigate the vanishing gradient problem by having a constant gradient for positive inputs
#    - B) It is bounded between -1 and 1
#    - C) It works only with multi-class classification
#    - D) It outputs values between 0 and 1
#    - **Answer: A) It helps mitigate the vanishing gradient problem by having a constant gradient for positive inputs**
#
# 42. **Which activation function is the best choice for the output layer of a regression model?**
#    - A) Linear
#    - B) ReLU
#    - C) Tanh
#    - D) Softmax
#    - **Answer: A) Linear**
#
# 43. **Which MATLAB function would you use to plot a linear activation function?**
#    - A) `fplot(@(x) x, [-10, 10])`
#    - B) `tanh(x)`
#    - C) `log(x)`
#    - D) `cos(x)`
#    - **Answer: A) `fplot(@(x) x, [-10, 10])`**
#
# 44. **What is a key feature of the Tanh activation function compared to Sigmoid?**
#    - A) It outputs values between -1 and 1, which helps center data and accelerates learning
#    - B) It only outputs values greater than 1
#    - C) It requires more computational resources than Sigmoid
#    - D) It cannot be used for binary classification
#    - **Answer: A) It outputs values between -1 and 1, which helps center data and accelerates learning**
#
# 45. **Which activation function is known to reduce the issue of vanishing gradients compared to the sigmoid function?**
#    - A) Tanh
#    - B) ReLU
#    - C) Softplus
#    - D) Exponential
#    - **Answer: A) Tanh**
#
# 46. **Which activation function tends to deactivate neurons by consistently outputting zero for all negative inputs?**
#    - A) ReLU
#    - B) Leaky ReLU
#    - C) Softmax
#    - D) Sigmoid
#    - **Answer: A) ReLU**
#
# 47. **Which MATLAB command can be used to implement the sigmoid activation function for an input matrix X?**
#    - A) `1 ./ (1 + exp(-X))`
#    - B) `log(X)`
#    - C) `tan(X)`
#    - D) `cosh(X)`
#    - **Answer: A) `1 ./ (1 + exp(-X))`
#
# 48. **What is the primary purpose of the softmax function in the output layer of a neural network?**
#    - A) To produce class probabilities that sum up to 1
#    - B) To output only negative values
#    - C) To increase the range of outputs
#    - D) To add biases to inputs
#    - **Answer: A) To produce class probabilities that sum up to 1**
#
# 49. **Which activation function is most often used in convolutional layers due to its simplicity and non-saturating nature?**
#    - A) ReLU
#    - B) Tanh
#    - C) Sigmoid
#    - D) Softmax
#    - **Answer: A) ReLU**
#
# 50. **How does Leaky ReLU differ from ReLU?**
#    - A) Leaky ReLU allows a small slope for negative inputs, avoiding dead neurons
#    - B) Leaky ReLU only outputs positive values
#    - C) ReLU always outputs between 0 and 1
#    - D) Leaky ReLU is more computationally expensive than ReLU
#    - **Answer: A) Leaky ReLU allows a small slope for negative inputs, avoiding dead neurons**
#
# 51. **What is the main disadvantage of using the Sigmoid function in hidden layers of deep neural networks?**
#    - A) Vanishing gradients, which slow down learning
#    - B) It is non-differentiable
#    - C) It always produces negative values
#    - D) It is computationally very expensive
#    - **Answer: A) Vanishing gradients, which slow down learning**
#
# 52. **Which activation function is most commonly used to output probabilities across multiple classes?**
#    - A) Softmax
#    - B) Tanh
#    - C) ReLU
#    - D) Linear
#    - **Answer: A) Softmax**
#
# 53. **Which of these functions can introduce sparsity in activations due to its output of zero for negative inputs?**
#    - A) ReLU
#    - B) Sigmoid
#    - C) Softmax
#    - D) Tanh
#    - **Answer: A) ReLU**
#
# 54. **Which activation function is a generalization of ReLU, where a small slope is learned during training?**
#    - A) Parametric ReLU (PReLU)
#    - B) Sigmoid
#    - C) Tanh
#    - D) Linear
#    - **Answer: A) Parametric ReLU (PReLU)**
#
# 55. **In MATLAB, which function would you use to calculate the softmax for a given vector X?**
#    - A) `exp(X) ./ sum(exp(X))`
#    - B) `log(X)`
#    - C) `sin(X)`
#    - D) `sqrt(X)`
#    - **Answer: A) `exp(X) ./ sum(exp(X))`
#
# 56. **Which activation function is commonly used in the hidden layers of a GAN (Generative Adversarial Network) discriminator?**
#    - A) Leaky ReLU
#    - B) Sigmoid
#    - C) Softmax
#    - D) Tanh
#    - **Answer: A) Leaky ReLU**
#
# 57. **What is the formula for the softplus activation function?**
#    - A) \( f(x) = \log(1 + e^x) \)
#    - B) \( f(x) = \max(0, x) \)
#    - C) \( f(x) = \frac{1}{1 + e^{-x}} \)
#    - D) \( f(x) = \tan(x) \)
#    - **Answer: A) \( f(x) = \log(1 + e^x) \)**
#
# 58. **Which MATLAB command can be used to define a custom function for softplus activation?**
#    - A) `softplus = @(x) log(1 + exp(x));`
#    - B) `softplus = @(x) tan(x);`
#    - C) `softplus = @(x) x.^2;`
#    - D) `softplus = @(x) sin(x);`
#    - **Answer: A) `softplus = @(x) log(1 + exp(x));`**
#
# 59. **Which activation function should be used if a model needs to predict probabilities for each class in a multi-class classification setting?**
#    - A) Softmax
#    - B) ReLU
#    - C) Tanh
#    - D) Sigmoid
#    - **Answer: A) Softmax**
#
# 60. **Which of the following activation functions can help alleviate the vanishing gradient problem commonly found with Sigmoid?**
#    - A) ReLU and Tanh
#    - B) Softmax and Linear
#    - C) Logarithm and Exponential
#    - D) None of the above
#    - **Answer: A) ReLU and Tanh**

# %% [markdown]
# 61. **What is the primary difference between ReLU and Leaky ReLU activation functions?**
#    - A) Leaky ReLU allows a small, non-zero gradient for negative inputs, while ReLU outputs zero for negative inputs
#    - B) Leaky ReLU always outputs positive values, while ReLU outputs negative values
#    - C) ReLU is more computationally expensive than Leaky ReLU
#    - D) ReLU has no slope for positive values
#    - **Answer: A) Leaky ReLU allows a small, non-zero gradient for negative inputs, while ReLU outputs zero for negative inputs**
#
# 62. **Which activation function can result in neurons permanently deactivating during training, leading to the "dead neuron" problem?**
#    - A) ReLU
#    - B) Sigmoid
#    - C) Softmax
#    - D) Tanh
#    - **Answer: A) ReLU**
#
# 63. **Which MATLAB command would be suitable for plotting the softmax activation function for an input matrix X?**
#    - A) `exp(X) ./ sum(exp(X))`
#    - B) `fplot(@softmax, X)`
#    - C) `log(X)`
#    - D) `sqrt(X)`
#    - **Answer: A) `exp(X) ./ sum(exp(X))`
#
# 64. **What is a key advantage of using the softplus activation function over ReLU?**
#    - A) It is differentiable at all points, including zero
#    - B) It always produces zero outputs
#    - C) It is computationally less expensive than ReLU
#    - D) It has a constant gradient for negative values
#    - **Answer: A) It is differentiable at all points, including zero**
#
# 65. **Which of the following activation functions is non-linear and helps neural networks learn complex relationships?**
#    - A) Tanh
#    - B) Linear
#    - C) Step Function
#    - D) None of the above
#    - **Answer: A) Tanh**
#
# 66. **In which scenario is the sigmoid activation function most commonly used?**
#    - A) In the output layer of binary classification problems
#    - B) In the hidden layers of very deep neural networks
#    - C) In the output layer for multi-class problems
#    - D) For regression tasks
#    - **Answer: A) In the output layer of binary classification problems**
#
# 67. **Which activation function is known for having a constant derivative for all positive inputs?**
#    - A) ReLU
#    - B) Sigmoid
#    - C) Tanh
#    - D) Softmax
#    - **Answer: A) ReLU**
#
# 68. **What is the range of output values for the sigmoid activation function?**
#    - A) 0 to 1
#    - B) -1 to 1
#    - C) -∞ to +∞
#    - D) 0 to ∞
#    - **Answer: A) 0 to 1**
#
# 69. **What is the main use of the Softmax function in a neural network's output layer?**
#    - A) To normalize output into a probability distribution
#    - B) To ensure that the output is non-negative
#    - C) To make all weights equal
#    - D) To reduce the learning rate
#    - **Answer: A) To normalize output into a probability distribution**
#
# 70. **Which activation function has the potential to learn from negative inputs by using a small slope?**
#    - A) Leaky ReLU
#    - B) Softmax
#    - C) Sigmoid
#    - D) ReLU
#    - **Answer: A) Leaky ReLU**
#
# 71. **Which MATLAB command can be used to define a parametric ReLU (PReLU) with parameter alpha?**
#    - A) `prelu = @(x, alpha) max(alpha * x, x);`
#    - B) `prelu = @(x) min(alpha * x, x);`
#    - C) `prelu = @(x) log(x);`
#    - D) `prelu = @(x) sin(x);`
#    - **Answer: A) `prelu = @(x, alpha) max(alpha * x, x);`**
#
# 72. **What is the range of the output values for the Tanh activation function?**
#    - A) -1 to 1
#    - B) 0 to 1
#    - C) -∞ to +∞
#    - D) 0 to 10
#    - **Answer: A) -1 to 1**
#
# 73. **Which activation function is defined mathematically as \( f(x) = \max(0, x) \)?**
#    - A) ReLU
#    - B) Sigmoid
#    - C) Tanh
#    - D) Softplus
#    - **Answer: A) ReLU**
#
# 74. **Which activation function is commonly used for binary output classification tasks in the final layer?**
#    - A) Sigmoid
#    - B) ReLU
#    - C) Tanh
#    - D) Softplus
#    - **Answer: A) Sigmoid**
#
# 75. **Which activation function has non-zero output for all input values and helps to prevent dying neurons?**
#    - A) Leaky ReLU
#    - B) ReLU
#    - C) Sigmoid
#    - D) Tanh
#    - **Answer: A) Leaky ReLU**
#
# 76. **Which activation function is defined as \( f(x) = \log(1 + e^x) \) and is a smooth approximation of ReLU?**
#    - A) Softplus
#    - B) ReLU
#    - C) Tanh
#    - D) Sigmoid
#    - **Answer: A) Softplus**
#
# 77. **Which activation function is commonly used in the hidden layers of generative adversarial networks (GANs)?**
#    - A) Leaky ReLU
#    - B) Softmax
#    - C) Sigmoid
#    - D) Linear
#    - **Answer: A) Leaky ReLU**
#
# 78. **Which function would you use in MATLAB to plot the Leaky ReLU activation for an input range of -10 to 10 with slope 0.01?**
#    - A) `fplot(@(x) max(0.01 * x, x), [-10, 10])`
#    - B) `fplot(@(x) min(0.01 * x, x), [-10, 10])`
#    - C) `plot(log(x))`
#    - D) `cos(x)`
#    - **Answer: A) `fplot(@(x) max(0.01 * x, x), [-10, 10])`**
#
# 79. **Which of the following activation functions is most suitable for a regression task output layer?**
#    - A) Linear
#    - B) Softmax
#    - C) Sigmoid
#    - D) ReLU
#    - **Answer: A) Linear**
#
# 80. **What type of problem does the Sigmoid activation function face in deep neural networks?**
#    - A) Vanishing gradients, leading to slow or halted learning
#    - B) Exploding gradients
#    - C) Over-complexity of the model
#    - D) Always outputting zero
#    - **Answer: A) Vanishing gradients, leading to slow or halted learning**
#
# 81. **Which of these activation functions can help prevent the "exploding gradient" problem by limiting output to a specific range?**
#    - A) Tanh
#    - B) ReLU
#    - C) Softmax
#    - D) Leaky ReLU
#    - **Answer: A) Tanh**
#
# 82. **Which MATLAB command is used to calculate the softplus activation function for a matrix X?**
#    - A) `log(1 + exp(X))`
#    - B) `tanh(X)`
#    - C) `sqrt(X)`
#    - D) `cos(X)`
#    - **Answer: A) `log(1 + exp(X))`
#
# 83. **Which activation function outputs a small, non-zero gradient for all negative inputs, thus preventing neurons from dying?**
#    - A) Leaky ReLU
#    - B) ReLU
#    - C) Softmax
#    - D) Linear
#    - **Answer: A) Leaky ReLU**
#
# 84. **What is a common use of the Softmax activation function in neural networks?**
#    - A) To output probabilities for multi-class classification
#    - B) To output only positive values
#    - C) To add noise to inputs
#    - D) To reduce learning rate
#    - **Answer: A) To output probabilities for multi-class classification**
#
# 85. **What is the key difference between Sigmoid and Tanh activation functions?**
#    - A) Tanh outputs values between -1 and 1, while Sigmoid outputs between 0 and 1
#    - B) Sigmoid has a higher computation cost than Tanh
#    - C) Tanh only works for positive values
#    - D) Sigmoid is non-differentiable
#    - **Answer: A) Tanh outputs values between -1 and 1, while Sigmoid outputs between 0 and 1**
#
# 86. **Which activation function would be most suitable for an RNN (Recurrent Neural Network) to deal with exploding and vanishing gradients?**
#    - A) Tanh
#    - B) Softmax
#    - C) Linear
#    - D) Sigmoid
#    - **Answer: A) Tanh**
#
# 87. **Which of the following activation functions provides a probabilistic interpretation of the network output in classification?**
#    - A) Softmax
#    - B) ReLU
#    - C) Tanh
#    - D) Softplus
#    - **Answer: A) Softmax**
#
# 88. **Which MATLAB function is commonly used to calculate the Tanh activation of a given matrix X?**
#    - A) `tanh(X)`
#    - B) `exp(X)`
#    - C) `log(X)`
#    - D) `sin(X)`
#    - **Answer: A) `tanh(X)`**
#
# 89. **What is the main advantage of using the ReLU activation function in deep neural networks?**
#    - A) It avoids vanishing gradients by keeping a constant gradient for positive inputs
#    - B) It reduces the number of parameters
#    - C) It is differentiable for all values of x
#    - D) It only works for binary outputs
#    - **Answer: A) It avoids vanishing gradients by keeping a constant gradient for positive inputs**
#
# 90. **Which activation function normalizes the output for each class in a multi-class classification problem?**
#    - A) Softmax
#    - B) ReLU
#    - C) Sigmoid
#    - D) Linear
#    - **Answer: A) Softmax**
#
# 91. **How does the Softplus activation function compare to ReLU in terms of differentiability?**
#    - A) Softplus is differentiable at all points, while ReLU is not differentiable at zero
#    - B) ReLU is differentiable, while Softplus is not
#    - C) Softplus cannot be used in hidden layers
#    - D) Softplus outputs only negative values
#    - **Answer: A) Softplus is differentiable at all points, while ReLU is not differentiable at zero**
#
# 92. **Which activation function has a smooth derivative and is therefore often used as a differentiable approximation to ReLU?**
#    - A) Softplus
#    - B) Leaky ReLU
#    - C) Sigmoid
#    - D) Tanh
#    - **Answer: A) Softplus**
#
# 93. **What is the benefit of using Tanh over Sigmoid in the hidden layers of a neural network?**
#    - A) Tanh centers the data at zero, which can accelerate convergence
#    - B) Tanh has fewer computations
#    - C) Tanh only outputs between 0 and 1
#    - D) Tanh is more suited for binary classification tasks
#    - **Answer: A) Tanh centers the data at zero, which can accelerate convergence**
#
# 94. **Which MATLAB command can you use to calculate the Softmax function for a vector X?**
#    - A) `exp(X) ./ sum(exp(X))`
#    - B) `log(X)`
#    - C) `sqrt(X)`
#    - D) `tanh(X)`
#    - **Answer: A) `exp(X) ./ sum(exp(X))`
#
# 95. **
#
# Which activation function allows for small gradients in the negative input region, avoiding dead neurons?**
#    - A) Leaky ReLU
#    - B) ReLU
#    - C) Sigmoid
#    - D) Tanh
#    - **Answer: A) Leaky ReLU**
#
# 96. **Which of the following functions is used in multi-class classification problems to output probabilities that sum to 1?**
#    - A) Softmax
#    - B) ReLU
#    - C) Linear
#    - D) Tanh
#    - **Answer: A) Softmax**
#
# 97. **Which activation function can suffer from saturation, leading to the vanishing gradient problem?**
#    - A) Sigmoid
#    - B) ReLU
#    - C) Softmax
#    - D) Linear
#    - **Answer: A) Sigmoid**
#
# 98. **What is a key benefit of using the Leaky ReLU activation function compared to standard ReLU?**
#    - A) Leaky ReLU allows a small gradient to pass even for negative inputs, avoiding dead neurons
#    - B) Leaky ReLU only works for binary outputs
#    - C) Leaky ReLU outputs only positive values
#    - D) Leaky ReLU has a bounded output
#    - **Answer: A) Leaky ReLU allows a small gradient to pass even for negative inputs, avoiding dead neurons**
#
# 99. **Which activation function is ideal for normalizing outputs for multiple classes so they represent probabilities?**
#    - A) Softmax
#    - B) ReLU
#    - C) Sigmoid
#    - D) Tanh
#    - **Answer: A) Softmax**
#
# 100. **What is the role of the softplus activation function in neural networks?**
#     - A) It acts as a smooth approximation to ReLU and is differentiable everywhere
#     - B) It is used for binary classification
#     - C) It outputs only negative values
#     - D) It cannot be used in hidden layers
#     - **Answer: A) It acts as a smooth approximation to ReLU and is differentiable everywhere**

# %% [markdown]
# ### **Lecture 11: Applications of Neural Networks in Different Domains**
#
# 1. **What is one common application of neural networks in the healthcare domain?**
#    - A) Disease diagnosis based on medical images
#    - B) Predicting stock market trends
#    - C) Video game development
#    - D) Weather forecasting
#    - **Answer: A) Disease diagnosis based on medical images**
#
# 2. **Which type of neural network is widely used for image classification tasks?**
#    - A) Convolutional Neural Networks (CNNs)
#    - B) Recurrent Neural Networks (RNNs)
#    - C) Perceptrons
#    - D) GANs
#    - **Answer: A) Convolutional Neural Networks (CNNs)**
#
# 3. **Which MATLAB function is typically used for image processing before training a CNN?**
#    - A) `imresize()`
#    - B) `fft()`
#    - C) `filter()`
#    - D) `log()`
#    - **Answer: A) `imresize()`**
#
# 4. **What is a popular application of Recurrent Neural Networks (RNNs)?**
#    - A) Speech recognition and language modeling
#    - B) Image classification
#    - C) Game playing
#    - D) Stock market visualization
#    - **Answer: A) Speech recognition and language modeling**
#
# 5. **Which type of neural network is best suited for processing sequential data such as time series?**
#    - A) RNN
#    - B) CNN
#    - C) Feedforward Neural Network
#    - D) Autoencoder
#    - **Answer: A) RNN**
#
# 6. **Which of the following applications can benefit from the use of Convolutional Neural Networks (CNNs)?**
#    - A) Object detection in images
#    - B) Predicting power usage over time
#    - C) Sorting numbers in an array
#    - D) Linear regression
#    - **Answer: A) Object detection in images**
#
# 7. **What type of neural network is commonly used for generating new images from random noise?**
#    - A) Generative Adversarial Networks (GANs)
#    - B) RNNs
#    - C) Feedforward Networks
#    - D) Softmax Networks
#    - **Answer: A) Generative Adversarial Networks (GANs)**
#
# 8. **Which MATLAB function is used for training a feedforward neural network?**
#    - A) `train()`
#    - B) `fitlm()`
#    - C) `lsqcurvefit()`
#    - D) `plot()`
#    - **Answer: A) `train()`**
#
# 9. **Which application domain benefits most from the use of neural networks for sentiment analysis?**
#    - A) Natural Language Processing (NLP)
#    - B) Image Processing
#    - C) Physics
#    - D) Weather Modeling
#    - **Answer: A) Natural Language Processing (NLP)**
#
# 10. **Which type of neural network would be most suitable for predicting customer churn based on past usage?**
#     - A) Feedforward Neural Network
#     - B) CNN
#     - C) GAN
#     - D) Softmax Network
#     - **Answer: A) Feedforward Neural Network**
#
# 11. **Which neural network architecture is most suitable for machine translation tasks?**
#     - A) Sequence-to-Sequence (Seq2Seq) model with RNN
#     - B) CNN
#     - C) GAN
#     - D) Single-layer perceptron
#     - **Answer: A) Sequence-to-Sequence (Seq2Seq) model with RNN**
#
# 12. **In which domain is transfer learning commonly applied using pre-trained CNNs?**
#     - A) Image classification and object recognition
#     - B) Time series forecasting
#     - C) Sorting algorithms
#     - D) Linear optimization
#     - **Answer: A) Image classification and object recognition**
#
# 13. **Which MATLAB toolbox is useful for implementing deep learning-based image recognition tasks?**
#     - A) Deep Learning Toolbox
#     - B) Statistics and Machine Learning Toolbox
#     - C) Control System Toolbox
#     - D) Signal Processing Toolbox
#     - **Answer: A) Deep Learning Toolbox**
#
# 14. **Which neural network is particularly suitable for predicting the next word in a text sequence?**
#     - A) RNN
#     - B) CNN
#     - C) Autoencoder
#     - D) GAN
#     - **Answer: A) RNN**
#
# 15. **Which of the following is a key application of autoencoders in neural networks?**
#     - A) Dimensionality reduction and denoising data
#     - B) Sorting data
#     - C) Generating textual data
#     - D) Finding shortest paths
#     - **Answer: A) Dimensionality reduction and denoising data**
#
# 16. **What type of neural network is often used in autonomous vehicles for detecting road signs?**
#     - A) CNN
#     - B) RNN
#     - C) Perceptron
#     - D) Softmax Network
#     - **Answer: A) CNN**
#
# 17. **Which application can benefit from using neural networks to analyze historical data and make predictions about future events?**
#     - A) Time series forecasting
#     - B) Video compression
#     - C) Image enhancement
#     - D) Text translation
#     - **Answer: A) Time series forecasting**
#
# 18. **Which type of neural network is commonly used for identifying fraudulent transactions based on patterns in historical transaction data?**
#     - A) Feedforward Neural Network
#     - B) CNN
#     - C) GAN
#     - D) Hopfield Network
#     - **Answer: A) Feedforward Neural Network**
#
# 19. **Which MATLAB function is used to convert an image to grayscale before feeding it into a neural network?**
#     - A) `rgb2gray()`
#     - B) `fft()`
#     - C) `filter()`
#     - D) `abs()`
#     - **Answer: A) `rgb2gray()`**
#
# 20. **What is the primary purpose of using an LSTM (Long Short-Term Memory) network?**
#     - A) To model and predict long-range dependencies in sequential data
#     - B) To enhance image details
#     - C) To generate new images
#     - D) To reduce model complexity
#     - **Answer: A) To model and predict long-range dependencies in sequential data**
#
# 21. **Which neural network is suitable for classifying handwritten digits, such as those in the MNIST dataset?**
#     - A) CNN
#     - B) RNN
#     - C) Hopfield Network
#     - D) GAN
#     - **Answer: A) CNN**
#
# 22. **Which of the following is a key application of Generative Adversarial Networks (GANs)?**
#     - A) Image generation
#     - B) Speech recognition
#     - C) Classification
#     - D) Regression
#     - **Answer: A) Image generation**
#
# 23. **What is the primary use of Boltzmann Machines in neural networks?**
#     - A) Pattern recognition and dimensionality reduction
#     - B) Predicting sequential data
#     - C) Image classification
#     - D) Sorting numbers
#     - **Answer: A) Pattern recognition and dimensionality reduction**
#
# 24. **Which type of neural network architecture is used for natural language processing tasks like question answering?**
#     - A) Transformer
#     - B) CNN
#     - C) Hopfield Network
#     - D) Kohonen Network
#     - **Answer: A) Transformer**
#
# 25. **Which MATLAB function is used for segmenting an image into multiple regions for further analysis in CNNs?**
#     - A) `imbinarize()`
#     - B) `filtfilt()`
#     - C) `fftshift()`
#     - D) `imfilter()`
#     - **Answer: A) `imbinarize()`**
#
# 26. **What type of neural network is most effective for generating text descriptions for images?**
#     - A) Encoder-Decoder Network
#     - B) Perceptron
#     - C) Feedforward Neural Network
#     - D) RNN
#     - **Answer: A) Encoder-Decoder Network**
#
# 27. **Which type of neural network is most suitable for analyzing sensor data in Internet of Things (IoT) applications?**
#     - A) RNN
#     - B) CNN
#     - C) GAN
#     - D) Radial Basis Function Network
#     - **Answer: A) RNN**
#
# 28. **Which type of neural network is used for real-time face detection in video streams?**
#     - A) CNN
#     - B) RNN
#     - C) Hopfield Network
#     - D) Feedforward Neural Network
#     - **Answer: A) CNN**
#
# 29. **What is the primary purpose of reinforcement learning in neural networks?**
#     - A) To train agents to take actions in an environment to maximize cumulative rewards
#     - B) To generate image sequences
#     - C) To reduce data redundancy
#     - D) To classify data points
#     - **Answer: A) To train agents to take actions in an environment to maximize cumulative rewards**
#
# 30. **Which MATLAB toolbox is best for implementing neural network applications in natural language processing?**
#     - A) Text Analytics Toolbox
#     - B) Deep Learning Toolbox
#     - C) Control System Toolbox
#     - D) Optimization Toolbox
#     - **Answer: A) Text Analytics Toolbox**

# %% [markdown]
# 31. **Which neural network is most suitable for analyzing sentiment in customer reviews?**
#    - A) RNN
#    - B) CNN
#    - C) GAN
#    - D) Hopfield Network
#    - **Answer: A) RNN**
#
# 32. **Which neural network architecture is effective for content-based image retrieval (CBIR)?**
#    - A) CNN
#    - B) RNN
#    - C) Perceptron
#    - D) Softmax Network
#    - **Answer: A) CNN**
#
# 33. **Which type of neural network can be used to predict the weather by analyzing temporal weather patterns?**
#    - A) RNN
#    - B) CNN
#    - C) GAN
#    - D) Feedforward Neural Network
#    - **Answer: A) RNN**
#
# 34. **What is the application of neural networks in the finance sector for stock market prediction?**
#    - A) Time series analysis using RNN
#    - B) Image classification using CNN
#    - C) Denoising using Autoencoders
#    - D) Object detection using YOLO
#    - **Answer: A) Time series analysis using RNN**
#
# 35. **Which type of neural network is typically used for detecting objects in images?**
#    - A) CNN
#    - B) RNN
#    - C) LSTM
#    - D) Autoencoder
#    - **Answer: A) CNN**
#
# 36. **Which MATLAB function is used to extract HOG features for image recognition tasks using neural networks?**
#    - A) `extractHOGFeatures()`
#    - B) `fft()`
#    - C) `filter()`
#    - D) `rgb2gray()`
#    - **Answer: A) `extractHOGFeatures()`**
#
# 37. **Which application benefits most from using a Transformer architecture in neural networks?**
#    - A) Machine translation and NLP tasks
#    - B) Image classification
#    - C) Game simulation
#    - D) Weather prediction
#    - **Answer: A) Machine translation and NLP tasks**
#
# 38. **Which type of neural network is most suitable for analyzing audio signals and detecting speech commands?**
#    - A) RNN
#    - B) CNN
#    - C) Hopfield Network
#    - D) Kohonen Network
#    - **Answer: A) RNN**
#
# 39. **What is the application of deep neural networks in the field of autonomous driving?**
#    - A) Detecting and classifying road signs
#    - B) Sorting data
#    - C) Predicting stock prices
#    - D) Designing circuits
#    - **Answer: A) Detecting and classifying road signs**
#
# 40. **Which neural network model is most suitable for creating a music generation system?**
#    - A) RNN with LSTM units
#    - B) CNN
#    - C) GAN
#    - D) Softmax Network
#    - **Answer: A) RNN with LSTM units**
#
# 41. **Which type of neural network is used for spam email classification?**
#    - A) Feedforward Neural Network
#    - B) CNN
#    - C) RNN
#    - D) GAN
#    - **Answer: A) Feedforward Neural Network**
#
# 42. **Which application of neural networks involves generating realistic photos from random noise?**
#    - A) Image generation using GANs
#    - B) Image compression using Autoencoders
#    - C) Speech recognition using RNN
#    - D) Time series prediction using LSTM
#    - **Answer: A) Image generation using GANs**
#
# 43. **Which MATLAB function is useful for splitting data into training and validation datasets in neural network applications?**
#    - A) `cvpartition()`
#    - B) `fft()`
#    - C) `imfilter()`
#    - D) `meshgrid()`
#    - **Answer: A) `cvpartition()`**
#
# 44. **Which type of neural network is commonly used for face recognition systems?**
#    - A) CNN
#    - B) RNN
#    - C) Hopfield Network
#    - D) Kohonen Network
#    - **Answer: A) CNN**
#
# 45. **Which neural network application involves denoising corrupted images?**
#    - A) Autoencoders
#    - B) GANs
#    - C) Perceptrons
#    - D) LSTM Networks
#    - **Answer: A) Autoencoders**
#
# 46. **Which neural network is used for solving reinforcement learning tasks where agents learn from the environment?**
#    - A) Deep Q Network (DQN)
#    - B) CNN
#    - C) RNN
#    - D) Kohonen Network
#    - **Answer: A) Deep Q Network (DQN)**
#
# 47. **Which MATLAB function is used to load an image dataset for training a neural network?**
#    - A) `imageDatastore()`
#    - B) `load()`
#    - C) `imwrite()`
#    - D) `fread()`
#    - **Answer: A) `imageDatastore()`**
#
# 48. **Which neural network is ideal for predicting sequences in natural language, such as translating text?**
#    - A) Seq2Seq model with Attention Mechanism
#    - B) CNN
#    - C) GAN
#    - D) Perceptron
#    - **Answer: A) Seq2Seq model with Attention Mechanism**
#
# 49. **Which neural network is most suitable for identifying anomalies in network security logs?**
#    - A) Autoencoders
#    - B) RNN
#    - C) CNN
#    - D) Softmax Network
#    - **Answer: A) Autoencoders**
#
# 50. **What is a common use of convolutional neural networks in medical imaging?**
#    - A) Diagnosing diseases from X-ray or MRI images
#    - B) Predicting the weather
#    - C) Translating languages
#    - D) Detecting fraud in credit card transactions
#    - **Answer: A) Diagnosing diseases from X-ray or MRI images**
#
# 51. **Which application uses LSTM networks to predict customer behavior?**
#    - A) Customer churn prediction
#    - B) Object detection
#    - C) Image enhancement
#    - D) Game theory modeling
#    - **Answer: A) Customer churn prediction**
#
# 52. **Which MATLAB function is used to train a CNN on an image dataset?**
#    - A) `trainNetwork()`
#    - B) `imfilter()`
#    - C) `fft()`
#    - D) `integral()`
#    - **Answer: A) `trainNetwork()`**
#
# 53. **Which type of neural network is suitable for identifying credit card fraud by recognizing unusual patterns?**
#    - A) Feedforward Neural Network
#    - B) GAN
#    - C) CNN
#    - D) Kohonen Network
#    - **Answer: A) Feedforward Neural Network**
#
# 54. **Which neural network application is commonly used in handwriting recognition?**
#    - A) Character classification using CNNs
#    - B) Sequence analysis using RNNs
#    - C) Time series prediction using LSTMs
#    - D) Data compression using Autoencoders
#    - **Answer: A) Character classification using CNNs**
#
# 55. **Which type of neural network is most commonly used in translation systems like Google Translate?**
#    - A) Transformer
#    - B) Feedforward Neural Network
#    - C) Kohonen Network
#    - D) GAN
#    - **Answer: A) Transformer**
#
# 56. **Which MATLAB function is used to enhance the contrast of images before feeding them into a neural network?**
#    - A) `imadjust()`
#    - B) `fft()`
#    - C) `gradient()`
#    - D) `polyfit()`
#    - **Answer: A) `imadjust()`**
#
# 57. **Which neural network is suitable for detecting sentiments in social media posts?**
#    - A) RNN
#    - B) CNN
#    - C) Kohonen Network
#    - D) GAN
#    - **Answer: A) RNN**
#
# 58. **Which type of neural network is most suitable for building chatbots capable of conversation in natural language?**
#    - A) Transformer-based model
#    - B) CNN
#    - C) Hopfield Network
#    - D) Perceptron
#    - **Answer: A) Transformer-based model**
#
# 59. **Which neural network model can generate a realistic face image from a description using text prompts?**
#    - A) GAN
#    - B) RNN
#    - C) CNN
#    - D) LSTM
#    - **Answer: A) GAN**
#
# 60. **Which application uses a convolutional neural network (CNN) to identify specific areas of interest in aerial images?**
#    - A) Land use classification
#    - B) Predicting customer churn
#    - C) Denoising images
#    - D) Translating documents
#    - **Answer: A) Land use classification**

# %% [markdown]
# 61. **Which type of neural network is typically used for generating new art or digital images?**
#    - A) GAN
#    - B) CNN
#    - C) RNN
#    - D) Perceptron
#    - **Answer: A) GAN**
#
# 62. **Which MATLAB function would be appropriate to reduce the size of an image before feeding it into a CNN?**
#    - A) `imresize()`
#    - B) `fft()`
#    - C) `imhist()`
#    - D) `sqrt()`
#    - **Answer: A) `imresize()`**
#
# 63. **Which neural network architecture is commonly used for detecting sentiment in customer feedback?**
#    - A) LSTM-based RNN
#    - B) CNN
#    - C) GAN
#    - D) Hopfield Network
#    - **Answer: A) LSTM-based RNN**
#
# 64. **Which neural network is often used for recognizing text in natural handwriting?**
#    - A) Convolutional Neural Network (CNN)
#    - B) Hopfield Network
#    - C) Kohonen Network
#    - D) GAN
#    - **Answer: A) Convolutional Neural Network (CNN)**
#
# 65. **Which MATLAB function can be used to visualize the training progress of a neural network?**
#    - A) `plotTrainingAccuracy()`
#    - B) `trainingProgressPlot()`
#    - C) `plot()`
#    - D) `trainingOptions()`
#    - **Answer: D) `trainingOptions()`**
#
# 66. **What type of neural network is most suitable for time series forecasting in the field of energy consumption prediction?**
#    - A) LSTM
#    - B) CNN
#    - C) GAN
#    - D) Feedforward Neural Network
#    - **Answer: A) LSTM**
#
# 67. **Which application uses an RNN architecture for automated caption generation for images?**
#    - A) Image captioning
#    - B) Disease detection
#    - C) Object detection
#    - D) Data compression
#    - **Answer: A) Image captioning**
#
# 68. **Which type of neural network is best suited for categorizing news articles by their content?**
#    - A) RNN
#    - B) CNN
#    - C) GAN
#    - D) Radial Basis Function Network
#    - **Answer: A) RNN**
#
# 69. **Which neural network is primarily used in gaming applications for making the AI of a game agent smarter?**
#    - A) Deep Q-Network (DQN)
#    - B) GAN
#    - C) CNN
#    - D) Kohonen Network
#    - **Answer: A) Deep Q-Network (DQN)**
#
# 70. **Which MATLAB function is used for feature extraction in CNN applications?**
#    - A) `activations()`
#    - B) `fft()`
#    - C) `filter()`
#    - D) `conj()`
#    - **Answer: A) `activations()`**
#
# 71. **Which neural network application is commonly used in the field of genomics for predicting DNA sequence binding?**
#    - A) CNN
#    - B) RNN
#    - C) GAN
#    - D) Hopfield Network
#    - **Answer: A) CNN**
#
# 72. **Which type of neural network is suitable for predicting human activity based on sensor data?**
#    - A) LSTM-based RNN
#    - B) CNN
#    - C) Kohonen Network
#    - D) GAN
#    - **Answer: A) LSTM-based RNN**
#
# 73. **Which type of neural network would be most suitable for recognizing objects in videos for a surveillance system?**
#    - A) 3D Convolutional Neural Network
#    - B) RNN
#    - C) Kohonen Network
#    - D) Perceptron
#    - **Answer: A) 3D Convolutional Neural Network**
#
# 74. **Which MATLAB function is used to read video data for object detection tasks using neural networks?**
#    - A) `VideoReader()`
#    - B) `imread()`
#    - C) `fft()`
#    - D) `read()`
#    - **Answer: A) `VideoReader()`**
#
# 75. **Which neural network is commonly used for predicting natural disasters, such as earthquakes, by analyzing sensor data?**
#    - A) LSTM
#    - B) CNN
#    - C) Hopfield Network
#    - D) GAN
#    - **Answer: A) LSTM**
#
# 76. **Which type of neural network is most suitable for converting text into voice in a speech synthesis application?**
#    - A) RNN
#    - B) CNN
#    - C) Perceptron
#    - D) Hopfield Network
#    - **Answer: A) RNN**
#
# 77. **Which neural network technique is useful for creating a personalized shopping experience for customers by analyzing historical purchasing patterns?**
#    - A) Feedforward Neural Network
#    - B) GAN
#    - C) CNN
#    - D) Kohonen Network
#    - **Answer: A) Feedforward Neural Network**
#
# 78. **Which neural network application is used in diagnosing cardiovascular diseases from ECG signals?**
#    - A) RNN for time series analysis
#    - B) CNN for image classification
#    - C) GAN for data generation
#    - D) Autoencoder for dimensionality reduction
#    - **Answer: A) RNN for time series analysis**
#
# 79. **What is the primary application of neural networks in drug discovery?**
#    - A) Predicting the interaction between molecules
#    - B) Classifying handwritten documents
#    - C) Enhancing audio signals
#    - D) Generating new video content
#    - **Answer: A) Predicting the interaction between molecules**
#
# 80. **Which MATLAB function can be used to save a trained neural network model for later use?**
#    - A) `save()`
#    - B) `saveModel()`
#    - C) `saveNet()`
#    - D) `train()`
#    - **Answer: A) `save()`**
#
# 81. **Which neural network is used for generating synthetic images of people who do not exist?**
#    - A) GAN
#    - B) CNN
#    - C) RNN
#    - D) Perceptron
#    - **Answer: A) GAN**
#
# 82. **Which type of neural network is suitable for building an automatic text summarization tool?**
#    - A) Transformer
#    - B) CNN
#    - C) Hopfield Network
#    - D) Kohonen Network
#    - **Answer: A) Transformer**
#
# 83. **Which application of neural networks is used in predictive maintenance of machinery by analyzing sensor data?**
#    - A) LSTM for time series prediction
#    - B) GAN for image generation
#    - C) CNN for feature extraction
#    - D) Kohonen Network for clustering
#    - **Answer: A) LSTM for time series prediction**
#
# 84. **Which neural network is used in digital assistants, such as Alexa, to recognize spoken commands?**
#    - A) RNN
#    - B) CNN
#    - C) Kohonen Network
#    - D) Perceptron
#    - **Answer: A) RNN**
#
# 85. **Which neural network is best suited for recognizing and classifying brain activity in EEG data?**
#    - A) LSTM-based RNN
#    - B) GAN
#    - C) CNN
#    - D) Kohonen Network
#    - **Answer: A) LSTM-based RNN**
#
# 86. **Which MATLAB function can be used to visualize the structure of a trained neural network?**
#    - A) `view()`
#    - B) `networkDiagram()`
#    - C) `imshow()`
#    - D) `showNet()`
#    - **Answer: A) `view()`**
#
# 87. **Which neural network model is used to predict the sentiment of tweets during political campaigns?**
#    - A) LSTM-based RNN
#    - B) CNN
#    - C) GAN
#    - D) Feedforward Network
#    - **Answer: A) LSTM-based RNN**
#
# 88. **Which type of neural network is most suitable for detecting diabetic retinopathy from retinal images?**
#    - A) CNN
#    - B) RNN
#    - C) Kohonen Network
#    - D) GAN
#    - **Answer: A) CNN**
#
# 89. **Which MATLAB function is used to calculate the confusion matrix to evaluate the classification performance of a neural network?**
#    - A) `confusionchart()`
#    - B) `fft()`
#    - C) `scatter()`
#    - D) `imresize()`
#    - **Answer: A) `confusionchart()`**
#
# 90. **Which neural network is used for generating captions for an image that include objects and their relations?**
#    - A) Encoder-Decoder Network with Attention
#    - B) GAN
#    - C) Hopfield Network
#    - D) Perceptron
#    - **Answer: A) Encoder-Decoder Network with Attention**
#
# 91. **What is the application of neural networks in the agriculture sector?**
#    - A) Detecting plant diseases through image analysis
#    - B) Sorting manufactured products
#    - C) Predicting real estate prices
#    - D) Identifying bank fraud
#    - **Answer: A) Detecting plant diseases through image analysis**
#
# 92. **Which type of neural network is suitable for recognizing patterns in seismic activity for earthquake prediction?**
#    - A) RNN
#    - B) CNN
#    - C) GAN
#    - D) Perceptron
#    - **Answer: A) RNN**
#
# 93. **Which application of neural networks is used in cybersecurity for identifying malware in a system?**
#    - A) CNN for image feature extraction
#    - B) Autoencoder for anomaly detection
#    - C) GAN for generating synthetic malware data
#    - D) Hopfield Network for memory retention
#    - **Answer: B) Autoencoder for anomaly detection**
#
# 94. **Which neural network is suitable for a handwriting-to-text recognition system?**
#    - A) CNN with RNN for sequence recognition
#    - B) Feedforward Neural Network
#    - C) Kohonen Network
#    - D) Hopfield Network
#    - **Answer: A) CNN with RNN for sequence recognition**
#
# 95. **Which MATLAB function can be used to split data into training, validation, and test sets?**
#    - A) `dividerand()`
#    - B) `partition()`
#    - C) `splitdata()`
#    - D) `load()`
#    - **Answer: A) `dividerand()`**
#
# 96. **Which neural network is best suited for recognizing specific objects in satellite imagery?**
#    - A) CNN
#    - B) RNN
#    - C) GAN
#    - D) Kohonen Network
#    - **Answer: A) CNN**
#
# 97. **Which application uses a Transformer architecture to generate human-like text in response to user input?**
#    - A) Chatbots
#    - B) Image classification
#    - C) Financial modeling
#    - D) Object detection
#    - **Answer: A) Chatbots**
#
# 98. **Which type of neural network is most suitable for learning representations of graph-structured data?**
#    - A) Graph Neural Network (GNN)
#    - B) CNN
#    - C) RNN
#    - D) Kohonen Network
#    - **Answer: A) Graph Neural Network (GNN)**
#
# 99. **Which MATLAB function is used to train a classification neural network on input features and labels?**
#    - A) `fitcnet()`
#    - B) `train()`
#    - C) `filter()`
#    - D) `predict()`
#    - **Answer: A) `fitcnet()`**
#
# 100. **Which neural network application can predict crop yields based on environmental factors such as temperature, rainfall, and soil moisture?**
#     - A) LSTM-based RNN for time series forecasting
#     - B) CNN for feature extraction
#     - C) Kohonen Network for clustering
#     - D) GAN for image generation
#     - **Answer: A) LSTM-based RNN for time series forecasting**

# %% [markdown]
# ### **Perceptron and MLP Implementation using MATLAB Neural Network Library**
#
# 1. **Which MATLAB function is used to create a simple perceptron?**
#    - A) `newp()`
#    - B) `feedforwardnet()`
#    - C) `train()`
#    - D) `patternnet()`
#    - **Answer: A) `newp()`**
#
# 2. **What is the primary activation function used in a perceptron model?**
#    - A) Hard limit (step function)
#    - B) Sigmoid
#    - C) Tanh
#    - D) ReLU
#    - **Answer: A) Hard limit (step function)**
#
# 3. **Which function is used to train a perceptron in MATLAB?**
#    - A) `train()`
#    - B) `trainNetwork()`
#    - C) `fitnet()`
#    - D) `patternnet()`
#    - **Answer: A) `train()`**
#
# 4. **Which MATLAB function is used to create a feedforward MLP network?**
#    - A) `feedforwardnet()`
#    - B) `newp()`
#    - C) `patternnet()`
#    - D) `sim()`
#    - **Answer: A) `feedforwardnet()`**
#
# 5. **What is the default training algorithm used by the `train()` function for a perceptron?**
#    - A) Gradient Descent
#    - B) Levenberg-Marquardt
#    - C) Stochastic Gradient Descent
#    - D) Adaptive Learning Rule
#    - **Answer: D) Adaptive Learning Rule**
#
# 6. **Which command is used to define an MLP with three hidden layers of 10 neurons each in MATLAB?**
#    - A) `net = feedforwardnet([10, 10, 10]);`
#    - B) `net = newff([10, 10, 10]);`
#    - C) `net = patternnet(10);`
#    - D) `net = perceptron();`
#    - **Answer: A) `net = feedforwardnet([10, 10, 10]);`**
#
# 7. **How can you initialize a perceptron’s weights in MATLAB?**
#    - A) `net.IW{1,1} = rand(1, n);`
#    - B) `initializeWeights(net);`
#    - C) `randomizeWeights(net);`
#    - D) `net.trainParam.lr = 0.01;`
#    - **Answer: A) `net.IW{1,1} = rand(1, n);`**
#
# 8. **Which function can be used to simulate the output of a trained perceptron?**
#    - A) `sim()`
#    - B) `predict()`
#    - C) `fit()`
#    - D) `classify()`
#    - **Answer: A) `sim()`**
#
# 9. **Which function is used to visualize an MLP architecture in MATLAB?**
#    - A) `view()`
#    - B) `plot()`
#    - C) `imshow()`
#    - D) `networkDisplay()`
#    - **Answer: A) `view()`**
#
# 10. **Which MATLAB function allows you to create a pattern recognition network for a classification task?**
#     - A) `patternnet()`
#     - B) `feedforwardnet()`
#     - C) `fitnet()`
#     - D) `perceptron()`
#     - **Answer: A) `patternnet()`**
#
# 11. **Which function is used to divide data into training, validation, and test sets in an MLP?**
#     - A) `divideind()`
#     - B) `splitData()`
#     - C) `dataPartition()`
#     - D) `trainTestSplit()`
#     - **Answer: A) `divideind()`**
#
# 12. **How can you specify the number of hidden neurons in an MLP created by the `feedforwardnet()` function?**
#     - A) By passing a vector of hidden layer sizes to the function
#     - B) By setting `net.hiddenLayers`
#     - C) By changing the activation function
#     - D) By using `addHiddenLayer()`
#     - **Answer: A) By passing a vector of hidden layer sizes to the function**
#
# 13. **Which training function is the default for the `train()` function in MATLAB for MLP networks?**
#     - A) `trainlm` (Levenberg-Marquardt)
#     - B) `trainscg` (Scaled Conjugate Gradient)
#     - C) `trainbr` (Bayesian Regularization)
#     - D) `trainrp` (Resilient Backpropagation)
#     - **Answer: A) `trainlm` (Levenberg-Marquardt)**
#
# 14. **Which MATLAB function is used to set training options like maximum epochs and learning rate for an MLP?**
#     - A) `trainingOptions()`
#     - B) `trainParam`
#     - C) `trainingConfig()`
#     - D) `trainOptionSet()`
#     - **Answer: B) `trainParam`**
#
# 15. **Which command is used to set the learning rate of an MLP in MATLAB?**
#     - A) `net.trainParam.lr = 0.01;`
#     - B) `net.learningRate = 0.01;`
#     - C) `setLearningRate(net, 0.01);`
#     - D) `net.lr = 0.01;`
#     - **Answer: A) `net.trainParam.lr = 0.01;`**
#
# 16. **Which activation function is typically used in the hidden layers of an MLP created using `feedforwardnet()`?**
#     - A) Sigmoid
#     - B) ReLU
#     - C) Tanh
#     - D) Logarithmic
#     - **Answer: A) Sigmoid**
#
# 17. **How can you change the activation function of a layer in MATLAB's `feedforwardnet()`?**
#     - A) `net.layers{i}.transferFcn = 'tansig';`
#     - B) `net.activationLayer = 'relu';`
#     - C) `setActivationFunction(net, i, 'tansig');`
#     - D) `net.setActivation(i, 'relu');`
#     - **Answer: A) `net.layers{i}.transferFcn = 'tansig';`**
#
# 18. **Which function is used to evaluate the performance of an MLP model in MATLAB?**
#     - A) `perform()`
#     - B) `evaluate()`
#     - C) `mse()`
#     - D) `crossVal()`
#     - **Answer: A) `perform()`**
#
# 19. **Which MATLAB function is used to add regularization to MLP training?**
#     - A) `net.performParam.regularization`
#     - B) `net.addRegularizer()`
#     - C) `net.trainParam.alpha`
#     - D) `net.regularization`
#     - **Answer: A) `net.performParam.regularization`**
#
# 20. **Which parameter should be modified to increase the number of training epochs in a perceptron model?**
#     - A) `net.trainParam.epochs`
#     - B) `net.maxTrainingIterations`
#     - C) `net.trainingCycles`
#     - D) `net.iterations`
#     - **Answer: A) `net.trainParam.epochs`**
#
# 21. **Which training algorithm is recommended for larger datasets when using the `train()` function with MLP in MATLAB?**
#     - A) `trainscg` (Scaled Conjugate Gradient)
#     - B) `trainlm` (Levenberg-Marquardt)
#     - C) `trainbr` (Bayesian Regularization)
#     - D) `trainrp` (Resilient Backpropagation)
#     - **Answer: A) `trainscg` (Scaled Conjugate Gradient)**
#
# 22. **Which type of network would you use in MATLAB for regression tasks involving the prediction of continuous outputs?**
#     - A) `fitnet()`
#     - B) `patternnet()`
#     - C) `perceptron()`
#     - D) `convolvenet()`
#     - **Answer: A) `fitnet()`**
#
# 23. **How can you access and modify the weights of a specific layer in an MLP in MATLAB?**
#     - A) `net.IW{layerIndex}`
#     - B) `net.layerWeights[layerIndex]`
#     - C) `modifyWeights(net, layerIndex)`
#     - D) `net.weights[layerIndex]`
#     - **Answer: A) `net.IW{layerIndex}`**
#
# 24. **Which MATLAB function is suitable for evaluating the accuracy of a trained classification MLP?**
#     - A) `confusion()`
#     - B) `errorRate()`
#     - C) `predictAccuracy()`
#     - D) `classificationPerform()`
#     - **Answer: A) `confusion()`**
#
# 25. **Which command in MATLAB is used to plot the regression fit between predicted and actual outputs for an MLP?**
#     - A) `plotregression()`
#     - B) `fitplot()`
#     - C) `regressionGraph()`
#     - D) `plotfit()`
#     - **Answer: A) `plotregression()`**
#
# 26. **Which activation function is used in the output layer of an MLP for regression tasks?**
#     - A) Linear
#     - B) Sigmoid
#     - C) ReLU
#     - D) Tanh
#     - **Answer: A) Linear**
#
# 27. **Which MATLAB command can be used to train a perceptron model with binary classification data?**
#     - A) `train(net, input, target)`
#     - B) `trainPerceptron(input, target)`
#     - C) `fit(net, input, target)`
#     - D) `trainClassifier(net, input, target)`
#     - **Answer: A) `train(net, input, target)`**
#
# 28. **How can you specify early stopping to avoid overfitting when training an MLP in MATLAB?**
#     - A) By setting `net.divideParam.valRatio` to a non-zero value
#     - B) By reducing the learning rate
#     - C) By changing `net.trainParam.lr`
#     - D) By increasing the number of hidden neurons
#     - **Answer: A) By setting `net.divideParam.valRatio` to a non-zero value**
#
# 29. **Which training function can be used in MATLAB to perform backpropagation for an MLP?**
#     - A) `trainlm` (Levenberg-Marquardt)
#     - B) `bp()`
#     - C) `forwardBackward()`
#     - D) `trainscg`
#     - **Answer: A) `trainlm` (Levenberg-Marquardt)**
#
# 30. **How can you modify the hidden layer transfer function to use ReLU in an MLP created by `feedforwardnet()`?**
#     - A) `net.layers{i}.transferFcn = 'poslin';`
#     - B) `net.hiddenLayerActivation = 'relu';`
#     - C) `net.hiddenTransferFcn = 'tansig';`
#     - D) `net.addActivation('relu');`
#     - **Answer: A) `net.layers{i}.transferFcn = 'poslin';`**

# %% [markdown]
# 31. **What is the purpose of using the `net.divideParam` property in an MLP network in MATLAB?**
#    - A) To specify the proportion of data used for training, validation, and testing
#    - B) To set the number of layers in the network
#    - C) To initialize weights randomly
#    - D) To define the activation function
#    - **Answer: A) To specify the proportion of data used for training, validation, and testing**
#
# 32. **Which command is used to update the biases of the first hidden layer in a feedforward MLP in MATLAB?**
#    - A) `net.b{1} = rand(size(net.b{1}));`
#    - B) `net.updateBias(1);`
#    - C) `net.setBias(1);`
#    - D) `net.modifyBias(1);`
#    - **Answer: A) `net.b{1} = rand(size(net.b{1}));`**
#
# 33. **Which MATLAB function would you use to evaluate the performance of an MLP on a mean square error basis?**
#    - A) `perform(net, targets, outputs)`
#    - B) `evaluate(net, targets, outputs)`
#    - C) `mse(targets, outputs)`
#    - D) `calculateMSE(net)`
#    - **Answer: A) `perform(net, targets, outputs)`**
#
# 34. **What is the default activation function for hidden layers in an MLP created by the `feedforwardnet()` function in MATLAB?**
#    - A) `tansig`
#    - B) `purelin`
#    - C) `logsig`
#    - D) `poslin`
#    - **Answer: A) `tansig`**
#
# 35. **Which command allows you to plot the confusion matrix for a classification MLP in MATLAB?**
#    - A) `plotconfusion(targets, outputs)`
#    - B) `plotMatrix(targets, outputs)`
#    - C) `confusionchart(outputs)`
#    - D) `drawConfusion(targets, outputs)`
#    - **Answer: A) `plotconfusion(targets, outputs)`**
#
# 36. **Which training option can be set to automatically stop training when validation error increases for several iterations?**
#    - A) `net.trainParam.max_fail`
#    - B) `net.stopOnValError`
#    - C) `net.valErrorStop`
#    - D) `net.trainUntilError()`
#    - **Answer: A) `net.trainParam.max_fail`**
#
# 37. **Which parameter in the `trainParam` structure can be used to control the maximum number of epochs during training in MATLAB?**
#    - A) `net.trainParam.epochs`
#    - B) `net.trainParam.maxEpoch`
#    - C) `net.maxTrainingSteps`
#    - D) `net.trainEpochs`
#    - **Answer: A) `net.trainParam.epochs`**
#
# 38. **Which function is used to configure a neural network without initializing the weights in MATLAB?**
#    - A) `configure()`
#    - B) `train()`
#    - C) `initialize()`
#    - D) `prepareNet()`
#    - **Answer: A) `configure()`**
#
# 39. **What is the main advantage of using the Levenberg-Marquardt training function (`trainlm`) for MLPs in MATLAB?**
#    - A) Faster convergence for smaller datasets
#    - B) Lower computational cost
#    - C) It works best for RNNs
#    - D) Best for sparse data
#    - **Answer: A) Faster convergence for smaller datasets**
#
# 40. **Which function can be used to obtain the final layer's weight matrix after training an MLP in MATLAB?**
#    - A) `net.LW{end}`
#    - B) `net.layers.weights`
#    - C) `net.getWeights()`
#    - D) `net.finalWeights`
#    - **Answer: A) `net.LW{end}`**
#
# 41. **Which MATLAB function can be used to initialize the weights of an MLP?**
#    - A) `init()`
#    - B) `initlay()`
#    - C) `initialize()`
#    - D) `initweights()`
#    - **Answer: B) `initlay()`**
#
# 42. **How can you control the ratio of data allocated to validation in an MLP using `divideParam`?**
#    - A) `net.divideParam.valRatio = 0.2;`
#    - B) `net.validationSize = 0.2;`
#    - C) `net.setValidationRatio(0.2);`
#    - D) `net.validationPartition(0.2);`
#    - **Answer: A) `net.divideParam.valRatio = 0.2;`**
#
# 43. **Which function in MATLAB helps determine whether a given dataset is suitable for training an MLP model?**
#    - A) `checkdata()`
#    - B) `validateInputs()`
#    - C) `size()`
#    - D) `datacheck()`
#    - **Answer: A) `checkdata()`**
#
# 44. **Which parameter must be adjusted to prevent overfitting in an MLP by controlling the learning process?**
#    - A) `net.trainParam.max_fail`
#    - B) `net.trainParam.regularization`
#    - C) `net.divideParam.trainRatio`
#    - D) `net.valStop`
#    - **Answer: A) `net.trainParam.max_fail`**
#
# 45. **How can you save the trained MLP model in MATLAB for future use?**
#    - A) `save('MLPModel.mat', 'net');`
#    - B) `saveModel(net, 'MLPModel');`
#    - C) `storeNetwork(net)`
#    - D) `net.save('MLPModel')`
#    - **Answer: A) `save('MLPModel.mat', 'net');`**
#
# 46. **Which command is used to retrieve the activation function of the second layer in a feedforward network?**
#    - A) `net.layers{2}.transferFcn`
#    - B) `net.hiddenLayer{2}`
#    - C) `net.getActivation(2)`
#    - D) `net.layerActivation(2)`
#    - **Answer: A) `net.layers{2}.transferFcn`**
#
# 47. **Which training function is suitable for very large datasets that do not fit into memory when using an MLP in MATLAB?**
#    - A) `trainscg` (Scaled Conjugate Gradient)
#    - B) `trainlm` (Levenberg-Marquardt)
#    - C) `trainbr` (Bayesian Regularization)
#    - D) `trainrp` (Resilient Backpropagation)
#    - **Answer: A) `trainscg` (Scaled Conjugate Gradient)**
#
# 48. **Which type of data splitting is used by default in MATLAB for training, validation, and testing an MLP?**
#    - A) Randomly partitioning the data
#    - B) Sequentially partitioning the data
#    - C) Cross-validation
#    - D) Bootstrapping
#    - **Answer: A) Randomly partitioning the data**
#
# 49. **How can you increase the generalization ability of a neural network in MATLAB?**
#    - A) By using more hidden neurons and early stopping
#    - B) By training for more epochs
#    - C) By only using the training dataset
#    - D) By setting learning rate to a high value
#    - **Answer: A) By using more hidden neurons and early stopping**
#
# 50. **Which MATLAB function can be used to visualize the training performance of an MLP?**
#    - A) `plotperform()`
#    - B) `plotError()`
#    - C) `showTraining()`
#    - D) `performPlot()`
#    - **Answer: A) `plotperform()`**
#
# 51. **What is the default learning rate for training a feedforward network in MATLAB?**
#    - A) 0.01
#    - B) 0.1
#    - C) 0.001
#    - D) 1
#    - **Answer: B) 0.1**
#
# 52. **Which MATLAB command is used to test a trained MLP on new input data?**
#    - A) `y = net(X);`
#    - B) `testNetwork(net, X);`
#    - C) `predict(net, X);`
#    - D) `simulate(net, X);`
#    - **Answer: A) `y = net(X);`**
#
# 53. **Which command would you use to set the training data ratio to 70% in an MLP in MATLAB?**
#    - A) `net.divideParam.trainRatio = 0.7;`
#    - B) `net.trainSet = 70;`
#    - C) `net.data.train = 70;`
#    - D) `setTrainingRatio(net, 0.7);`
#    - **Answer: A) `net.divideParam.trainRatio = 0.7;`**
#
# 54. **How can the number of epochs be dynamically adjusted based on validation performance in MATLAB?**
#    - A) `net.trainParam.max_fail`
#    - B) `net.trainParam.adjustEpochs`
#    - C) `net.validationControl`
#    - D) `net.dynamicEpochAdjustment`
#    - **Answer: A) `net.trainParam.max_fail`**
#
# 55. **What is the purpose of using `mse()` function in the context of MLP in MATLAB?**
#    - A) To calculate mean squared error for evaluating performance
#    - B) To update network weights
#    - C) To change activation functions
#    - D) To normalize input data
#    - **Answer: A) To calculate mean squared error for evaluating performance**
#
# 56. **Which property of the `trainParam` structure is used to set the goal for the performance function in MATLAB?**
#    - A) `net.trainParam.goal`
#    - B) `net.performanceGoal`
#    - C) `net.setGoal()`
#    - D) `net.trainGoal`
#    - **Answer: A) `net.trainParam.goal`**
#
# 57. **Which MATLAB function is used to load data from a `.mat` file for training an MLP?**
#    - A) `load()`
#    - B) `import()`
#    - C) `loadmat()`
#    - D) `dataset()`
#    - **Answer: A) `load()`**
#
# 58. **Which training parameter would you adjust to control the minimum gradient for stopping training?**
#    - A) `net.trainParam.min_grad`
#    - B) `net.gradientThreshold`
#    - C) `net.trainParam.grad_min`
#    - D) `net.trainParam.stop_grad`
#    - **Answer: A) `net.trainParam.min_grad`**
#
# 59. **Which command is used to reset a network to its initial state before retraining in MATLAB?**
#    - A) `net = init(net);`
#    - B) `net.reset()`
#    - C) `net.restart()`
#    - D) `net.initialize()`
#    - **Answer: A) `net = init(net);`**
#
# 60. **How can you ensure that the weights of an MLP are adjusted to prevent overfitting during training in MATLAB?**
#    - A) By using L2 regularization (`net.performParam.regularization`)
#    - B) By increasing the number of hidden layers
#    - C) By setting `net.trainParam.lr` to a high value
#    - D) By reducing the dataset size
#    - **Answer: A) By using L2 regularization (`net.performParam.regularization`)**

# %% [markdown]
# 61. **What is the function of `net.trainParam.mu` in MATLAB’s Levenberg-Marquardt training?**
#    - A) It controls the learning rate adaptation
#    - B) It controls the amount of regularization
#    - C) It is the initial value for the combination coefficient of Gauss-Newton and gradient descent
#    - D) It controls the weight update frequency
#    - **Answer: C) It is the initial value for the combination coefficient of Gauss-Newton and gradient descent**
#
# 62. **Which MATLAB command is used to save all training details and workspace variables after completing MLP training?**
#    - A) `save('workspace.mat');`
#    - B) `saveAll('workspace');`
#    - C) `store('trainingDetails');`
#    - D) `exportAll('trainingResults')`
#    - **Answer: A) `save('workspace.mat');`**
#
# 63. **Which method is used in MATLAB to set custom weight initialization for a specific layer of an MLP?**
#    - A) `net.IW{layerIndex} = initFunc;`
#    - B) `net.layers{layerIndex}.weights = initFunc;`
#    - C) `net.layerWeights{layerIndex}.init = customInit;`
#    - D) `net.initLayer(layerIndex) = initFunc;`
#    - **Answer: A) `net.IW{layerIndex} = initFunc;`**
#
# 64. **Which transfer function would be ideal to use for the hidden layers in an MLP to capture both positive and negative relationships in data?**
#    - A) `tansig`
#    - B) `purelin`
#    - C) `logsig`
#    - D) `relu`
#    - **Answer: A) `tansig`**
#
# 65. **Which MATLAB function is used to calculate the prediction accuracy for a classification network?**
#    - A) `classificationAccuracy()`
#    - B) `confusion()`
#    - C) `accuracyCalc()`
#    - D) `predictAccuracy()`
#    - **Answer: B) `confusion()`**
#
# 66. **Which command is used to set the initial weights of the network to a Gaussian distribution?**
#    - A) `net.initFcn = 'initnw';`
#    - B) `net.initFcn = 'initwb';`
#    - C) `net.initFcn = 'initgauss';`
#    - D) `net.weightInit = 'gaussian';`
#    - **Answer: B) `net.initFcn = 'initwb';`**
#
# 67. **How can you determine if an MLP has converged during training in MATLAB?**
#    - A) Check if `net.trainParam.goal` has been achieved
#    - B) Inspect the network output for zero variance
#    - C) Verify that all hidden units are active
#    - D) Observe if the weight updates stop changing
#    - **Answer: A) Check if `net.trainParam.goal` has been achieved**
#
# 68. **Which function is used to add noise to training data to prevent overfitting in MATLAB?**
#    - A) `awgn(data, SNR)`
#    - B) `addNoise(data)`
#    - C) `noisyData()`
#    - D) `perturb(data)`
#    - **Answer: A) `awgn(data, SNR)`**
#
# 69. **Which training parameter in `trainParam` helps you control the learning rate of an MLP in MATLAB?**
#    - A) `net.trainParam.lr`
#    - B) `net.learningSpeed`
#    - C) `net.lr`
#    - D) `net.rate`
#    - **Answer: A) `net.trainParam.lr`**
#
# 70. **Which command is used to set a learning rate that decreases during training to allow fine-tuning of weights in an MLP?**
#    - A) `net.trainParam.lr_dec`
#    - B) `net.learningRateDrop()`
#    - C) `net.trainParam.lr_decay`
#    - D) `net.decreaseLR()`
#    - **Answer: A) `net.trainParam.lr_dec`**
#
# 71. **What function can be used in MATLAB to determine the significance of each input feature after training an MLP?**
#    - A) `networkImpact()`
#    - B) `inputContribution()`
#    - C) `trainImpact()`
#    - D) `inputWeights()`
#    - **Answer: B) `inputContribution()`**
#
# 72. **Which function is used to manually configure an MLP model to accept input data and target labels before training?**
#    - A) `configure(net, inputs, targets)`
#    - B) `setTrainingData(net, inputs, targets)`
#    - C) `prepareForTraining(net, inputs, targets)`
#    - D) `initializeTrainingData()`
#    - **Answer: A) `configure(net, inputs, targets)`**
#
# 73. **Which training function is more suitable for handling noisy data in an MLP?**
#    - A) `trainbr` (Bayesian Regularization)
#    - B) `trainlm` (Levenberg-Marquardt)
#    - C) `trainscg` (Scaled Conjugate Gradient)
#    - D) `trainrp` (Resilient Backpropagation)
#    - **Answer: A) `trainbr` (Bayesian Regularization)**
#
# 74. **Which parameter must be configured to use early stopping based on the validation dataset in MATLAB?**
#    - A) `net.trainParam.max_fail`
#    - B) `net.stopCondition`
#    - C) `net.trainValidationStop`
#    - D) `net.stopOnValidation`
#    - **Answer: A) `net.trainParam.max_fail`**
#
# 75. **Which command is used to add a new hidden layer to an existing MLP in MATLAB?**
#    - A) `addLayer(net, num_neurons)`
#    - B) `net = feedforwardnet([current, num_neurons]);`
#    - C) `appendHiddenLayer(net, num_neurons)`
#    - D) `addHiddenNeuron(net, num_neurons)`
#    - **Answer: B) `net = feedforwardnet([current, num_neurons]);`**
#
# 76. **Which MATLAB function would you use to visualize both the training and validation errors during training of an MLP?**
#    - A) `plottrainstate()`
#    - B) `trainGraph()`
#    - C) `viewValidationErrors()`
#    - D) `showTrainState()`
#    - **Answer: A) `plottrainstate()`**
#
# 77. **What is the function of `net.divideFcn` in a feedforward network in MATLAB?**
#    - A) It defines how data is divided into training, validation, and testing sets
#    - B) It sets the ratio between hidden layers and output layer
#    - C) It divides the learning rate during training
#    - D) It divides the weight matrix into parts
#    - **Answer: A) It defines how data is divided into training, validation, and testing sets**
#
# 78. **Which property is modified to increase the batch size for training a neural network in MATLAB?**
#    - A) `net.trainParam.batchSize`
#    - B) `net.batchSize`
#    - C) `net.trainParam.miniBatchSize`
#    - D) `net.batchControl`
#    - **Answer: C) `net.trainParam.miniBatchSize`**
#
# 79. **Which MATLAB command is used to display the regression fit between predicted and actual outputs for an MLP?**
#    - A) `plotregression(targets, outputs)`
#    - B) `drawRegression(targets, outputs)`
#    - C) `showFit()`
#    - D) `linearFitPlot(targets, outputs)`
#    - **Answer: A) `plotregression(targets, outputs)`**
#
# 80. **How can you specify a different cost function for training an MLP in MATLAB?**
#    - A) `net.performFcn = 'mse';`
#    - B) `net.setCostFunction('mae');`
#    - C) `net.costFunction = 'crossentropy';`
#    - D) `net.changeLoss('mse');`
#    - **Answer: A) `net.performFcn = 'mse';`**
#
# 81. **Which function is used to remove a layer from a network structure in MATLAB?**
#    - A) There is no direct function; you need to recreate the network without the specific layer
#    - B) `removeLayer()`
#    - C) `deleteLayer()`
#    - D) `stripLayer()`
#    - **Answer: A) There is no direct function; you need to recreate the network without the specific layer**
#
# 82. **Which activation function in MLP helps the model learn sparse representations by making some neuron activations zero?**
#    - A) ReLU (`poslin`)
#    - B) `logsig`
#    - C) `tansig`
#    - D) `purelin`
#    - **Answer: A) ReLU (`poslin`)**
#
# 83. **How can you determine the amount of data being used for testing in MATLAB?**
#    - A) Check `net.divideParam.testRatio`
#    - B) Use `net.testingSize`
#    - C) Check `net.validationRatio`
#    - D) Look at `net.trainRatio`
#    - **Answer: A) Check `net.divideParam.testRatio`**
#
# 84. **Which property of `net.trainParam` is used to limit the time spent training a neural network in MATLAB?**
#    - A) `net.trainParam.time`
#    - B) `net.trainTime`
#    - C) `net.trainingDuration`
#    - D) `net.limitTrainingTime`
#    - **Answer: A) `net.trainParam.time`**
#
# 85. **Which function in MATLAB can be used to plot the weight distribution of an MLP during training?**
#    - A) `plotwb(net)`
#    - B) `plotWeights(net)`
#    - C) `plotWeightDistribution()`
#    - D) `weightplot()`
#    - **Answer: A) `plotwb(net)`**
#
# 86. **What does the `trainFcn` property of an MLP determine in MATLAB?**
#    - A) The training algorithm to be used
#    - B) The number of hidden layers
#    - C) The size of the validation set
#    - D) The activation function
#    - **Answer: A) The training algorithm to be used**
#
# 87. **Which function can you use to manually stop the training process of an MLP in MATLAB?**
#    - A) `stopTraining()`
#    - B) Manually click the "Stop Training" button in the MATLAB training window
#    - C) `pauseTraining()`
#    - D) `terminateTrain()`
#    - **Answer: B) Manually click the "Stop Training" button in the MATLAB training window**
#
# 88. **How can you adjust the number of neurons in the output layer for an MLP?**
#    - A) Change `net.numOutputs`
#    - B) Adjust the output layer in `net.LW{end}`
#    - C) Use `setOutputLayerSize()`
#    - D) `net = feedforwardnet(outputSize)`
#    - **Answer: B) Adjust the output layer in `net.LW{end}`**
#
# 89. **Which property is used to set the maximum validation check failures in a training MLP network?**
#    - A) `net.trainParam.max_fail`
#    - B) `net.trainValidationFails`
#    - C) `net.validationStop`
#    - D) `net.failControl`
#    - **Answer: A) `net.trainParam.max_fail`**
#
# 90. **Which MATLAB function is used to create a radial basis function network (RBF)?**
#    - A) `newrb()`
#    - B) `feedforwardnet()`
#    - C) `rbfnet()`
#    - D) `newp()`
#    - **Answer: A) `newrb()`**
#
# 91. **Which command is used to modify the transfer function of the output layer in an MLP?**
#    - A) `net.layers{end}.transferFcn = 'purelin';`
#    - B) `net.outputTransferFcn = 'relu';`
#    - C) `net.modifyLayerTransfer()`
#    - D) `setOutputActivation(net, 'purelin')`
#    - **Answer: A) `net.layers{end}.transferFcn = 'purelin';`**
#
# 92. **Which parameter in MATLAB controls how many times the network weights are updated for each training epoch in an MLP?**
#    - A) `net.trainParam.showWindow`
#    - B) `net.trainParam.epochs`
#    - C) `net.trainParam.max_fail`
#    - D) `net.trainParam.mc`
#    - **Answer: A) `net.trainParam.showWindow`**
#
# 93. **How can you access the validation performance of the network during training in MATLAB?**
#    - A) Check `net.trainRecord.validationPerf`
#    - B) Use `net.performanceVal()`
#    - C) View `net.valCheck`
#    - D) Monitor `net.validationState`
#    - **Answer: A) Check `net.trainRecord.validationPerf`**
#
# 94. **Which parameter is used to set the maximum amount of time a training session should last for in MATLAB?**
#    - A) `net.trainParam.time`
#    - B) `net.maxTrainingDuration`
#    - C) `net.trainingEnd`
#    - D) `net.trainTimeout`
#    - **Answer: A) `net.trainParam.time`**
#
# 95. **Which MATLAB function is used to display a plot of the network’s error histogram?**
#    - A) `ploterrhist()`
#    - B) `histogram()`
#    - C) `ploterror()`
#    - D) `viewErrorHist()`
#    - **Answer: A) `ploterrhist()`**
#
# 96. **Which MATLAB function is used to create a self-organizing map (SOM)?**
#    - A) `newsom()`
#    - B) `createSOM()`
#    - C) `somNet()`
#    - D) `newself()`
#    - **Answer: A) `newsom()`**
#
# 97. **Which parameter allows you to specify early stopping in MATLAB to avoid overfitting?**
#    - A) `net.trainParam.max_fail`
#    - B) `net.earlyStop`
#    - C) `net.valStop`
#    - D) `net.stopCriteria`
#    - **Answer: A) `net.trainParam.max_fail`**
#
# 98. **Which MATLAB function is used to generate a performance report for an MLP after training?**
#    - A) `perform(net, t, y)`
#    - B) `generatePerformanceReport()`
#    - C) `viewReport()`
#    - D) `net.performanceSummary()`
#    - **Answer: A) `perform(net, t, y)`**
#
# 99. **Which function can be used to save training results automatically during training in MATLAB?**
#    - A) `checkpoint(net)`
#    - B) `net.trainParam.saveResult = true;`
#    - C) `autosaveTraining()`
#    - D) `autosave('trainingData');`
#    - **Answer: A) `checkpoint(net)`**
#
# 100. **Which command is used to visualize the architecture of an MLP in MATLAB?**
#     - A) `view(net)`
#     - B) `showNetwork()`
#     - C) `displayArchitecture(net)`
#     - D) `networkGraph()`
#     - **Answer: A) `view(net)`**
