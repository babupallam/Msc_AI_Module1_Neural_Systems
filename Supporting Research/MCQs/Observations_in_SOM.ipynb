# %% [markdown]
# <a href="https://colab.research.google.com/github/babupallam/Msc_AI_Module1_Neural_Systems/blob/main/Supporting%20Research/MCQs/Observations_in_SOM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. **What is the primary difference between supervised and unsupervised learning?**
#    - A) Unsupervised learning requires labels, whereas supervised learning does not
#    - B) Supervised learning uses target values, while unsupervised learning identifies patterns without targets
#    - C) Both require human intervention for learning
#    - D) Unsupervised learning is slower than supervised learning
#    - **Answer: B) Supervised learning uses target values, while unsupervised learning identifies patterns without targets**【200†source】
#
# 2. **What is pattern recognition mainly used for?**
#    - A) Identifying trends in data
#    - B) Classifying 'objects' into classes
#    - C) Randomly generating data points
#    - D) Increasing the number of hidden layers
#    - **Answer: B) Classifying 'objects' into classes**【200†source】
#
# 3. **What is the main application of clustering in unsupervised learning?**
#    - A) Creating labels for data
#    - B) Grouping similar patterns together
#    - C) Optimizing gradient descent
#    - D) Predicting target outcomes
#    - **Answer: B) Grouping similar patterns together**【200†source】
#
# 4. **Which neural network algorithm uses unsupervised competitive learning?**
#    - A) Backpropagation
#    - B) Self-Organizing Maps (SOM)
#    - C) Recurrent Neural Networks (RNN)
#    - D) Convolutional Neural Networks (CNN)
#    - **Answer: B) Self-Organizing Maps (SOM)**【200†source】
#
# 5. **Who initially introduced the concept of Self-Organizing Maps (SOM)?**
#    - A) T. Kohonen
#    - B) C. von der Malsburg
#    - C) Geoffrey Hinton
#    - D) Yann LeCun
#    - **Answer: B) C. von der Malsburg**【200†source】
#
# 6. **What is a key feature of the SOM algorithm's output?**
#    - A) Randomly generated weight vectors
#    - B) Topographic ordering of similar patterns close to each other
#    - C) Fully connected neural layers
#    - D) Exponential weight growth
#    - **Answer: B) Topographic ordering of similar patterns close to each other**【200†source】
#
# 7. **What type of learning rate function is often used in SOM training?**
#    - A) Constant learning rate
#    - B) Linear decrease over time
#    - C) Exponential growth over time
#    - D) No learning rate
#    - **Answer: B) Linear decrease over time**【200†source】
#
# 8. **What is the function of a ‘neighbourhood’ in SOM training?**
#    - A) Determines which neurons are not affected
#    - B) Identifies the winner and modifies neighbouring neurons accordingly
#    - C) Randomly activates different neurons
#    - D) Adds noise to input vectors
#    - **Answer: B) Identifies the winner and modifies neighbouring neurons accordingly**【200†source】
#
# 9. **Which function can be used as the shape of a neighbourhood in SOM?**
#    - A) Sigmoid
#    - B) Gaussian
#    - C) Tanh
#    - D) Rectifier
#    - **Answer: B) Gaussian**【200†source】
#
# 10. **What is the purpose of data preprocessing in the context of SOM?**
#     - A) Randomize the order of neurons
#     - B) Standardize features to make comparisons meaningful
#     - C) Train hidden layers
#     - D) Reduce input dimensionality to a single feature
#     - **Answer: B) Standardize features to make comparisons meaningful**【200†source】
#
# 11. **What is the 'U-Matrix' in the context of SOMs?**
#     - A) A visualization technique that shows contours between nodes to indicate groupings
#     - B) A way to calculate the error in the weights
#     - C) A linear function applied during training
#     - D) A method to reduce network size
#     - **Answer: A) A visualization technique that shows contours between nodes to indicate groupings**【200†source】
#
# 12. **What does a high learning rate in SOM training signify?**
#     - A) Slow adaptation of weights
#     - B) Weights rapidly adjust to resemble input vectors
#     - C) No change in neighbourhood size
#     - D) Increases error in final model
#     - **Answer: B) Weights rapidly adjust to resemble input vectors**【200†source】
#
# 13. **What is a major sensory system mapped in the brain referred to as?**
#     - A) Random mapping
#     - B) Topographic mapping
#     - C) Modular clustering
#     - D) Fully connected mapping
#     - **Answer: B) Topographic mapping**【200†source】
#
# 14. **Which of the following is an example of a 'feature' used in pattern recognition?**
#     - A) Labels of data
#     - B) Eyes, nose, mouth for facial recognition
#     - C) Random noise
#     - D) Output of another neural network
#     - **Answer: B) Eyes, nose, mouth for facial recognition**【200†source】
#
# 15. **What is the term used when the output space of SOM has no noticeable changes in weights?**
#     - A) Convergence
#     - B) Deviation
#     - C) Divergence
#     - D) Backpropagation
#     - **Answer: A) Convergence**【200†source】
#
# 16. **What is the purpose of visualizing a SOM using a 'poverty map'?**
#     - A) To increase the number of nodes
#     - B) To cluster based on poverty indicators
#     - C) To train on economic datasets
#     - D) To enhance the accuracy of financial models
#     - **Answer: B) To cluster based on poverty indicators**【200†source】
#
# 17. **What distance measure is often used in SOM training to identify the winning neuron?**
#     - A) Cosine similarity
#     - B) Euclidean distance
#     - C) Manhattan distance
#     - D) Correlation coefficient
#     - **Answer: B) Euclidean distance**【200†source】
#
# 18. **What does the SOM weight update rule depend on?**
#     - A) Random initialization of weights only
#     - B) Learning rate, neighbourhood function, and difference between current and input weights
#     - C) Number of nodes in the input layer
#     - D) Activation function only
#     - **Answer: B) Learning rate, neighbourhood function, and difference between current and input weights**【200†source】
#
# 19. **Which unsupervised learning technique is often used for data visualization and organization?**
#     - A) Convolutional Neural Networks (CNN)
#     - B) Recurrent Neural Networks (RNN)
#     - C) Self-Organizing Maps (SOM)
#     - D) Support Vector Machines (SVM)
#     - **Answer: C) Self-Organizing Maps (SOM)**【200†source】
#
# 20. **What is a common disadvantage of SOMs?**
#     - A) They always require supervised labels
#     - B) Large quantities of high-quality representative data are required
#     - C) They cannot visualize clusters
#     - D) They are incapable of unsupervised learning
#     - **Answer: B) Large quantities of high-quality representative data are required**【200†source**

# %% [markdown]
# 1. **How is the 'degree of neighbourhood' in SOM calculated?**
#    - A) All neighbours are treated equivalently
#    - B) Degree diminishes with distance from the winning neuron
#    - C) Fixed values throughout training
#    - D) Constant across all nodes
#    - **Answer: B) Degree diminishes with distance from the winning neuron**【205:0†source】
#
# 2. **What type of neighbourhood functions are used in SOM?**
#    - A) Rectangular, Bell curve, Gaussian
#    - B) Gaussian, Constant amplitude, Mexican hat
#    - C) Logarithmic, Exponential, Linear
#    - D) Fully connected, Random, Pruned
#    - **Answer: B) Gaussian, Constant amplitude, Mexican hat**【205:0†source】
#
# 3. **Which metric is typically used to determine the winner in a Self-Organizing Map?**
#    - A) Cosine Similarity
#    - B) Manhattan Distance
#    - C) Euclidean Distance
#    - D) Hamming Distance
#    - **Answer: C) Euclidean Distance**【205:0†source】
#
# 4. **How does the width of the neighbourhood in a SOM change over time?**
#    - A) Increases linearly
#    - B) Remains constant
#    - C) Decreases over time, often in ordering and convergence phases
#    - D) Changes randomly
#    - **Answer: C) Decreases over time, often in ordering and convergence phases**【205:0†source】
#
# 5. **Which shapes are possible for the output space of a SOM?**
#    - A) Circle, Ellipse, Triangle
#    - B) Square, Rectangular, Hexagonal
#    - C) Oval, Diamond, Star
#    - D) Octagon, Pentagon, Sphere
#    - **Answer: B) Square, Rectangular, Hexagonal**【205:0†source】
#
# 6. **How does the 'U-Matrix' help in visualizing SOMs?**
#    - A) It shows how well the network is converging
#    - B) It produces contours between nodes indicating groupings
#    - C) It displays weights randomly
#    - D) It optimizes learning rate
#    - **Answer: B) It produces contours between nodes indicating groupings**【205:0†source】
#
# 7. **What is the effect of a high learning rate in SOM training?**
#    - A) Slows down the adjustment of weights
#    - B) Weights rapidly adjust to resemble the input vector
#    - C) Prevents convergence
#    - D) Does not affect weight adjustment
#    - **Answer: B) Weights rapidly adjust to resemble the input vector**【205:2†source】
#
# 8. **Which neighbourhood function is characterized by inhibitory effects for distant nodes?**
#    - A) Mexican Hat
#    - B) Gaussian
#    - C) Linear
#    - D) Constant Amplitude
#    - **Answer: A) Mexican Hat**【205:0†source】
#
# 9. **Which distance measure is also known as the "hexagonal equivalent" used in SOM?**
#    - A) Manhattan Distance
#    - B) Euclidean Distance
#    - C) Chebyshev Distance
#    - D) Minkowski Distance
#    - **Answer: A) Manhattan Distance**【205:0†source】
#
# 10. **What happens to a body map if a body part receives significant sensory input for an extended period?**
#     - A) It remains fixed
#     - B) Its map territory expands in the brain
#     - C) It leads to full sensory deprivation
#     - D) The map contracts due to overuse
#     - **Answer: B) Its map territory expands in the brain**【205:3†source】
#
# 11. **Which of the following is a visualization method used for SOMs to assess grouping on the map?**
#     - A) Histogram
#     - B) Poverty Map
#     - C) Line Chart
#     - D) Regression Plot
#     - **Answer: B) Poverty Map**【205:5†source】
#
# 12. **What are the two main phases during which learning rate and neighbourhood size decrease in SOMs?**
#     - A) Initialization and Optimization
#     - B) Ordering and Convergence
#     - C) Backpropagation and Propagation
#     - D) Clustering and Labeling
#     - **Answer: B) Ordering and Convergence**【205:0†source】
#
# 13. **What is a common disadvantage of Self-Organizing Maps (SOM)?**
#     - A) Requires supervised labels
#     - B) Needs a large quantity of representative data
#     - C) Limited to linear problems
#     - D) Unable to visualize patterns
#     - **Answer: B) Needs a large quantity of representative data**【205:0†source】
#
# 14. **How are the weights of each node updated in SOMs?**
#     - A) Using gradient descent
#     - B) By adding the product of learning rate, neighbourhood function, and difference between input and current weights
#     - C) By pruning neurons randomly
#     - D) Through reinforcement learning
#     - **Answer: B) By adding the product of learning rate, neighbourhood function, and difference between input and current weights**【205:0†source】
#
# 15. **Which property characterizes 'topographic mapping' in SOM?**
#     - A) Random mapping of neurons
#     - B) Similar input patterns are mapped to neighboring neurons
#     - C) The output neurons are fully connected
#     - D) Only non-neighbouring neurons respond to the input
#     - **Answer: B) Similar input patterns are mapped to neighboring neurons**【205:4†source】
#
# 16. **Which alternative to SOM provides a more 'principled' approach using an objective function?**
#     - A) Generative Topographic Mapping (GTM)
#     - B) Reinforcement Learning
#     - C) Convolutional Neural Networks (CNN)
#     - D) Hopfield Networks
#     - **Answer: A) Generative Topographic Mapping (GTM)**【205:0†source】
#
# 17. **What is 'Growing Neural Gas' (GNG) used for in SOM applications?**
#     - A) To pre-train a convolutional layer
#     - B) To grow and adapt the network as new input arrives
#     - C) To prune neurons from a pre-trained network
#     - D) To generate training data
#     - **Answer: B) To grow and adapt the network as new input arrives**【205:0†source】
#
# 18. **What is the main benefit of assigning labels to individual nodes in an SOM?**
#     - A) It makes the map harder to interpret
#     - B) It confers meaning to the output map and aids in classification
#     - C) It ensures all data is classified
#     - D) It optimizes the learning rate
#     - **Answer: B) It confers meaning to the output map and aids in classification**【205:5†source】
#
# 19. **Which aspect of SOM ensures topological preservation of data?**
#     - A) Constant weight values
#     - B) Neighbourhood functions that adapt over time
#     - C) Fully connected nodes
#     - D) Supervised learning mechanism
#     - **Answer: B) Neighbourhood functions that adapt over time**【205:0†source】
#
# 20. **How is the winning neuron identified in SOM during the training phase?**
#     - A) Based on Manhattan distance
#     - B) By selecting the neuron with the smallest Euclidean distance to the input vector
#     - C) By calculating dot product with the input
#     - D) Through random selection
#     - **Answer: B) By selecting the neuron with the smallest Euclidean distance to the input vector**【205:7†source】

# %% [markdown]
# 1. **What happens to the map area in the brain when a body part receives extensive sensory input for an extended period?**
#    - A) The corresponding map territory shrinks
#    - B) The corresponding map territory expands
#    - C) The map becomes inactive
#    - D) The sensory input switches to another area
#    - **Answer: B) The corresponding map territory expands**【209:4†source】
#
# 2. **Which technique can be used to give meaning to SOM nodes or areas on the map?**
#    - A) Assigning labels to individual nodes or areas
#    - B) Clustering based on a pre-trained model
#    - C) Applying a supervised learning algorithm
#    - D) Random weight assignment
#    - **Answer: A) Assigning labels to individual nodes or areas**【209:6†source】
#
# 3. **What is a common type of visualization used to show groupings between SOM nodes?**
#    - A) Regression plots
#    - B) U-Matrix method
#    - C) Scatter plots
#    - D) Decision trees
#    - **Answer: B) U-Matrix method**【209:6†source】
#
# 4. **How does the 'degree of neighbourhood' change in a Self-Organizing Map?**
#    - A) It stays constant over time
#    - B) It diminishes with increasing distance from the winning neuron
#    - C) It depends on the input vector's value
#    - D) It increases over time
#    - **Answer: B) It diminishes with increasing distance from the winning neuron**【209:1†source】
#
# 5. **What is the purpose of using a Gaussian neighbourhood function in SOM?**
#    - A) To suppress all neighbouring neurons
#    - B) To adjust weights in a bell-shaped fashion around the winning neuron
#    - C) To fully connect all nodes to the input
#    - D) To ensure convergence after each iteration
#    - **Answer: B) To adjust weights in a bell-shaped fashion around the winning neuron**【209:1†source】
#
# 6. **What is one of the disadvantages of SOM visualization?**
#    - A) It always provides inaccurate results
#    - B) Neurons far apart may not necessarily represent very different input patterns
#    - C) The output map is always difficult to interpret
#    - D) SOMs cannot handle high-dimensional data
#    - **Answer: B) Neurons far apart may not necessarily represent very different input patterns**【209:5†source】
#
# 7. **Which distance measure is often used in SOMs for determining the winner neuron?**
#    - A) Euclidean distance
#    - B) Cosine similarity
#    - C) Jaccard index
#    - D) Minkowski distance
#    - **Answer: A) Euclidean distance**【209:7†source】
#
# 8. **What is the role of 'learning rate' in SOM training?**
#    - A) It defines the activation level of each neuron
#    - B) It adjusts how strongly weights change towards the input vector
#    - C) It fixes the neighbourhood size
#    - D) It scales the input vector values
#    - **Answer: B) It adjusts how strongly weights change towards the input vector**【209:5†source】
#
# 9. **What aspect of SOM visualization is addressed by assigning labels to neurons or map areas?**
#    - A) Visualization quality
#    - B) Training accuracy
#    - C) Interpretability of the output map
#    - D) Number of training cycles required
#    - **Answer: C) Interpretability of the output map**【209:6†source】
#
# 10. **Which aspect of SOM convergence involves stopping after the map shows no noticeable changes in weights?**
#     - A) Neighborhood convergence
#     - B) Weight optimization
#     - C) Map stabilization
#     - D) Learning rate scheduling
#     - **Answer: C) Map stabilization**【209:5†source】
#
# 11. **What is the 'Generative Topographic Mapping' (GTM) primarily used for in comparison to SOMs?**
#     - A) To optimize classification accuracy
#     - B) To provide a principled alternative to SOMs using an objective function
#     - C) To generate new features for SOM training
#     - D) To train recurrent neural networks
#     - **Answer: B) To provide a principled alternative to SOMs using an objective function**【209:5†source】
#
# 12. **Which learning strategy allows SOMs to better adapt to incoming data after initial training?**
#     - A) Backpropagation
#     - B) Incremental learning
#     - C) Growing SOMs
#     - D) Reinforcement learning
#     - **Answer: C) Growing SOMs**【209:5†source】
#
# 13. **What type of unsupervised learning technique can be used to add, grow, and adapt neurons during training?**
#     - A) Hebbian learning
#     - B) Neural Gas (GNG)
#     - C) Genetic algorithm
#     - D) SOM pruning
#     - **Answer: B) Neural Gas (GNG)**【209:5†source】
#
# 14. **Which unsupervised learning method is based on Hebbian principles and learning without distinction between input and output units?**
#     - A) Auto-associative networks
#     - B) Backpropagation networks
#     - C) Feedforward neural networks
#     - D) Generative Adversarial Networks
#     - **Answer: A) Auto-associative networks**【209:5†source】
#
# 15. **Which component of the SOM weight update equation determines the adjustment rate based on the winning neuron’s neighbourhood?**
#     - A) Learning rate (µ)
#     - B) Neighborhood function (λ)
#     - C) Weight decay
#     - D) Recurrent activation
#     - **Answer: B) Neighborhood function (λ)**【209:7†source】
#
# 16. **What function describes the decrease in learning rate during SOM training?**
#     - A) Random decrement
#     - B) Step function
#     - C) Linear or exponential decrease
#     - D) Convergence phase only
#     - **Answer: C) Linear or exponential decrease**【209:5†source】
#
# 17. **How does Growing SOM (GSOM) differ from standard SOM?**
#     - A) GSOM maintains fixed network size
#     - B) GSOM dynamically adds neurons during training
#     - C) GSOM uses supervised labels
#     - D) GSOM avoids competitive learning
#     - **Answer: B) GSOM dynamically adds neurons during training**【209:5†source】
#
# 18. **Which measure helps assess the quality of a SOM output?**
#     - A) Mean squared error
#     - B) Average quantization error
#     - C) Cross-entropy loss
#     - D) Confusion matrix
#     - **Answer: B) Average quantization error**【209:5†source】
#
# 19. **What does 'topological preservation' in SOM output imply?**
#     - A) Nodes with similar input data are placed close to each other
#     - B) Nodes have equal weights across the lattice
#     - C) Output neurons have random activations
#     - D) The training follows a gradient descent algorithm
#     - **Answer: A) Nodes with similar input data are placed close to each other**【209:5†source】
#
# 20. **What is one way in which a trained SOM can be used for new data?**
#     - A) The new data is classified based on weights closest to the input vector
#     - B) Weights are re-initialized for each new input
#     - C) The map is discarded after initial use
#     - D) Only supervised techniques can be used after SOM training
#     - **Answer: A) The new data is classified based on weights closest to the input vector**【209:7†source】

# %% [markdown]
# 1. **What is the purpose of a 'U-Matrix' in Self-Organizing Maps (SOM)?**
#    - A) Determine the learning rate
#    - B) Show contours between nodes to indicate groupings
#    - C) Measure neighborhood distance
#    - D) Minimize weight changes
#    - **Answer: B) Show contours between nodes to indicate groupings**【213:4†source】
#
# 2. **Which learning algorithm involves continuously adding neurons as new data arrives?**
#    - A) Hebbian learning
#    - B) Neural Gas (GNG)
#    - C) Backpropagation
#    - D) Cascade correlation
#    - **Answer: B) Neural Gas (GNG)**【213:0†source】
#
# 3. **Which neighborhood function shape allows inhibitory effects for distant neurons?**
#    - A) Linear decay
#    - B) Mexican hat
#    - C) Gaussian
#    - D) Constant amplitude
#    - **Answer: B) Mexican hat**【213:0†source】
#
# 4. **What is one advantage of Generative Topographic Mapping (GTM) over SOMs?**
#    - A) GTM provides a principled alternative with an objective function
#    - B) GTM requires less data preprocessing
#    - C) GTM is a supervised method
#    - D) GTM avoids visualization altogether
#    - **Answer: A) GTM provides a principled alternative with an objective function**【213:0†source】
#
# 5. **Which alternative unsupervised learning model is based on Hebbian principles?**
#    - A) Adaptive Resonance Theory (ART)
#    - B) Neural Gas (GNG)
#    - C) Auto-associative networks
#    - D) Backpropagation networks
#    - **Answer: C) Auto-associative networks**【213:0†source】
#
# 6. **What effect does a high learning rate have on the adjustment of weights in SOM?**
#    - A) No change in weights
#    - B) Rapid adjustment of weights to resemble input vectors
#    - C) Slower convergence
#    - D) Random neuron activation
#    - **Answer: B) Rapid adjustment of weights to resemble input vectors**【213:6†source】
#
# 7. **What is the outcome of using a neighborhood function value close to 1 in SOM training?**
#    - A) Minimal change in weights
#    - B) Weight values adjust significantly towards the input vector
#    - C) Increased convergence time
#    - D) The SOM becomes unstable
#    - **Answer: B) Weight values adjust significantly towards the input vector**【213:6†source】
#
# 8. **Which measure can be used to assess how well a SOM represents the data?**
#    - A) Mean Squared Error (MSE)
#    - B) Average Quantization Error
#    - C) Recall Score
#    - D) Gradient Descent Loss
#    - **Answer: B) Average Quantization Error**【213:0†source】
#
# 9. **What is the primary visualization feature of SOM used to identify cluster boundaries?**
#    - A) Histogram
#    - B) U-Matrix
#    - C) Box Plot
#    - D) Heat Map
#    - **Answer: B) U-Matrix**【213:4†source】
#
# 10. **Which algorithm is used for growing a Self-Organizing Map to adapt to input dynamically?**
#     - A) Generative Adversarial Networks (GAN)
#     - B) Growing Neural Gas (GNG)
#     - C) Recurrent Neural Network (RNN)
#     - D) Deep Belief Network (DBN)
#     - **Answer: B) Growing Neural Gas (GNG)**【213:0†source**
#
# 11. **How is the neighborhood function value affected during the training process of SOMs?**
#     - A) Increases linearly
#     - B) Decreases over time during ordering and convergence phases
#     - C) Remains constant
#     - D) Depends on random weights
#     - **Answer: B) Decreases over time during ordering and convergence phases**【213:0†source】
#
# 12. **Which aspect of Self-Organizing Maps ensures similar inputs are represented close to each other?**
#     - A) Fully connected neurons
#     - B) Topological preservation
#     - C) Gradient descent optimization
#     - D) Reinforcement learning
#     - **Answer: B) Topological preservation**【213:4†source】
#
# 13. **What is the main reason for random initialization of weights in SOMs?**
#     - A) To reduce computational complexity
#     - B) To prevent bias in learning and ensure diverse initial conditions
#     - C) To maintain fixed neuron values
#     - D) To immediately achieve convergence
#     - **Answer: B) To prevent bias in learning and ensure diverse initial conditions**【213:7†source】
#
# 14. **Which type of map in the brain is similar to the behavior of a SOM?**
#     - A) Fully connected map
#     - B) Sensory homunculus
#     - C) Direct feedback map
#     - D) Recurrent map
#     - **Answer: B) Sensory homunculus**【213:0†source】
#
# 15. **What does the Mexican hat neighborhood function in SOMs accomplish?**
#     - A) Inhibits learning for neighboring neurons
#     - B) Encourages strong learning for distant neurons
#     - C) Creates a ring of inhibition around the winning neuron
#     - D) Avoids weight updates completely
#     - **Answer: C) Creates a ring of inhibition around the winning neuron**【213:0†source】
#
# 16. **What happens to cortical maps in the brain when a body part receives more sensory input?**
#     - A) The corresponding map territory expands
#     - B) The map territory shrinks
#     - C) No changes occur
#     - D) The territory switches with another body part
#     - **Answer: A) The corresponding map territory expands**【213:2†source】
#
# 17. **Which SOM visualization method uses color coding for interpretation?**
#     - A) Poverty Map
#     - B) Histogram
#     - C) Regression Plot
#     - D) Scatter Plot
#     - **Answer: A) Poverty Map**【213:4†source】
#
# 18. **What is the function of weight updates in a Self-Organizing Map?**
#     - A) Randomly change neuron values
#     - B) Adjust weights to resemble input vectors
#     - C) Remove neurons from the map
#     - D) Only modify neurons outside the neighborhood
#     - **Answer: B) Adjust weights to resemble input vectors**【213:8†source】
#
# 19. **Which approach helps to assign meaning to nodes in a SOM output?**
#     - A) Increasing the number of neurons
#     - B) Assigning labels to individual nodes or areas
#     - C) Pruning all non-used neurons
#     - D) Applying supervised learning afterward
#     - **Answer: B) Assigning labels to individual nodes or areas**【213:4†source】
#
# 20. **What property of SOM makes it a good tool for data exploration and visualization?**
#     - A) Ability to fully connect all neurons
#     - B) Topographic mapping that preserves similarities in the data
#     - C) Its capacity to directly predict target labels
#     - D) Use of supervised training
#     - **Answer: B) Topographic mapping that preserves similarities in the data**【213:4†source】
