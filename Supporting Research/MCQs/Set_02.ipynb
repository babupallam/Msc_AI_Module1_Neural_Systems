# %% [markdown]
# <a href="https://colab.research.google.com/github/babupallam/Msc_AI_Module1_Neural_Systems/blob/main/Supporting%20Research/MCQs/Set_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **MCQ Questions and Answers: Recursive Deterministic Perceptron (RDP) Neural Networks**
#
# 1. **What is the Recursive Deterministic Perceptron (RDP)?**
#    - A) A feedforward multilayer neural network
#    - B) A type of recurrent neural network
#    - C) A convolutional neural network
#    - D) A radial basis function network
#    - **Answer: A) A feedforward multilayer neural network**【118†source】
#
# 2. **What is one of the biggest limitations of the Single Layer Perceptron (SLPT)?**
#    - A) Cannot solve XOR problems
#    - B) Can only solve linearly separable problems
#    - C) Requires a lot of computational power
#    - D) Is not suitable for regression tasks
#    - **Answer: B) Can only solve linearly separable problems**【119†source】
#
# 3. **What approach does the RDP use to solve non-linearly separable problems?**
#    - A) Batch normalization
#    - B) Increment the affine dimension of the input vector
#    - C) Use of advanced optimization algorithms
#    - D) Use of an ensemble of networks
#    - **Answer: B) Increment the affine dimension of the input vector**【120†source】
#
# 4. **How does RDP differ from SLPT?**
#    - A) RDP is a deep recurrent neural network
#    - B) RDP uses multiple intermediate neurons for non-linear problems
#    - C) SLPT uses modular learning whereas RDP does not
#    - D) SLPT is trained using backpropagation only
#    - **Answer: B) RDP uses multiple intermediate neurons for non-linear problems**【119†source】
#
# 5. **Which method of RDP construction can be proven to be NP-complete?**
#    - A) Batch Method
#    - B) Incremental Method
#    - C) Modular Method
#    - D) Cascade Correlation Method
#    - **Answer: A) Batch Method**【120†source】
#
# 6. **Which datasets were used to test RDP’s performance in comparison to other methods?**
#    - A) MNIST, CIFAR-10
#    - B) IRIS, Soybean, Wisconsin Breast Cancer
#    - C) ImageNet, COCO
#    - D) VOC, ADE20K
#    - **Answer: B) IRIS, Soybean, Wisconsin Breast Cancer**【120†source】
#
# 7. **What type of problems does RDP guarantee a solution for?**
#    - A) Only classification problems
#    - B) Any two-class classification problem, even if non-linearly separable
#    - C) Only problems with a specific distribution
#    - D) Only problems with Euclidean data
#    - **Answer: B) Any two-class classification problem, even if non-linearly separable**【120†source】
#
# 8. **Which hyperplane-related operation is essential for solving XOR problems using RDP?**
#    - A) Gradient calculation
#    - B) Constructing an affine dimension
#    - C) Linear separation using intermediate neurons
#    - D) Backpropagation through hyperplanes
#    - **Answer: C) Linear separation using intermediate neurons**【120†source】
#
# 9. **How does the RDP approach differ from Support Vector Machines (SVM)?**
#    - A) RDP uses user-defined parameters
#    - B) RDP does not require kernel functions
#    - C) SVM provides probabilistic outputs
#    - D) RDP always converges slower than SVM
#    - **Answer: B) RDP does not require kernel functions**【120†source】
#
# 10. **How are intermediate neurons (IN) used in RDP?**
#     - A) They help increase the affine dimension of input vectors
#     - B) They are used to reduce model complexity
#     - C) They are only used for training speed-up
#     - D) They have no effect on network performance
#     - **Answer: A) They help increase the affine dimension of input vectors**【120†source】
#
# 11. **Which learning methods are used in RDP to construct the network?**
#     - A) Stochastic Gradient Descent
#     - B) Batch, Incremental, Modular
#     - C) Backpropagation and Adam
#     - D) Genetic Algorithms
#     - **Answer: B) Batch, Incremental, Modular**【119†source】
#
# 12. **Which of the following is an advantage of RDP compared to Backpropagation?**
#     - A) RDP requires a learning rate parameter
#     - B) RDP guarantees 100% correct decision boundaries for training datasets
#     - C) Backpropagation is always faster
#     - D) RDP needs more computational power
#     - **Answer: B) RDP guarantees 100% correct decision boundaries for training datasets**【119†source】
#
# 13. **What is the primary characteristic of the Modular learning method in RDP?**
#     - A) It is computationally expensive
#     - B) It combines subsets of classes sequentially
#     - C) It always produces smaller topologies
#     - D) It has polynomial time complexity
#     - **Answer: D) It has polynomial time complexity**【120†source】
#
# 14. **What does the "affine dimension" refer to in RDP construction?**
#     - A) The distance between two points in the dataset
#     - B) The number of dimensions of input vectors
#     - C) An extension of input vectors to aid in separation
#     - D) The learning rate of the network
#     - **Answer: C) An extension of input vectors to aid in separation**【118†source】
#
# 15. **Which RDP construction method is most suited for achieving the smallest topology size?**
#     - A) Incremental
#     - B) Modular
#     - C) Batch
#     - D) Backpropagation
#     - **Answer: C) Batch**【119†source】
#
# 16. **In what situation is the complexity of RDP’s batch method proven to be NP-complete?**
#     - A) When both classes have arbitrary cardinalities
#     - B) When using random weights
#     - C) When training on Euclidean data
#     - D) When convergence is not required
#     - **Answer: A) When both classes have arbitrary cardinalities**【120†source】
#
# 17. **What is a notable benefit of the Incremental and Modular methods over the Batch method?**
#     - A) Faster computation with larger topologies
#     - B) Lower complexity without sacrificing accuracy
#     - C) Ability to deal with regression tasks
#     - D) Guaranteed exact solutions in finite time
#     - **Answer: B) Lower complexity without sacrificing accuracy**【120†source】
#
# 18. **Which neural network topology does RDP generalize?**
#     - A) Recurrent Neural Network
#     - B) Convolutional Neural Network
#     - C) Single Layer Perceptron (SLPT)
#     - D) Hopfield Network
#     - **Answer: C) Single Layer Perceptron (SLPT)**【118†source】
#
# 19. **What is the role of a hyperplane in the context of RDP?**
#     - A) To represent decision boundaries that classify data points
#     - B) To calculate the gradient descent
#     - C) To replace activation functions
#     - D) To normalize input data
#     - **Answer: A) To represent decision boundaries that classify data points**【121†source】
#
# 20. **How is convergence guaranteed in an RDP neural network?**
#     - A) By using stochastic optimization techniques
#     - B) Through recursive addition of intermediate neurons
#     - C) By manual parameter tuning
#     - D) Through use of random initializations
#     - **Answer: B) Through recursive addition of intermediate neurons**【118†source】
#
# ---

# %% [markdown]
# 21. **What property allows the Recursive Deterministic Perceptron (RDP) to guarantee convergence?**
#    - A) Adding multiple layers
#    - B) Incrementing the affine dimension of input vectors
#    - C) Using gradient descent
#    - D) Employing sigmoid activation functions
#    - **Answer: B) Incrementing the affine dimension of input vectors**【126:0†source】
#
# 22. **Which classification problems are RDPs capable of solving?**
#    - A) Only linearly separable problems
#    - B) Non-linearly separable problems and multi-class problems
#    - C) Only binary problems
#    - D) Only Euclidean distance problems
#    - **Answer: B) Non-linearly separable problems and multi-class problems**【126:0†source】
#
# 23. **What is the main disadvantage of using the Batch method in RDP neural networks?**
#    - A) High computational complexity (NP-complete)
#    - B) It cannot guarantee correct decision boundaries
#    - C) Requires user-defined parameters
#    - D) Limited to linearly separable datasets
#    - **Answer: A) High computational complexity (NP-complete)**【126:0†source】
#
# 24. **Which method for constructing RDP networks offers polynomial time complexity?**
#    - A) Batch
#    - B) Incremental
#    - C) Genetic Algorithm
#    - D) Modular
#    - **Answer: B) Incremental**【126:0†source】
#
# 25. **What does the Incremental method in RDP allow in terms of network learning?**
#    - A) Incorporates new neurons without sacrificing previous learning
#    - B) Increases computational complexity
#    - C) Always results in smaller topologies
#    - D) Requires more hidden neurons
#    - **Answer: A) Incorporates new neurons without sacrificing previous learning**【126:0†source】
#
# 26. **What feature of the RDP helps transform a non-linearly separable (NLS) problem into a linearly separable one?**
#    - A) The use of hyperplanes
#    - B) The addition of intermediate neurons (INs)
#    - C) Using backpropagation algorithms
#    - D) Increasing the number of hidden layers
#    - **Answer: B) The addition of intermediate neurons (INs)**【126:0†source】
#
# 27. **Which benchmark datasets are typically used to evaluate RDP neural network performance?**
#    - A) MNIST, CIFAR-10
#    - B) IRIS, Soybean, Wisconsin Breast Cancer
#    - C) COCO, ImageNet
#    - D) ADE20K, VOC
#    - **Answer: B) IRIS, Soybean, Wisconsin Breast Cancer**【126:0†source】
#
# 28. **In which type of dataset does the Incremental method typically have an advantage?**
#    - A) Small datasets only
#    - B) Larger, more difficult datasets
#    - C) Only binary classification datasets
#    - D) Single-output datasets
#    - **Answer: B) Larger, more difficult datasets**【126:0†source】
#
# 29. **Which geometric approach is used to describe the decision regions in RDP models?**
#    - A) Convex Hull
#    - B) Computational Geometry involving open polyhedral sets
#    - C) Hyperplanes using random distributions
#    - D) Quadratic programming
#    - **Answer: B) Computational Geometry involving open polyhedral sets**【126:0†source】
#
# 30. **How does the Modular method in RDP neural networks work?**
#    - A) Breaks problems into smaller sub-networks
#    - B) Uses all neurons at once for high performance
#    - C) Optimizes convergence time by adjusting parameters
#    - D) Focuses on single-layer topologies only
#    - **Answer: A) Breaks problems into smaller sub-networks**【126:0†source】
#
# 31. **Which construction method among Batch, Incremental, and Modular has the highest level of computational complexity?**
#    - A) Incremental
#    - B) Batch
#    - C) Modular
#    - D) Backpropagation
#    - **Answer: B) Batch**【126:0†source】
#
# 32. **Which learning method for RDP networks guarantees 100% correct decision boundaries for training datasets?**
#    - A) Stochastic Gradient Descent
#    - B) Backpropagation
#    - C) Recursive Deterministic Perceptron
#    - D) Genetic Algorithm
#    - **Answer: C) Recursive Deterministic Perceptron**【126:0†source】
#
# 33. **How is the number of intermediate neurons (INs) controlled in an RDP network?**
#    - A) By user-defined parameters
#    - B) Automatically by convergence requirements
#    - C) By random initialization
#    - D) Through manual neuron additions
#    - **Answer: B) Automatically by convergence requirements**【126:0†source】
#
# 34. **What is one of the key advantages of the Modular method over the Batch method in RDP neural networks?**
#    - A) Improved accuracy on training data
#    - B) Lower complexity due to parallel processing capabilities
#    - C) Guaranteed global minimum
#    - D) Faster learning rate
#    - **Answer: B) Lower complexity due to parallel processing capabilities**【126:0†source】
#
# 35. **Which property helps RDP overcome the catastrophic forgetting problem?**
#    - A) Adding more hidden neurons
#    - B) Adding intermediate neurons iteratively
#    - C) Using deep learning techniques
#    - D) Utilizing high learning rates
#    - **Answer: B) Adding intermediate neurons iteratively**【126:0†source】
#
# 36. **Which comparison is generally true between RDP and Support Vector Machines (SVM)?**
#    - A) Both require kernel functions
#    - B) RDP is capable of self-construction while SVM requires kernel selection
#    - C) SVM always outperforms RDP
#    - D) RDP only works for linearly separable data
#    - **Answer: B) RDP is capable of self-construction while SVM requires kernel selection**【126:0†source】
#
# 37. **What type of neural network topology does RDP generalize?**
#    - A) Hopfield Network
#    - B) Single Layer Perceptron (SLPT)
#    - C) Radial Basis Network
#    - D) Convolutional Neural Network
#    - **Answer: B) Single Layer Perceptron (SLPT)**【126:0†source】
#
# 38. **What is the benefit of the Recursive Deterministic Perceptron being able to extract knowledge transparently?**
#    - A) Can be explained using logical rules
#    - B) Is always faster than other models
#    - C) Requires minimal computational resources
#    - D) Produces smaller topologies
#    - **Answer: A) Can be explained using logical rules**【126:0†source】
#
# 39. **What is the definition of “affine dimension” in the context of RDP?**
#    - A) The number of layers in the network
#    - B) An extension of input vectors to separate non-linearly separable classes
#    - C) The threshold used by each neuron
#    - D) The degree of freedom of each neuron
#    - **Answer: B) An extension of input vectors to separate non-linearly separable classes**【126:0†source】
#
# 40. **Which approach is NOT used for constructing RDP networks?**
#    - A) Batch
#    - B) Incremental
#    - C) Modular
#    - D) Gradient Boosting
#    - **Answer: D) Gradient Boosting**【126:0†source】

# %% [markdown]
# 41. **Which method in RDP networks is best suited for problems with dynamic data?**
#    - A) Batch
#    - B) Incremental
#    - C) Modular Batch
#    - D) None of the above
#    - **Answer: B) Incremental**【130:0†source】
#
# 42. **What is a primary disadvantage of the Batch method in RDP network construction?**
#    - A) Limited to binary classification
#    - B) Complexity is NP-complete for general cases
#    - C) Cannot achieve 100% decision boundary accuracy
#    - D) Uses a stochastic approach for neuron addition
#    - **Answer: B) Complexity is NP-complete for general cases**【130:0†source】
#
# 43. **What is a benefit of using the Modular method for RDP neural networks?**
#    - A) Smaller topologies are always produced
#    - B) Requires no additional computational power
#    - C) Allows for easier parallel processing
#    - D) Guarantees better accuracy than Incremental
#    - **Answer: C) Allows for easier parallel processing**【130:0†source】
#
# 44. **Which dataset is often used as a benchmark for evaluating RDP, backpropagation, and Cascade Correlation methods?**
#    - A) MNIST
#    - B) Wisconsin Breast Cancer
#    - C) ImageNet
#    - D) CIFAR-10
#    - **Answer: B) Wisconsin Breast Cancer**【130:14†source】
#
# 45. **Which characteristic makes RDP different from SVM in solving NLS problems?**
#    - A) Requires kernel functions
#    - B) Uses intermediate neurons instead of data mapping
#    - C) Relies on backpropagation
#    - D) Requires hyperplane optimization
#    - **Answer: B) Uses intermediate neurons instead of data mapping**【130:6†source】
#
# 46. **What is the purpose of adding intermediate neurons (INs) in an RDP network?**
#    - A) To replace hidden layers
#    - B) To convert a non-linearly separable dataset to linearly separable
#    - C) To increase the model complexity
#    - D) To optimize the weights of the output layer
#    - **Answer: B) To convert a non-linearly separable dataset to linearly separable**【130:6†source】
#
# 47. **Which method in RDP is the best choice when dealing with small datasets that are computationally feasible?**
#    - A) Modular Incremental
#    - B) Modular Batch
#    - C) Incremental
#    - D) Batch
#    - **Answer: D) Batch**【130:18†source】
#
# 48. **What is a significant advantage of the Incremental learning method compared to the Batch method in RDP?**
#    - A) Requires more computational resources
#    - B) Can add new data without retraining from scratch
#    - C) Always produces smaller topologies
#    - D) No need for intermediate neurons
#    - **Answer: B) Can add new data without retraining from scratch**【130:0†source】
#
# 49. **What is the role of hyperplanes in RDP's approach to solving the XOR classification problem?**
#    - A) They are used to replace neurons
#    - B) They define the boundaries between different classes
#    - C) They increase the learning rate
#    - D) They perform the backpropagation step
#    - **Answer: B) They define the boundaries between different classes**【130:3†source】
#
# 50. **What differentiates the Modular method from the Incremental method in RDP neural networks?**
#    - A) Modular combines multiple RDP models
#    - B) Incremental requires parallel processing
#    - C) Modular works only on linearly separable problems
#    - D) Incremental guarantees smaller topologies
#    - **Answer: A) Modular combines multiple RDP models**【130:13†source】
#
# 51. **Which of the following statements is true about RDP networks compared to Cascade Correlation?**
#    - A) RDP provides slightly worse generalization than Cascade Correlation
#    - B) Cascade Correlation requires kernel functions
#    - C) RDP needs a higher number of parameters
#    - D) Cascade Correlation always uses smaller datasets
#    - **Answer: A) RDP provides slightly worse generalization than Cascade Correlation**【130:16†source】
#
# 52. **Which type of classification problems can RDP solve with guaranteed convergence?**
#    - A) Linearly separable problems only
#    - B) Multi-class classification problems
#    - C) Any two-class classification problem
#    - D) Problems with missing data
#    - **Answer: C) Any two-class classification problem**【130:1†source】
#
# 53. **Which aspect is NOT required from the user when constructing an RDP neural network?**
#    - A) Selection of kernel function
#    - B) Defining a learning rate
#    - C) Adding intermediate neurons
#    - D) Setting batch size
#    - **Answer: A) Selection of kernel function**【130:6†source】
#
# 54. **What is a potential advantage of using the Batch method despite its high complexity?**
#    - A) Produces smaller topologies
#    - B) Requires no computational power
#    - C) Faster than the Incremental method
#    - D) Always ensures parallel processing
#    - **Answer: A) Produces smaller topologies**【130:18†source】
#
# 55. **In RDP, which method combines subsets of classes sequentially to achieve classification?**
#    - A) Batch
#    - B) Incremental
#    - C) Modular
#    - D) Backpropagation
#    - **Answer: C) Modular**【130:0†source】
#
# 56. **What property allows RDP to avoid catastrophic interference during training?**
#    - A) Convolutional layer adjustment
#    - B) Use of affine dimension expansion
#    - C) Weight initialization strategy
#    - D) Incremental neuron addition
#    - **Answer: D) Incremental neuron addition**【130:1†source】
#
# 57. **How is a non-linearly separable (NLS) dataset transformed into a linearly separable one in RDP?**
#    - A) Using a kernel function
#    - B) Increasing the affine dimension with intermediate neurons
#    - C) Applying gradient descent optimization
#    - D) Combining hidden layers
#    - **Answer: B) Increasing the affine dimension with intermediate neurons**【130:5†source】
#
# 58. **What is the primary factor affecting the level of generalization of an RDP network?**
#    - A) Number of intermediate neurons
#    - B) Size of the input layer
#    - C) Learning rate
#    - D) Dataset size
#    - **Answer: A) Number of intermediate neurons**【130:0†source】
#
# 59. **What type of neural network topology does RDP effectively generalize?**
#    - A) Radial Basis Network
#    - B) Single Layer Perceptron
#    - C) Recurrent Neural Network
#    - D) Long Short-Term Memory (LSTM)
#    - **Answer: B) Single Layer Perceptron**【130:0†source】
#
# 60. **Which RDP construction method reduces the complexity to O(n log n) instead of NP-complete?**
#    - A) Batch
#    - B) Incremental
#    - C) Modular
#    - D) Backpropagation
#    - **Answer: B) Incremental**【130:0†source】

# %% [markdown]
# 61. **What is the role of the affine dimension in RDP neural networks?**
#    - A) Increase the depth of the network
#    - B) Allow NLS data to be transformed into LS data
#    - C) Adjust the weights of hidden neurons
#    - D) Optimize learning rate
#    - **Answer: B) Allow NLS data to be transformed into LS data**【134:4†source】
#
# 62. **What is a major limitation of the Batch method in RDP?**
#    - A) High computational complexity (NP-complete)
#    - B) Cannot handle multi-class problems
#    - C) Requires parallel processing to function
#    - D) Does not provide 100% correct decision boundaries
#    - **Answer: A) High computational complexity (NP-complete)**【134:4†source】
#
# 63. **Which RDP construction method is suited for parallel processing?**
#    - A) Incremental
#    - B) Modular
#    - C) Batch
#    - D) Cascade Correlation
#    - **Answer: B) Modular**【134:4†source】
#
# 64. **How does the Modular approach help in building RDP neural networks?**
#    - A) It allows the problem to be split into smaller subproblems
#    - B) It adds neurons without affecting other parts of the network
#    - C) It reduces the need for intermediate neurons
#    - D) It automatically converges without the need for user input
#    - **Answer: A) It allows the problem to be split into smaller subproblems**【134:4†source】
#
# 65. **What are the three methods of constructing an RDP?**
#    - A) Sequential, Random, Modular
#    - B) Batch, Incremental, Modular
#    - C) Hierarchical, Gradient, Polynomial
#    - D) Batch, Recurrent, Modular
#    - **Answer: B) Batch, Incremental, Modular**【134:4†source】
#
# 66. **Which characteristic of the Incremental method helps to avoid catastrophic interference?**
#    - A) Adding intermediate neurons (IN) progressively
#    - B) Using non-linearly separable subsets
#    - C) Regular updating of the learning rate
#    - D) Parallel weight optimization
#    - **Answer: A) Adding intermediate neurons (IN) progressively**【134:4†source】
#
# 67. **What makes RDP different from SVM for classification problems?**
#    - A) RDP requires a kernel function
#    - B) SVM cannot handle linearly separable problems
#    - C) RDP adds intermediate neurons instead of mapping data
#    - D) RDP uses gradient descent
#    - **Answer: C) RDP adds intermediate neurons instead of mapping data**【134:4†source】
#
# 68. **Which method is best for dynamically updating an RDP neural network?**
#    - A) Batch
#    - B) Incremental
#    - C) Modular Batch
#    - D) Recurrent Training
#    - **Answer: B) Incremental**【134:14†source】
#
# 69. **What is the goal of using intermediate neurons in RDP neural networks?**
#    - A) Reduce overfitting
#    - B) Increase affine dimensions to make data linearly separable
#    - C) Improve backpropagation
#    - D) Eliminate redundant data
#    - **Answer: B) Increase affine dimensions to make data linearly separable**【134:17†source】
#
# 70. **Which performance metric often differentiates RDP from backpropagation?**
#    - A) Convergence time
#    - B) Dataset cardinality
#    - C) Number of classes
#    - D) Learning rate schedule
#    - **Answer: A) Convergence time**【134:6†source】
#
# 71. **How is the Batch method implemented in RDP neural networks?**
#    - A) It adds neurons until no error exists
#    - B) It selects a maximal linearly separable subset
#    - C) It adjusts the learning rate automatically
#    - D) It backpropagates error through multiple layers
#    - **Answer: B) It selects a maximal linearly separable subset**【134:1†source】
#
# 72. **Why does the Incremental method reduce computational complexity compared to the Batch method?**
#    - A) It adds only a subset of intermediate neurons
#    - B) It processes data one point at a time
#    - C) It removes redundant input points
#    - D) It uses stochastic optimization techniques
#    - **Answer: B) It processes data one point at a time**【134:1†source】
#
# 73. **How does the Modular method affect the level of generalisation of an RDP network?**
#    - A) It tends to produce overfitting
#    - B) It allows greater flexibility by dividing into subproblems
#    - C) It restricts the RDP to only linear problems
#    - D) It has no effect on generalisation
#    - **Answer: B) It allows greater flexibility by dividing into subproblems**【134:10†source】
#
# 74. **Which dataset is commonly used to compare RDP with other neural network models?**
#    - A) CIFAR-10
#    - B) Wisconsin Breast Cancer
#    - C) MNIST
#    - D) COCO
#    - **Answer: B) Wisconsin Breast Cancer**【134:10†source】
#
# 75. **Which approach is used to augment the affine dimension in RDP networks?**
#    - A) Adding random noise to input data
#    - B) Using additional intermediate neurons
#    - C) Introducing hidden layers
#    - D) Clustering input data
#    - **Answer: B) Using additional intermediate neurons**【134:17†source】
#
# 76. **What is the primary advantage of the Incremental method in terms of model size?**
#    - A) It uses fewer neurons overall
#    - B) It guarantees a minimal topology
#    - C) It converges faster than other methods
#    - D) It offers polynomial time complexity
#    - **Answer: D) It offers polynomial time complexity**【134:6†source】
#
# 77. **Which neural network learning method often provides better generalization than RDP?**
#    - A) Stochastic Gradient Descent
#    - B) Backpropagation
#    - C) Modular Incremental
#    - D) Adaboost
#    - **Answer: B) Backpropagation**【134:6†source】
#
# 78. **Which characteristic of the Modular approach in RDP allows for improved performance on large datasets?**
#    - A) It increases neuron count proportionally
#    - B) It divides the dataset into smaller parts for independent processing
#    - C) It iteratively optimizes learning rate
#    - D) It uses a support vector machine at each module
#    - **Answer: B) It divides the dataset into smaller parts for independent processing**【134:16†source】
#
# 79. **Which property does an RDP network always guarantee after learning?**
#    - A) Maximum generalization
#    - B) 100% correct decision boundaries on training data
#    - C) Minimum number of neurons
#    - D) Constant convergence time
#    - **Answer: B) 100% correct decision boundaries on training data**【134:7†source】
#
# 80. **How does the Modular method provide flexibility in constructing RDP networks?**
#    - A) It requires fewer neurons to train
#    - B) It allows integration of Batch and Incremental learning for sub-networks
#    - C) It reduces the number of training cycles required
#    - D) It eliminates the need for affine transformation
#    - **Answer: B) It allows integration of Batch and Incremental learning for sub-networks**【134:19†source】

# %% [markdown]
# 81. **How does the Batch method of RDP construct an RDP neural network?**
#    - A) Adds new neurons incrementally
#    - B) Selects linearly separable subsets of maximum cardinality
#    - C) Combines subnetworks in a hierarchical manner
#    - D) Uses random weights for hidden layers
#    - **Answer: B) Selects linearly separable subsets of maximum cardinality**【138:0†source】
#
# 82. **What is the key characteristic of an RDP network regarding convergence?**
#    - A) It requires stochastic gradient descent
#    - B) It always guarantees convergence for all training datasets
#    - C) It depends on the kernel function for convergence
#    - D) It requires user-defined learning rates
#    - **Answer: B) It always guarantees convergence for all training datasets**【138:11†source】
#
# 83. **Which problem does the Incremental method of RDP solve effectively?**
#    - A) Static classification problems
#    - B) Dynamic classification problems that require frequent retraining
#    - C) Non-Euclidean clustering
#    - D) Neural network compression
#    - **Answer: B) Dynamic classification problems that require frequent retraining**【138:2†source】
#
# 84. **What is the function of intermediate neurons (INs) in RDP neural networks?**
#    - A) Reduce model complexity
#    - B) Transform a non-linearly separable problem into a linearly separable one
#    - C) Perform backpropagation
#    - D) Provide parallel computations
#    - **Answer: B) Transform a non-linearly separable problem into a linearly separable one**【138:0†source】
#
# 85. **What is a key disadvantage of the Batch method compared to other methods of constructing RDP?**
#    - A) It cannot solve non-linear problems
#    - B) High computational complexity, proven to be NP-complete
#    - C) It is less flexible in terms of topology
#    - D) It always produces larger topologies
#    - **Answer: B) High computational complexity, proven to be NP-complete**【138:0†source】
#
# 86. **What differentiates RDP from backpropagation in terms of learning characteristics?**
#    - A) Backpropagation always requires user-defined parameters, whereas RDP does not
#    - B) RDP requires kernel functions, unlike backpropagation
#    - C) Backpropagation has a guaranteed convergence
#    - D) RDP is only applicable to linearly separable datasets
#    - **Answer: A) Backpropagation always requires user-defined parameters, whereas RDP does not**【138:11†source】
#
# 87. **Which approach is commonly used by the Modular method in RDP neural networks?**
#    - A) Divides the problem into smaller subproblems that can be solved independently
#    - B) Requires a kernel function for each subproblem
#    - C) Adds new neurons until convergence is achieved
#    - D) Adjusts weights through stochastic gradient descent
#    - **Answer: A) Divides the problem into smaller subproblems that can be solved independently**【138:2†source】
#
# 88. **What is an advantage of the Incremental method compared to Batch in RDP?**
#    - A) Produces smaller topologies consistently
#    - B) Faster convergence for large and dynamic datasets
#    - C) Guarantees a global optimal solution
#    - D) Uses fewer intermediate neurons
#    - **Answer: B) Faster convergence for large and dynamic datasets**【138:18†source】
#
# 89. **How is the performance of the RDP evaluated in comparison to Cascade Correlation?**
#    - A) RDP outperforms Cascade Correlation in all cases
#    - B) Cascade Correlation has slightly better generalisation than RDP
#    - C) Both methods achieve identical performance
#    - D) RDP is superior in terms of convergence speed only
#    - **Answer: B) Cascade Correlation has slightly better generalisation than RDP**【138:9†source】
#
# 90. **Which datasets are used to compare RDP with other neural network algorithms?**
#    - A) CIFAR-10, ImageNet
#    - B) Iris, Soybean, Wisconsin Breast Cancer
#    - C) MNIST, COCO
#    - D) ADE20K, VOC
#    - **Answer: B) Iris, Soybean, Wisconsin Breast Cancer**【138:15†source】
#
# 91. **What is the complexity of the Incremental method of RDP in terms of its computational requirements?**
#    - A) O(n^2)
#    - B) O(n log n)
#    - C) NP-complete
#    - D) O(1)
#    - **Answer: B) O(n log n)**【138:14†source】
#
# 92. **How does the Modular method ensure that previously learned information is retained?**
#    - A) Uses batch training after every iteration
#    - B) Combines sub-networks without requiring retraining
#    - C) Adjusts weights through recurrent learning
#    - D) Stores intermediate neuron states
#    - **Answer: B) Combines sub-networks without requiring retraining**【138:7†source】
#
# 93. **What is the role of affine transformation in RDP networks?**
#    - A) To adjust the learning rate of the model
#    - B) To provide a new representation that makes data linearly separable
#    - C) To optimize the output layer
#    - D) To calculate error gradients
#    - **Answer: B) To provide a new representation that makes data linearly separable**【138:0†source】
#
# 94. **Which RDP construction method is likely to result in the smallest topology size?**
#    - A) Incremental
#    - B) Modular
#    - C) Batch
#    - D) Hybrid Incremental-Batch
#    - **Answer: C) Batch**【138:0†source】
#
# 95. **How is the computational cost of building an RDP with the Batch method described?**
#    - A) Linear in complexity
#    - B) NP-complete when dealing with arbitrary cardinalities
#    - C) Polynomial and logarithmic
#    - D) Constant and independent of data size
#    - **Answer: B) NP-complete when dealing with arbitrary cardinalities**【138:0†source】
#
# 96. **What differentiates the Incremental approach from the Batch approach in terms of adding new information?**
#    - A) Batch requires manual weight updates
#    - B) Incremental adds neurons progressively without re-learning all previous data
#    - C) Batch uses random initialization
#    - D) Incremental is restricted to only small datasets
#    - **Answer: B) Incremental adds neurons progressively without re-learning all previous data**【138:0†source】
#
# 97. **Which of the following is true about the level of generalisation of the Batch vs. Modular method in RDP?**
#    - A) Modular provides a significantly lower level of generalisation
#    - B) Both provide identical levels of generalisation
#    - C) Modular offers slightly better generalisation than Batch due to additional degrees of freedom
#    - D) Batch is always better than Modular in all cases
#    - **Answer: C) Modular offers slightly better generalisation than Batch due to additional degrees of freedom**【138:18†source】
#
# 98. **Why is the Modular method advantageous when parallel processing is available?**
#    - A) It reduces the number of neurons used
#    - B) Subproblems can be solved concurrently, improving efficiency
#    - C) It applies a stochastic gradient for faster convergence
#    - D) Reduces memory requirements
#    - **Answer: B) Subproblems can be solved concurrently, improving efficiency**【138:2†source】
#
# 99. **How does RDP compare to backpropagation in terms of decision boundary properties?**
#    - A) Backpropagation always finds better decision boundaries
#    - B) RDP always guarantees a correct decision boundary
#    - C) Backpropagation is deterministic whereas RDP is probabilistic
#    - D) Both methods are equally reliable in guaranteeing correct boundaries
#    - **Answer: B) RDP always guarantees a correct decision boundary**【138:11†source】
#
# 100. **What advantage does the Incremental RDP method have when data is non-static or frequently changing?**
#    - A) It does not require re-training of the entire network
#    - B) It guarantees the lowest possible complexity
#    - C) It provides a larger model for better generalisation
#    - D) It supports recurrent learning features
#    - **Answer: A) It does not require re-training of the entire network**【138:2†source】

# %% [markdown]
# 101. **What is one of the key disadvantages of RDP neural networks compared to other feedforward multilayer neural networks?**
#    - A) The requirement for user-defined parameters
#    - B) High computational time needed to find linear separable subsets
#    - C) Lack of convergence guarantee
#    - D) The absence of hidden layers
#    - **Answer: B) High computational time needed to find linear separable subsets**【142:0†source】
#
# 102. **What is a primary advantage of the Recursive Deterministic Perceptron (RDP) over backpropagation (BP)?**
#    - A) Requires fewer parameters from the user
#    - B) Uses stochastic optimization methods
#    - C) Requires kernel functions to converge
#    - D) Inability to handle non-linearly separable problems
#    - **Answer: A) Requires fewer parameters from the user**【142:0†source】
#
# 103. **Which RDP construction method was proven to be NP-complete?**
#    - A) Incremental
#    - B) Modular
#    - C) Batch
#    - D) Cascade
#    - **Answer: C) Batch**【142:0†source】
#
# 104. **How can the generalization of an RDP model be improved according to the documents?**
#    - A) By increasing the number of intermediate neurons
#    - B) By using support vector machines
#    - C) By adding new intermediate neurons to interpolate misclassified testing patterns
#    - D) By using fewer hidden layers
#    - **Answer: C) By adding new intermediate neurons to interpolate misclassified testing patterns**【142:0†source】
#
# 105. **What advantage does RDP have regarding convergence compared to backpropagation and Cascade Correlation (CC)?**
#    - A) Backpropagation is guaranteed to converge
#    - B) RDP always guarantees convergence
#    - C) CC converges faster than RDP
#    - D) RDP converges only with user-defined weights
#    - **Answer: B) RDP always guarantees convergence**【142:0†source】
#
# 106. **What is one of the methods used by RDP to solve XOR classification problems?**
#    - A) Adding random neurons
#    - B) Using convolutional filters
#    - C) Adding intermediate neurons to augment the affine dimension
#    - D) Using kernel functions
#    - **Answer: C) Adding intermediate neurons to augment the affine dimension**【142:4†source】
#
# 107. **What is the effect of adding intermediate neurons (IN) to the topology of RDP?**
#    - A) Reduce the depth of the network
#    - B) Provide additional degrees of freedom to transform non-linear problems into linearly separable problems
#    - C) Reduce the model’s accuracy
#    - D) Decrease the convergence time
#    - **Answer: B) Provide additional degrees of freedom to transform non-linear problems into linearly separable problems**【142:4†source】
#
# 108. **How does the Modular method differ from the Batch and Incremental methods?**
#    - A) It splits the dataset into smaller subsets to solve independently
#    - B) It uses only one neuron to classify data
#    - C) It uses convolutional layers
#    - D) It relies on kernel functions to determine separability
#    - **Answer: A) It splits the dataset into smaller subsets to solve independently**【142:1†source】
#
# 109. **Which dataset was commonly used to test the performance of RDP, backpropagation, and Cascade Correlation?**
#    - A) CIFAR-10
#    - B) Iris
#    - C) ImageNet
#    - D) MNIST
#    - **Answer: B) Iris**【142:1†source】
#
# 110. **Which learning method often provides better generalization than the RDP method?**
#    - A) Incremental learning
#    - B) Backpropagation
#    - C) Modular learning
#    - D) Genetic Algorithms
#    - **Answer: B) Backpropagation**【142:1†source】
#
# 111. **How does the addition of intermediate neurons affect RDP networks' decision boundaries?**
#    - A) It adds randomness to the boundaries
#    - B) It forms linear decision boundaries between classes
#    - C) It uses Gaussian kernels to form the boundaries
#    - D) It adds noise to the decision process
#    - **Answer: B) It forms linear decision boundaries between classes**【142:4†source】
#
# 112. **What are the advantages of the Incremental RDP method compared to the Batch method?**
#    - A) Larger topologies with more hidden neurons
#    - B) More flexibility in adding neurons one at a time without retraining from scratch
#    - C) Requires user-defined kernel functions
#    - D) Guaranteed minimal generalization error
#    - **Answer: B) More flexibility in adding neurons one at a time without retraining from scratch**【142:4†source】
#
# 113. **What performance metrics are used to compare RDP construction methods?**
#    - A) Affine dimension, weight values, and threshold values
#    - B) Convergence time, level of generalization, and topology size
#    - C) Kernel function efficiency, computational complexity, and number of epochs
#    - D) Stochastic optimization speed, number of neurons, and bias values
#    - **Answer: B) Convergence time, level of generalization, and topology size**【142:4†source】
#
# 114. **How is the performance of the Modular method affected by the availability of parallel processing?**
#    - A) It reduces computational efficiency
#    - B) It allows for solving subproblems concurrently, improving efficiency
#    - C) It increases computational overhead
#    - D) It prevents the method from converging
#    - **Answer: B) It allows for solving subproblems concurrently, improving efficiency**【142:1†source】
#
# 115. **What type of decision region is defined by an RDP neural network?**
#    - A) Gaussian clusters
#    - B) A finite union of open polytopes
#    - C) Radial Basis Functions
#    - D) Convex hulls only
#    - **Answer: B) A finite union of open polytopes**【142:0†source】
#
# 116. **What optimization approach is suggested to reduce the number of connections in RDP networks?**
#    - A) Use of hyperplanes with the greatest number of zero weight components
#    - B) Application of convolutional filters
#    - C) Use of support vector machines
#    - D) Decreasing learning rate
#    - **Answer: A) Use of hyperplanes with the greatest number of zero weight components**【142:0†source】
#
# 117. **How is catastrophic interference avoided in RDP networks?**
#    - A) By using dropout regularization
#    - B) By freezing the weights of intermediate neurons once added
#    - C) By continuously updating the network topology
#    - D) By adding Gaussian noise to the inputs
#    - **Answer: B) By freezing the weights of intermediate neurons once added**【142:0†source】
#
# 118. **What is the Incremental method's primary feature in training an RDP network?**
#    - A) It retrains the entire network with each new data point
#    - B) It adds neurons progressively for each incorrectly classified point
#    - C) It requires a kernel function for separability
#    - D) It utilizes gradient descent for training
#    - **Answer: B) It adds neurons progressively for each incorrectly classified point**【142:4†source】
